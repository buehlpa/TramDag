# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# HbA1c= SI + LS(sex)+ LS(age)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
n=100_000

np.random.seed(0)

mean, sd = 60, 5
age = []
while len(age) < n:
    sample = np.random.normal(mean, sd, n)
    valid = sample[(sample >= 50) & (sample <= 70)]
    age.extend(valid)
age = np.array(age[:n])

sex = np.random.binomial(1, 0.5, n)

# Base model
hb_raw = 0.02 * age + 4.6 - 5 * sex

df = pd.DataFrame({'age': age, 'sex': sex, 'HbA1c': hb_raw})
df.head()
sns.pairplot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   age     100000 non-null  float64
#  1   sex     100000 non-null  int64
#  2   HbA1c   100000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 2.3 MB

# %%
from sklearn.model_selection import train_test_split
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %%
import os
from utils.configuration import *

# %%
experiment_name = "ukb_prep"      ## <--- set experiment name
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"  ## <--- set log directory
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"configuration.json")

# %%
setup_configuration(experiment_name,EXPERIMENT_DIR)
# Out:
# Configuration already exists/home/bule/TramDag/dev_experiment_logs/ukb_prep/configuration.json

# %%
data_type={'age':'continous','sex':'ordinal_Xc_Yo','HbA1c':'continous'}
data_type
# Out:
# {'age': 'continous', 'sex': 'ordinal_Xc_Yo', 'HbA1c': 'continous'}

# %%
write_data_type_to_configuration(data_type, CONF_DICT_PATH)
# Out:
# ---------------------------------------------------------------------------------------------------------
#                                        |                       MODEL SETTINGS
# Variable             | dtype           | As Predictor                   | As Target
# ---------------------------------------------------------------------------------------------------------
# age                  | continous       | continuous [c]                 | continuous [c]
# sex                  | ordinal_Xc_Yo   | continuous [c]                 | ordinal    [0,…,K]
# HbA1c                | continous       | continuous [c]                 | continuous [c]
# ---------------------------------------------------------------------------------------------------------
# Configuration updated successfully.

# %%
interactive_adj_matrix(CONF_DICT_PATH,seed=19)
# Out:
# /home/bule/TramDag/utils/configuration.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
interactive_nn_names_matrix(CONF_DICT_PATH, seed=5)

# %% [markdown]
# # API usage

# %%
# load configuration
from utils.tramdag import TramDagConfig , TramDagModel

cfg = TramDagConfig.load("/home/bule/TramDag/dev_experiment_logs/ukb_prep/configuration.json")
cfg.compute_levels(train_df)
device='cpu'

# %%
# initalize model
td_model = TramDagModel.from_config(cfg, set_initial_weights=True,verbose=True,debug=True,device=device,initial_data = train_df)
# Out:
# [DEBUG] TramDagModel using device: cpu
#
# [INFO] Building model for node 'age' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              age  sex     HbA1c
# 75220  65.437379    0  5.908748
# 48955  53.764302    0  5.675286
# 44966  60.308627    1  0.806173
# 13568  67.304162    0  5.946083
# 92727  69.484093    0  5.989682
# ...          ...  ...       ...
# 6265   66.221686    1  0.924434
# 54886  55.693262    0  5.713865
# 76820  57.918085    0  5.758362
# 860    61.837724    1  0.836754
# 15795  62.915791    1  0.858316
#
# [80000 rows x 3 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1760536318.csv
# [DEBUG] R script written to: /tmp/tmphk8jkufh.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1760536318.csv")
# model <- Colr(`age` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.138706
# -1.746753
# -1.746753
# -1.715804
# -0.8361357
# -0.8361357
# -0.8361357
# -0.8361356
# -0.005819186
# -0.005819171
# -0.005819156
# -0.005819141
# 0.8370085
# 0.8370085
# 0.8370086
# 0.8370086
# 1.679304
# 1.74409
# 1.74409
# 2.138861
#
# [DEBUG] R-estimated thetas for node 'age': [-2.138706   -1.746753   -1.746753   -1.715804   -0.8361357  -0.8361357
#  -0.8361357  -0.8361356  -0.00581919 -0.00581917 -0.00581916 -0.00581914
#   0.8370085   0.8370085   0.8370086   0.8370086   1.679304    1.74409
#   1.74409     2.138861  ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed theta_tilde: [  4.7927656   -0.7342439  -27.631021    -3.4599004    0.3436607
#  -27.631021   -27.631021   -16.635532     0.25777262 -18.021826
#  -17.991055   -18.021826     0.27984598 -27.631021   -15.942385
#  -27.631021     0.2789113   -2.7040985  -27.631021    -0.7255789 ]
# [DEBUG] Transformed theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1760536318.csv
#
# [INFO] Building model for node 'sex' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              age  sex     HbA1c
# 75220  65.437379    0  5.908748
# 48955  53.764302    0  5.675286
# 44966  60.308627    1  0.806173
# 13568  67.304162    0  5.946083
# 92727  69.484093    0  5.989682
# ...          ...  ...       ...
# 6265   66.221686    1  0.924434
# 54886  55.693262    0  5.713865
# 76820  57.918085    0  5.758362
# 860    61.837724    1  0.836754
# 15795  62.915791    1  0.858316
#
# [80000 rows x 3 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1760536334.csv
# [DEBUG] R script written to: /tmp/tmpmxugryvk.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
# data <- read_csv("temp/initial_data_1760536334.csv")
# data$sex <- as.numeric(as.factor(data$sex)) - 1
# model <- glm(`sex` ~ 1, data=data, family=binomial(link="logit"))
# cat(coef(model), sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -0.009950082
#
# [DEBUG] R-estimated thetas for node 'sex': [-0.00995008]
# [DEBUG] Expected number of thetas: 1
# [DEBUG] Last linear layer shape: torch.Size([1, 1])
# [DEBUG] Inverse transforming thetas for ordinal outcome...
# [DEBUG] Transformed theta_tilde: [[-0.00995008]]
# [DEBUG] Transformed theta_tilde shape: torch.Size([1, 1])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=1, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1760536334.csv
#
# [INFO] Building model for node 'HbA1c' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              age  sex     HbA1c
# 75220  65.437379    0  5.908748
# 48955  53.764302    0  5.675286
# 44966  60.308627    1  0.806173
# 13568  67.304162    0  5.946083
# 92727  69.484093    0  5.989682
# ...          ...  ...       ...
# 6265   66.221686    1  0.924434
# 54886  55.693262    0  5.713865
# 76820  57.918085    0  5.758362
# 860    61.837724    1  0.836754
# 15795  62.915791    1  0.858316
#
# [80000 rows x 3 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1760536336.csv
# [DEBUG] R script written to: /tmp/tmp3ixzkjkl.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1760536336.csv")
# model <- Colr(`HbA1c` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -1.992626
# -0.02169694
# -0.02169692
# -0.02169691
# -0.02169689
# -0.02169688
# -0.02169686
# -0.02169685
# -0.02169683
# -0.02169682
# -0.0216968
# -0.02169679
# -0.02169677
# -0.02169676
# -0.02169674
# -0.02169673
# -0.02169671
# -0.0216967
# -0.02169668
# 1.992497
#
# [DEBUG] R-estimated thetas for node 'HbA1c': [-1.992626   -0.02169694 -0.02169692 -0.02169691 -0.02169689 -0.02169688
#  -0.02169686 -0.02169685 -0.02169683 -0.02169682 -0.0216968  -0.02169679
#  -0.02169677 -0.02169676 -0.02169674 -0.02169673 -0.02169671 -0.0216967
#  -0.02169668  1.992497  ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed theta_tilde: [  4.9388456   1.8208879 -17.703373  -18.49183   -17.703373  -18.49183
#  -17.703373  -18.49183   -17.703373  -18.49183   -17.703373  -18.30951
#  -17.798683  -18.30951   -17.798683  -18.30951   -17.703373  -18.49183
#  -17.703373    1.8709836]
# [DEBUG] Transformed theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1760536336.csv

# %%
td_model.fit(train_df, val_df,
            #  train_list=['target'],
             learning_rate=1e-3,
             epochs=550,batch_size=1000,
             save_linear_shifts=True,
             verbose=True,debug=False,
             device=device,
             num_workers = 8,
             persistent_workers = True,
             prefetch_factor = 8,
             train_mode = "sequential")#,
# Out:
# [INFO] Computing new minmax dict from training data...
# [INFO] Saved new minmax dict to /home/bule/TramDag/dev_experiment_logs/ukb_prep/min_max_scaling.json
# [INFO] Training 3 nodes (sequential) on cpu
#
# [INFO] Training node 'age' for 550 epochs on cpu (pid=505227)
# [INFO] Existing model found. Loading weights and history...
#
# ===== Epoch 501/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 501: Train NLL=2.8603 | Val NLL=2.8531 | Time=1.18s
#
# ===== Epoch 502/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 502: Train NLL=2.8601 | Val NLL=2.8529 | Time=0.79s
#
# ===== Epoch 503/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 503: Train NLL=2.8599 | Val NLL=2.8526 | Time=0.91s
#
# ===== Epoch 504/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 504: Train NLL=2.8596 | Val NLL=2.8524 | Time=0.75s
#
# ===== Epoch 505/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 505: Train NLL=2.8594 | Val NLL=2.8522 | Time=0.76s
#
# ===== Epoch 506/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 506: Train NLL=2.8591 | Val NLL=2.8520 | Time=0.81s
#
# ===== Epoch 507/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 507: Train NLL=2.8589 | Val NLL=2.8517 | Time=0.76s
#
# ===== Epoch 508/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 508: Train NLL=2.8587 | Val NLL=2.8515 | Time=0.73s
#
# ===== Epoch 509/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 509: Train NLL=2.8585 | Val NLL=2.8513 | Time=0.76s
#
# ===== Epoch 510/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 510: Train NLL=2.8582 | Val NLL=2.8511 | Time=0.79s
#
# ===== Epoch 511/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 511: Train NLL=2.8580 | Val NLL=2.8508 | Time=0.95s
#
# ===== Epoch 512/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 512: Train NLL=2.8578 | Val NLL=2.8506 | Time=0.95s
#
# ===== Epoch 513/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 513: Train NLL=2.8576 | Val NLL=2.8504 | Time=0.94s
#
# ===== Epoch 514/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 514: Train NLL=2.8573 | Val NLL=2.8502 | Time=0.78s
#
# ===== Epoch 515/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 515: Train NLL=2.8571 | Val NLL=2.8500 | Time=0.74s
#
# ===== Epoch 516/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 516: Train NLL=2.8569 | Val NLL=2.8498 | Time=0.78s
#
# ===== Epoch 517/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 517: Train NLL=2.8567 | Val NLL=2.8496 | Time=0.91s
#
# ===== Epoch 518/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 518: Train NLL=2.8565 | Val NLL=2.8494 | Time=0.74s
#
# ===== Epoch 519/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 519: Train NLL=2.8563 | Val NLL=2.8492 | Time=0.77s
#
# ===== Epoch 520/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 520: Train NLL=2.8561 | Val NLL=2.8490 | Time=0.82s
#
# ===== Epoch 521/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 521: Train NLL=2.8559 | Val NLL=2.8488 | Time=0.76s
#
# ===== Epoch 522/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 522: Train NLL=2.8557 | Val NLL=2.8486 | Time=0.75s
#
# ===== Epoch 523/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 523: Train NLL=2.8555 | Val NLL=2.8484 | Time=0.99s
#
# ===== Epoch 524/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 524: Train NLL=2.8553 | Val NLL=2.8482 | Time=0.74s
#
# ===== Epoch 525/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 525: Train NLL=2.8551 | Val NLL=2.8480 | Time=0.75s
#
# ===== Epoch 526/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 526: Train NLL=2.8549 | Val NLL=2.8478 | Time=0.77s
#
# ===== Epoch 527/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 527: Train NLL=2.8547 | Val NLL=2.8476 | Time=0.98s
#
# ===== Epoch 528/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 528: Train NLL=2.8545 | Val NLL=2.8474 | Time=0.73s
#
# ===== Epoch 529/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 529: Train NLL=2.8543 | Val NLL=2.8472 | Time=0.77s
#
# ===== Epoch 530/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 530: Train NLL=2.8541 | Val NLL=2.8471 | Time=0.78s
#
# ===== Epoch 531/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 531: Train NLL=2.8539 | Val NLL=2.8469 | Time=0.84s
#
# ===== Epoch 532/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 532: Train NLL=2.8537 | Val NLL=2.8467 | Time=0.80s
#
# ===== Epoch 533/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 533: Train NLL=2.8536 | Val NLL=2.8465 | Time=0.78s
#
# ===== Epoch 534/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 534: Train NLL=2.8534 | Val NLL=2.8463 | Time=0.77s
#
# ===== Epoch 535/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 535: Train NLL=2.8532 | Val NLL=2.8462 | Time=0.78s
#
# ===== Epoch 536/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 536: Train NLL=2.8530 | Val NLL=2.8460 | Time=0.79s
#
# ===== Epoch 537/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 537: Train NLL=2.8528 | Val NLL=2.8458 | Time=0.87s
#
# ===== Epoch 538/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 538: Train NLL=2.8526 | Val NLL=2.8457 | Time=0.74s
#
# ===== Epoch 539/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 539: Train NLL=2.8525 | Val NLL=2.8455 | Time=0.78s
#
# ===== Epoch 540/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 540: Train NLL=2.8523 | Val NLL=2.8453 | Time=0.98s
#
# ===== Epoch 541/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 541: Train NLL=2.8521 | Val NLL=2.8451 | Time=0.74s
#
# ===== Epoch 542/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 542: Train NLL=2.8519 | Val NLL=2.8450 | Time=0.74s
#
# ===== Epoch 543/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 543: Train NLL=2.8518 | Val NLL=2.8448 | Time=0.80s
#
# ===== Epoch 544/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 544: Train NLL=2.8516 | Val NLL=2.8447 | Time=1.02s
#
# ===== Epoch 545/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 545: Train NLL=2.8514 | Val NLL=2.8445 | Time=0.75s
#
# ===== Epoch 546/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 546: Train NLL=2.8513 | Val NLL=2.8443 | Time=0.90s
#
# ===== Epoch 547/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 547: Train NLL=2.8511 | Val NLL=2.8442 | Time=0.94s
#
# ===== Epoch 548/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 548: Train NLL=2.8510 | Val NLL=2.8440 | Time=0.75s
#
# ===== Epoch 549/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 549: Train NLL=2.8508 | Val NLL=2.8439 | Time=0.75s
#
# ===== Epoch 550/550 =====
# [INFO] Saved new best model.
# [INFO] Epoch 550: Train NLL=2.8506 | Val NLL=2.8437 | Time=0.93s
#
# [INFO] Training node 'sex' for 550 epochs on cpu (pid=505227)
# [INFO] Existing model found. Loading weights and history...
#
# ===== Epoch 501/550 =====
# [INFO] Epoch 501: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.68s
#
# ===== Epoch 502/550 =====
# [INFO] Epoch 502: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.33s
#
# ===== Epoch 503/550 =====
# [INFO] Epoch 503: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.52s
#
# ===== Epoch 504/550 =====
# [INFO] Epoch 504: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.34s
#
# ===== Epoch 505/550 =====
# [INFO] Epoch 505: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.27s
#
# ===== Epoch 506/550 =====
# [INFO] Epoch 506: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.47s
#
# ===== Epoch 507/550 =====
# [INFO] Epoch 507: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.34s
#
# ===== Epoch 508/550 =====
# [INFO] Epoch 508: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.32s
#
# ===== Epoch 509/550 =====
# [INFO] Epoch 509: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.48s
#
# ===== Epoch 510/550 =====
# [INFO] Epoch 510: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.34s
#
# ===== Epoch 511/550 =====
# [INFO] Epoch 511: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.34s
#
# ===== Epoch 512/550 =====
# [INFO] Epoch 512: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.67s
#
# ===== Epoch 513/550 =====
# [INFO] Epoch 513: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.35s
#
# ===== Epoch 514/550 =====
# [INFO] Epoch 514: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.28s
#
# ===== Epoch 515/550 =====
# [INFO] Epoch 515: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.35s
#
# ===== Epoch 516/550 =====
# [INFO] Epoch 516: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.49s
#
# ===== Epoch 517/550 =====
# [INFO] Epoch 517: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.28s
#
# ===== Epoch 518/550 =====
# [INFO] Epoch 518: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.29s
#
# ===== Epoch 519/550 =====
# [INFO] Epoch 519: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.47s
#
# ===== Epoch 520/550 =====
# [INFO] Epoch 520: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.32s
#
# ===== Epoch 521/550 =====
# [INFO] Epoch 521: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.34s
#
# ===== Epoch 522/550 =====
# [INFO] Epoch 522: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.46s
#
# ===== Epoch 523/550 =====
# [INFO] Epoch 523: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.48s
#
# ===== Epoch 524/550 =====
# [INFO] Epoch 524: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.51s
#
# ===== Epoch 525/550 =====
# [INFO] Epoch 525: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.48s
#
# ===== Epoch 526/550 =====
# [INFO] Epoch 526: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.53s
#
# ===== Epoch 527/550 =====
# [INFO] Epoch 527: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.33s
#
# ===== Epoch 528/550 =====
# [INFO] Epoch 528: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.44s
#
# ===== Epoch 529/550 =====
# [INFO] Epoch 529: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.65s
#
# ===== Epoch 530/550 =====
# [INFO] Epoch 530: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.33s
#
# ===== Epoch 531/550 =====
# [INFO] Epoch 531: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.34s
#
# ===== Epoch 532/550 =====
# [INFO] Epoch 532: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.47s
#
# ===== Epoch 533/550 =====
# [INFO] Epoch 533: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.43s
#
# ===== Epoch 534/550 =====
# [INFO] Epoch 534: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.31s
#
# ===== Epoch 535/550 =====
# [INFO] Epoch 535: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.50s
#
# ===== Epoch 536/550 =====
# [INFO] Epoch 536: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.32s
#
# ===== Epoch 537/550 =====
# [INFO] Epoch 537: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.50s
#
# ===== Epoch 538/550 =====
# [INFO] Epoch 538: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.44s
#
# ===== Epoch 539/550 =====
# [INFO] Epoch 539: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.44s
#
# ===== Epoch 540/550 =====
# [INFO] Epoch 540: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.46s
#
# ===== Epoch 541/550 =====
# [INFO] Epoch 541: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.44s
#
# ===== Epoch 542/550 =====
# [INFO] Epoch 542: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.48s
#
# ===== Epoch 543/550 =====
# [INFO] Epoch 543: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.46s
#
# ===== Epoch 544/550 =====
# [INFO] Epoch 544: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.45s
#
# ===== Epoch 545/550 =====
# [INFO] Epoch 545: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.45s
#
# ===== Epoch 546/550 =====
# [INFO] Epoch 546: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.47s
#
# ===== Epoch 547/550 =====
# [INFO] Epoch 547: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.47s
#
# ===== Epoch 548/550 =====
# [INFO] Epoch 548: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.49s
#
# ===== Epoch 549/550 =====
# [INFO] Epoch 549: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.41s
#
# ===== Epoch 550/550 =====
# [INFO] Epoch 550: Train NLL=0.6931 | Val NLL=0.6931 | Time=0.48s
#
# [INFO] Training node 'HbA1c' for 550 epochs on cpu (pid=505227)
# [INFO] Existing model found. Loading weights and history...
#
# ===== Epoch 501/550 =====
# [INFO] Saved linear shift weights for epoch 501 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 501: Train NLL=-0.3374 | Val NLL=-0.3396 | Time=1.30s
#
# ===== Epoch 502/550 =====
# [INFO] Saved linear shift weights for epoch 502 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 502: Train NLL=-0.3399 | Val NLL=-0.3420 | Time=1.12s
#
# ===== Epoch 503/550 =====
# [INFO] Saved linear shift weights for epoch 503 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 503: Train NLL=-0.3424 | Val NLL=-0.3445 | Time=0.90s
#
# ===== Epoch 504/550 =====
# [INFO] Saved linear shift weights for epoch 504 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 504: Train NLL=-0.3449 | Val NLL=-0.3470 | Time=0.89s
#
# ===== Epoch 505/550 =====
# [INFO] Saved linear shift weights for epoch 505 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 505: Train NLL=-0.3473 | Val NLL=-0.3495 | Time=1.17s
#
# ===== Epoch 506/550 =====
# [INFO] Saved linear shift weights for epoch 506 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 506: Train NLL=-0.3498 | Val NLL=-0.3519 | Time=0.88s
#
# ===== Epoch 507/550 =====
# [INFO] Saved linear shift weights for epoch 507 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 507: Train NLL=-0.3523 | Val NLL=-0.3544 | Time=0.95s
#
# ===== Epoch 508/550 =====
# [INFO] Saved linear shift weights for epoch 508 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 508: Train NLL=-0.3547 | Val NLL=-0.3568 | Time=0.88s
#
# ===== Epoch 509/550 =====
# [INFO] Saved linear shift weights for epoch 509 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 509: Train NLL=-0.3572 | Val NLL=-0.3593 | Time=1.06s
#
# ===== Epoch 510/550 =====
# [INFO] Saved linear shift weights for epoch 510 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 510: Train NLL=-0.3596 | Val NLL=-0.3617 | Time=1.11s
#
# ===== Epoch 511/550 =====
# [INFO] Saved linear shift weights for epoch 511 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 511: Train NLL=-0.3620 | Val NLL=-0.3641 | Time=1.06s
#
# ===== Epoch 512/550 =====
# [INFO] Saved linear shift weights for epoch 512 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 512: Train NLL=-0.3644 | Val NLL=-0.3665 | Time=0.92s
#
# ===== Epoch 513/550 =====
# [INFO] Saved linear shift weights for epoch 513 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 513: Train NLL=-0.3668 | Val NLL=-0.3689 | Time=0.91s
#
# ===== Epoch 514/550 =====
# [INFO] Saved linear shift weights for epoch 514 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 514: Train NLL=-0.3692 | Val NLL=-0.3713 | Time=1.05s
#
# ===== Epoch 515/550 =====
# [INFO] Saved linear shift weights for epoch 515 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 515: Train NLL=-0.3716 | Val NLL=-0.3737 | Time=0.87s
#
# ===== Epoch 516/550 =====
# [INFO] Saved linear shift weights for epoch 516 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 516: Train NLL=-0.3740 | Val NLL=-0.3761 | Time=0.96s
#
# ===== Epoch 517/550 =====
# [INFO] Saved linear shift weights for epoch 517 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 517: Train NLL=-0.3764 | Val NLL=-0.3785 | Time=0.88s
#
# ===== Epoch 518/550 =====
# [INFO] Saved linear shift weights for epoch 518 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 518: Train NLL=-0.3788 | Val NLL=-0.3808 | Time=1.06s
#
# ===== Epoch 519/550 =====
# [INFO] Saved linear shift weights for epoch 519 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 519: Train NLL=-0.3811 | Val NLL=-0.3832 | Time=0.87s
#
# ===== Epoch 520/550 =====
# [INFO] Saved linear shift weights for epoch 520 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 520: Train NLL=-0.3835 | Val NLL=-0.3856 | Time=1.03s
#
# ===== Epoch 521/550 =====
# [INFO] Saved linear shift weights for epoch 521 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 521: Train NLL=-0.3858 | Val NLL=-0.3879 | Time=0.93s
#
# ===== Epoch 522/550 =====
# [INFO] Saved linear shift weights for epoch 522 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 522: Train NLL=-0.3882 | Val NLL=-0.3902 | Time=0.87s
#
# ===== Epoch 523/550 =====
# [INFO] Saved linear shift weights for epoch 523 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 523: Train NLL=-0.3905 | Val NLL=-0.3926 | Time=1.08s
#
# ===== Epoch 524/550 =====
# [INFO] Saved linear shift weights for epoch 524 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 524: Train NLL=-0.3928 | Val NLL=-0.3949 | Time=0.87s
#
# ===== Epoch 525/550 =====
# [INFO] Saved linear shift weights for epoch 525 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 525: Train NLL=-0.3951 | Val NLL=-0.3972 | Time=0.98s
#
# ===== Epoch 526/550 =====
# [INFO] Saved linear shift weights for epoch 526 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 526: Train NLL=-0.3975 | Val NLL=-0.3995 | Time=0.94s
#
# ===== Epoch 527/550 =====
# [INFO] Saved linear shift weights for epoch 527 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 527: Train NLL=-0.3998 | Val NLL=-0.4018 | Time=1.04s
#
# ===== Epoch 528/550 =====
# [INFO] Saved linear shift weights for epoch 528 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 528: Train NLL=-0.4021 | Val NLL=-0.4041 | Time=1.07s
#
# ===== Epoch 529/550 =====
# [INFO] Saved linear shift weights for epoch 529 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 529: Train NLL=-0.4044 | Val NLL=-0.4064 | Time=1.08s
#
# ===== Epoch 530/550 =====
# [INFO] Saved linear shift weights for epoch 530 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 530: Train NLL=-0.4066 | Val NLL=-0.4087 | Time=0.94s
#
# ===== Epoch 531/550 =====
# [INFO] Saved linear shift weights for epoch 531 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 531: Train NLL=-0.4089 | Val NLL=-0.4110 | Time=1.03s
#
# ===== Epoch 532/550 =====
# [INFO] Saved linear shift weights for epoch 532 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 532: Train NLL=-0.4112 | Val NLL=-0.4132 | Time=0.94s
#
# ===== Epoch 533/550 =====
# [INFO] Saved linear shift weights for epoch 533 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 533: Train NLL=-0.4135 | Val NLL=-0.4155 | Time=0.92s
#
# ===== Epoch 534/550 =====
# [INFO] Saved linear shift weights for epoch 534 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 534: Train NLL=-0.4158 | Val NLL=-0.4178 | Time=0.98s
#
# ===== Epoch 535/550 =====
# [INFO] Saved linear shift weights for epoch 535 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 535: Train NLL=-0.4180 | Val NLL=-0.4200 | Time=0.90s
#
# ===== Epoch 536/550 =====
# [INFO] Saved linear shift weights for epoch 536 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 536: Train NLL=-0.4203 | Val NLL=-0.4223 | Time=1.02s
#
# ===== Epoch 537/550 =====
# [INFO] Saved linear shift weights for epoch 537 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 537: Train NLL=-0.4225 | Val NLL=-0.4245 | Time=0.87s
#
# ===== Epoch 538/550 =====
# [INFO] Saved linear shift weights for epoch 538 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 538: Train NLL=-0.4248 | Val NLL=-0.4268 | Time=1.03s
#
# ===== Epoch 539/550 =====
# [INFO] Saved linear shift weights for epoch 539 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 539: Train NLL=-0.4270 | Val NLL=-0.4290 | Time=1.08s
#
# ===== Epoch 540/550 =====
# [INFO] Saved linear shift weights for epoch 540 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 540: Train NLL=-0.4292 | Val NLL=-0.4312 | Time=0.90s
#
# ===== Epoch 541/550 =====
# [INFO] Saved linear shift weights for epoch 541 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 541: Train NLL=-0.4315 | Val NLL=-0.4334 | Time=0.96s
#
# ===== Epoch 542/550 =====
# [INFO] Saved linear shift weights for epoch 542 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 542: Train NLL=-0.4337 | Val NLL=-0.4357 | Time=0.90s
#
# ===== Epoch 543/550 =====
# [INFO] Saved linear shift weights for epoch 543 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 543: Train NLL=-0.4359 | Val NLL=-0.4378 | Time=1.01s
#
# ===== Epoch 544/550 =====
# [INFO] Saved linear shift weights for epoch 544 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 544: Train NLL=-0.4381 | Val NLL=-0.4401 | Time=0.94s
#
# ===== Epoch 545/550 =====
# [INFO] Saved linear shift weights for epoch 545 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 545: Train NLL=-0.4403 | Val NLL=-0.4423 | Time=1.08s
#
# ===== Epoch 546/550 =====
# [INFO] Saved linear shift weights for epoch 546 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 546: Train NLL=-0.4425 | Val NLL=-0.4445 | Time=1.05s
#
# ===== Epoch 547/550 =====
# [INFO] Saved linear shift weights for epoch 547 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 547: Train NLL=-0.4447 | Val NLL=-0.4467 | Time=1.22s
#
# ===== Epoch 548/550 =====
# [INFO] Saved linear shift weights for epoch 548 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 548: Train NLL=-0.4469 | Val NLL=-0.4489 | Time=0.91s
#
# ===== Epoch 549/550 =====
# [INFO] Saved linear shift weights for epoch 549 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 549: Train NLL=-0.4491 | Val NLL=-0.4510 | Time=0.87s
#
# ===== Epoch 550/550 =====
# [INFO] Saved linear shift weights for epoch 550 -> /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/linear_shifts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 550: Train NLL=-0.4512 | Val NLL=-0.4532 | Time=0.94s

# %%
linear_shift=td_model.linear_shift_history()
linear_shift
import matplotlib.pyplot as plt
import pandas as pd

def plot_shift_histories(data_dict, node='target'):
    """
    Plot the evolution of shift terms across epochs for a given node (e.g., 'target').

    Args:
        data_dict (dict): Dictionary where keys are node names (e.g., 'target')
                          and values are DataFrames with epochs as columns and shifts as rows.
        node (str): Node name to plot (default='target')
    """
    df = data_dict[node].copy()

    # Flatten nested lists in DataFrame cells
    df = df.applymap(lambda x: x[0][0] if isinstance(x, list) and isinstance(x[0], list) else x)

    # Convert column names to integers if possible
    df.columns = [int(c.replace('epoch_', '')) if isinstance(c, str) and c.startswith('epoch_') else c for c in df.columns]

    # Sort by epoch
    df = df.reindex(sorted(df.columns), axis=1)

    # Plot each shift
    plt.figure(figsize=(10, 6))
    for shift in df.index:
        plt.plot(df.columns, df.loc[shift], label=shift)

    plt.xlabel('Epoch')
    plt.ylabel('Shift value')
    plt.title(f'Shift term history for node: {node}')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
    
plot_shift_histories(linear_shift, node='HbA1c')
# Out:
# [WARNING] No linear shift history found for node 'age' at /home/bule/TramDag/dev_experiment_logs/ukb_prep/age/linear_shifts_all_epochs.json
# [WARNING] No linear shift history found for node 'sex' at /home/bule/TramDag/dev_experiment_logs/ukb_prep/sex/linear_shifts_all_epochs.json
# /tmp/ipykernel_505227/4185427859.py:18: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: x[0][0] if isinstance(x, list) and isinstance(x[0], list) else x)

# %%
td_model.plot_history()
# Out:
# [INFO] Loaded training/validation histories for 3 nodes.

# %%
td_model.show_samples_vs_true(train_df)

# %%
rsamples, latents = td_model.sample()
# Out:
# [INFO] Starting full DAG sampling with 10000 samples per node.
# [INFO] Deleting all previously sampled data.
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ukb_prep/age/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ukb_prep/sex/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ukb_prep/HbA1c/sampling
#
# ----*----------*-------------*--------Sample Node: age ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node age from standard logistic distribution
# [WARNING] target_col 'age' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 47.83it/s]
# [INFO] Completed sampling for node 'age'
#
# ----*----------*-------------*--------Sample Node: sex ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node sex from standard logistic distribution
# [WARNING] target_col 'sex' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Completed sampling for node 'sex'
#
# ----*----------*-------------*--------Sample Node: HbA1c ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node HbA1c from standard logistic distribution
# [WARNING] target_col 'HbA1c' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 47.04it/s]
# [INFO] Completed sampling for node 'HbA1c'
# [INFO] DAG sampling completed successfully for all nodes.

# %%
td_model.show_samples_vs_true(train_df)
