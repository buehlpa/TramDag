# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "tramdagpaper_exp6_1_linearDGP_ls_25"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# they made 3 experiments:
# 1. Linear-shift DGP and linear-shift model
# 2. Complex-shift DGP and complex-shift model
# 3. Linear-shift DGP and complex-shift model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return -0.3*x  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        z2 = logit(u2)
        x2 = (z2 - 2 * x1) / 5#5#   0.42  in the trainagle strucutred cont last line is 5 for SI
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 -f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          - f(X2)        | replace h(x2|x1) with z
    # z3          = 0.63*x3 + beta3 * x1          - f(X2)        | reformulate to x2
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z3+0.2 * x1   +f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        z3 = logit(u3)
        x3 = (z3 + 0.2 * x1 + f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])
        
    #df = pd.DataFrame({'x1': x1, 'x2': x2})#, 'x3': x3})
    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df

n_obs=10_000

df = dgp(n_obs=n_obs, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")


if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=n_obs)

    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")


sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Setting Seed: 42
#          x1        x2        x3
# 0  0.790178 -0.257718  0.149574
# 1  0.276383  0.055677 -5.949408
# 2  0.736578  0.053836 -1.297906
# 3  0.808237  0.022891 -4.875233
# 4  0.749825 -0.335202  2.289209

# %% [markdown]
# ## 2.1 train test split

# %%
# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# 2. Compute quantiles from training data
quantiles = train_df.quantile([0.05, 0.95])
min_vals = quantiles.loc[0.05]
max_vals = quantiles.loc[0.95]

# 3. Normalize all sets using training quantiles
def normalize_with_quantiles(df, min_vals, max_vals):
    return (df - min_vals) / (max_vals - min_vals)

# train_df = normalize_with_quantiles(train_df, min_vals, max_vals)
# val_df = normalize_with_quantiles(val_df, min_vals, max_vals)
# test_df = normalize_with_quantiles(test_df, min_vals, max_vals)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 8000, Validation size: 1000, Test size: 1000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous 

adj_matrix = np.array([
    [ "0", "ls", "ls"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "ls"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)

# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
plot_nn_names_matrix(nn_names_matrix,data_type)

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/tramdagpaper_exp6_1_linearDGP_ls_25_conf.json
# /tmp/ipykernel_2075198/1695834966.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
# /tmp/ipykernel_2075198/1695834966.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['max']=max_vals[i].tolist()
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.1205322246468743,
#   'max': 0.794692622870355},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift'},
#   'min': -0.8142888901184293,
#   'max': 0.4238437120810543},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls', 'x2': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift',
#    'x2': 'LinearShift'},
#   'min': -4.421199142423371,
#   'max': 4.916709870336174}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3']#['x2']#'x1','x2']#,'x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 512#4112
epochs = 1000 # <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
use_scheduler =  False

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)
    #tram_model =get_fully_specified_tram_model_hardcoded_init_weights_for_si(node, conf_dict, verbose=True).to(device)


    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################.
    
    ## <---------- TODO use standard SGD and no scheduler
    # optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    # optimizer = torch.optim.AdamW(
    # tram_model.parameters(),
    # lr=1e-3,           # ← two orders of magnitude smaller
    # eps=1e-8,
    # weight_decay=1e-2
    # )   
    optimizer =torch.optim.Adam(tram_model.parameters(), lr=0.01)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1)
        #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer,max_lr=1e-3, total_steps=epochs * len(train_loader),pct_start=0.1, anneal_strategy="cos"       # pick your sweet-spot

    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR,
            save_linear_shifts=True
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 800...
# Epoch 801/1000 | Train Loss: -0.5740 | Val Loss: -0.5583
#   [Train: 0.79s | Val: 0.51s | Save: 0.01s | Total: 1.30s]
# Epoch 802/1000 | Train Loss: -0.5759 | Val Loss: -0.5583
#   [Train: 0.85s | Val: 0.43s | Save: 0.01s | Total: 1.29s]
# Epoch 803/1000 | Train Loss: -0.5727 | Val Loss: -0.5584
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 804/1000 | Train Loss: -0.5758 | Val Loss: -0.5584
#   [Train: 0.88s | Val: 0.48s | Save: 0.01s | Total: 1.37s]
# Epoch 805/1000 | Train Loss: -0.5740 | Val Loss: -0.5583
#   [Train: 0
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Epoch 985/1000 | Train Loss: -0.5740 | Val Loss: -0.5580
#   [Train: 0.91s | Val: 0.48s | Save: 0.01s | Total: 1.40s]
# Epoch 986/1000 | Train Loss: -0.5729 | Val Loss: -0.5581
#   [Train: 0.71s | Val: 0.41s | Save: 0.01s | Total: 1.13s]
# Epoch 987/1000 | Train Loss: -0.5747 | Val Loss: -0.5582
#   [Train: 0.85s | Val: 0.41s | Save: 0.02s | Total: 1.28s]
# Epoch 988/1000 | Train Loss: -0.5759 | Val Loss: -0.5581
#   [Train: 0.92s | Val: 0.48s | Save: 0.01s | Total: 1.41s]
# Epoch 989/1000 | Train Loss: -0.5759 | Val Loss: -0.5582
#   [Train: 0.81s | Val: 0.42s | Save: 0.01s | Total: 1.25s]
# Epoch 990/1000 | Train Loss: -0.5741 | Val Loss: -0.5581
#   [Train: 0.87s | Val: 0.44s | Save: 0.01s | Total: 1.31s]
# Epoch 991/1000 | Train Loss: -0.5750 | Val Loss: -0.5582
#   [Train: 0.68s | Val: 0.42s | Save: 0.01s | Total: 1.11s]
# Epoch 992/1000 | Train Loss: -0.5745 | Val Loss: -0.5581
#   [Train: 0.76s | Val: 0.40s | Save: 0.01s | Total: 1.17s]
# Epoch 993/1000 | Train Loss: -0.5719 | Val Loss: -0.5582
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 994/1000 | Train Loss: -0.5745 | Val Loss: -0.5581
#   [Train: 0.81s | Val: 0.44s | Save: 0.02s | Total: 1.26s]
# Epoch 995/1000 | Train Loss: -0.5733 | Val Loss: -0.5581
#   [Train: 0.89s | Val: 0.51s | Save: 0.01s | Total: 1.41s]
# Epoch 996/1000 | Train Loss: -0.5726 | Val Loss: -0.5582
#   [Train: 0.76s | Val: 0.43s | Save: 0.01s | Total: 1.20s]
# Epoch 997/1000 | Train Loss: -0.5738 | Val Loss: -0.5581
#   [Train: 0.91s | Val: 0.46s | Save: 0.01s | Total: 1.38s]
# Epoch 998/1000 | Train Loss: -0.5739 | Val Loss: -0.5581
#   [Train: 0.81s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 999/1000 | Train Loss: -0.5732 | Val Loss: -0.5582
#   [Train: 0.87s | Val: 0.48s | Save: 0.01s | Total: 1.36s]
# Epoch 1000/1000 | Train Loss: -0.5749 | Val Loss: -0.5582
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# Existing model found. Loading weights and history...
# Continuing training from epoch 800...
# {'shift_0': [[1.9186159372329712]]}
# Appended linear shift weights for epoch 801 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 801/1000 | Train Loss: 0.3596 | Val Loss: 0.3287
#   [Train: 0.96s | Val: 0.53s | Save: 0.01s | Total: 1.52s]
# {'shift_0': [[1.9029361009597778]]}
# Appended linear shift weights for epoch 802 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 802/1000 | Train Loss: 0.3606 | Val Loss: 0.3289
#   [Train: 0.83s | Val: 0.49s | Save: 0.01s | Total: 1.35s]
# {'shift_0': [[1.923563838005066]]}
# Appended linear shift weights for epoch 803 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 803/1000 | Train Loss: 0.3596 | Val Loss: 0.3287
#   [Train: 0.80s | Val: 0.57s | Save: 0.01s | Total: 1.41s]
# {'shift_0': [[1.9220006465911865]]}
# Appended linear shift weights for epoch 804 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 804/1000 | Train Loss: 0.3634 | Val Loss: 0.3286
#   [Train: 0.85s | Val: 0.49s | Save: 0.01s | Total: 1.37s]
# {'shift_0': [[1.9078129529953003]]}
# Appended linear shift weights for epoch 805 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 805/1000 | Train Loss: 0.3607 | Val Loss: 0.3289
#   [Train: 0.90s | Val: 0.43s | Save: 0.01s | Total: 1.36s]
# {'shift_0': [[1.9164437055587769]]}
# Appended linear shift weights for epoch 806 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 806/1000 | Train Loss: 0.3587 | Val Loss: 0.3288
#   [Train: 0.98s | Val: 0.48s | Save: 0.01s | Total: 1.48s]
# {'shift_0': [[1.9093600511550903]]}
# Appended linear shift weights for epoch 807 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 807/1000 | Train Loss: 0.3614 | Val Loss: 0.3289
#   [Train: 0.98s | Val: 0.48s | Save: 0.01s | Total: 1.49s]
# {'shift_0': [[1.9306063652038574]]}
# Appended linear shift weights for epoch 808 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 808/1000 | Train Loss: 0.3609 | Val Loss: 0.3287
#   [Train: 0.88s | Val: 0.51s | Save: 0.01s | Total: 1.41s]
# {'shift_0': [[1.9161118268966675]]}
# Appended linear shift weights for epoch 809 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 809/1000 | Train Loss: 0.3605 | Val Loss: 0.3288
#   [Train: 1.04s | Val: 0.48s | Save: 0.01s | Total: 1.54s]
# {'shift_0': [[1.9385488033294678]]}
# Appended linear shift weights for epoch 810 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 810/1000 | Train Loss: 0.3573 | Val Loss: 0.3287
#   [Train: 0.87s | Val: 0.44s | Save: 0.01s | Total: 1.34s]
# {'shift_0': [[1.930254578590393]]}
# Appended linear shift weights for epoch 811 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 811/1000 | Train Loss: 0.3588 | Val Loss: 0.3288
#   [Train: 0.95s | Val: 0.43s | Save: 0.01s | Total: 1.42s]
# {'shift_0': [[1.9192817211151123]]}
# Appended linear shift weights for epoch 812 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 812/1000 | Train Loss: 0.3590 | Val Loss: 0.3287
#   [Train: 0.92s | Val: 0.44s | Save: 0.01s | Total: 1.39s]
# {'shift_0': [[1.9142361879348755]]}
# Appended linear shift weights for epoch 813 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 813/1000 | Train Loss: 0.3598 | Val Loss: 0.3288
#   [Train: 0.84s | Val: 0.43s | Save: 0.01s | Total: 1.31s]
# {'shift_0': [[1.9273736476898193]]}
# Appended linear shift weights for epoch 814 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 814/1000 | Train Loss: 0.3612 | Val Loss: 0.3286
#   [Train: 0.84s | Val: 0.42s | Save: 0.01s | Total: 1.30s]
# {'shift_0': [[1.9217268228530884]]}
# Appended linear shift weights for epoch 815 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 815/1000 | Train Loss: 0.3604 | Val Loss: 0.3287
#   [Train: 1.03s | Val: 0.51s | Save: 0.01s | Total: 1.57s]
# {'shift_0': [[1.9201512336730957]]}
# Appended linear shift weights for epoch 816 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 816/1000 | Train Loss: 0.3595 | Val Loss: 0.3288
#   [Train: 0.99s | Val: 0.39s | Save: 0.01s | Total: 1.41s]
# {'shift_0': [[1.9255577325820923]]}
# Appended linear shift weights for epoch 817 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 817/1000 | Train Loss: 0.3594 | Val Loss: 0.3287
#   [Train: 1.07s | Val: 0.51s | Save: 0.01s | Total: 1.61s]
# {'shift_0': [[1.9248932600021362]]}
# Appended linear shift weights for epoch 818 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 818/1000 | Train Loss: 0.3597 | Val Loss: 0.3288
#   [Train: 0.92s | Val: 0.46s | Save: 0.01s | Total: 1.41s]
# {'shift_0': [[1.919516682624817]]}
# Appended linear shift weights for epoch 819 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 819/1000 | Train Loss: 0.3597 | Val Loss: 0.3288
#   [Train: 0.92s | Val: 0.39s | Save: 0.01s | Total: 1.34s]
# {'shift_0': [[1.9203861951828003]]}
# Appended linear shift weights for epoch 820 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 820/1000 | Train Loss: 0.3581 | Val Loss: 0.3287
#   [Train: 0.86s | Val: 0.43s | Save: 0.01s | Total: 1.32s]
# {'shift_0': [[1.9176671504974365]]}
# Appended linear shift weights for epoch 821 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 821/1000 | Train Loss: 0.3611 | Val Loss: 0.3287
#   [Train: 0.90s | Val: 0.41s | Save: 0.01s | Total: 1.34s]
# {'shift_0': [[1.9180537462234497]]}
# Appended linear shift weights for epoch 822 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 822/1000 | Train Loss: 0.3607 | Val Loss: 0.3287
#   [Train: 0.95s | Val: 0.47s | Save: 0.01s | Total: 1.45s]
# {'shift_0': [[1.9296611547470093]]}
# Appended linear shift weights for epoch 823 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 823/1000 | Train Loss: 0.3577 | Val Loss: 0.3287
#   [Train: 0.83s | Val: 0.45s | Save: 0.01s | Total: 1.30s]
# {'shift_0': [[1.9279272556304932]]}
# Appended linear shift weights for epoch 824 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 824/1000 | Train Loss: 0.3601 | Val Loss: 0.3287
#   [Train: 1.03s | Val: 0.53s | Save: 0.01s | Total: 1.59s]
# {'shift_0': [[1.9150315523147583]]}
# Appended linear shift weights for epoch 825 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 825/1000 | Train Loss: 0.3590 | Val Loss: 0.3288
#   [Train: 0.90s | Val: 0.54s | Save: 0.01s | Total: 1.48s]
# {'shift_0': [[1.9053332805633545]]}
# Appended linear shift weights for epoch 826 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 826/1000 | Train Loss: 0.3595 | Val Loss: 0.3288
#   [Train: 0.98s | Val: 0.44s | Save: 0.01s | Total: 1.45s]
# {'shift_0': [[1.9325734376907349]]}
# Appended linear shift weights for epoch 827 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Saved new best model.
# Epoch 827/1000 | Train Loss: 0.3575 | Val Loss: 0.3285
#   [Train: 0.97s | Val: 0.55s | Save: 0.01s | Total: 1.55s]
# {'shift_0': [[1.9108796119689941]]}
# Appended linear shift weights for epoch 828 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 828/1000 | Train Loss: 0.3605 | Val Loss: 0.3287
#   [Train: 0.97s | Val: 0.46s | Save: 0.01s | Total: 1.46s]
# {'shift_0': [[1.9220677614212036]]}
# Appended linear shift weights for epoch 829 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 829/1000 | Train Loss: 0.3607 | Val Loss: 0.3287
#   [Train: 0.93s | Val: 0.45s | Save: 0.01s | Total: 1.43s]
# {'shift_0': [[1.9211702346801758]]}
# Appended linear shift weights for epoch 830 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 830/1000 | Train Loss: 0.3589 | Val Loss: 0.3287
#   [Train: 0.89s | Val: 0.43s | Save: 0.01s | Total: 1.35s]
# {'shift_0': [[1.9326177835464478]]}
# Appended linear shift weights for epoch 831 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 831/1000 | Train Loss: 0.3592 | Val Loss: 0.3286
#   [Train: 0.92s | Val: 0.43s | Save: 0.01s | Total: 1.38s]
# {'shift_0': [[1.920479655265808]]}
# Appended linear shift weights for epoch 832 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 832/1000 | Train Loss: 0.3607 | Val Loss: 0.3287
#   [Train: 0.88s | Val: 0.47s | Save: 0.01s | Total: 1.38s]
# {'shift_0': [[1.9337842464447021]]}
# Appended linear shift weights for epoch 833 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 833/1000 | Train Loss: 0.3604 | Val Loss: 0.3287
#   [Train: 0.96s | Val: 0.39s | Save: 0.01s | Total: 1.38s]
# {'shift_0': [[1.9216870069503784]]}
# Appended linear shift weights for epoch 834 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 834/1000 | Train Loss: 0.3610 | Val Loss: 0.3287
#   [Train: 0.97s | Val: 0.47s | Save: 0.01s | Total: 1.47s]
# {'shift_0': [[1.9289863109588623]]}
# Appended linear shift weights for epoch 835 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 835/1000 | Train Loss: 0.3612 | Val Loss: 0.3286
#   [Train: 1.06s | Val: 0.44s | Save: 0.01s | Total: 1.52s]
# {'shift_0': [[1.9228662252426147]]}
# Appended linear shift weights for epoch 836 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 836/1000 | Train Loss: 0.3577 | Val Loss: 0.3288
#   [Train: 0.86s | Val: 0.50s | Save: 0.01s | Total: 1.38s]
# {'shift_0': [[1.9217073917388916]]}
# Appended linear shift weights for epoch 837 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 837/1000 | Train Loss: 0.3594 | Val Loss: 0.3288
#   [Train: 0.97s | Val: 0.44s | Save: 0.01s | Total: 1.45s]
# {'shift_0': [[1.9244706630706787]]}
# Appended linear shift weights for epoch 838 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 838/1000 | Train Loss: 0.3596 | Val Loss: 0.3286
#   [Train: 0.92s | Val: 0.55s | Save: 0.01s | Total: 1.49s]
# {'shift_0': [[1.925492286682129]]}
# Appended linear shift weights for epoch 839 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 839/1000 | Train Loss: 0.3604 | Val Loss: 0.3286
#   [Train: 0.89s | Val: 0.49s | Save: 0.01s | Total: 1.42s]
# {'shift_0': [[1.9291572570800781]]}
# Appended linear shift weights for epoch 840 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 840/1000 | Train Loss: 0.3602 | Val Loss: 0.3288
#   [Train: 0.87s | Val: 0.50s | Save: 0.01s | Total: 1.40s]
# {'shift_0': [[1.9261298179626465]]}
# Appended linear shift weights for epoch 841 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 841/1000 | Train Loss: 0.3620 | Val Loss: 0.3287
#   [Train: 0.89s | Val: 0.49s | Save: 0.01s | Total: 1.41s]
# {'shift_0': [[1.9218127727508545]]}
# Appended linear shift weights for epoch 842 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 842/1000 | Train Loss: 0.3586 | Val Loss: 0.3287
#   [Train: 0.95s | Val: 0.58s | Save: 0.01s | Total: 1.56s]
# {'shift_0': [[1.9269291162490845]]}
# Appended linear shift weights for epoch 843 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 843/1000 | Train Loss: 0.3608 | Val Loss: 0.3287
#   [Train: 0.80s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# {'shift_0': [[1.9142438173294067]]}
# Appended linear shift weights for epoch 844 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 844/1000 | Train Loss: 0.3588 | Val Loss: 0.3288
#   [Train: 0.91s | Val: 0.54s | Save: 0.01s | Total: 1.47s]
# {'shift_0': [[1.9251703023910522]]}
# Appended linear shift weights for epoch 845 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 845/1000 | Train Loss: 0.3605 | Val Loss: 0.3286
#   [Train: 0.91s | Val: 0.49s | Save: 0.01s | Total: 1.43s]
# {'shift_0': [[1.9291335344314575]]}
# Appended linear shift weights for epoch 846 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 846/1000 | Train Loss: 0.3591 | Val Loss: 0.3287
#   [Train: 0.99s | Val: 0.42s | Save: 0.01s | Total: 1.44s]
# {'shift_0': [[1.9273960590362549]]}
# Appended linear shift weights for epoch 847 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 847/1000 | Train Loss: 0.3598 | Val Loss: 0.3287
#   [Train: 0.79s | Val: 0.42s | Save: 0.01s | Total: 1.24s]
# {'shift_0': [[1.9241307973861694]]}
# Appended linear shift weights for epoch 848 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 848/1000 | Train Loss: 0.3599 | Val Loss: 0.3287
#   [Train: 0.84s | Val: 0.56s | Save: 0.01s | Total: 1.43s]
# {'shift_0': [[1.929829478263855]]}
# Appended linear shift weights for epoch 849 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 849/1000 | Train Loss: 0.3598 | Val Loss: 0.3286
#   [Train: 0.94s | Val: 0.52s | Save: 0.01s | Total: 1.50s]
# {'shift_0': [[1.931631088256836]]}
# Appended linear shift weights for epoch 850 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 850/1000 | Train Loss: 0.3594 | Val Loss: 0.3287
#   [Train: 0.87s | Val: 0.48s | Save: 0.01s | Total: 1.38s]
# {'shift_0': [[1.925718903541565]]}
# Appended linear shift weights for epoch 851 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 851/1000 | Train Loss: 0.3610 | Val Loss: 0.3286
#   [Train: 0.92s | Val: 0.51s | Save: 0.01s | Total: 1.46s]
# {'shift_0': [[1.9237602949142456]]}
# Appended linear shift weights for epoch 852 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 852/1000 | Train Loss: 0.3585 | Val Loss: 0.3286
#   [Train: 0.87s | Val: 0.46s | Save: 0.01s | Total: 1.37s]
# {'shift_0': [[1.929808259010315]]}
# Appended linear shift weights for epoch 853 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 853/1000 | Train Loss: 0.3590 | Val Loss: 0.3287
#   [Train: 0.95s | Val: 0.52s | Save: 0.01s | Total: 1.50s]
# {'shift_0': [[1.9227828979492188]]}
# Appended linear shift weights for epoch 854 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 854/1000 | Train Loss: 0.3617 | Val Loss: 0.3287
#   [Train: 0.90s | Val: 0.49s | Save: 0.01s | Total: 1.42s]
# {'shift_0': [[1.9309440851211548]]}
# Appended linear shift weights for epoch 855 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 855/1000 | Train Loss: 0.3590 | Val Loss: 0.3287
#   [Train: 0.79s | Val: 0.50s | Save: 0.01s | Total: 1.33s]
# {'shift_0': [[1.9346681833267212]]}
# Appended linear shift weights for epoch 856 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 856/1000 | Train Loss: 0.3583 | Val Loss: 0.3287
#   [Train: 0.89s | Val: 0.39s | Save: 0.01s | Total: 1.31s]
# {'shift_0': [[1.9345406293869019]]}
# Appended linear shift weights for epoch 857 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 857/1000 | Train Loss: 0.3604 | Val Loss: 0.3286
#   [Train: 0.95s | Val: 0.41s | Save: 0.01s | Total: 1.40s]
# {'shift_0': [[1.9216970205307007]]}
# Appended linear shift weights for epoch 858 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 858/1000 | Train Loss: 0.3618 | Val Loss: 0.3287
#   [Train: 0.96s | Val: 0.49s | Save: 0.01s | Total: 1.48s]
# {'shift_0': [[1.9338204860687256]]}
# Appended linear shift weights for epoch 859 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 859/1000 | Train Loss: 0.3595 | Val Loss: 0.3287
#   [Train: 1.03s | Val: 0.48s | Save: 0.01s | Total: 1.54s]
# {'shift_0': [[1.9356902837753296]]}
# Appended linear shift weights for epoch 860 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 860/1000 | Train Loss: 0.3603 | Val Loss: 0.3287
#   [Train: 0.90s | Val: 0.45s | Save: 0.01s | Total: 1.39s]
# {'shift_0': [[1.9269124269485474]]}
# Appended linear shift weights for epoch 861 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 861/1000 | Train Loss: 0.3590 | Val Loss: 0.3287
#   [Train: 0.90s | Val: 0.51s | Save: 0.01s | Total: 1.44s]
# {'shift_0': [[1.9412682056427002]]}
# Appended linear shift weights for epoch 862 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 862/1000 | Train Loss: 0.3601 | Val Loss: 0.3286
#   [Train: 0.86s | Val: 0.46s | Save: 0.01s | Total: 1.35s]
# {'shift_0': [[1.9216904640197754]]}
# Appended linear shift weights for epoch 863 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 863/1000 | Train Loss: 0.3609 | Val Loss: 0.3287
#   [Train: 1.04s | Val: 0.49s | Save: 0.01s | Total: 1.56s]
# {'shift_0': [[1.9236066341400146]]}
# Appended linear shift weights for epoch 864 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 864/1000 | Train Loss: 0.3586 | Val Loss: 0.3287
#   [Train: 0.82s | Val: 0.45s | Save: 0.01s | Total: 1.32s]
# {'shift_0': [[1.9346771240234375]]}
# Appended linear shift weights for epoch 865 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 865/1000 | Train Loss: 0.3583 | Val Loss: 0.3286
#   [Train: 1.04s | Val: 0.54s | Save: 0.01s | Total: 1.61s]
# {'shift_0': [[1.9341521263122559]]}
# Appended linear shift weights for epoch 866 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 866/1000 | Train Loss: 0.3605 | Val Loss: 0.3286
#   [Train: 1.57s | Val: 0.51s | Save: 0.01s | Total: 2.11s]
# {'shift_0': [[1.913393497467041]]}
# Appended linear shift weights for epoch 867 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 867/1000 | Train Loss: 0.3585 | Val Loss: 0.3287
#   [Train: 1.47s | Val: 0.46s | Save: 0.01s | Total: 1.96s]
# {'shift_0': [[1.927473783493042]]}
# Appended linear shift weights for epoch 868 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Saved new best model.
# Epoch 868/1000 | Train Loss: 0.3596 | Val Loss: 0.3285
#   [Train: 1.53s | Val: 0.43s | Save: 0.01s | Total: 1.99s]
# {'shift_0': [[1.942201018333435]]}
# Appended linear shift weights for epoch 869 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 869/1000 | Train Loss: 0.3601 | Val Loss: 0.3286
#   [Train: 1.50s | Val: 0.87s | Save: 0.01s | Total: 2.70s]
# {'shift_0': [[1.9209364652633667]]}
# Appended linear shift weights for epoch 870 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 870/1000 | Train Loss: 0.3584 | Val Loss: 0.3287
#   [Train: 0.86s | Val: 0.41s | Save: 0.01s | Total: 1.29s]
# {'shift_0': [[1.929660439491272]]}
# Appended linear shift weights for epoch 871 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 871/1000 | Train Loss: 0.3602 | Val Loss: 0.3286
#   [Train: 0.97s | Val: 0.52s | Save: 0.01s | Total: 1.52s]
# {'shift_0': [[1.933327555656433]]}
# Appended linear shift weights for epoch 872 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 872/1000 | Train Loss: 0.3598 | Val Loss: 0.3286
#   [Train: 0.84s | Val: 0.49s | Save: 0.01s | Total: 1.36s]
# {'shift_0': [[1.9308172464370728]]}
# Appended linear shift weights for epoch 873 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 873/1000 | Train Loss: 0.3591 | Val Loss: 0.3287
#   [Train: 1.06s | Val: 0.56s | Save: 0.01s | Total: 1.65s]
# {'shift_0': [[1.9308778047561646]]}
# Appended linear shift weights for epoch 874 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 874/1000 | Train Loss: 0.3594 | Val Loss: 0.3286
#   [Train: 0.98s | Val: 0.52s | Save: 0.01s | Total: 1.52s]
# {'shift_0': [[1.9368053674697876]]}
# Appended linear shift weights for epoch 875 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Saved new best model.
# Epoch 875/1000 | Train Loss: 0.3583 | Val Loss: 0.3285
#   [Train: 0.99s | Val: 0.59s | Save: 0.01s | Total: 1.62s]
# {'shift_0': [[1.947836995124817]]}
# Appended linear shift weights for epoch 876 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 876/1000 | Train Loss: 0.3600 | Val Loss: 0.3286
#   [Train: 1.03s | Val: 0.50s | Save: 0.01s | Total: 1.55s]
# {'shift_0': [[1.9283373355865479]]}
# Appended linear shift weights for epoch 877 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# Epoch 877/1000 | Train Loss: 0.3598 | Val Loss: 0.3287
#   [Train: 0.90s | Val: 0.52s | Save: 0.00s | Total: 1.44s]
# {'shift_0': [[1.9271364212036133]]}
# Appended linear shift weights for epoch 878 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/linear_shifts_all_epochs.json
# ...
# Epoch 954/1000 | Train Loss: 2.4122 | Val Loss: 2.4118
#   [Train: 1.08s | Val: 0.64s | Save: 0.01s | Total: 1.78s]
# {'shift_0': [[-0.18492060899734497]], 'shift_1': [[0.3059934675693512]]}
# Appended linear shift weights for epoch 955 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 955/1000 | Train Loss: 2.4128 | Val Loss: 2.4121
#   [Train: 1.15s | Val: 0.71s | Save: 0.01s | Total: 1.92s]
# {'shift_0': [[-0.19734272360801697]], 'shift_1': [[0.32068124413490295]]}
# Appended linear shift weights for epoch 956 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 956/1000 | Train Loss: 2.4133 | Val Loss: 2.4118
#   [Train: 1.02s | Val: 0.57s | Save: 0.01s | Total: 1.64s]
# {'shift_0': [[-0.1862279176712036]], 'shift_1': [[0.295960932970047]]}
# Appended linear shift weights for epoch 957 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 957/1000 | Train Loss: 2.4115 | Val Loss: 2.4120
#   [Train: 1.22s | Val: 0.71s | Save: 0.01s | Total: 1.99s]
# {'shift_0': [[-0.200589120388031]], 'shift_1': [[0.30476832389831543]]}
# Appended linear shift weights for epoch 958 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 958/1000 | Train Loss: 2.4110 | Val Loss: 2.4118
#   [Train: 1.30s | Val: 0.63s | Save: 0.01s | Total: 1.98s]
# {'shift_0': [[-0.19166286289691925]], 'shift_1': [[0.2923257052898407]]}
# Appended linear shift weights for epoch 959 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 959/1000 | Train Loss: 2.4130 | Val Loss: 2.4120
#   [Train: 1.14s | Val: 0.67s | Save: 0.01s | Total: 1.85s]
# {'shift_0': [[-0.20253273844718933]], 'shift_1': [[0.3052555024623871]]}
# Appended linear shift weights for epoch 960 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 960/1000 | Train Loss: 2.4118 | Val Loss: 2.4118
#   [Train: 1.16s | Val: 0.67s | Save: 0.01s | Total: 1.88s]
# {'shift_0': [[-0.1870597004890442]], 'shift_1': [[0.2937118113040924]]}
# Appended linear shift weights for epoch 961 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 961/1000 | Train Loss: 2.4114 | Val Loss: 2.4121
#   [Train: 1.16s | Val: 0.60s | Save: 0.01s | Total: 1.81s]
# {'shift_0': [[-0.2058476209640503]], 'shift_1': [[0.296265184879303]]}
# Appended linear shift weights for epoch 962 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 962/1000 | Train Loss: 2.4114 | Val Loss: 2.4118
#   [Train: 1.07s | Val: 0.56s | Save: 0.01s | Total: 1.69s]
# {'shift_0': [[-0.20101456344127655]], 'shift_1': [[0.30603742599487305]]}
# Appended linear shift weights for epoch 963 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 963/1000 | Train Loss: 2.4134 | Val Loss: 2.4119
#   [Train: 1.10s | Val: 0.61s | Save: 0.01s | Total: 1.76s]
# {'shift_0': [[-0.19325843453407288]], 'shift_1': [[0.29822391271591187]]}
# Appended linear shift weights for epoch 964 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 964/1000 | Train Loss: 2.4140 | Val Loss: 2.4120
#   [Train: 1.20s | Val: 0.59s | Save: 0.01s | Total: 1.84s]
# {'shift_0': [[-0.18631908297538757]], 'shift_1': [[0.2926691472530365]]}
# Appended linear shift weights for epoch 965 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 965/1000 | Train Loss: 2.4122 | Val Loss: 2.4121
#   [Train: 1.15s | Val: 0.60s | Save: 0.01s | Total: 1.81s]
# {'shift_0': [[-0.19288118183612823]], 'shift_1': [[0.293629914522171]]}
# Appended linear shift weights for epoch 966 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 966/1000 | Train Loss: 2.4121 | Val Loss: 2.4119
#   [Train: 1.06s | Val: 0.60s | Save: 0.01s | Total: 1.71s]
# {'shift_0': [[-0.20332752168178558]], 'shift_1': [[0.3092069923877716]]}
# Appended linear shift weights for epoch 967 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 967/1000 | Train Loss: 2.4129 | Val Loss: 2.4117
#   [Train: 1.02s | Val: 0.66s | Save: 0.01s | Total: 1.73s]
# {'shift_0': [[-0.19120921194553375]], 'shift_1': [[0.2810582220554352]]}
# Appended linear shift weights for epoch 968 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 968/1000 | Train Loss: 2.4118 | Val Loss: 2.4120
#   [Train: 1.09s | Val: 0.71s | Save: 0.01s | Total: 1.86s]
# {'shift_0': [[-0.19624458253383636]], 'shift_1': [[0.2927953004837036]]}
# Appended linear shift weights for epoch 969 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 969/1000 | Train Loss: 2.4126 | Val Loss: 2.4119
#   [Train: 1.09s | Val: 0.69s | Save: 0.01s | Total: 1.83s]
# {'shift_0': [[-0.19106067717075348]], 'shift_1': [[0.2912522256374359]]}
# Appended linear shift weights for epoch 970 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 970/1000 | Train Loss: 2.4114 | Val Loss: 2.4120
#   [Train: 1.12s | Val: 0.58s | Save: 0.01s | Total: 1.77s]
# {'shift_0': [[-0.19283539056777954]], 'shift_1': [[0.3123520612716675]]}
# Appended linear shift weights for epoch 971 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 971/1000 | Train Loss: 2.4136 | Val Loss: 2.4119
#   [Train: 0.83s | Val: 0.54s | Save: 0.01s | Total: 1.42s]
# {'shift_0': [[-0.18975701928138733]], 'shift_1': [[0.3083910346031189]]}
# Appended linear shift weights for epoch 972 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 972/1000 | Train Loss: 2.4115 | Val Loss: 2.4119
#   [Train: 0.99s | Val: 0.56s | Save: 0.01s | Total: 1.59s]
# {'shift_0': [[-0.2016546130180359]], 'shift_1': [[0.30200353264808655]]}
# Appended linear shift weights for epoch 973 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 973/1000 | Train Loss: 2.4112 | Val Loss: 2.4118
#   [Train: 0.81s | Val: 0.51s | Save: 0.01s | Total: 1.37s]
# {'shift_0': [[-0.18723788857460022]], 'shift_1': [[0.30746161937713623]]}
# Appended linear shift weights for epoch 974 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 974/1000 | Train Loss: 2.4125 | Val Loss: 2.4119
#   [Train: 1.01s | Val: 0.52s | Save: 0.01s | Total: 1.59s]
# {'shift_0': [[-0.2017112374305725]], 'shift_1': [[0.31446900963783264]]}
# Appended linear shift weights for epoch 975 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 975/1000 | Train Loss: 2.4130 | Val Loss: 2.4117
#   [Train: 0.97s | Val: 0.45s | Save: 0.01s | Total: 1.47s]
# {'shift_0': [[-0.1853400021791458]], 'shift_1': [[0.28148582577705383]]}
# Appended linear shift weights for epoch 976 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 976/1000 | Train Loss: 2.4123 | Val Loss: 2.4121
#   [Train: 1.43s | Val: 0.44s | Save: 0.01s | Total: 1.91s]
# {'shift_0': [[-0.20186370611190796]], 'shift_1': [[0.2852998375892639]]}
# Appended linear shift weights for epoch 977 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 977/1000 | Train Loss: 2.4111 | Val Loss: 2.4118
#   [Train: 1.39s | Val: 0.88s | Save: 0.01s | Total: 2.60s]
# {'shift_0': [[-0.19543178379535675]], 'shift_1': [[0.3134981095790863]]}
# Appended linear shift weights for epoch 978 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 978/1000 | Train Loss: 2.4106 | Val Loss: 2.4118
#   [Train: 0.89s | Val: 0.50s | Save: 0.01s | Total: 1.43s]
# {'shift_0': [[-0.1846623420715332]], 'shift_1': [[0.28747546672821045]]}
# Appended linear shift weights for epoch 979 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 979/1000 | Train Loss: 2.4120 | Val Loss: 2.4122
#   [Train: 0.89s | Val: 0.49s | Save: 0.01s | Total: 1.43s]
# {'shift_0': [[-0.20299844443798065]], 'shift_1': [[0.30997708439826965]]}
# Appended linear shift weights for epoch 980 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 980/1000 | Train Loss: 2.4106 | Val Loss: 2.4118
#   [Train: 0.93s | Val: 0.58s | Save: 0.01s | Total: 1.55s]
# {'shift_0': [[-0.19351620972156525]], 'shift_1': [[0.2971770167350769]]}
# Appended linear shift weights for epoch 981 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 981/1000 | Train Loss: 2.4136 | Val Loss: 2.4120
#   [Train: 1.13s | Val: 0.63s | Save: 0.01s | Total: 1.81s]
# {'shift_0': [[-0.20464621484279633]], 'shift_1': [[0.2874327600002289]]}
# Appended linear shift weights for epoch 982 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 982/1000 | Train Loss: 2.4123 | Val Loss: 2.4119
#   [Train: 1.11s | Val: 0.58s | Save: 0.01s | Total: 1.75s]
# {'shift_0': [[-0.21015620231628418]], 'shift_1': [[0.3019018769264221]]}
# Appended linear shift weights for epoch 983 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 983/1000 | Train Loss: 2.4115 | Val Loss: 2.4117
#   [Train: 1.07s | Val: 0.54s | Save: 0.01s | Total: 1.68s]
# {'shift_0': [[-0.19513115286827087]], 'shift_1': [[0.29829227924346924]]}
# Appended linear shift weights for epoch 984 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 984/1000 | Train Loss: 2.4133 | Val Loss: 2.4119
#   [Train: 0.99s | Val: 0.44s | Save: 0.01s | Total: 1.47s]
# {'shift_0': [[-0.1860160231590271]], 'shift_1': [[0.29196375608444214]]}
# Appended linear shift weights for epoch 985 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 985/1000 | Train Loss: 2.4120 | Val Loss: 2.4120
#   [Train: 0.99s | Val: 0.61s | Save: 0.01s | Total: 1.65s]
# {'shift_0': [[-0.1923026442527771]], 'shift_1': [[0.3166808784008026]]}
# Appended linear shift weights for epoch 986 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 986/1000 | Train Loss: 2.4119 | Val Loss: 2.4118
#   [Train: 0.98s | Val: 0.61s | Save: 0.01s | Total: 1.64s]
# {'shift_0': [[-0.18622125685214996]], 'shift_1': [[0.29448622465133667]]}
# Appended linear shift weights for epoch 987 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 987/1000 | Train Loss: 2.4108 | Val Loss: 2.4120
#   [Train: 1.01s | Val: 0.49s | Save: 0.01s | Total: 1.55s]
# {'shift_0': [[-0.2144142985343933]], 'shift_1': [[0.3166818618774414]]}
# Appended linear shift weights for epoch 988 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 988/1000 | Train Loss: 2.4130 | Val Loss: 2.4116
#   [Train: 0.93s | Val: 0.52s | Save: 0.01s | Total: 1.49s]
# {'shift_0': [[-0.1897251456975937]], 'shift_1': [[0.2995862662792206]]}
# Appended linear shift weights for epoch 989 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 989/1000 | Train Loss: 2.4135 | Val Loss: 2.4121
#   [Train: 1.06s | Val: 0.51s | Save: 0.01s | Total: 1.62s]
# {'shift_0': [[-0.1949148327112198]], 'shift_1': [[0.3044622540473938]]}
# Appended linear shift weights for epoch 990 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 990/1000 | Train Loss: 2.4139 | Val Loss: 2.4119
#   [Train: 1.02s | Val: 0.43s | Save: 0.01s | Total: 1.49s]
# {'shift_0': [[-0.19552107155323029]], 'shift_1': [[0.2996954917907715]]}
# Appended linear shift weights for epoch 991 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 991/1000 | Train Loss: 2.4100 | Val Loss: 2.4118
#   [Train: 0.97s | Val: 0.51s | Save: 0.01s | Total: 1.53s]
# {'shift_0': [[-0.19838263094425201]], 'shift_1': [[0.3002279996871948]]}
# Appended linear shift weights for epoch 992 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 992/1000 | Train Loss: 2.4134 | Val Loss: 2.4118
#   [Train: 0.97s | Val: 0.59s | Save: 0.01s | Total: 1.60s]
# {'shift_0': [[-0.18602889776229858]], 'shift_1': [[0.2878381013870239]]}
# Appended linear shift weights for epoch 993 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 993/1000 | Train Loss: 2.4097 | Val Loss: 2.4121
#   [Train: 1.04s | Val: 0.69s | Save: 0.01s | Total: 1.79s]
# {'shift_0': [[-0.2050871104001999]], 'shift_1': [[0.2950277030467987]]}
# Appended linear shift weights for epoch 994 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 994/1000 | Train Loss: 2.4126 | Val Loss: 2.4118
#   [Train: 0.97s | Val: 0.50s | Save: 0.01s | Total: 1.52s]
# {'shift_0': [[-0.18592411279678345]], 'shift_1': [[0.29455897212028503]]}
# Appended linear shift weights for epoch 995 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 995/1000 | Train Loss: 2.4134 | Val Loss: 2.4121
#   [Train: 1.10s | Val: 0.62s | Save: 0.01s | Total: 1.77s]
# {'shift_0': [[-0.21389999985694885]], 'shift_1': [[0.30586785078048706]]}
# Appended linear shift weights for epoch 996 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 996/1000 | Train Loss: 2.4116 | Val Loss: 2.4117
#   [Train: 1.09s | Val: 0.57s | Save: 0.01s | Total: 1.72s]
# {'shift_0': [[-0.18502798676490784]], 'shift_1': [[0.29578590393066406]]}
# Appended linear shift weights for epoch 997 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 997/1000 | Train Loss: 2.4120 | Val Loss: 2.4121
#   [Train: 0.95s | Val: 0.49s | Save: 0.01s | Total: 1.49s]
# {'shift_0': [[-0.1987798660993576]], 'shift_1': [[0.2871312201023102]]}
# Appended linear shift weights for epoch 998 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 998/1000 | Train Loss: 2.4112 | Val Loss: 2.4119
#   [Train: 0.92s | Val: 0.46s | Save: 0.01s | Total: 1.44s]
# {'shift_0': [[-0.19916187226772308]], 'shift_1': [[0.30989551544189453]]}
# Appended linear shift weights for epoch 999 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 999/1000 | Train Loss: 2.4119 | Val Loss: 2.4118
#   [Train: 1.05s | Val: 0.49s | Save: 0.01s | Total: 1.60s]
# {'shift_0': [[-0.19409574568271637]], 'shift_1': [[0.284946084022522]]}
# Appended linear shift weights for epoch 1000 to: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/linear_shifts_all_epochs.json
# Epoch 1000/1000 | Train Loss: 2.4120 | Val Loss: 2.4119
#   [Train: 0.85s | Val: 0.49s | Save: 0.01s | Total: 1.38s]

# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs

# %%
show_training_history(conf_dict,EXPERIMENT_DIR)

# %% [markdown]
# ## 6.2 inspect transformation function for source nodes h()

# %%
show_hdag_for_source_nodes(conf_dict,EXPERIMENT_DIR,device=device,xmin_plot=0,xmax_plot=1) # TODO for other nodes funciton
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# h() for  x1:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance
#
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(conf_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# Train loader (x1): 100%|██████████| 2/2 [00:01<00:00,  1.80it/s]
# Val loader (x1): 100%|██████████| 1/1 [00:00<00:00,  2.22it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# Train loader (x2): 100%|██████████| 2/2 [00:00<00:00,  2.38it/s]
# Val loader (x2): 100%|██████████| 1/1 [00:00<00:00,  2.25it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--
# Train loader (x3): 100%|██████████| 2/2 [00:00<00:00,  2.34it/s]
# Val loader (x3): 100%|██████████| 1/1 [00:00<00:00,  2.15it/s]

# %% [markdown]
# ### Coefficient estimates

# %%
# x1-> x2, x1-> x3, x2-> x3
true_coeffs = {'x2': [2],'x3': [-0.2, 0.3]}

for node in conf_dict:
    print(f'\n----*----------*-------------*--------check LS of {node} ------------*-----------------*-------------------*--')
    
    if conf_dict[node]['node_type'] == 'source':
        print(f"Node type :source")
        continue
    
    # Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    # Load saved shifts
    shift_path = os.path.join(NODE_DIR, "linear_shifts_all_epochs.json")
    with open(shift_path, 'r') as f:
        all_shift_weights = json.load(f)

    # Sort epochs numerically
    epochs = sorted(all_shift_weights.keys(), key=lambda x: int(x.split('_')[1]))

    # Number of shifts (incoming edges) for this node
    example_epoch = all_shift_weights[epochs[0]]
    num_shifts = len(example_epoch)

    # Plot per shift (incoming edge)
    for shifts_idx in range(num_shifts):
        shift_name = f"shift_{shifts_idx}"
        weights_over_time = []

        for epoch in epochs:
            weight_matrix = np.array(all_shift_weights[epoch][shift_name])  # shape: [out_features, in_features]
            avg_weight = weight_matrix.mean()
            weights_over_time.append(avg_weight)

        plt.figure()
        plt.plot(range(1, len(epochs) + 1), weights_over_time)

        # If this node has a true coefficient for this shift, draw a horizontal red line
        if node in true_coeffs:
            true_val = true_coeffs[node][shifts_idx]
            plt.axhline(y=true_val, color='r', linestyle='--', label=f"True coeff = {true_val}")
            plt.legend()

        plt.title(f"Linear Shift Weights in h({node}), ")
        plt.xlabel("Epoch")
        plt.ylabel(fr'$\hat{{\beta}}_{{{conf_dict[node]["parents"][shifts_idx]}}}$')
        plt.grid(True)
        plt.tight_layout()
        plt.show()
# Out:
# ----*----------*-------------*--------check LS of x1 ------------*-----------------*-------------------*--
# Node type :source
#
# ----*----------*-------------*--------check LS of x2 ------------*-----------------*-------------------*--
# ----*----------*-------------*--------check LS of x3 ------------*-----------------*-------------------*--

# %%
verbose=False


batch_size = 4112
for node in conf_dict:
    print(f'\n----*----------*-------------*--------check CS of {node} ------------*-----------------*-------------------*--')
    
    if (conf_dict[node]['node_type'] == 'source'):
        print(f"Node type : other , is not supported yet")
        continue
    
    
    #### 0. Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    
    ##### 1. Load model 
    model_path = os.path.join(NODE_DIR, "best_model.pt")
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose)
    tram_model = tram_model.to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()
    
    # for name, param in tram_model.state_dict().items():
    #     print(f"{name}: {param.data}")
        
    for i in range(len(tram_model.nn_shift)):
        print(tram_model.nn_shift[i].fc.weight.data)
# Out:
# ----*----------*-------------*--------check CS of x1 ------------*-----------------*-------------------*--
# Node type : other , is not supported yet
#
# ----*----------*-------------*--------check CS of x2 ------------*-----------------*-------------------*--
# tensor([[0.5895]], device='cuda:0')
#
# ----*----------*-------------*--------check CS of x3 ------------*-----------------*-------------------*--
# tensor([[-0.6292]], device='cuda:0')
# tensor([[0.2878]], device='cuda:0')

# %% [markdown]
# # 7. Sample from Graph

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            n= 10_000,
                            batch_size = 1,
                            delete_all_previously_sampled=True,
                            verbose=True)
# Out:
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x1/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x1/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# h() for samples in  x1: 100%|██████████| 10000/10000 [00:03<00:00, 3096.79it/s]
# source node, Defaults to SI and 1 as inputs
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:57<00:00, 172.72it/s]
# /home/bule/TramDag/utils/sampling_tram_data.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x2: 100%|██████████| 10000/10000 [00:05<00:00, 1851.93it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:58<00:00, 172.38it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0-1): 2 x LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x3: 100%|██████████| 10000/10000 [00:07<00:00, 1310.07it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:57<00:00, 172.61it/s]

# %% [markdown]
# ## 7.3 Inspect Sampling

# %%
show_samples_vs_true(train_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')
