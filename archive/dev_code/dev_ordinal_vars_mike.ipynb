# %%
import os
from utils.configuration import *

# %%
experiment_name = "ordinal_vars_mike"      ## <--- set experiment name
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"  ## <--- set log directory
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"configuration.json")

# %%
CONF_DICT_PATH
# Out:
# '/home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/configuration.json'

# %%
setup_configuration(experiment_name,EXPERIMENT_DIR)
# Out:
# Configuration already exists/home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/configuration.json

# %%
# here you need to specify which varibles are in the graph and what type they are (continous or ordinal) for the model builder 
data_type= {'x1':'continous',
            'x2':'continous',
            'x3':'continous',
            't1':'ordinal_Xc_Yo',
            't2':'ordinal_Xc_Yo',
            'x5':'continous',
            'x6':'continous',
            'y':'continous'} 

write_data_type_to_configuration(data_type, CONF_DICT_PATH)
# Out:
# ---------------------------------------------------------------------------------------------------------
#                                        |                       MODEL SETTINGS
# Variable             | dtype           | As Predictor                   | As Target
# ---------------------------------------------------------------------------------------------------------
# x1                   | continous       | continuous [c]                 | continuous [c]
# x2                   | continous       | continuous [c]                 | continuous [c]
# x3                   | continous       | continuous [c]                 | continuous [c]
# t1                   | ordinal_Xc_Yo   | continuous [c]                 | ordinal    [0,…,K]
# t2                   | ordinal_Xc_Yo   | continuous [c]                 | ordinal    [0,…,K]
# x5                   | continous       | continuous [c]                 | continuous [c]
# x6                   | continous       | continuous [c]                 | continuous [c]
# y                    | continous       | continuous [c]                 | continuous [c]
# ---------------------------------------------------------------------------------------------------------
# Configuration updated successfully.

# %%
interactive_adj_matrix(CONF_DICT_PATH,seed=19)
# Out:
# /home/bule/TramDag/utils/configuration.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
interactive_nn_names_matrix(CONF_DICT_PATH, seed=5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
import pandas as pd
from scipy.special import logit

df = pd.DataFrame(
    make_blobs(n_samples=10_000, centers=8, n_features=8, random_state=13)[0],
    columns=['x1','x2','x3','x5','t1','t2','x6','y']
)


df['t1'] = (df['t1'] > df['t1'].median()).astype(int)
df['t2']=df['t1'].copy()
print(df.head())
df.info()
# Out:
#          x1         x2        x3        x5  t1  t2        x6         y
# 0  3.758992  -1.131220 -0.095220  9.899652   0   0  3.906152 -3.767058
# 1 -8.768500 -10.650421  2.893708  9.475817   0   0  7.026890 -8.332300
# 2  9.450577   5.692370 -3.912306  0.038899   1   1  5.710581 -2.963938
# 3  3.996866   4.773048 -9.309254 -4.166017   0   0 -2.438505  2.368463
# 4  2.789833   4.072897 -8.760611 -2.006136   0   0 -2.966617  2.577728
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      10000 non-null  float64
#  1   x2      10000 non-null  float64
#  2   x3      10000 non-null  float64
#  3   x5      10000 non-null  float64
#  4   t1      10000 non-null  int64
#  5   t2      10000 non-null  int64
#  6   x6      10000 non-null  float64
#  7   y       10000 non-null  float64
# dtypes: float64(6), int64(2)
# memory usage: 625.1 KB

# %%
# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# %%
from utils.tramdag import TramDagConfig , TramDagModel

cfg = TramDagConfig.load(CONF_DICT_PATH)
cfg.compute_levels(train_df)
device='cpu'

# %%
td_model = TramDagModel.from_config(cfg, set_initial_weights=True,verbose=True,debug=True,device=device,initial_data = train_df) 
# 1m52s
# Out:
# [DEBUG] TramDagModel using device: cpu
#
# [INFO] Building model for node 'x1' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561185.csv
# [DEBUG] R script written to: /tmp/tmppa0ih33i.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1761561185.csv")
# model <- Colr(`x1` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.342685
# -1.740876
# -1.740876
# -1.740876
# -1.740876
# -0.3917993
# -0.3917993
# -0.3917993
# -0.3917993
# -0.3917992
# -0.3917992
# -0.3917992
# -0.3917992
# -0.3917992
# -0.3917992
# 0.2316041
# 1.449474
# 1.449474
# 1.449474
# 2.222755
#
# [DEBUG] R-estimated thetas for node 'x1': [-2.342685  -1.740876  -1.740876  -1.740876  -1.740876  -0.3917993
#  -0.3917993 -0.3917993 -0.3917993 -0.3917992 -0.3917992 -0.3917992
#  -0.3917992 -0.3917992 -0.3917992  0.2316041  1.449474   1.449474
#   1.449474   2.222755 ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [  4.5887866   -0.19186531 -27.631021   -27.631021   -27.631021
#    1.0486743  -27.631021   -27.631021   -27.631021   -16.230066
#  -27.631021   -27.631021   -27.631021   -27.631021   -27.631021
#   -0.14471908   0.8670922  -27.631021   -27.631021     0.15431984]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561185.csv
# [DEBUG] Saved initial model state for node 'x1' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x1/initial_model.pt (overwrite=True)
#
# [INFO] Building model for node 'x2' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561190.csv
# [DEBUG] R script written to: /tmp/tmp04wzeg65.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1761561190.csv")
# model <- Colr(`x2` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.218559
# -1.255445
# -1.255445
# -0.9995559
# -0.9995559
# -0.9995559
# -0.9995558
# -0.1612364
# -0.06670246
# -0.06670245
# -0.06670243
# -0.06670242
# -0.01309015
# 0.476259
# 0.476259
# 0.476259
# 0.476259
# 0.4997027
# 1.250116
# 2.229194
#
# [DEBUG] R-estimated thetas for node 'x2': [-2.218559   -1.255445   -1.255445   -0.9995559  -0.9995559  -0.9995559
#  -0.9995558  -0.1612364  -0.06670246 -0.06670245 -0.06670243 -0.06670242
#  -0.01309015  0.476259    0.476259    0.476259    0.476259    0.4997027
#   1.250116    2.229194  ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [  4.7129126    0.48232862 -27.631021    -1.2323397  -27.631021
#  -27.631021   -16.635532     0.2719165   -2.311157   -18.021826
#  -18.021826   -18.021826    -2.8990514   -0.4600467  -27.631021
#  -27.631021   -27.631021    -3.7414088    0.1114297    0.50802207]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561190.csv
# [DEBUG] Saved initial model state for node 'x2' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x2/initial_model.pt (overwrite=True)
#
# [INFO] Building model for node 'x3' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561193.csv
# [DEBUG] R script written to: /tmp/tmp4fjjfj3g.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1761561193.csv")
# model <- Colr(`x3` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.203132
# -1.093425
# -1.057398
# -1.057398
# -1.057398
# -0.8170397
# -0.4370793
# -0.4370793
# -0.4370793
# -0.4370793
# -0.4370793
# -0.06809107
# -0.06809106
# -0.06809104
# 0.3513063
# 1.175761
# 1.175761
# 1.312207
# 1.312207
# 2.211916
#
# [DEBUG] R-estimated thetas for node 'x3': [-2.203132   -1.093425   -1.057398   -1.057398   -1.057398   -0.8170397
#  -0.4370793  -0.4370793  -0.4370793  -0.4370793  -0.4370793  -0.06809107
#  -0.06809106 -0.06809104  0.3513063   1.175761    1.175761    1.312207
#   1.312207    2.211916  ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [  4.7283397    0.70974326  -3.305417   -27.631021   -27.631021
#   -1.3030397   -0.7716998  -27.631021   -27.631021   -27.631021
#  -27.631021    -0.8068298  -18.021826   -18.021826    -0.65191966
#    0.24735744 -27.631021    -1.9228277  -27.631021     0.3776741 ]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561193.csv
# [DEBUG] Saved initial model state for node 'x3' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x3/initial_model.pt (overwrite=True)
#
# [INFO] Building model for node 't1' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561197.csv
# [DEBUG] R script written to: /tmp/tmpelyx31qm.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
# data <- read_csv("temp/initial_data_1761561197.csv")
# data$t1 <- as.numeric(as.factor(data$t1)) - 1
# model <- glm(`t1` ~ 1, data=data, family=binomial(link="logit"))
# cat(coef(model), sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  0.009000061
#
# [DEBUG] R-estimated thetas for node 't1': [0.00900006]
# [DEBUG] Expected number of thetas: 1
# [DEBUG] Last linear layer shape: torch.Size([1, 1])
# [DEBUG] Inverse transforming thetas for ordinal outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [[0.00900006]]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([1, 1])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=1, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561197.csv
# [DEBUG] Saved initial model state for node 't1' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t1/initial_model.pt (overwrite=True)
#
# [INFO] Building model for node 't2' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561199.csv
# [DEBUG] R script written to: /tmp/tmpy63quwrs.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
# data <- read_csv("temp/initial_data_1761561199.csv")
# data$t2 <- as.numeric(as.factor(data$t2)) - 1
# model <- glm(`t2` ~ 1, data=data, family=binomial(link="logit"))
# cat(coef(model), sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  0.009000061
#
# [DEBUG] R-estimated thetas for node 't2': [0.00900006]
# [DEBUG] Expected number of thetas: 1
# [DEBUG] Last linear layer shape: torch.Size([1, 1])
# [DEBUG] Inverse transforming thetas for ordinal outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [[0.00900006]]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([1, 1])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=1, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561199.csv
# [DEBUG] Saved initial model state for node 't2' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t2/initial_model.pt (overwrite=True)
#
# [INFO] Building model for node 'x5' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561201.csv
# [DEBUG] R script written to: /tmp/tmp_6j0rx1x.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1761561201.csv")
# model <- Colr(`x5` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.228916
# -1.352136
# -0.9239665
# -0.5771275
# -0.5771275
# -0.5771275
# -0.5771275
# -0.5771275
# 0.07589798
# 0.5914713
# 0.5914713
# 0.5914714
# 0.5914714
# 0.5914714
# 0.5914714
# 0.5914714
# 0.5914714
# 0.8528216
# 1.283529
# 2.276085
#
# [DEBUG] R-estimated thetas for node 'x5': [-2.228916   -1.352136   -0.9239665  -0.5771275  -0.5771275  -0.5771275
#  -0.5771275  -0.5771275   0.07589798  0.5914713   0.5914713   0.5914714
#   0.5914714   0.5914714   0.5914714   0.5914714   0.5914714   0.8528216
#   1.283529    2.276085  ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [  4.7025557    0.33871892  -0.6265243   -0.88046765 -27.631021
#  -27.631021   -27.631021   -27.631021    -0.08192065  -0.39363784
#  -27.631021   -16.635532   -27.631021   -27.631021   -27.631021
#  -27.631021   -27.631021    -1.2083745   -0.6192548    0.5295227 ]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561201.csv
# [DEBUG] Saved initial model state for node 'x5' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x5/initial_model.pt (overwrite=True)
#
# [INFO] Building model for node 'x6' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561205.csv
# [DEBUG] R script written to: /tmp/tmptappx7uq.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1761561205.csv")
# model <- Colr(`x6` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.199559
# -1.503473
# -1.43077
# -0.9722417
# 0.03533331
# 0.03533332
# 0.03533334
# 0.03533335
# 0.03533337
# 0.03533338
# 0.0353334
# 0.03533341
# 0.09505789
# 0.7545571
# 0.7545572
# 0.7545572
# 0.9450703
# 1.237781
# 1.4419
# 2.233169
#
# [DEBUG] R-estimated thetas for node 'x6': [-2.199559   -1.503473   -1.43077    -0.9722417   0.03533331  0.03533332
#   0.03533334  0.03533335  0.03533337  0.03533338  0.0353334   0.03533341
#   0.09505789  0.7545571   0.7545572   0.7545572   0.9450703   1.237781
#   1.4419      2.233169  ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [ 4.7319126e+00  5.8688875e-03 -2.5848010e+00 -5.4172397e-01
#   5.5328208e-01 -1.8309509e+01 -1.7798683e+01 -1.8309509e+01
#  -1.7798683e+01 -1.8309509e+01 -1.7798683e+01 -1.8309509e+01
#  -2.7880025e+00 -6.8467721e-02 -1.5942385e+01 -2.7631021e+01
#  -1.5612657e+00 -1.0786476e+00 -1.4852574e+00  1.8747032e-01]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561205.csv
# [DEBUG] Saved initial model state for node 'x6' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x6/initial_model.pt (overwrite=True)
#
# [INFO] Building model for node 'y' with settings: {'set_initial_weights': True, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2         x3        x5  t1  t2        x6         y
# 9254   5.790936 -7.249819   6.229806  6.689151   1   1  1.649284  6.730776
# 1561   2.400405  4.557155  -9.872843 -6.638451   0   0 -1.641476  2.115917
# 1670  -9.930820 -9.865590   1.492166  6.758005   0   0  5.124343 -7.871000
# 6087   4.827056 -5.193179   5.285507  9.157148   1   1  1.794985  7.551717
# 6669   6.572506 -4.023019   5.458759  9.673777   1   1  0.357335  5.307645
# ...         ...       ...        ...       ...  ..  ..       ...       ...
# 5734  10.089638  3.268733  -6.138526  1.147616   1   1  4.632081 -1.416370
# 5191   8.794295  3.537923  -5.136052  1.756384   1   1  7.567315 -1.000883
# 5390  -4.647563  2.710111  10.264334 -6.417286   1   1 -2.431899  3.603696
# 860   -8.692852 -8.695716   1.769343  5.199065   0   0  6.421811 -8.024136
# 7270  -3.894834 -3.009861 -10.793729 -2.080070   1   1 -2.497435  7.983131
#
# [8000 rows x 8 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
# [DEBUG] Wrote DataFrame to temporary CSV: temp/initial_data_1761561210.csv
# [DEBUG] R script written to: /tmp/tmp1ydj7aaz.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("temp/initial_data_1761561210.csv")
# model <- Colr(`y` ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.22019
# -1.335656
# -1.248591
# -1.125519
# -1.125519
# -1.125519
# -0.9353142
# 0.05528583
# 0.05528585
# 0.05528586
# 0.05528588
# 0.05528589
# 0.05528591
# 0.05528592
# 0.2324828
# 1.503425
# 1.503425
# 1.503425
# 1.503425
# 2.251559
#
# [DEBUG] R-estimated thetas for node 'y': [-2.22019    -1.335656   -1.248591   -1.125519   -1.125519   -1.125519
#  -0.9353142   0.05528583  0.05528585  0.05528586  0.05528588  0.05528589
#   0.05528591  0.05528592  0.2324828   1.503425    1.503425    1.503425
#   1.503425    2.251559  ]
# [DEBUG] R-estimated thetas shape: torch.Size([20])
# [DEBUG] Expected number of thetas: 20
# [DEBUG] Last linear layer shape: torch.Size([20, 1])
# [DEBUG] Inverse transforming thetas for continuous outcome...
# [DEBUG] Transformed thetas -> theta_tilde: [  4.711282     0.35196275  -2.397251    -2.0328195  -27.631021
#  -27.631021    -1.5630442    0.5264133  -17.798683   -18.30951
#  -17.798683   -18.30951    -17.798683   -18.30951     -1.6405874
#    0.9416501  -27.631021   -27.631021   -27.631021     0.10710707]
# [DEBUG] Transformed thetas -> theta_tilde shape: torch.Size([20])
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [DEBUG] Removed temporary CSV file: temp/initial_data_1761561210.csv
# [DEBUG] Saved initial model state for node 'y' to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/initial_model.pt (overwrite=True)

# %%
td_model.fit(train_df, val_df,
             epochs=1500,batch_size=1_000,
             learning_rate=1e-2,
             verbose=True,debug=False,
             device=device,
             num_workers = 8,
             persistent_workers = True,
             prefetch_factor = 8,
             train_mode = "sequential")#,

#30 eps 1m 49s seq mode from start 1000 bs
#30 eps 2m 27s parllel multiprocessing mode from start 1000 bs
# 200 eps 9m 30s seq mode from start 1000 bs
# Out:
# [INFO] Computing new minmax dict from training data...
# [INFO] Saved new minmax dict to /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/min_max_scaling.json
# [INFO] Training 8 nodes (sequential) on cpu
#
# [INFO] Training node 'x1' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# [INFO] Training node 'x2' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# [INFO] Training node 'x3' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# [INFO] Training node 't1' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# [INFO] Training node 't2' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# [INFO] Training node 'x5' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# [INFO] Training node 'x6' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# [INFO] Training node 'y' for 1500 epochs on cpu (pid=396303)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# ===== Epoch 1468/1500 =====
# [INFO] Saved linear shift weights for epoch 1468 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1468 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1468: Train NLL=1.5451 | Val NLL=1.4702 | Time=0.79s
#
# ===== Epoch 1469/1500 =====
# [INFO] Saved linear shift weights for epoch 1469 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1469 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1469: Train NLL=1.4742 | Val NLL=1.4424 | Time=0.80s
#
# ===== Epoch 1470/1500 =====
# [INFO] Saved linear shift weights for epoch 1470 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1470 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1470: Train NLL=1.4541 | Val NLL=1.4332 | Time=0.53s
#
# ===== Epoch 1471/1500 =====
# [INFO] Saved linear shift weights for epoch 1471 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1471 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1471: Train NLL=1.4521 | Val NLL=1.4364 | Time=0.45s
#
# ===== Epoch 1472/1500 =====
# [INFO] Saved linear shift weights for epoch 1472 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1472 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1472: Train NLL=1.4496 | Val NLL=1.4247 | Time=0.81s
#
# ===== Epoch 1473/1500 =====
# [INFO] Saved linear shift weights for epoch 1473 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1473 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 1473: Train NLL=1.4492 | Val NLL=1.4234 | Time=1.10s
#
# ===== Epoch 1474/1500 =====
# [INFO] Saved linear shift weights for epoch 1474 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1474 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1474: Train NLL=1.4498 | Val NLL=1.4277 | Time=0.46s
#
# ===== Epoch 1475/1500 =====
# [INFO] Saved linear shift weights for epoch 1475 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1475 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1475: Train NLL=1.4502 | Val NLL=1.4263 | Time=0.51s
#
# ===== Epoch 1476/1500 =====
# [INFO] Saved linear shift weights for epoch 1476 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1476 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1476: Train NLL=1.4499 | Val NLL=1.4284 | Time=0.46s
#
# ===== Epoch 1477/1500 =====
# [INFO] Saved linear shift weights for epoch 1477 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1477 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 1477: Train NLL=1.4475 | Val NLL=1.4224 | Time=0.72s
#
# ===== Epoch 1478/1500 =====
# [INFO] Saved linear shift weights for epoch 1478 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1478 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1478: Train NLL=1.4461 | Val NLL=1.4279 | Time=0.51s
#
# ===== Epoch 1479/1500 =====
# [INFO] Saved linear shift weights for epoch 1479 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1479 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1479: Train NLL=1.4487 | Val NLL=1.4309 | Time=0.50s
#
# ===== Epoch 1480/1500 =====
# [INFO] Saved linear shift weights for epoch 1480 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1480 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1480: Train NLL=1.4477 | Val NLL=1.4260 | Time=0.67s
#
# ===== Epoch 1481/1500 =====
# [INFO] Saved linear shift weights for epoch 1481 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1481 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1481: Train NLL=1.4474 | Val NLL=1.4320 | Time=0.48s
#
# ===== Epoch 1482/1500 =====
# [INFO] Saved linear shift weights for epoch 1482 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1482 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1482: Train NLL=1.4486 | Val NLL=1.4255 | Time=0.43s
#
# ===== Epoch 1483/1500 =====
# [INFO] Saved linear shift weights for epoch 1483 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1483 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1483: Train NLL=1.4485 | Val NLL=1.4445 | Time=0.91s
#
# ===== Epoch 1484/1500 =====
# [INFO] Saved linear shift weights for epoch 1484 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1484 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1484: Train NLL=1.4506 | Val NLL=1.4260 | Time=0.70s
#
# ===== Epoch 1485/1500 =====
# [INFO] Saved linear shift weights for epoch 1485 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1485 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1485: Train NLL=1.4494 | Val NLL=1.4311 | Time=0.48s
#
# ===== Epoch 1486/1500 =====
# [INFO] Saved linear shift weights for epoch 1486 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1486 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1486: Train NLL=1.4480 | Val NLL=1.4242 | Time=0.54s
#
# ===== Epoch 1487/1500 =====
# [INFO] Saved linear shift weights for epoch 1487 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1487 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1487: Train NLL=1.4481 | Val NLL=1.4278 | Time=0.44s
#
# ===== Epoch 1488/1500 =====
# [INFO] Saved linear shift weights for epoch 1488 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1488 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1488: Train NLL=1.4470 | Val NLL=1.4442 | Time=0.71s
#
# ===== Epoch 1489/1500 =====
# [INFO] Saved linear shift weights for epoch 1489 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1489 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1489: Train NLL=1.4541 | Val NLL=1.4277 | Time=0.48s
#
# ===== Epoch 1490/1500 =====
# [INFO] Saved linear shift weights for epoch 1490 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1490 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1490: Train NLL=1.4483 | Val NLL=1.4286 | Time=0.49s
#
# ===== Epoch 1491/1500 =====
# [INFO] Saved linear shift weights for epoch 1491 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1491 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1491: Train NLL=1.4476 | Val NLL=1.4254 | Time=0.51s
#
# ===== Epoch 1492/1500 =====
# [INFO] Saved linear shift weights for epoch 1492 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1492 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1492: Train NLL=1.4474 | Val NLL=1.4267 | Time=0.70s
#
# ===== Epoch 1493/1500 =====
# [INFO] Saved linear shift weights for epoch 1493 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1493 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1493: Train NLL=1.4473 | Val NLL=1.4330 | Time=0.60s
#
# ===== Epoch 1494/1500 =====
# [INFO] Saved linear shift weights for epoch 1494 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1494 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1494: Train NLL=1.4472 | Val NLL=1.4235 | Time=0.72s
#
# ===== Epoch 1495/1500 =====
# [INFO] Saved linear shift weights for epoch 1495 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1495 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1495: Train NLL=1.4463 | Val NLL=1.4341 | Time=0.73s
#
# ===== Epoch 1496/1500 =====
# [INFO] Saved linear shift weights for epoch 1496 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1496 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1496: Train NLL=1.4487 | Val NLL=1.4308 | Time=0.46s
#
# ===== Epoch 1497/1500 =====
# [INFO] Saved linear shift weights for epoch 1497 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1497 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1497: Train NLL=1.4492 | Val NLL=1.4283 | Time=0.49s
#
# ===== Epoch 1498/1500 =====
# [INFO] Saved linear shift weights for epoch 1498 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1498 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1498: Train NLL=1.4476 | Val NLL=1.4263 | Time=0.42s
#
# ===== Epoch 1499/1500 =====
# [INFO] Saved linear shift weights for epoch 1499 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1499 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1499: Train NLL=1.4481 | Val NLL=1.4248 | Time=0.70s
#
# ===== Epoch 1500/1500 =====
# [INFO] Saved linear shift weights for epoch 1500 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 1500 -> /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/simple_intercepts_all_epochs.json
# [INFO] Epoch 1500: Train NLL=1.4467 | Val NLL=1.4294 | Time=0.48s

# %%
samples, latents = td_model.sample(debug=False)#,do_interventions ={'x1':1.0,'t1':1.0,'t2':1.0})
# Out:
# [INFO] Starting full DAG sampling with 10000 samples per node.
# [INFO] Deleting all previously sampled data.
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x1/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x2/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x3/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t1/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t2/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x5/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x6/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x1 from standard logistic distribution
# [INFO] Loaded best model weights for node 'x1' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x1/best_model.pt
# [WARNING] target_col 'x1' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 41.89it/s]
# [INFO] Completed sampling for node 'x1'
#
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x2 from standard logistic distribution
# [INFO] Loaded best model weights for node 'x2' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x2/best_model.pt
# [WARNING] target_col 'x2' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 43.68it/s]
# [INFO] Completed sampling for node 'x2'
#
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x3 from standard logistic distribution
# [INFO] Loaded best model weights for node 'x3' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x3/best_model.pt
# [WARNING] target_col 'x3' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 43.84it/s]
# [INFO] Completed sampling for node 'x3'
#
# ----*----------*-------------*--------Sample Node: t1 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node t1 from standard logistic distribution
# [INFO] Loaded best model weights for node 't1' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t1/best_model.pt
# [WARNING] target_col 't1' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Completed sampling for node 't1'
#
# ----*----------*-------------*--------Sample Node: t2 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node t2 from standard logistic distribution
# [INFO] Loaded best model weights for node 't2' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t2/best_model.pt
# [WARNING] target_col 't2' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Completed sampling for node 't2'
#
# ----*----------*-------------*--------Sample Node: x5 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x5 from standard logistic distribution
# [INFO] Loaded best model weights for node 'x5' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x5/best_model.pt
# [WARNING] target_col 'x5' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 44.54it/s]
# [INFO] Completed sampling for node 'x5'
#
# ----*----------*-------------*--------Sample Node: x6 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x6 from standard logistic distribution
# [INFO] Loaded best model weights for node 'x6' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x6/best_model.pt
# [WARNING] target_col 'x6' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 42.20it/s]
# [INFO] Completed sampling for node 'x6'
#
# ----*----------*-------------*--------Sample Node: y ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node y from standard logistic distribution
# [INFO] Loaded best model weights for node 'y' from /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/y/best_model.pt
# [WARNING] target_col 'y' not in DataFrame columns — is this intended to be used as a Sampler?
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 43.26it/s]
# [INFO] Completed sampling for node 'y'
# [INFO] DAG sampling completed successfully for all nodes.

# %%
td_model.plot_shift_histories()
# Out:
# [WARNING] No linear shift history found for node 'x1' at /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x1/linear_shifts_all_epochs.json
# [WARNING] No linear shift history found for node 'x2' at /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x2/linear_shifts_all_epochs.json
# [WARNING] No linear shift history found for node 'x3' at /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/x3/linear_shifts_all_epochs.json
# [WARNING] No linear shift history found for node 't1' at /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t1/linear_shifts_all_epochs.json
# [WARNING] No linear shift history found for node 't2' at /home/bule/TramDag/dev_experiment_logs/ordinal_vars_mike/t2/linear_shifts_all_epochs.json
# /home/bule/TramDag/utils/tramdag.py:1595: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(

# %%
td_model.plot_simple_intercepts()
# Out:
# /home/bule/TramDag/utils/tramdag.py:1652: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(extract_scalar)

# %%
td_model.show_samples_vs_true(train_df)
