# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "continous_3vars_1"   ## <--- set experiment name
seed=42
DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
#
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df

# %%
EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")

if not os.path.exists(EXP_DATA_PATH):
    print(f"Generating data for {experiment_name}...")
    # Config
    n_samples = 1_000
    n_features = 3
    rng = np.random.default_rng(seed=42)

    # Define different distributions
    distributions = [
        # lambda n: rng.normal(loc=0, scale=1, size=n),         # standard normal
        # lambda n: rng.uniform(low=0, high=1, size=n),          # uniform [0,1]
        # lambda n: rng.exponential(scale=1.0, size=n),          # exponential
        # lambda n: rng.gamma(shape=2.0, scale=1.0, size=n),     # gamma
        lambda n: rng.beta(a=2.0, b=5.0, size=n),              # beta
        lambda n: rng.lognormal(mean=0.0, sigma=1.0, size=n),  # log-normal
        lambda n: rng.chisquare(df=2, size=n),                 # chi-squared
        lambda n: rng.triangular(left=0.0, mode=0.5, right=1.0, size=n), # triangular
        lambda n: rng.weibull(a=2.0, size=n),                  # weibull
        lambda n: rng.pareto(a=2.5, size=n),                   # pareto
    ]
    # Create features
    X = np.column_stack([dist(n_samples) for dist in distributions[:n_features]])
    # Wrap in DataFrame
    feature_names = [f'x{i}' for i in range(1,n_features+1)]
    df = pd.DataFrame(X, columns=feature_names)
    
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")

# Get min_vals and max_vals as torch tensors
quantiles = df.quantile([0.05, 0.95])
min_vals = quantiles.loc[0.05].values.astype(np.float32)
max_vals = quantiles.loc[0.95].values.astype(np.float32)
sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Generating data for continous_3vars_1...

# %% [markdown]
# ### train test split

# %%
# train
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
# Validation and test
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 800, Validation size: 100, Test size: 100

# %% [markdown]
# # 4. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous , images , ordinal
adj_matrix = np.array([
    [ "0", "ci", "ci"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "cs"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)


# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 5. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
plot_nn_names_matrix(nn_names_matrix,data_type)
# Out:
# *************
#  Model has Complex intercepts and Coomplex shifts , please add your Model to the modelzoo
# ************

# %% [markdown]
# - add custom models for the ci or cs

# %%
# TODO: fucniton to automate
# if different models should be used, defin model in utils.models 
# e.g ComplexInterceptCUSTOMImage # any possible eg VITS

# rename the modelnames in the nn_names_matrix
# e.g.nn_names_matrix[2,3]='ComplexInterceptCUSTOMImage'

# %% [markdown]
# - model configurations

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/continous_3vars_1/continous_3vars_1_conf.json
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.07071796804666519,
#   'max': 0.5724170804023743},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ci'},
#   'transformation_term_nn_models_in_h()': {'x1': 'ComplexInterceptDefaultTabular'},
#   'min': 0.187801331281662,
#   'max': 5.138251304626465},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ci', 'x2': 'cs'},
#   'transformation_term_nn_models_in_h()': {'x1': 'ComplexInterceptDefaultTabular',
#    'x2': 'ComplexShiftDefaultTabular'},
#   'min': 0.08642906695604324,
#   'max': 6.093839645385742}}

# %% [markdown]
# ## 6. Fit models
#
# - each model independently fitting

# %%
DEV_TRAINING=True
train_list=['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required

batch_size = 512 
epochs = 1000    # <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
use_scheduler = True

# %%
# For each NODE 
for node in conf_dict:
    # Skip if node is not in train_list
    if node not in train_list:
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')

    # Skip unsupported types
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):
        continue

    ########################## 1. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True)
    tram_model = tram_model.to(device)

    ########################## 2. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=32, verbose=True)

    ########################## 3. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)

    model_path = os.path.join(NODE_DIR, "best_model.pt")
    last_model_path = os.path.join(NODE_DIR, "last_model.pt")
    train_hist_path = os.path.join(NODE_DIR, "train_loss_hist.json")
    val_hist_path = os.path.join(NODE_DIR, "val_loss_hist.json")

    ########################## 4. Load Model & History ######################
    if os.path.exists(model_path) and os.path.exists(train_hist_path) and os.path.exists(val_hist_path):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(model_path))

        with open(train_hist_path, 'r') as f:
            train_loss_hist = json.load(f)
        with open(val_hist_path, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist = []
        val_loss_hist = []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################
    optimizer = torch.optim.Adam(tram_model.parameters(), lr=0.001, eps=1e-7, weight_decay=0.0)

    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=40)

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################
    if DEV_TRAINING:
        for epoch in range(start_epoch, epochs):
            #### Training
            train_loss = 0.0
            tram_model.train()
            if use_scheduler:
                scheduler.step()

            for x, y in train_loader:
                optimizer.zero_grad()
            
                y = y.to(device)
                
                
                int_input, shift_list = preprocess_inputs(x, device=device)
                # print(f"train int_input: {int_input}")
                # print(f"train shift_list: {shift_list}")
                y_pred = tram_model(int_input=int_input,shift_input=shift_list)
                
                loss = contram_nll(y_pred, y, min_max=min_max)
                loss.backward()
                optimizer.step()
                train_loss += loss.item()

            avg_train_loss = train_loss / len(train_loader)
            train_loss_hist.append(avg_train_loss)

            #### Validation
            val_loss = 0.0
            tram_model.eval()
            with torch.no_grad():
                for x, y in val_loader:
                    
                    y = y.to(device)

                    int_input, shift_list = preprocess_inputs(x, device=device)
                    # print(f"train int_input: {int_input}")
                    # print(f"train shift_list: {shift_list}")
                    y_pred = tram_model(int_input=int_input,shift_input=shift_list)
                    loss = contram_nll(y_pred, y, min_max=min_max)
                    val_loss += loss.item()

            avg_val_loss = val_loss / len(val_loader)
            val_loss_hist.append(avg_val_loss)

            print(f"Epoch {epoch+1}/{epochs}, Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}")

            #### Save Best Model
            if avg_val_loss < best_val_loss:
                best_val_loss = avg_val_loss
                torch.save(tram_model.state_dict(), model_path)
                print("Saved new best model.")

            #### Save Last Model
            torch.save(tram_model.state_dict(), last_model_path)

            #### Save Loss History
            with open(train_hist_path, 'w') as f:
                json.dump(train_loss_hist, f)
            with open(val_hist_path, 'w') as f:
                json.dump(val_loss_hist, f)
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 600...
# /home/bule/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/optim/lr_scheduler.py:227: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 601/1000, Train Loss: -0.2545, Val Loss: -0.2548
# Saved new best model.
# Epoch 602/1000, Train Loss: -0.2551, Val Loss: -0.2553
# Saved new best model.
# Epoch 603/1000, Train Loss: -0.2555, Val Loss: -0.2558
# Saved new best model.
# Epoch 604/1000, Train Loss: -0.2560, Val Loss: -0.2563
# Saved new best model.
# Epoch 605/1000, Train Loss: -0.2565, Val Loss: -0.2567
# Saved new best model.
# Epoch 606/1000, Train Loss: -0.2569, Val Loss: -0.2572
# Saved new best model.
# Epoch 607/1000, Train Loss: -0.2574, Val Loss: -0.2576
# Saved new best model.
# Epoch 608/1000, Train Loss: -0.2578, Val Loss: -0.2581
# Saved new best model.
# Epoch 609/1000, Train Loss: -0.2583, Val Loss: -0.2585
# Saved new best model.
# Epoch 610/1000, Train Loss: -0.2587, Val Loss: -0.2589
# Saved new best model.
# Epoch 611/1000, Train Loss: -0.2591, Val Loss: -0.2593
# Saved new best model.
# Epoch 612/1000, Train Loss: -0.2594, Val Loss: -0.2596
# Saved new best model.
# Epoch 613/1000, Train Loss: -0.2598, Val Loss: -0.2600
# Saved new best model.
# Epoch 614/1000, Train Loss: -0.2601, Val Loss: -0.2603
# Saved new best model.
# Epoch 615/1000, Train Loss: -0.2605, Val Loss: -0.2607
# Saved new best model.
# Epoch 616/1000, Train Loss: -0.2608, Val Loss: -0.2610
# Saved new best model.
# Epoch 617/1000, Train Loss: -0.2611, Val Loss: -0.2613
# Saved new best model.
# Epoch 618/1000, Train Loss: -0.2614, Val Loss: -0.2615
# Saved new best model.
# Epoch 619/1000, Train Loss: -0.2616, Val Loss: -0.2618
# Saved new best model.
# Epoch 620/1000, Train Loss: -0.2618, Val Loss: -0.2620
# Saved new best model.
# Epoch 621/1000, Train Loss: -0.2621, Val Loss: -0.2622
# Saved new best model.
# Epoch 622/1000, Train Loss: -0.2623, Val Loss: -0.2624
# Saved new best model.
# Epoch 623/1000, Train Loss: -0.2625, Val Loss: -0.2626
# Saved new best model.
# Epoch 624/1000, Train Loss: -0.2626, Val Loss: -0.2627
# Saved new best model.
# Epoch 625/1000, Train Loss: -0.2628, Val Loss: -0.2629
# Saved new best model.
# Epoch 626/1000, Train Loss: -0.2629, Val Loss: -0.2630
# Saved new best model.
# Epoch 627/1000, Train Loss: -0.2630, Val Loss: -0.2631
# Saved new best model.
# Epoch 628/1000, Train Loss: -0.2631, Val Loss: -0.2632
# Saved new best model.
# Epoch 629/1000, Train Loss: -0.2632, Val Loss: -0.2633
# Saved new best model.
# Epoch 630/1000, Train Loss: -0.2633, Val Loss: -0.2633
# Saved new best model.
# Epoch 631/1000, Train Loss: -0.2634, Val Loss: -0.2634
# Saved new best model.
# Epoch 632/1000, Train Loss: -0.2634, Val Loss: -0.2634
# Saved new best model.
# Epoch 633/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 634/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 635/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 636/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 637/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 638/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 639/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 640/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Epoch 641/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 642/1000, Train Loss: -0.2635, Val Loss: -0.2635
# Saved new best model.
# Epoch 643/1000, Train Loss: -0.2635, Val Loss: -0.2636
# Saved new best model.
# Epoch 644/1000, Train Loss: -0.2636, Val Loss: -0.2636
# Saved new best model.
# Epoch 645/1000, Train Loss: -0.2636, Val Loss: -0.2636
# Saved new best model.
# Epoch 646/1000, Train Loss: -0.2636, Val Loss: -0.2636
# Saved new best model.
# Epoch 647/1000, Train Loss: -0.2636, Val Loss: -0.2636
# Saved new best model.
# Epoch 648/1000, Train Loss: -0.2637, Val Loss: -0.2637
# Saved new best model.
# Epoch 649/1000, Train Loss: -0.2637, Val Loss: -0.2637
# Saved new best model.
# Epoch 650/1000, Train Loss: -0.2638, Val Loss: -0.2638
# Saved new best model.
# Epoch 651/1000, Train Loss: -0.2638, Val Loss: -0.2639
# Saved new best model.
# Epoch 652/1000, Train Loss: -0.2639, Val Loss: -0.2640
# Saved new best model.
# Epoch 653/1000, Train Loss: -0.2640, Val Loss: -0.2641
# Saved new best model.
# Epoch 654/1000, Train Loss: -0.2641, Val Loss: -0.2642
# Saved new best model.
# Epoch 655/1000, Train Loss: -0.2643, Val Loss: -0.2643
# Saved new best model.
# Epoch 656/1000, Train Loss: -0.2644, Val Loss: -0.2645
# Saved new best model.
# Epoch 657/1000, Train Loss: -0.2646, Val Loss: -0.2647
# Saved new best model.
# Epoch 658/1000, Train Loss: -0.2648, Val Loss: -0.2649
# Saved new best model.
# Epoch 659/1000, Train Loss: -0.2650, Val Loss: -0.2651
# Saved new best model.
# Epoch 660/1000, Train Loss: -0.2652, Val Loss: -0.2653
# Saved new best model.
# Epoch 661/1000, Train Loss: -0.2654, Val Loss: -0.2655
# Saved new best model.
# Epoch 662/1000, Train Loss: -0.2656, Val Loss: -0.2658
# Saved new best model.
# Epoch 663/1000, Train Loss: -0.2659, Val Loss: -0.2661
# Saved new best model.
# Epoch 664/1000, Train Loss: -0.2662, Val Loss: -0.2664
# Saved new best model.
# Epoch 665/1000, Train Loss: -0.2665, Val Loss: -0.2667
# Saved new best model.
# Epoch 666/1000, Train Loss: -0.2668, Val Loss: -0.2670
# Saved new best model.
# Epoch 667/1000, Train Loss: -0.2671, Val Loss: -0.2673
# Saved new best model.
# Epoch 668/1000, Train Loss: -0.2675, Val Loss: -0.2677
# Saved new best model.
# Epoch 669/1000, Train Loss: -0.2678, Val Loss: -0.2680
# Saved new best model.
# Epoch 670/1000, Train Loss: -0.2682, Val Loss: -0.2684
# Saved new best model.
# Epoch 671/1000, Train Loss: -0.2686, Val Loss: -0.2688
# Saved new best model.
# Epoch 672/1000, Train Loss: -0.2690, Val Loss: -0.2692
# Saved new best model.
# Epoch 673/1000, Train Loss: -0.2694, Val Loss: -0.2696
# Saved new best model.
# Epoch 674/1000, Train Loss: -0.2698, Val Loss: -0.2700
# Saved new best model.
# Epoch 675/1000, Train Loss: -0.2702, Val Loss: -0.2704
# Saved new best model.
# Epoch 676/1000, Train Loss: -0.2706, Val Loss: -0.2708
# Saved new best model.
# Epoch 677/1000, Train Loss: -0.2710, Val Loss: -0.2713
# Saved new best model.
# Epoch 678/1000, Train Loss: -0.2714, Val Loss: -0.2717
# Saved new best model.
# Epoch 679/1000, Train Loss: -0.2719, Val Loss: -0.2721
# Saved new best model.
# Epoch 680/1000, Train Loss: -0.2723, Val Loss: -0.2725
# Saved new best model.
# Epoch 681/1000, Train Loss: -0.2727, Val Loss: -0.2730
# Saved new best model.
# Epoch 682/1000, Train Loss: -0.2731, Val Loss: -0.2734
# Saved new best model.
# Epoch 683/1000, Train Loss: -0.2736, Val Loss: -0.2738
# Saved new best model.
# Epoch 684/1000, Train Loss: -0.2740, Val Loss: -0.2742
# Saved new best model.
# Epoch 685/1000, Train Loss: -0.2744, Val Loss: -0.2746
# Saved new best model.
# Epoch 686/1000, Train Loss: -0.2748, Val Loss: -0.2750
# Saved new best model.
# Epoch 687/1000, Train Loss: -0.2751, Val Loss: -0.2754
# Saved new best model.
# Epoch 688/1000, Train Loss: -0.2755, Val Loss: -0.2757
# Saved new best model.
# Epoch 689/1000, Train Loss: -0.2759, Val Loss: -0.2761
# Saved new best model.
# Epoch 690/1000, Train Loss: -0.2763, Val Loss: -0.2765
# Saved new best model.
# Epoch 691/1000, Train Loss: -0.2766, Val Loss: -0.2768
# Saved new best model.
# Epoch 692/1000, Train Loss: -0.2769, Val Loss: -0.2771
# Saved new best model.
# Epoch 693/1000, Train Loss: -0.2773, Val Loss: -0.2774
# Saved new best model.
# Epoch 694/1000, Train Loss: -0.2776, Val Loss: -0.2777
# Saved new best model.
# Epoch 695/1000, Train Loss: -0.2778, Val Loss: -0.2780
# Saved new best model.
# Epoch 696/1000, Train Loss: -0.2781, Val Loss: -0.2783
# Saved new best model.
# Epoch 697/1000, Train Loss: -0.2784, Val Loss: -0.2785
# Saved new best model.
# Epoch 698/1000, Train Loss: -0.2786, Val Loss: -0.2788
# Saved new best model.
# Epoch 699/1000, Train Loss: -0.2788, Val Loss: -0.2790
# Saved new best model.
# Epoch 700/1000, Train Loss: -0.2791, Val Loss: -0.2792
# Saved new best model.
# Epoch 701/1000, Train Loss: -0.2793, Val Loss: -0.2794
# Saved new best model.
# Epoch 702/1000, Train Loss: -0.2794, Val Loss: -0.2795
# Saved new best model.
# Epoch 703/1000, Train Loss: -0.2796, Val Loss: -0.2797
# Saved new best model.
# Epoch 704/1000, Train Loss: -0.2797, Val Loss: -0.2798
# Saved new best model.
# Epoch 705/1000, Train Loss: -0.2799, Val Loss: -0.2799
# Saved new best model.
# Epoch 706/1000, Train Loss: -0.2800, Val Loss: -0.2801
# Saved new best model.
# Epoch 707/1000, Train Loss: -0.2801, Val Loss: -0.2802
# Saved new best model.
# Epoch 708/1000, Train Loss: -0.2802, Val Loss: -0.2802
# Saved new best model.
# Epoch 709/1000, Train Loss: -0.2803, Val Loss: -0.2803
# Saved new best model.
# Epoch 710/1000, Train Loss: -0.2803, Val Loss: -0.2804
# Saved new best model.
# Epoch 711/1000, Train Loss: -0.2804, Val Loss: -0.2804
# Saved new best model.
# Epoch 712/1000, Train Loss: -0.2804, Val Loss: -0.2804
# Saved new best model.
# Epoch 713/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 714/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 715/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 716/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 717/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 718/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 719/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 720/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Epoch 721/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 722/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 723/1000, Train Loss: -0.2805, Val Loss: -0.2805
# Saved new best model.
# Epoch 724/1000, Train Loss: -0.2805, Val Loss: -0.2806
# Saved new best model.
# Epoch 725/1000, Train Loss: -0.2806, Val Loss: -0.2806
# Saved new best model.
# Epoch 726/1000, Train Loss: -0.2806, Val Loss: -0.2806
# Saved new best model.
# Epoch 727/1000, Train Loss: -0.2806, Val Loss: -0.2806
# Saved new best model.
# Epoch 728/1000, Train Loss: -0.2806, Val Loss: -0.2807
# Saved new best model.
# Epoch 729/1000, Train Loss: -0.2807, Val Loss: -0.2807
# Saved new best model.
# Epoch 730/1000, Train Loss: -0.2807, Val Loss: -0.2808
# Saved new best model.
# Epoch 731/1000, Train Loss: -0.2808, Val Loss: -0.2808
# Saved new best model.
# Epoch 732/1000, Train Loss: -0.2809, Val Loss: -0.2809
# Saved new best model.
# Epoch 733/1000, Train Loss: -0.2810, Val Loss: -0.2810
# Saved new best model.
# Epoch 734/1000, Train Loss: -0.2811, Val Loss: -0.2811
# Saved new best model.
# Epoch 735/1000, Train Loss: -0.2812, Val Loss: -0.2812
# Saved new best model.
# Epoch 736/1000, Train Loss: -0.2813, Val Loss: -0.2814
# Saved new best model.
# Epoch 737/1000, Train Loss: -0.2814, Val Loss: -0.2815
# Saved new best model.
# Epoch 738/1000, Train Loss: -0.2816, Val Loss: -0.2817
# Saved new best model.
# Epoch 739/1000, Train Loss: -0.2818, Val Loss: -0.2819
# Saved new best model.
# Epoch 740/1000, Train Loss: -0.2820, Val Loss: -0.2821
# Saved new best model.
# Epoch 741/1000, Train Loss: -0.2822, Val Loss: -0.2823
# Saved new best model.
# Epoch 742/1000, Train Loss: -0.2824, Val Loss: -0.2825
# Saved new best model.
# Epoch 743/1000, Train Loss: -0.2826, Val Loss: -0.2828
# Saved new best model.
# Epoch 744/1000, Train Loss: -0.2829, Val Loss: -0.2830
# Saved new best model.
# Epoch 745/1000, Train Loss: -0.2832, Val Loss: -0.2833
# Saved new best model.
# Epoch 746/1000, Train Loss: -0.2834, Val Loss: -0.2836
# Saved new best model.
# Epoch 747/1000, Train Loss: -0.2837, Val Loss: -0.2839
# Saved new best model.
# Epoch 748/1000, Train Loss: -0.2840, Val Loss: -0.2842
# Saved new best model.
# Epoch 749/1000, Train Loss: -0.2843, Val Loss: -0.2845
# Saved new best model.
# Epoch 750/1000, Train Loss: -0.2846, Val Loss: -0.2849
# Saved new best model.
# Epoch 751/1000, Train Loss: -0.2850, Val Loss: -0.2852
# Saved new best model.
# Epoch 752/1000, Train Loss: -0.2854, Val Loss: -0.2856
# Saved new best model.
# Epoch 753/1000, Train Loss: -0.2857, Val Loss: -0.2859
# Saved new best model.
# Epoch 754/1000, Train Loss: -0.2861, Val Loss: -0.2863
# Saved new best model.
# Epoch 755/1000, Train Loss: -0.2864, Val Loss: -0.2867
# Saved new best model.
# Epoch 756/1000, Train Loss: -0.2868, Val Loss: -0.2870
# Saved new best model.
# Epoch 757/1000, Train Loss: -0.2872, Val Loss: -0.2874
# Saved new best model.
# Epoch 758/1000, Train Loss: -0.2876, Val Loss: -0.2878
# Saved new best model.
# Epoch 759/1000, Train Loss: -0.2880, Val Loss: -0.2882
# Saved new best model.
# Epoch 760/1000, Train Loss: -0.2883, Val Loss: -0.2885
# Saved new best model.
# Epoch 761/1000, Train Loss: -0.2887, Val Loss: -0.2889
# Saved new best model.
# Epoch 762/1000, Train Loss: -0.2891, Val Loss: -0.2893
# Saved new best model.
# Epoch 763/1000, Train Loss: -0.2895, Val Loss: -0.2897
# Saved new best model.
# Epoch 764/1000, Train Loss: -0.2898, Val Loss: -0.2900
# Saved new best model.
# Epoch 765/1000, Train Loss: -0.2902, Val Loss: -0.2904
# Saved new best model.
# Epoch 766/1000, Train Loss: -0.2906, Val Loss: -0.2908
# Saved new best model.
# Epoch 767/1000, Train Loss: -0.2909, Val Loss: -0.2911
# Saved new best model.
# Epoch 768/1000, Train Loss: -0.2912, Val Loss: -0.2915
# Saved new best model.
# Epoch 769/1000, Train Loss: -0.2916, Val Loss: -0.2918
# Saved new best model.
# Epoch 770/1000, Train Loss: -0.2919, Val Loss: -0.2921
# Saved new best model.
# Epoch 771/1000, Train Loss: -0.2922, Val Loss: -0.2924
# Saved new best model.
# Epoch 772/1000, Train Loss: -0.2925, Val Loss: -0.2927
# Saved new best model.
# Epoch 773/1000, Train Loss: -0.2928, Val Loss: -0.2930
# Saved new best model.
# Epoch 774/1000, Train Loss: -0.2931, Val Loss: -0.2933
# Saved new best model.
# Epoch 775/1000, Train Loss: -0.2933, Val Loss: -0.2935
# Saved new best model.
# Epoch 776/1000, Train Loss: -0.2936, Val Loss: -0.2937
# Saved new best model.
# Epoch 777/1000, Train Loss: -0.2938, Val Loss: -0.2940
# Saved new best model.
# Epoch 778/1000, Train Loss: -0.2941, Val Loss: -0.2942
# Saved new best model.
# Epoch 779/1000, Train Loss: -0.2943, Val Loss: -0.2944
# Saved new best model.
# Epoch 780/1000, Train Loss: -0.2945, Val Loss: -0.2946
# Saved new best model.
# Epoch 781/1000, Train Loss: -0.2946, Val Loss: -0.2947
# Saved new best model.
# Epoch 782/1000, Train Loss: -0.2948, Val Loss: -0.2949
# Saved new best model.
# Epoch 783/1000, Train Loss: -0.2950, Val Loss: -0.2950
# Saved new best model.
# Epoch 784/1000, Train Loss: -0.2951, Val Loss: -0.2952
# Saved new best model.
# Epoch 785/1000, Train Loss: -0.2952, Val Loss: -0.2953
# Saved new best model.
# Epoch 786/1000, Train Loss: -0.2953, Val Loss: -0.2954
# Saved new best model.
# Epoch 787/1000, Train Loss: -0.2954, Val Loss: -0.2955
# Saved new best model.
# Epoch 788/1000, Train Loss: -0.2955, Val Loss: -0.2955
# Saved new best model.
# Epoch 789/1000, Train Loss: -0.2956, Val Loss: -0.2956
# Saved new best model.
# Epoch 790/1000, Train Loss: -0.2956, Val Loss: -0.2957
# Saved new best model.
# Epoch 791/1000, Train Loss: -0.2957, Val Loss: -0.2957
# Saved new best model.
# Epoch 792/1000, Train Loss: -0.2957, Val Loss: -0.2957
# Saved new best model.
# Epoch 793/1000, Train Loss: -0.2957, Val Loss: -0.2958
# Saved new best model.
# Epoch 794/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 795/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 796/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 797/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 798/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 799/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 800/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Epoch 801/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 802/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 803/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 804/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 805/1000, Train Loss: -0.2958, Val Loss: -0.2958
# Saved new best model.
# Epoch 806/1000, Train Loss: -0.2958, Val Loss: -0.2959
# Saved new best model.
# Epoch 807/1000, Train Loss: -0.2959, Val Loss: -0.2959
# Saved new best model.
# Epoch 808/1000, Train Loss: -0.2959, Val Loss: -0.2959
# Saved new best model.
# Epoch 809/1000, Train Loss: -0.2959, Val Loss: -0.2960
# Saved new best model.
# Epoch 810/1000, Train Loss: -0.2960, Val Loss: -0.2960
# Saved new best model.
# Epoch 811/1000, Train Loss: -0.2960, Val Loss: -0.2961
# Saved new best model.
# Epoch 812/1000, Train Loss: -0.2961, Val Loss: -0.2962
# Saved new best model.
# Epoch 813/1000, Train Loss: -0.2962, Val Loss: -0.2962
# Saved new best model.
# Epoch 814/1000, Train Loss: -0.2963, Val Loss: -0.2963
# Saved new best model.
# Epoch 815/1000, Train Loss: -0.2964, Val Loss: -0.2965
# Saved new best model.
# Epoch 816/1000, Train Loss: -0.2965, Val Loss: -0.2966
# Saved new best model.
# Epoch 817/1000, Train Loss: -0.2966, Val Loss: -0.2967
# Saved new best model.
# Epoch 818/1000, Train Loss: -0.2968, Val Loss: -0.2969
# Saved new best model.
# Epoch 819/1000, Train Loss: -0.2970, Val Loss: -0.2971
# Saved new best model.
# Epoch 820/1000, Train Loss: -0.2971, Val Loss: -0.2972
# Saved new best model.
# Epoch 821/1000, Train Loss: -0.2973, Val Loss: -0.2974
# Saved new best model.
# Epoch 822/1000, Train Loss: -0.2975, Val Loss: -0.2976
# Saved new best model.
# Epoch 823/1000, Train Loss: -0.2977, Val Loss: -0.2979
# Saved new best model.
# Epoch 824/1000, Train Loss: -0.2980, Val Loss: -0.2981
# Saved new best model.
# Epoch 825/1000, Train Loss: -0.2982, Val Loss: -0.2984
# Saved new best model.
# Epoch 826/1000, Train Loss: -0.2985, Val Loss: -0.2986
# Saved new best model.
# Epoch 827/1000, Train Loss: -0.2987, Val Loss: -0.2989
# Saved new best model.
# Epoch 828/1000, Train Loss: -0.2990, Val Loss: -0.2992
# Saved new best model.
# Epoch 829/1000, Train Loss: -0.2993, Val Loss: -0.2995
# Saved new best model.
# Epoch 830/1000, Train Loss: -0.2996, Val Loss: -0.2998
# Saved new best model.
# Epoch 831/1000, Train Loss: -0.2999, Val Loss: -0.3001
# Saved new best model.
# Epoch 832/1000, Train Loss: -0.3003, Val Loss: -0.3004
# Saved new best model.
# Epoch 833/1000, Train Loss: -0.3006, Val Loss: -0.3008
# Saved new best model.
# Epoch 834/1000, Train Loss: -0.3009, Val Loss: -0.3011
# Saved new best model.
# Epoch 835/1000, Train Loss: -0.3012, Val Loss: -0.3014
# Saved new best model.
# Epoch 836/1000, Train Loss: -0.3016, Val Loss: -0.3018
# Saved new best model.
# Epoch 837/1000, Train Loss: -0.3019, Val Loss: -0.3021
# Saved new best model.
# Epoch 838/1000, Train Loss: -0.3023, Val Loss: -0.3025
# Saved new best model.
# Epoch 839/1000, Train Loss: -0.3027, Val Loss: -0.3028
# Saved new best model.
# Epoch 840/1000, Train Loss: -0.3030, Val Loss: -0.3032
# Saved new best model.
# Epoch 841/1000, Train Loss: -0.3034, Val Loss: -0.3036
# Saved new best model.
# Epoch 842/1000, Train Loss: -0.3037, Val Loss: -0.3039
# Saved new best model.
# Epoch 843/1000, Train Loss: -0.3040, Val Loss: -0.3042
# Saved new best model.
# Epoch 844/1000, Train Loss: -0.3044, Val Loss: -0.3046
# Saved new best model.
# Epoch 845/1000, Train Loss: -0.3047, Val Loss: -0.3049
# Saved new best model.
# Epoch 846/1000, Train Loss: -0.3051, Val Loss: -0.3053
# Saved new best model.
# Epoch 847/1000, Train Loss: -0.3054, Val Loss: -0.3056
# Saved new best model.
# Epoch 848/1000, Train Loss: -0.3057, Val Loss: -0.3059
# Saved new best model.
# Epoch 849/1000, Train Loss: -0.3060, Val Loss: -0.3062
# Saved new best model.
# Epoch 850/1000, Train Loss: -0.3063, Val Loss: -0.3065
# Saved new best model.
# Epoch 851/1000, Train Loss: -0.3066, Val Loss: -0.3068
# Saved new best model.
# Epoch 852/1000, Train Loss: -0.3069, Val Loss: -0.3071
# Saved new best model.
# Epoch 853/1000, Train Loss: -0.3072, Val Loss: -0.3073
# Saved new best model.
# Epoch 854/1000, Train Loss: -0.3074, Val Loss: -0.3076
# Saved new best model.
# Epoch 855/1000, Train Loss: -0.3077, Val Loss: -0.3078
# Saved new best model.
# Epoch 856/1000, Train Loss: -0.3079, Val Loss: -0.3080
# Saved new best model.
# Epoch 857/1000, Train Loss: -0.3081, Val Loss: -0.3083
# Saved new best model.
# Epoch 858/1000, Train Loss: -0.3083, Val Loss: -0.3085
# Saved new best model.
# Epoch 859/1000, Train Loss: -0.3085, Val Loss: -0.3086
# Saved new best model.
# Epoch 860/1000, Train Loss: -0.3087, Val Loss: -0.3088
# Saved new best model.
# Epoch 861/1000, Train Loss: -0.3089, Val Loss: -0.3090
# Saved new best model.
# Epoch 862/1000, Train Loss: -0.3090, Val Loss: -0.3091
# Saved new best model.
# Epoch 863/1000, Train Loss: -0.3092, Val Loss: -0.3092
# Saved new best model.
# Epoch 864/1000, Train Loss: -0.3093, Val Loss: -0.3094
# Saved new best model.
# Epoch 865/1000, Train Loss: -0.3094, Val Loss: -0.3095
# Saved new best model.
# Epoch 866/1000, Train Loss: -0.3095, Val Loss: -0.3096
# Saved new best model.
# Epoch 867/1000, Train Loss: -0.3096, Val Loss: -0.3096
# Saved new best model.
# Epoch 868/1000, Train Loss: -0.3097, Val Loss: -0.3097
# Saved new best model.
# Epoch 869/1000, Train Loss: -0.3097, Val Loss: -0.3098
# Saved new best model.
# Epoch 870/1000, Train Loss: -0.3098, Val Loss: -0.3098
# Saved new best model.
# Epoch 871/1000, Train Loss: -0.3098, Val Loss: -0.3099
# Saved new best model.
# Epoch 872/1000, Train Loss: -0.3099, Val Loss: -0.3099
# Saved new best model.
# Epoch 873/1000, Train Loss: -0.3099, Val Loss: -0.3099
# Saved new best model.
# Epoch 874/1000, Train Loss: -0.3099, Val Loss: -0.3099
# Saved new best model.
# Epoch 875/1000, Train Loss: -0.3099, Val Loss: -0.3099
# Saved new best model.
# Epoch 876/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 877/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 878/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 879/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 880/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Epoch 881/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 882/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 883/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 884/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 885/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 886/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 887/1000, Train Loss: -0.3100, Val Loss: -0.3100
# Saved new best model.
# Epoch 888/1000, Train Loss: -0.3101, Val Loss: -0.3101
# Saved new best model.
# Epoch 889/1000, Train Loss: -0.3101, Val Loss: -0.3101
# Saved new best model.
# Epoch 890/1000, Train Loss: -0.3101, Val Loss: -0.3102
# Saved new best model.
# Epoch 891/1000, Train Loss: -0.3102, Val Loss: -0.3102
# Saved new best model.
# Epoch 892/1000, Train Loss: -0.3102, Val Loss: -0.3103
# Saved new best model.
# Epoch 893/1000, Train Loss: -0.3103, Val Loss: -0.3104
# Saved new best model.
# Epoch 894/1000, Train Loss: -0.3104, Val Loss: -0.3105
# Saved new best model.
# Epoch 895/1000, Train Loss: -0.3105, Val Loss: -0.3106
# Saved new best model.
# Epoch 896/1000, Train Loss: -0.3106, Val Loss: -0.3107
# Saved new best model.
# Epoch 897/1000, Train Loss: -0.3107, Val Loss: -0.3108
# Saved new best model.
# Epoch 898/1000, Train Loss: -0.3109, Val Loss: -0.3110
# Saved new best model.
# Epoch 899/1000, Train Loss: -0.3110, Val Loss: -0.3111
# Saved new best model.
# Epoch 900/1000, Train Loss: -0.3112, Val Loss: -0.3113
# Saved new best model.
# Epoch 901/1000, Train Loss: -0.3114, Val Loss: -0.3115
# Saved new best model.
# Epoch 902/1000, Train Loss: -0.3116, Val Loss: -0.3117
# Saved new best model.
# Epoch 903/1000, Train Loss: -0.3118, Val Loss: -0.3119
# Saved new best model.
# Epoch 904/1000, Train Loss: -0.3120, Val Loss: -0.3121
# Saved new best model.
# Epoch 905/1000, Train Loss: -0.3122, Val Loss: -0.3123
# Saved new best model.
# Epoch 906/1000, Train Loss: -0.3125, Val Loss: -0.3126
# Saved new best model.
# Epoch 907/1000, Train Loss: -0.3127, Val Loss: -0.3129
# Saved new best model.
# Epoch 908/1000, Train Loss: -0.3130, Val Loss: -0.3131
# Saved new best model.
# Epoch 909/1000, Train Loss: -0.3132, Val Loss: -0.3134
# Saved new best model.
# Epoch 910/1000, Train Loss: -0.3135, Val Loss: -0.3137
# Saved new best model.
# Epoch 911/1000, Train Loss: -0.3138, Val Loss: -0.3140
# Saved new best model.
# Epoch 912/1000, Train Loss: -0.3141, Val Loss: -0.3143
# Saved new best model.
# Epoch 913/1000, Train Loss: -0.3144, Val Loss: -0.3146
# Saved new best model.
# Epoch 914/1000, Train Loss: -0.3147, Val Loss: -0.3149
# Saved new best model.
# Epoch 915/1000, Train Loss: -0.3150, Val Loss: -0.3152
# Saved new best model.
# Epoch 916/1000, Train Loss: -0.3154, Val Loss: -0.3156
# Saved new best model.
# Epoch 917/1000, Train Loss: -0.3157, Val Loss: -0.3159
# Saved new best model.
# Epoch 918/1000, Train Loss: -0.3160, Val Loss: -0.3162
# Saved new best model.
# Epoch 919/1000, Train Loss: -0.3164, Val Loss: -0.3166
# Saved new best model.
# Epoch 920/1000, Train Loss: -0.3167, Val Loss: -0.3169
# Saved new best model.
# Epoch 921/1000, Train Loss: -0.3170, Val Loss: -0.3172
# Saved new best model.
# Epoch 922/1000, Train Loss: -0.3174, Val Loss: -0.3176
# Saved new best model.
# Epoch 923/1000, Train Loss: -0.3177, Val Loss: -0.3179
# Saved new best model.
# Epoch 924/1000, Train Loss: -0.3180, Val Loss: -0.3182
# Saved new best model.
# Epoch 925/1000, Train Loss: -0.3183, Val Loss: -0.3185
# Saved new best model.
# Epoch 926/1000, Train Loss: -0.3187, Val Loss: -0.3188
# Saved new best model.
# Epoch 927/1000, Train Loss: -0.3190, Val Loss: -0.3191
# Saved new best model.
# Epoch 928/1000, Train Loss: -0.3193, Val Loss: -0.3194
# Saved new best model.
# Epoch 929/1000, Train Loss: -0.3196, Val Loss: -0.3197
# Saved new best model.
# Epoch 930/1000, Train Loss: -0.3198, Val Loss: -0.3200
# Saved new best model.
# Epoch 931/1000, Train Loss: -0.3201, Val Loss: -0.3203
# Saved new best model.
# Epoch 932/1000, Train Loss: -0.3204, Val Loss: -0.3205
# Saved new best model.
# Epoch 933/1000, Train Loss: -0.3206, Val Loss: -0.3208
# Saved new best model.
# Epoch 934/1000, Train Loss: -0.3209, Val Loss: -0.3210
# Saved new best model.
# Epoch 935/1000, Train Loss: -0.3211, Val Loss: -0.3212
# Saved new best model.
# Epoch 936/1000, Train Loss: -0.3213, Val Loss: -0.3214
# Saved new best model.
# Epoch 937/1000, Train Loss: -0.3215, Val Loss: -0.3216
# Saved new best model.
# Epoch 938/1000, Train Loss: -0.3217, Val Loss: -0.3218
# Saved new best model.
# Epoch 939/1000, Train Loss: -0.3219, Val Loss: -0.3220
# Saved new best model.
# Epoch 940/1000, Train Loss: -0.3221, Val Loss: -0.3222
# Saved new best model.
# Epoch 941/1000, Train Loss: -0.3222, Val Loss: -0.3223
# Saved new best model.
# Epoch 942/1000, Train Loss: -0.3224, Val Loss: -0.3224
# Saved new best model.
# Epoch 943/1000, Train Loss: -0.3225, Val Loss: -0.3226
# Saved new best model.
# Epoch 944/1000, Train Loss: -0.3226, Val Loss: -0.3227
# Saved new best model.
# Epoch 945/1000, Train Loss: -0.3227, Val Loss: -0.3228
# Saved new best model.
# Epoch 946/1000, Train Loss: -0.3228, Val Loss: -0.3229
# Saved new best model.
# Epoch 947/1000, Train Loss: -0.3229, Val Loss: -0.3229
# Saved new best model.
# Epoch 948/1000, Train Loss: -0.3230, Val Loss: -0.3230
# Saved new best model.
# Epoch 949/1000, Train Loss: -0.3230, Val Loss: -0.3231
# Saved new best model.
# Epoch 950/1000, Train Loss: -0.3231, Val Loss: -0.3231
# Saved new best model.
# Epoch 951/1000, Train Loss: -0.3231, Val Loss: -0.3232
# Saved new best model.
# Epoch 952/1000, Train Loss: -0.3232, Val Loss: -0.3232
# Saved new best model.
# Epoch 953/1000, Train Loss: -0.3232, Val Loss: -0.3232
# Saved new best model.
# Epoch 954/1000, Train Loss: -0.3232, Val Loss: -0.3232
# Saved new best model.
# Epoch 955/1000, Train Loss: -0.3232, Val Loss: -0.3232
# Saved new best model.
# Epoch 956/1000, Train Loss: -0.3232, Val Loss: -0.3232
# Saved new best model.
# Epoch 957/1000, Train Loss: -0.3232, Val Loss: -0.3233
# Saved new best model.
# Epoch 958/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 959/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 960/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Epoch 961/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 962/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 963/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 964/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 965/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 966/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 967/1000, Train Loss: -0.3233, Val Loss: -0.3233
# Saved new best model.
# Epoch 968/1000, Train Loss: -0.3233, Val Loss: -0.3234
# Saved new best model.
# Epoch 969/1000, Train Loss: -0.3234, Val Loss: -0.3234
# Saved new best model.
# Epoch 970/1000, Train Loss: -0.3234, Val Loss: -0.3234
# Saved new best model.
# Epoch 971/1000, Train Loss: -0.3235, Val Loss: -0.3235
# Saved new best model.
# Epoch 972/1000, Train Loss: -0.3235, Val Loss: -0.3236
# Saved new best model.
# Epoch 973/1000, Train Loss: -0.3236, Val Loss: -0.3236
# Saved new best model.
# Epoch 974/1000, Train Loss: -0.3237, Val Loss: -0.3237
# Saved new best model.
# Epoch 975/1000, Train Loss: -0.3238, Val Loss: -0.3238
# Saved new best model.
# Epoch 976/1000, Train Loss: -0.3239, Val Loss: -0.3239
# Saved new best model.
# Epoch 977/1000, Train Loss: -0.3240, Val Loss: -0.3241
# Saved new best model.
# Epoch 978/1000, Train Loss: -0.3241, Val Loss: -0.3242
# Saved new best model.
# Epoch 979/1000, Train Loss: -0.3243, Val Loss: -0.3244
# Saved new best model.
# Epoch 980/1000, Train Loss: -0.3244, Val Loss: -0.3245
# Saved new best model.
# Epoch 981/1000, Train Loss: -0.3246, Val Loss: -0.3247
# Saved new best model.
# Epoch 982/1000, Train Loss: -0.3248, Val Loss: -0.3249
# Saved new best model.
# Epoch 983/1000, Train Loss: -0.3250, Val Loss: -0.3251
# Saved new best model.
# Epoch 984/1000, Train Loss: -0.3252, Val Loss: -0.3253
# Saved new best model.
# Epoch 985/1000, Train Loss: -0.3254, Val Loss: -0.3255
# Saved new best model.
# Epoch 986/1000, Train Loss: -0.3256, Val Loss: -0.3257
# Saved new best model.
# Epoch 987/1000, Train Loss: -0.3258, Val Loss: -0.3260
# Saved new best model.
# Epoch 988/1000, Train Loss: -0.3261, Val Loss: -0.3262
# Saved new best model.
# Epoch 989/1000, Train Loss: -0.3263, Val Loss: -0.3265
# Saved new best model.
# Epoch 990/1000, Train Loss: -0.3266, Val Loss: -0.3268
# Saved new best model.
# Epoch 991/1000, Train Loss: -0.3269, Val Loss: -0.3271
# Saved new best model.
# Epoch 992/1000, Train Loss: -0.3272, Val Loss: -0.3273
# Saved new best model.
# Epoch 993/1000, Train Loss: -0.3275, Val Loss: -0.3276
# Saved new best model.
# Epoch 994/1000, Train Loss: -0.3278, Val Loss: -0.3279
# Saved new best model.
# Epoch 995/1000, Train Loss: -0.3280, Val Loss: -0.3282
# Saved new best model.
# Epoch 996/1000, Train Loss: -0.3284, Val Loss: -0.3285
# Saved new best model.
# Epoch 997/1000, Train Loss: -0.3287, Val Loss: -0.3289
# Saved new best model.
# Epoch 998/1000, Train Loss: -0.3290, Val Loss: -0.3292
# Saved new best model.
# Epoch 999/1000, Train Loss: -0.3293, Val Loss: -0.3295
# Saved new best model.
# Epoch 1000/1000, Train Loss: -0.3296, Val Loss: -0.3298
# Saved new best model.
# Skipping node x2 as it's not in the training list.
# Skipping node x3 as it's not in the training list.

# %% [markdown]
# (out['min'][0],out['max'][1])

# %% [markdown]
# - NLL curves

# %%
plt.figure(figsize=(14, 6))
for node in conf_dict:
    train_hist, val_hist = load_history(node, EXPERIMENT_DIR)
    if train_hist is None or val_hist is None:
        print(f"No history found for node: {node}")
        continue

    epochs = range(1, len(train_hist) + 1)
    plt.plot(epochs, train_hist, label=f"{node} - train", linestyle="--")
    plt.plot(epochs, val_hist, label=f"{node} - val")

plt.title("Training and Validation Loss Across Nodes")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sample from Graph

# %%
n = 100_000  # Desired number of latent samples for starters
batch_size = 1
verbose=True

# %%
for node in conf_dict:
    print(f'\n----*----------*-------------*--------Sample Node: {node} ------------*-----------------*-------------------*--')
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    SAMPLING_DIR=os.path.join(NODE_DIR, 'sampling')
    os.makedirs(SAMPLING_DIR,exist_ok=True)
    
    #checkk if parents are sampled already
    if check_roots_and_latents(NODE_DIR,verbose=verbose):
        continue
    
    skipping_node =False
    # check if node is source or not
    if conf_dict[node]['node_type'] == 'source':
        pass
    else:
        for parent in conf_dict[node]['parents']:
            if not check_roots_and_latents(os.path.join(EXPERIMENT_DIR, parent),verbose=verbose):
                skipping_node=True
                break
            
    if skipping_node:
        print(f"Skipping {node} as parent {parent} is not sampled yet.")
        continue
            
    
    #sampling from latent
    latent_sample = sample_standard_logistic((n,), device=device)
    if verbose:
        print("-- sampled latents")
    
    
    # load model 
    model_path = os.path.join(NODE_DIR, "best_model.pt")
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose)
    tram_model = tram_model.to(device)
    tram_model.load_state_dict(torch.load(model_path))
    if verbose:
        print("-- loaded modelweights")
    
    #Sampling Dataloader
    dataset = SamplingDataset(node=node,EXPERIMENT_DIR=EXPERIMENT_DIR,number_of_samples=n, conf_dict=conf_dict, transform=None)
    sample_loader = DataLoader(dataset, batch_size=1, shuffle=True, num_workers=0)
    
    
    #Forward pass with the sampled data
    output_list = []
    with torch.no_grad():
        for x in tqdm(sample_loader, desc=f"Sampling {node}"):
            x = [xi.to(device) for xi in x]
            int_input, shift_list = preprocess_inputs(x, device=device)
            model_outputs = tram_model(int_input=int_input, shift_input=shift_list)
            output_list.append(model_outputs)

    if conf_dict[node]['node_type'] == 'source':
        
        if verbose:
            print("source node, Defaults to SI and 1 as inputs")
            
        theta_single =     output_list[0]['int_out'][0]  # Shape: (20,)
        theta_single=transform_intercepts_continous(theta_single)
        thetas_expanded = theta_single.repeat(n, 1)  # Shape: (n, 20)
        shifts = torch.zeros(n, device=device)
        
    else:
        
        if verbose:
            print("node has parents, previously sampled data is loaded for each pa(node)")
            
        y_pred=merge_outputs(output_list, skip_nan=True)
        shifts=y_pred['shift_out']
        if shifts is None:
            print("shift_out was None; defaulting to zeros.")
            shifts = torch.zeros(n, device=device)
        thetas=y_pred['int_out']
        thetas_expanded=transform_intercepts_continous(thetas).squeeze()
        shifts=shifts.squeeze()
        print(thetas_expanded.shape)
        print(shifts.shape)
        
        

    low = torch.full((n,), -1e5, device=device)
    high = torch.full((n,), 1e5, device=device)
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)
    

    ## Root finder
    root = bisection_root_finder(
    lambda targets: vectorized_object_function(
        thetas_expanded,
        targets,
        shifts,
        latent_sample,
        k_min=min_max[0],
        k_max=min_max[1]
    ),low,high, max_iter=10_000,tol=1e-10)
    
    #### Saving
    # save root and latents to 
    root_path = os.path.join(SAMPLING_DIR,"roots.pt")
    latents_path=os.path.join(SAMPLING_DIR, "latents.pt")
    
    if torch.isnan(root).any():
        print(f'caution! sampling for {node} consits of nans')
    
    torch.save(root, root_path)
    torch.save(latent_sample, latents_path)
# Out:
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/continous_3vars_1/x1/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# Sampling x1: 100%|██████████| 100000/100000 [00:16<00:00, 5883.69it/s]
# source node, Defaults to SI and 1 as inputs
# Bisection root finding: 100%|██████████| 10000/10000 [01:04<00:00, 154.54it/s]
# /home/bule/TramDag/utils/sampling_tram_data.py:40: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/continous_3vars_1/x2/sampling
# -- sampled latents
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): ComplexInterceptDefaultTabular(
#     (fc1): Linear(in_features=1, out_features=8, bias=True)
#     (relu1): ReLU()
#     (fc2): Linear(in_features=8, out_features=8, bias=True)
#     (relu2): ReLU()
#     (fc3): Linear(in_features=8, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList()
# )
# -- loaded modelweights
# Sampling x2: 100%|██████████| 100000/100000 [00:35<00:00, 2853.82it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# shift_out was None; defaulting to zeros.
# torch.Size([100000, 20])
# torch.Size([100000])
# Bisection root finding: 100%|██████████| 10000/10000 [01:04<00:00, 154.17it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/continous_3vars_1/x3/sampling
# -- sampled latents
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): ComplexInterceptDefaultTabular(
#     (fc1): Linear(in_features=1, out_features=8, bias=True)
#     (relu1): ReLU()
#     (fc2): Linear(in_features=8, out_features=8, bias=True)
#     (relu2): ReLU()
#     (fc3): Linear(in_features=8, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=1, out_features=8, bias=True)
#       (relu1): ReLU()
#       (fc2): Linear(in_features=8, out_features=8, bias=True)
#       (relu2): ReLU()
#       (fc3): Linear(in_features=8, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# Sampling x3: 100%|██████████| 100000/100000 [00:57<00:00, 1739.23it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# torch.Size([100000, 20])
# torch.Size([100000])
# Bisection root finding: 100%|██████████| 10000/10000 [01:06<00:00, 151.08it/s]

# %%
## BUG in the sampling part 
for node in conf_dict.keys():
    root_np = torch.load(f'/home/bule/TramDag/dev_experiment_logs/continous_3vars_1/{node}/sampling/roots.pt').cpu()
    # Plot overlaid histograms
    plt.figure(figsize=(8, 4))
    plt.hist(df[node] , bins=100, alpha=0.5, label=f'True Values {node}', color='blue', density=True)
    plt.hist(root_np, bins=100, alpha=0.5, label='Estimated Roots', color='red', density=True)
    plt.xlabel("Value")
    plt.ylabel("Density")
    plt.title("Overlay of True vs Estimated Values")
    plt.legend()
    plt.grid(True)
    plt.show()
