# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'
from sklearn.model_selection import train_test_split

import torch
if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# own utils # TODO resolve namespace pollution by restricitn g importis in init
from utils.configuration import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.loss_continous import *
from utils.tram_data_helpers import *
from scipy.special import logit
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "tramdagpaper_exp6_1_linearDGP_ls"   ## <--- set experiment name
seed=42
np.random.seed(seed)

LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
DATA_PATH = EXPERIMENT_DIR # <----------- change to different source if needed
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"configuration.json")

os.makedirs(EXPERIMENT_DIR,exist_ok=True)
# check if configration dict already exists if not create:

if os.path.exists(CONF_DICT_PATH):
    configuration_dict=load_configuration_dict(CONF_DICT_PATH)
    print(f"Loaded existing configuration from {CONF_DICT_PATH}")
else:
    configuration_dict=create_and_write_new_configuration_dict(experiment_name,CONF_DICT_PATH,EXPERIMENT_DIR,DATA_PATH,LOG_DIR)
    print(f"Created new configuration file at {CONF_DICT_PATH}")
# Out:
# Loaded existing configuration from /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_new/configuration.json

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. Linear-shift DGP and linear-shift model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return -0.3*x  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        z2 = logit(u2)
        x2 = (z2 - 2 * x1) / 5#5#   0.42  in the trainagle strucutred cont last line is 5 for SI
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 -f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          - f(X2)        | replace h(x2|x1) with z
    # z3          = 0.63*x3 + beta3 * x1          - f(X2)        | reformulate to x2
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z3+0.2 * x1   +f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        z3 = logit(u3)
        x3 = (z3 + 0.2 * x1 + f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])
        
    #df = pd.DataFrame({'x1': x1, 'x2': x2})#, 'x3': x3})
    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df

n_obs=10_000

df = dgp(n_obs=n_obs, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")

if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=100000, seed=42)
    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)
else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")

sns.pairplot(df)

data_type= {'x1':'continous','x2':'continous','x3':'continous'} 

write_data_type_to_configuration(data_type, CONF_DICT_PATH)

df.info()
# Out:
# Setting Seed: 42
# Loaded data from /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_new/tramdagpaper_exp6_1_linearDGP_ls_new.csv
# Variable 'x1' is modeled as a continuous variable. for target and predictor.
# Variable 'x2' is modeled as a continuous variable. for target and predictor.
# Variable 'x3' is modeled as a continuous variable. for target and predictor.
# Configuration updated successfully.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   x1      100000 non-null  float64
#  1   x2      100000 non-null  float64
#  2   x3      100000 non-null  float64
# dtypes: float64(3)
# memory usage: 2.3 MB

# %% [markdown]
# ## 2.1 train test split

# %%
# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# 2. Compute quantiles from training data
quantiles = train_df.quantile([0.05, 0.95])
min_vals = quantiles.loc[0.05]
max_vals = quantiles.loc[0.95]

train_df.to_csv(os.path.join(EXPERIMENT_DIR, f"{experiment_name}_train.csv"), index=False)
val_df.to_csv(os.path.join(EXPERIMENT_DIR, f"{experiment_name}_val.csv"), index=False)
test_df.to_csv(os.path.join(EXPERIMENT_DIR, f"{experiment_name}_test.csv"), index=False)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 80000, Validation size: 10000, Test size: 10000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
interactive_adj_matrix(CONF_DICT_PATH,seed=10)
# Out:
# /home/bule/TramDag/utils/configuration.py:114: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
interactive_nn_names_matrix(CONF_DICT_PATH, seed=5)

# %%
levels_dict=create_levels_dict(df,data_type)

write_nodes_information_to_configuration(CONF_DICT_PATH, min_vals, max_vals,levels_dict)
# Out:
# {'x1': {'Modelnr': 0, 'data_type': 'continous', 'node_type': 'source', 'parents': [], 'parents_datatype': {}, 'transformation_terms_in_h()': {}, 'min': 0.12157964485414735, 'max': 0.794303998711493, 'batch_size': 512, 'epochs': 100, 'learning_rate': 0.01, 'use_scheduler': False, 'transformation_term_nn_models_in_h()': {}}, 'x2': {'Modelnr': 1, 'data_type': 'continous', 'node_type': 'internal', 'parents': ['x1'], 'parents_datatype': {'x1': 'continous'}, 'transformation_terms_in_h()': {'x1': np.str_('ls')}, 'min': -0.8069206639187695, 'max': 0.418925659248077, 'batch_size': 512, 'epochs': 100, 'learning_rate': 0.01, 'use_scheduler': False, 'transformation_term_nn_models_in_h()': {'x1': np.str_('LinearShift')}}, 'x3': {'Modelnr': 2, 'data_type': 'continous', 'node_type': 'sink', 'parents': ['x1', 'x2'], 'parents_datatype': {'x1': 'continous', 'x2': 'continous'}, 'transformation_terms_in_h()': {'x1': np.str_('ls'), 'x2': np.str_('ls')}, 'min': -4.4354394138675595, 'max': 4.9162449184293, 'batch_size': 512, 'epochs': 100, 'learning_rate': 0.01, 'use_scheduler': False, 'transformation_term_nn_models_in_h()': {'x1': np.str_('LinearShift'), 'x2': np.str_('LinearShift')}}}
# Configuration updated successfully.

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %%
# hyperparams:
train_list=['x1','x2','x3']#<-  set the nodes which have to be trained , useful if further training is required else lsit all vars
configuration_dict = load_configuration_dict(CONF_DICT_PATH)
# if you change the hyperparams -> write them to the config file!

# %%
# For each NODE 
node_list = configuration_dict['nodes'] 

for node in node_list:
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')

    ########################## 0. Get hyperparameters ###############################
    # batch_size, epochs, learning_rate, use_scheduler = get_hyperparameters_for_node(node,node_list)
    
    ############ Edited hyperparameters ##########
    batch_size = 512
    epochs = 500
    learning_rate = 0.01
    use_scheduler = False
    ###########################################
    
    print(f"Using hyperparameters: batch_size={batch_size}, epochs={epochs}, learning_rate={learning_rate}, use_scheduler={use_scheduler}\n")
    
    ########################## 1. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (node_list[node]['node_type'] == 'source') and (node_list[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 2. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    

    ########################## 3. Check if training is complete ###############################
    if not check_if_training_complete(node, NODE_DIR, epochs):
        continue
    
    ########################## 4. Create Model ##############################
    tram_model= get_fully_specified_tram_model(node, configuration_dict, debug=True, set_initial_weights=True)
    
    ########################## 5. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, node_list, train_df, val_df, batch_size=batch_size,return_intercept_shift=True, debug=False)

    ########################## 6. Optimizer & Scheduler ######################.
    optimizer =torch.optim.Adam(tram_model.parameters(), lr=learning_rate)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
    else:
        scheduler = None

    ########################## 7. Training Loop ##############################
    
    train_val_loop(
                node,
                node_list,
                NODE_DIR,
                tram_model,
                train_loader,
                val_loader,
                epochs,
                optimizer,
                use_scheduler,
                scheduler,
                save_linear_shifts=True,
                verbose=1,
                device=device,
                debug=False) # TODO startvalues for bernsteinpols
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# Using hyperparameters: batch_size=512, epochs=500, learning_rate=0.01, use_scheduler=False
#
# Node x1 not trained yet or training incomplete. Starting from epoch 100.
# [DEBUG] R script written to: /tmp/tmpn63gi3a6.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("/home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_new/tramdagpaper_exp6_1_linearDGP_ls_new_train.csv")
# model <- Colr(x1 ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.246133
# -1.745155
# -1.057427
# -1.057427
# -0.7017669
# -0.2315873
# -0.04547494
# -0.04547492
# -0.04547491
# -0.04547489
# -0.04547488
# -0.04547486
# -0.04547485
# -0.04547483
# -0.04547482
# -0.0454748
# -0.04547479
# 0.3690576
# 1.216967
# 2.239766
#
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# Existing model found. Loading weights and history...
# /home/bule/TramDag/utils/tram_model_helpers.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   theta_tilde = torch.tensor(theta_tilde, dtype=last_linear.weight.dtype, device=last_linear.weight.device)
# Epoch 101/500  Train NLL: -0.5747  Val NLL: -0.5782  [Train: 2.34s  Val: 0.37s  Total: 2.71s]
# Epoch 102/500  Train NLL: -0.5743  Val NLL: -0.5782  [Train: 2.27s  Val: 0.36s  Total: 2.64s]
# Epoch 103/500  Train NLL: -0.5739  Val NLL: -0.5782  [Train: 2.24s  Val: 0.33s  Total: 2.57s]
# Epoch 104/500  Train NLL: -0.5748  Val NLL: -0.5782  [Train: 2.44s  Val: 0.37s  Total: 2.81s]
# Saved new best model.
# Epoch 129/500  Train NLL: -0.5741  Val NLL: -0.5783  [Train: 2.16s  Val: 0.35s  Total: 2.52s]
# Saved new best model.
# Epoch 130/500  Train NLL: -0.5744  Val NLL: -0.5783  [Train: 2.16s  Val: 0.34s  Total: 2.51s]
# Saved new best model.
# Epoch 131/500  Train NLL: -0.5744  Val NLL: -0.5784  [Train: 2.14s  Val: 0.34s  Total: 2.48s]
# Saved new best model.
# Epoch 132/500  Train NLL: -0.5737  Val NLL: -0.5784  [Train: 2.22s  Val: 0.35s  Total: 2.57s]
# Epoch 133/500  Train NLL: -0.5742  Val NLL: -0.5782  [Train: 2.24s  Val: 0.35s  Total: 2.60s]
# Saved new best model.
# Epoch 134/500  Train NLL: -0.5735  Val NLL: -0.5784  [Train: 2.19s  Val: 0.34s  Total: 2.53s]
# Epoch 135/500  Train NLL: -0.5743  Val NLL: -0.5784  [Train: 2.24s  Val: 0.36s  Total: 2.60s]
# Epoch 136/500  Train NLL: -0.5743  Val NLL: -0.5783  [Train: 2.34s  Val: 0.33s  Total: 2.67s]
# Epoch 137/500  Train NLL: -0.5743  Val NLL: -0.5784  [Train: 2.44s  Val: 0.37s  Total: 2.81s]
# Epoch 138/500  Train NLL: -0.5740  Val NLL: -0.5784  [Train: 1.88s  Val: 0.37s  Total: 2.26s]
# Epoch 139/500  Train NLL: -0.5741  Val NLL: -0.5784  [Train: 2.37s  Val: 0.34s  Total: 2.71s]
# Epoch 140/500  Train NLL: -0.5735  Val NLL: -0.5784  [Train: 2.36s  Val: 0.37s  Total: 2.74s]
# Epoch 141/500  Train NLL: -0.5747  Val NLL: -0.5784  [Train: 2.14s  Val: 0.34s  Total: 2.48s]
# Epoch 142/500  Train NLL: -0.5743  Val NLL: -0.5784  [Train: 2.38s  Val: 0.34s  Total: 2.72s]
# Epoch 143/500  Train NLL: -0.5741  Val NLL: -0.5783  [Train: 2.25s  Val: 0.36s  Total: 2.62s]
# Epoch 144/500  Train NLL: -0.5737  Val NLL: -0.5784  [Train: 2.19s  Val: 0.32s  Total: 2.51s]
# Epoch 145/500  Train NLL: -0.5745  Val NLL: -0.5784  [Train: 2.21s  Val: 0.36s  Total: 2.57s]
# Saved new best model.
# Epoch 146/500  Train NLL: -0.5741  Val NLL: -0.5784  [Train: 2.02s  Val: 0.36s  Total: 2.38s]
# Saved new best model.
# Epoch 147/500  Train NLL: -0.5743  Val NLL: -0.5784  [Train: 2.35s  Val: 0.36s  Total: 2.72s]
# Saved new best model.
# Epoch 148/500  Train NLL: -0.5748  Val NLL: -0.5784  [Train: 2.31s  Val: 0.39s  Total: 2.71s]
# Epoch 149/500  Train NLL: -0.5743  Val NLL: -0.5784  [Train: 2.16s  Val: 0.39s  Total: 2.55s]
# Saved new best model.
# Epoch 150/500  Train NLL: -0.5746  Val NLL: -0.5784  [Train: 2.29s  Val: 0.38s  Total: 2.68s]
# Epoch 151/500  Train NLL: -0.5740  Val NLL: -0.5784  [Train: 2.35s  Val: 0.35s  Total: 2.71s]
# Epoch 152/500  Train NLL: -0.5745  Val NLL: -0.5784  [Train: 2.38s  Val: 0.35s  Total: 2.72s]
# Saved new best model.
# Epoch 153/500  Train NLL: -0.5742  Val NLL: -0.5784  [Train: 2.17s  Val: 0.40s  Total: 2.57s]
# Epoch 154/500  Train NLL: -0.5743  Val NLL: -0.5784  [Train: 2.27s  Val: 0.39s  Total: 2.66s]
# Saved new best model.
# Epoch 155/500  Train NLL: -0.5746  Val NLL: -0.5784  [Train: 2.17s  Val: 0.40s  Total: 2.57s]
# Epoch 156/500  Train NLL: -0.5745  Val NLL: -0.5784  [Train: 2.32s  Val: 0.37s  Total: 2.69s]
# Saved new best model.
# Epoch 157/500  Train NLL: -0.5748  Val NLL: -0.5784  [Train: 1.81s  Val: 0.39s  Total: 2.20s]
# Epoch 158/500  Train NLL: -0.5738  Val NLL: -0.5784  [Train: 2.26s  Val: 0.35s  Total: 2.61s]
# Saved new best model.
# Epoch 159/500  Train NLL: -0.5751  Val NLL: -0.5785  [Train: 2.10s  Val: 0.34s  Total: 2.45s]
# Saved new best model.
# Epoch 160/500  Train NLL: -0.5747  Val NLL: -0.5785  [Train: 2.12s  Val: 0.37s  Total: 2.50s]
# Saved new best model.
# Epoch 161/500  Train NLL: -0.5744  Val NLL: -0.5785  [Train: 2.21s  Val: 0.33s  Total: 2.55s]
# Saved new best model.
# Epoch 162/500  Train NLL: -0.5743  Val NLL: -0.5785  [Train: 2.34s  Val: 0.39s  Total: 2.74s]
# Epoch 163/500  Train NLL: -0.5737  Val NLL: -0.5784  [Train: 2.39s  Val: 0.38s  Total: 2.77s]
# Epoch 164/500  Train NLL: -0.5745  Val NLL: -0.5785  [Train: 2.02s  Val: 0.36s  Total: 2.38s]
# Epoch 165/500  Train NLL: -0.5740  Val NLL: -0.5784  [Train: 2.20s  Val: 0.34s  Total: 2.54s]
# Epoch 166/500  Train NLL: -0.5753  Val NLL: -0.5785  [Train: 2.21s  Val: 0.36s  Total: 2.58s]
# Epoch 167/500  Train NLL: -0.5752  Val NLL: -0.5785  [Train: 2.31s  Val: 0.33s  Total: 2.65s]
# Epoch 168/500  Train NLL: -0.5743  Val NLL: -0.5785  [Train: 1.87s  Val: 0.33s  Total: 2.19s]
# Epoch 169/500  Train NLL: -0.5744  Val NLL: -0.5785  [Train: 2.41s  Val: 0.35s  Total: 2.76s]
# Epoch 170/500  Train NLL: -0.5746  Val NLL: -0.5784  [Train: 1.86s  Val: 0.37s  Total: 2.23s]
# Epoch 171/500  Train NLL: -0.5744  Val NLL: -0.5785  [Train: 2.36s  Val: 0.35s  Total: 2.72s]
# Epoch 172/500  Train NLL: -0.5748  Val NLL: -0.5784  [Train: 2.10s  Val: 0.37s  Total: 2.48s]
# Epoch 173/500  Train NLL: -0.5746  Val NLL: -0.5785  [Train: 2.39s  Val: 0.38s  Total: 2.78s]
# Epoch 174/500  Train NLL: -0.5748  Val NLL: -0.5785  [Train: 2.23s  Val: 0.38s  Total: 2.61s]
# Epoch 175/500  Train NLL: -0.5745  Val NLL: -0.5785  [Train: 2.30s  Val: 0.35s  Total: 2.65s]
# Saved new best model.
# Epoch 176/500  Train NLL: -0.5739  Val NLL: -0.5785  [Train: 2.32s  Val: 0.32s  Total: 2.65s]
# Epoch 177/500  Train NLL: -0.5746  Val NLL: -0.5785  [Train: 1.93s  Val: 0.34s  Total: 2.27s]
# Saved new best model.
# Epoch 178/500  Train NLL: -0.5747  Val NLL: -0.5785  [Train: 2.36s  Val: 0.39s  Total: 2.75s]
# Saved new best model.
# Epoch 179/500  Train NLL: -0.5739  Val NLL: -0.5785  [Train: 2.39s  Val: 0.36s  Total: 2.75s]
# Epoch 180/500  Train NLL: -0.5751  Val NLL: -0.5785  [Train: 1.80s  Val: 0.36s  Total: 2.16s]
# Epoch 181/500  Train NLL: -0.5742  Val NLL: -0.5785  [Train: 2.37s  Val: 0.41s  Total: 2.78s]
# Saved new best model.
# Epoch 182/500  Train NLL: -0.5744  Val NLL: -0.5785  [Train: 2.31s  Val: 0.34s  Total: 2.65s]
# Saved new best model.
# Epoch 183/500  Train NLL: -0.5745  Val NLL: -0.5785  [Train: 2.26s  Val: 0.32s  Total: 2.59s]
# Epoch 184/500  Train NLL: -0.5743  Val NLL: -0.5785  [Train: 2.31s  Val: 0.34s  Total: 2.65s]
# Epoch 185/500  Train NLL: -0.5741  Val NLL: -0.5785  [Train: 2.27s  Val: 0.36s  Total: 2.63s]
# Epoch 186/500  Train NLL: -0.5741  Val NLL: -0.5785  [Train: 2.35s  Val: 0.33s  Total: 2.69s]
# Saved new best model.
# Epoch 187/500  Train NLL: -0.5749  Val NLL: -0.5785  [Train: 2.28s  Val: 0.40s  Total: 2.69s]
# Saved new best model.
# Epoch 188/500  Train NLL: -0.5753  Val NLL: -0.5785  [Train: 2.35s  Val: 0.35s  Total: 2.71s]
# Epoch 189/500  Train NLL: -0.5746  Val NLL: -0.5785  [Train: 2.20s  Val: 0.36s  Total: 2.57s]
# Epoch 190/500  Train NLL: -0.5740  Val NLL: -0.5785  [Train: 2.47s  Val: 0.35s  Total: 2.81s]
# Saved new best model.
# Epoch 191/500  Train NLL: -0.5744  Val NLL: -0.5785  [Train: 2.44s  Val: 0.36s  Total: 2.81s]
# Epoch 192/500  Train NLL: -0.5746  Val NLL: -0.5785  [Train: 2.34s  Val: 0.37s  Total: 2.71s]
# Saved new best model.
# Epoch 193/500  Train NLL: -0.5745  Val NLL: -0.5785  [Train: 2.03s  Val: 0.31s  Total: 2.34s]
# Epoch 194/500  Train NLL: -0.5743  Val NLL: -0.5785  [Train: 2.31s  Val: 0.36s  Total: 2.67s]
# Epoch 195/500  Train NLL: -0.5738  Val NLL: -0.5785  [Train: 2.23s  Val: 0.35s  Total: 2.59s]
# Epoch 196/500  Train NLL: -0.5741  Val NLL: -0.5785  [Train: 2.37s  Val: 0.36s  Total: 2.73s]
# Epoch 197/500  Train NLL: -0.5745  Val NLL: -0.5785  [Train: 2.48s  Val: 0.37s  Total: 2.86s]
# Epoch 487/500  Train NLL: -0.5745  Val NLL: -0.5787  [Train: 2.32s  Val: 0.34s  Total: 2.66s]
# Epoch 488/500  Train NLL: -0.5745  Val NLL: -0.5786  [Train: 2.21s  Val: 0.34s  Total: 2.55s]
# Epoch 489/500  Train NLL: -0.5749  Val NLL: -0.5786  [Train: 2.28s  Val: 0.34s  Total: 2.63s]
# Epoch 490/500  Train NLL: -0.5745  Val NLL: -0.5786  [Train: 2.40s  Val: 0.38s  Total: 2.78s]
# Epoch 491/500  Train NLL: -0.5743  Val NLL: -0.5787  [Train: 2.23s  Val: 0.36s  Total: 2.60s]
# Epoch 492/500  Train NLL: -0.5742  Val NLL: -0.5787  [Train: 2.22s  Val: 0.38s  Total: 2.60s]
# Epoch 493/500  Train NLL: -0.5747  Val NLL: -0.5786  [Train: 2.13s  Val: 0.38s  Total: 2.51s]
# Epoch 494/500  Train NLL: -0.5748  Val NLL: -0.5786  [Train: 2.13s  Val: 0.36s  Total: 2.49s]
# Epoch 495/500  Train NLL: -0.5743  Val NLL: -0.5787  [Train: 1.85s  Val: 0.32s  Total: 2.18s]
# Epoch 496/500  Train NLL: -0.5747  Val NLL: -0.5786  [Train: 2.23s  Val: 0.37s  Total: 2.61s]
# Epoch 497/500  Train NLL: -0.5740  Val NLL: -0.5786  [Train: 2.39s  Val: 0.33s  Total: 2.72s]
# Epoch 498/500  Train NLL: -0.5745  Val NLL: -0.5786  [Train: 1.95s  Val: 0.36s  Total: 2.31s]
# Epoch 499/500  Train NLL: -0.5745  Val NLL: -0.5786  [Train: 2.37s  Val: 0.35s  Total: 2.73s]
# Epoch 500/500  Train NLL: -0.5748  Val NLL: -0.5787  [Train: 2.36s  Val: 0.34s  Total: 2.70s]
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# Using hyperparameters: batch_size=512, epochs=500, learning_rate=0.01, use_scheduler=False
#
# Node x2 not trained yet or training incomplete. Starting from epoch 100.
# [DEBUG] R script written to: /tmp/tmpcmkxfryp.R
# [DEBUG] R code:
#
# library(MASS)
# library(tram)
# library(readr)
#
# data <- read_csv("/home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_new/tramdagpaper_exp6_1_linearDGP_ls_new_train.csv")
# model <- Colr(x2 ~ 1, data=data, order=19)
# cat(model$theta, sep="\n")
#
# [DEBUG] Rscript succeeded
# [DEBUG] STDOUT:
#  -2.365815
# -2.192995
# -1.395693
# -1.395693
# -1.395693
# -1.395693
# -0.4454886
# -0.4454886
# -0.4454885
# -0.4449945
# 0.4256674
# 0.4256674
# 0.4256675
# 0.4256675
# 1.379649
# 1.389401
# 1.389401
# 1.389401
# 2.182844
# 2.356535
#
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# Existing model found. Loading weights and history...
# /home/bule/TramDag/utils/tram_model_helpers.py:316: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   theta_tilde = torch.tensor(theta_tilde, dtype=last_linear.weight.dtype, device=last_linear.weight.device)
# Epoch 101/500  Train NLL: 0.3475  Val NLL: 0.3409  [Train: 2.51s  Val: 0.39s  Total: 2.90s]
# Epoch 102/500  Train NLL: 0.3480  Val NLL: 0.3410  [Train: 2.56s  Val: 0.39s  Total: 2.95s]
# Epoch 103/500  Train NLL: 0.3475  Val NLL: 0.3409  [Train: 2.57s  Val: 0.42s  Total: 2.99s]
# Epoch 104/500  Train NLL: 0.3475  Val NLL: 0.3409  [Train: 2.46s  Val: 0.39s  Total: 2.86s]
# Epoch 105/500  Train NLL: 0.3472  Val NLL: 0.3409  [Train: 2.54s  Val: 0.45s  Total: 3.00s]
# Saved new best model.
# Epoch 106/500  Train NLL: 0.3467  Val NLL: 0.3407  [Train: 2.33s  Val: 0.42s  Total: 2.76s]
# Epoch 107/500  Train NLL: 0.3476  Val NLL: 0.3408  [Train: 2.66s  Val: 0.41s  Total: 3.07s]
# Epoch 108/500  Train NLL: 0.3468  Val NLL: 0.3410  [Train: 2.42s  Val: 0.41s  Total: 2.84s]
# Epoch 109/500  Train NLL: 0.3472  Val NLL: 0.3410  [Train: 2.62s  Val: 0.43s  Total: 3.05s]
# Epoch 110/500  Train NLL: 0.3474  Val NLL: 0.3407  [Train: 2.46s  Val: 0.40s  Total: 2.87s]
# Saved new best model.
# Epoch 111/500  Train NLL: 0.3476  Val NLL: 0.3407  [Train: 2.42s  Val: 0.38s  Total: 2.81s]
# Epoch 112/500  Train NLL: 0.3476  Val NLL: 0.3410  [Train: 2.33s  Val: 0.45s  Total: 2.79s]
# Saved new best model.
# Epoch 113/500  Train NLL: 0.3470  Val NLL: 0.3407  [Train: 2.50s  Val: 0.40s  Total: 2.91s]
# Epoch 114/500  Train NLL: 0.3474  Val NLL: 0.3407  [Train: 2.47s  Val: 0.39s  Total: 2.86s]
# Epoch 115/500  Train NLL: 0.3472  Val NLL: 0.3408  [Train: 2.40s  Val: 0.40s  Total: 2.81s]
# Saved new best model.
# Epoch 116/500  Train NLL: 0.3473  Val NLL: 0.3406  [Train: 2.51s  Val: 0.39s  Total: 2.91s]
# Epoch 117/500  Train NLL: 0.3479  Val NLL: 0.3407  [Train: 2.54s  Val: 0.41s  Total: 2.95s]
# Saved new best model.
# Epoch 118/500  Train NLL: 0.3473  Val NLL: 0.3406  [Train: 2.48s  Val: 0.41s  Total: 2.89s]
# Epoch 119/500  Train NLL: 0.3469  Val NLL: 0.3407  [Train: 2.56s  Val: 0.42s  Total: 2.98s]
# Epoch 120/500  Train NLL: 0.3476  Val NLL: 0.3407  [Train: 2.41s  Val: 0.43s  Total: 2.85s]
# Epoch 121/500  Train NLL: 0.3474  Val NLL: 0.3408  [Train: 2.43s  Val: 0.41s  Total: 2.85s]
# Epoch 122/500  Train NLL: 0.3482  Val NLL: 0.3407  [Train: 2.21s  Val: 0.40s  Total: 2.62s]
# Epoch 499/500  Train NLL: 2.4172  Val NLL: 2.4158  [Train: 2.83s  Val: 0.44s  Total: 3.28s]
# Epoch 500/500  Train NLL: 2.4172  Val NLL: 2.4159  [Train: 2.81s  Val: 0.48s  Total: 3.31s]

# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs

# %%
show_training_history(node_list,EXPERIMENT_DIR)

# %% [markdown]
# ## 6.2 inspect transformation function for source nodes h()

# %%
show_hdag_for_source_nodes(configuration_dict,EXPERIMENT_DIR,device=device,xmin_plot=0,xmax_plot=1) # TODO for other nodes funciton
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# [WARNING] target_col 'x1' not in DataFrame columns — is this intended for use as a Sampler?
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance
#
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(configuration_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--

# %% [markdown]
# ### Coefficient estimates

# %%
# x1-> x2, x1-> x3, x2-> x3
true_coeffs = {'x2': [2],'x3': [-0.2, 0.3]}

for node in node_list:
    print(f'\n----*----------*-------------*--------check LS of {node} ------------*-----------------*-------------------*--')
    
    if node_list[node]['node_type'] == 'source':
        print(f"Node type :source")
        continue
    
    # Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    # Load saved shifts
    shift_path = os.path.join(NODE_DIR, "linear_shifts_all_epochs.json")
    with open(shift_path, 'r') as f:
        all_shift_weights = json.load(f)

    # Sort epochs numerically
    epochs = sorted(all_shift_weights.keys(), key=lambda x: int(x.split('_')[1]))

    # Number of shifts (incoming edges) for this node
    example_epoch = all_shift_weights[epochs[0]]
    num_shifts = len(example_epoch)

    # Plot per shift (incoming edge)
    for shifts_idx in range(num_shifts):
        shift_name = f"shift_{shifts_idx}"
        weights_over_time = []

        for epoch in epochs:
            weight_matrix = np.array(all_shift_weights[epoch][shift_name])  # shape: [out_features, in_features]
            avg_weight = weight_matrix.mean()
            weights_over_time.append(avg_weight)

        plt.figure()
        plt.plot(range(1, len(epochs) + 1), weights_over_time)

        # If this node has a true coefficient for this shift, draw a horizontal red line
        if node in true_coeffs:
            true_val = true_coeffs[node][shifts_idx]
            plt.axhline(y=true_val, color='r', linestyle='--', label=f"True coeff = {true_val}")
            plt.legend()

        plt.title(f"Linear Shift Weights in h({node}), ")
        plt.xlabel("Epoch")
        plt.ylabel(fr'$\hat{{\beta}}_{{{node_list[node]["parents"][shifts_idx]}}}$')
        plt.grid(True)
        plt.tight_layout()
        plt.show()
# Out:
# ----*----------*-------------*--------check LS of x1 ------------*-----------------*-------------------*--
# Node type :source
#
# ----*----------*-------------*--------check LS of x2 ------------*-----------------*-------------------*--
# ----*----------*-------------*--------check LS of x3 ------------*-----------------*-------------------*--

# %% [markdown]
# - best model , parameters

# %%
verbose=False
batch_size = 4112
for node in node_list:
    print(f'\n----*----------*-------------*--------check CS of {node} ------------*-----------------*-------------------*--')
    
    if (node_list[node]['node_type'] == 'source'):
        print(f"Node type : other , is not supported yet")
        continue
    #### 0. Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    
    ##### 1. Load model 
    model_path = os.path.join(NODE_DIR, "best_model.pt")
    tram_model = get_fully_specified_tram_model(node, configuration_dict, debug=verbose)
    tram_model = tram_model.to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()
    
        
    for i in range(len(tram_model.nn_shift)):
        print(tram_model.nn_shift[i].fc.weight.data)
# Out:
# ----*----------*-------------*--------check CS of x1 ------------*-----------------*-------------------*--
# Node type : other , is not supported yet
#
# ----*----------*-------------*--------check CS of x2 ------------*-----------------*-------------------*--
# tensor([[1.9894]], device='cuda:0')
#
# ----*----------*-------------*--------check CS of x3 ------------*-----------------*-------------------*--
# tensor([[-0.2437]], device='cuda:0')
# tensor([[0.2835]], device='cuda:0')

# %% [markdown]
# # 7. Sample from Graph

# %%
sample_full_dag(configuration_dict,
                EXPERIMENT_DIR,
                device,
                do_interventions={},
                number_of_samples= 10_000,
                batch_size = 32,
                delete_all_previously_sampled=True,
                verbose=True,
                debug=False)
# Out:
# [INFO] Deleting all previously sampled data.
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_new/x1/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_new/x2/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_new/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# [WARNING] target_col 'x1' not in DataFrame columns — is this intended for use as a Sampler?
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 323.61it/s]
# [INFO] Completed sampling for node 'x1'
#
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# [WARNING] target_col 'x2' not in DataFrame columns — is this intended for use as a Sampler?
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 323.06it/s]
# [INFO] Completed sampling for node 'x2'
#
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# [WARNING] target_col 'x3' not in DataFrame columns — is this intended for use as a Sampler?
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:31<00:00, 322.07it/s]
# [INFO] Completed sampling for node 'x3'
# [INFO] DAG sampling completed successfully for all nodes.

# %% [markdown]
# ## 7.3 Inspect Sampling

# %%
show_samples_vs_true(test_df,node_list,EXPERIMENT_DIR)
