# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "tramdagpaper_exp6_1_complexDGP_cs2"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# they made 3 experiments:
# 1. Linear-shift DGP and linear-shift model
# 2. Complex-shift DGP and complex-shift model  <------------------
# 3. Linear-shift DGP and complex-shift model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return 0.75*np.arctan(5*(x+0.12))  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        z2 = logit(u2)
        x2 = (z2 - 2 * x1) / 5#5#   0.42  in the trainagle strucutred cont last line is 5 for SI
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 -f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          - f(X2)        | replace h(x2|x1) with z
    # z3          = 0.63*x3 + beta3 * x1          - f(X2)        | reformulate to x2
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z3+0.2 * x1   +f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        z3 = logit(u3)
        x3 = (z3 + 0.2 * x1 + f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])
        
    #df = pd.DataFrame({'x1': x1, 'x2': x2})#, 'x3': x3})
    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df

n_obs=10_000

df = dgp(n_obs=n_obs, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")


if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=n_obs)

    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")


sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Setting Seed: 42
#          x1        x2        x3
# 0  0.790178 -0.257718 -0.691040
# 1  0.276383  0.055677 -5.064867
# 2  0.736578  0.053836 -0.420455
# 3  0.808237  0.022891 -4.125809
# 4  0.749825 -0.335202  1.151025

# %% [markdown]
# ## 2.1 train test split

# %%
# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# 2. Compute quantiles from training data
quantiles = train_df.quantile([0.05, 0.95])
min_vals = quantiles.loc[0.05]
max_vals = quantiles.loc[0.95]

# 3. Normalize all sets using training quantiles
def normalize_with_quantiles(df, min_vals, max_vals):
    return (df - min_vals) / (max_vals - min_vals)

# train_df = normalize_with_quantiles(train_df, min_vals, max_vals)
# val_df = normalize_with_quantiles(val_df, min_vals, max_vals)
# test_df = normalize_with_quantiles(test_df, min_vals, max_vals)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 8000, Validation size: 1000, Test size: 1000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous , images , ordinal
# data_type={'x1':'cont','x2':'cont'}  # continous , images , ordinal

adj_matrix = np.array([
    [ "0", "ls", "ls"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "cs"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)

# adj_matrix = np.array([
#     [ "0", "ls"],  # A -> B (cs), A -> C (ls)
#     [ "0", "0" ]  # B -> D (ls)  # C -> D (cs)
# ], object)


# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
# nn_names_matrix[1,2]='ComplexShiftCustomTabular'
plot_nn_names_matrix(nn_names_matrix,data_type)
# Out:
# *************
#  Model has Complex intercepts and Coomplex shifts , please add your Model to the modelzoo
# ************

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/tramdagpaper_exp6_1_complexDGP_cs2_conf.json
# /tmp/ipykernel_467870/1695834966.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
# /tmp/ipykernel_467870/1695834966.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['max']=max_vals[i].tolist()
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.1205322246468743,
#   'max': 0.794692622870355},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift'},
#   'min': -0.8142888901184293,
#   'max': 0.4238437120810543},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls', 'x2': 'cs'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift',
#    'x2': 'ComplexShiftDefaultTabular'},
#   'min': -5.064947514999738,
#   'max': 4.864295579713656}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3']#['x2']#'x1','x2']#,'x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 512#4112
epochs = 300# <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
learning_rate=0.1
use_scheduler =  True

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)
    #tram_model =get_fully_specified_tram_model_hardcoded_init_weights_for_si(node, conf_dict, verbose=True).to(device)


    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################.
    
    ## <---------- TODO use standard SGD and no scheduler
    # optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    # optimizer = torch.optim.AdamW(
    # tram_model.parameters(),
    # lr=1e-3,           # ← two orders of magnitude smaller
    # eps=1e-8,
    # weight_decay=1e-2
    # )   
    optimizer =torch.optim.Adam(tram_model.parameters(), lr=learning_rate)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
        #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer,max_lr=1e-3, total_steps=epochs * len(train_loader),pct_start=0.1, anneal_strategy="cos"       # pick your sweet-spot

    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR,
            save_linear_shifts=True
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# No existing model found. Starting fresh...
# Saved new best model.
# Epoch 1/300 | Train Loss: 1.1186 | Val Loss: 0.7148
#   [Train: 1.82s | Val: 0.28s | Save: 0.00s | Total: 2.11s]
# Saved new best model.
# Epoch 2/300 | Train Loss: 0.5205 | Val Loss: 0.3387
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 3/300 | Train Loss: 0.2467 | Val Loss: 0.1574
#   [Train: 1.51s | Val: 0.27s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 4/300 | Train Loss: 0.1064 | Val Loss: 0.0591
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.76s]
# Saved new best model.
# Epoch 5/300 | Train Loss: 0.0257 | Val Loss: 0.0005
#   [Train: 1.52s | Val: 0.26s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 6/300 | Train Loss: -0.0220 | Val Loss: -0.0364
#   [Train: 1.48s | Val: 0.27s | Save: 0.00s | Total: 1.76s]
# Saved new best model.
# Epoch 7/300 | Train Loss: -0.0534 | Val Loss: -0.0591
#   [Train: 1.49s | Val: 0.26s | Save: 0.00s | Total: 1.75s]
# Saved new best model.
# Epoch 8/300 | Train Loss: -0.0711 | Val Loss: -0.0720
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 9/300 | Train Loss: -0.0808 | Val Loss: -0.0779
#   [Train: 1.50s | Val: 0.28s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 10/300 | Train Loss: -0.0853 | Val Loss: -0.0794
#   [Train: 1.47s | Val: 0.27s | Save: 0.00s | Total: 1.75s]
# Saved new best model.
# Epoch 11/300 | Train Loss: -0.1140 | Val Loss: -0.1364
#   [Train: 1.46s | Val: 0.28s | Save: 0.00s | Total: 1.74s]
# Saved new best model.
# Epoch 12/300 | Train Loss: -0.1667 | Val Loss: -0.1829
#   [Train: 1.47s | Val: 0.27s | Save: 0.00s | Total: 1.74s]
# Saved new best model.
# Epoch 13/300 | Train Loss: -0.2103 | Val Loss: -0.2213
#   [Train: 1.48s | Val: 0.27s | Save: 0.00s | Total: 1.76s]
# Saved new best model.
# Epoch 14/300 | Train Loss: -0.2456 | Val Loss: -0.2527
#   [Train: 1.47s | Val: 0.27s | Save: 0.00s | Total: 1.75s]
# Saved new best model.
# Epoch 15/300 | Train Loss: -0.2746 | Val Loss: -0.2793
#   [Train: 1.47s | Val: 0.28s | Save: 0.00s | Total: 1.75s]
# Saved new best model.
# Epoch 16/300 | Train Loss: -0.2997 | Val Loss: -0.3015
#   [Train: 1.51s | Val: 0.27s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 17/300 | Train Loss: -0.3203 | Val Loss: -0.3199
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 18/300 | Train Loss: -0.3380 | Val Loss: -0.3352
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.80s]
# Saved new best model.
# Epoch 19/300 | Train Loss: -0.3509 | Val Loss: -0.3479
#   [Train: 1.50s | Val: 0.28s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 20/300 | Train Loss: -0.3628 | Val Loss: -0.3582
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 21/300 | Train Loss: -0.3739 | Val Loss: -0.3667
#   [Train: 1.49s | Val: 0.30s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 22/300 | Train Loss: -0.3809 | Val Loss: -0.3736
#   [Train: 1.52s | Val: 0.28s | Save: 0.00s | Total: 1.80s]
# Saved new best model.
# Epoch 23/300 | Train Loss: -0.3872 | Val Loss: -0.3790
#   [Train: 1.50s | Val: 0.29s | Save: 0.00s | Total: 1.80s]
# Saved new best model.
# Epoch 24/300 | Train Loss: -0.3920 | Val Loss: -0.3832
#   [Train: 1.51s | Val: 0.26s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 25/300 | Train Loss: -0.3959 | Val Loss: -0.3863
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.81s]
# Saved new best model.
# Epoch 26/300 | Train Loss: -0.3981 | Val Loss: -0.3884
#   [Train: 1.51s | Val: 0.27s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 27/300 | Train Loss: -0.3999 | Val Loss: -0.3899
#   [Train: 1.49s | Val: 0.29s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 28/300 | Train Loss: -0.4021 | Val Loss: -0.3907
#   [Train: 1.50s | Val: 0.29s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 29/300 | Train Loss: -0.4020 | Val Loss: -0.3910
#   [Train: 1.51s | Val: 0.29s | Save: 0.00s | Total: 1.81s]
# Saved new best model.
# Epoch 30/300 | Train Loss: -0.4028 | Val Loss: -0.3911
#   [Train: 1.49s | Val: 0.30s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 31/300 | Train Loss: -0.4080 | Val Loss: -0.4058
#   [Train: 1.54s | Val: 0.26s | Save: 0.00s | Total: 1.80s]
# Saved new best model.
# Epoch 32/300 | Train Loss: -0.4225 | Val Loss: -0.4193
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 33/300 | Train Loss: -0.4358 | Val Loss: -0.4311
#   [Train: 1.52s | Val: 0.29s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 34/300 | Train Loss: -0.4469 | Val Loss: -0.4416
#   [Train: 1.50s | Val: 0.29s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 35/300 | Train Loss: -0.4581 | Val Loss: -0.4511
#   [Train: 1.52s | Val: 0.27s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 36/300 | Train Loss: -0.4659 | Val Loss: -0.4592
#   [Train: 1.48s | Val: 0.28s | Save: 0.00s | Total: 1.76s]
# Saved new best model.
# Epoch 37/300 | Train Loss: -0.4746 | Val Loss: -0.4671
#   [Train: 1.52s | Val: 0.30s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 38/300 | Train Loss: -0.4826 | Val Loss: -0.4737
#   [Train: 1.51s | Val: 0.26s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 39/300 | Train Loss: -0.4891 | Val Loss: -0.4799
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 40/300 | Train Loss: -0.4951 | Val Loss: -0.4856
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 41/300 | Train Loss: -0.5002 | Val Loss: -0.4904
#   [Train: 1.50s | Val: 0.27s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 42/300 | Train Loss: -0.5035 | Val Loss: -0.4948
#   [Train: 1.51s | Val: 0.31s | Save: 0.00s | Total: 1.83s]
# Saved new best model.
# Epoch 43/300 | Train Loss: -0.5091 | Val Loss: -0.4990
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 44/300 | Train Loss: -0.5141 | Val Loss: -0.5026
#   [Train: 1.52s | Val: 0.29s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 45/300 | Train Loss: -0.5170 | Val Loss: -0.5057
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 46/300 | Train Loss: -0.5197 | Val Loss: -0.5084
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1.77s]
# Saved new best model.
# Epoch 47/300 | Train Loss: -0.5225 | Val Loss: -0.5113
#   [Train: 1.52s | Val: 0.20s | Save: 0.00s | Total: 1.72s]
# Saved new best model.
# Epoch 48/300 | Train Loss: -0.5252 | Val Loss: -0.5137
#   [Train: 0.46s | Val: 0.23s | Save: 0.00s | Total: 0.70s]
# Saved new best model.
# Epoch 49/300 | Train Loss: -0.5286 | Val Loss: -0.5158
#   [Train: 0.37s | Val: 0.19s | Save: 0.00s | Total: 0.56s]
# Saved new best model.
# Epoch 50/300 | Train Loss: -0.5283 | Val Loss: -0.5176
#   [Train: 0.42s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 51/300 | Train Loss: -0.5304 | Val Loss: -0.5193
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.71s]
# Saved new best model.
# Epoch 52/300 | Train Loss: -0.5326 | Val Loss: -0.5207
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 53/300 | Train Loss: -0.5336 | Val Loss: -0.5218
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 54/300 | Train Loss: -0.5343 | Val Loss: -0.5231
#   [Train: 0.43s | Val: 0.18s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 55/300 | Train Loss: -0.5387 | Val Loss: -0.5241
#   [Train: 0.42s | Val: 0.18s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 56/300 | Train Loss: -0.5378 | Val Loss: -0.5250
#   [Train: 0.37s | Val: 0.17s | Save: 0.00s | Total: 0.55s]
# Saved new best model.
# Epoch 57/300 | Train Loss: -0.5388 | Val Loss: -0.5256
#   [Train: 0.38s | Val: 0.20s | Save: 0.00s | Total: 0.58s]
# Saved new best model.
# Epoch 58/300 | Train Loss: -0.5399 | Val Loss: -0.5264
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 59/300 | Train Loss: -0.5387 | Val Loss: -0.5268
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 60/300 | Train Loss: -0.5409 | Val Loss: -0.5273
#   [Train: 0.43s | Val: 0.21s | Save: 0.00s | Total: 0.63s]
# Saved new best model.
# Epoch 61/300 | Train Loss: -0.5412 | Val Loss: -0.5276
#   [Train: 0.38s | Val: 0.20s | Save: 0.00s | Total: 0.58s]
# Saved new best model.
# Epoch 62/300 | Train Loss: -0.5410 | Val Loss: -0.5279
#   [Train: 0.43s | Val: 0.18s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 63/300 | Train Loss: -0.5419 | Val Loss: -0.5282
#   [Train: 0.40s | Val: 0.22s | Save: 0.00s | Total: 0.63s]
# Saved new best model.
# Epoch 64/300 | Train Loss: -0.5419 | Val Loss: -0.5284
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 65/300 | Train Loss: -0.5419 | Val Loss: -0.5285
#   [Train: 0.38s | Val: 0.19s | Save: 0.00s | Total: 0.58s]
# Saved new best model.
# Epoch 66/300 | Train Loss: -0.5409 | Val Loss: -0.5287
#   [Train: 0.40s | Val: 0.24s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 67/300 | Train Loss: -0.5422 | Val Loss: -0.5287
#   [Train: 0.41s | Val: 0.17s | Save: 0.00s | Total: 0.59s]
# Saved new best model.
# Epoch 68/300 | Train Loss: -0.5418 | Val Loss: -0.5288
#   [Train: 0.46s | Val: 0.18s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 69/300 | Train Loss: -0.5405 | Val Loss: -0.5288
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 70/300 | Train Loss: -0.5415 | Val Loss: -0.5288
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 71/300 | Train Loss: -0.5419 | Val Loss: -0.5315
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.70s]
# Saved new best model.
# Epoch 72/300 | Train Loss: -0.5448 | Val Loss: -0.5341
#   [Train: 0.44s | Val: 0.18s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 73/300 | Train Loss: -0.5485 | Val Loss: -0.5358
#   [Train: 0.43s | Val: 0.17s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 74/300 | Train Loss: -0.5506 | Val Loss: -0.5377
#   [Train: 0.40s | Val: 0.19s | Save: 0.00s | Total: 0.60s]
# Saved new best model.
# Epoch 75/300 | Train Loss: -0.5521 | Val Loss: -0.5397
#   [Train: 0.44s | Val: 0.18s | Save: 0.00s | Total: 0.63s]
# Saved new best model.
# Epoch 76/300 | Train Loss: -0.5550 | Val Loss: -0.5409
#   [Train: 0.42s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 77/300 | Train Loss: -0.5545 | Val Loss: -0.5422
#   [Train: 0.46s | Val: 0.18s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 78/300 | Train Loss: -0.5551 | Val Loss: -0.5438
#   [Train: 0.31s | Val: 0.18s | Save: 0.00s | Total: 0.49s]
# Saved new best model.
# Epoch 79/300 | Train Loss: -0.5558 | Val Loss: -0.5448
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 80/300 | Train Loss: -0.5580 | Val Loss: -0.5455
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 81/300 | Train Loss: -0.5584 | Val Loss: -0.5469
#   [Train: 0.40s | Val: 0.18s | Save: 0.00s | Total: 0.59s]
# Saved new best model.
# Epoch 82/300 | Train Loss: -0.5604 | Val Loss: -0.5476
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 83/300 | Train Loss: -0.5614 | Val Loss: -0.5477
#   [Train: 0.38s | Val: 0.23s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 84/300 | Train Loss: -0.5627 | Val Loss: -0.5493
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.68s]
# Saved new best model.
# Epoch 85/300 | Train Loss: -0.5633 | Val Loss: -0.5496
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# Saved new best model.
# Epoch 86/300 | Train Loss: -0.5645 | Val Loss: -0.5503
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 87/300 | Train Loss: -0.5646 | Val Loss: -0.5508
#   [Train: 0.33s | Val: 0.17s | Save: 0.00s | Total: 0.51s]
# Saved new best model.
# Epoch 88/300 | Train Loss: -0.5658 | Val Loss: -0.5513
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 89/300 | Train Loss: -0.5652 | Val Loss: -0.5520
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 90/300 | Train Loss: -0.5654 | Val Loss: -0.5520
#   [Train: 0.42s | Val: 0.18s | Save: 0.00s | Total: 0.60s]
# Saved new best model.
# Epoch 91/300 | Train Loss: -0.5678 | Val Loss: -0.5526
#   [Train: 0.38s | Val: 0.18s | Save: 0.00s | Total: 0.57s]
# Saved new best model.
# Epoch 92/300 | Train Loss: -0.5678 | Val Loss: -0.5529
#   [Train: 0.37s | Val: 0.18s | Save: 0.00s | Total: 0.56s]
# Saved new best model.
# Epoch 93/300 | Train Loss: -0.5677 | Val Loss: -0.5535
#   [Train: 0.36s | Val: 0.20s | Save: 0.00s | Total: 0.56s]
# Epoch 94/300 | Train Loss: -0.5670 | Val Loss: -0.5535
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 95/300 | Train Loss: -0.5684 | Val Loss: -0.5540
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 96/300 | Train Loss: -0.5682 | Val Loss: -0.5542
#   [Train: 0.37s | Val: 0.17s | Save: 0.00s | Total: 0.54s]
# Saved new best model.
# Epoch 97/300 | Train Loss: -0.5694 | Val Loss: -0.5544
#   [Train: 0.39s | Val: 0.18s | Save: 0.00s | Total: 0.58s]
# Epoch 98/300 | Train Loss: -0.5670 | Val Loss: -0.5544
#   [Train: 0.39s | Val: 0.18s | Save: 0.00s | Total: 0.58s]
# Saved new best model.
# Epoch 99/300 | Train Loss: -0.5683 | Val Loss: -0.5549
#   [Train: 0.34s | Val: 0.18s | Save: 0.00s | Total: 0.52s]
# Saved new best model.
# Epoch 100/300 | Train Loss: -0.5687 | Val Loss: -0.5551
#   [Train: 0.32s | Val: 0.19s | Save: 0.00s | Total: 0.51s]
# Saved new best model.
# Epoch 101/300 | Train Loss: -0.5682 | Val Loss: -0.5552
#   [Train: 0.36s | Val: 0.17s | Save: 0.00s | Total: 0.53s]
# Saved new best model.
# Epoch 102/300 | Train Loss: -0.5690 | Val Loss: -0.5556
#   [Train: 0.35s | Val: 0.18s | Save: 0.00s | Total: 0.53s]
# Epoch 103/300 | Train Loss: -0.5690 | Val Loss: -0.5554
#   [Train: 0.36s | Val: 0.17s | Save: 0.00s | Total: 0.54s]
# Saved new best model.
# Epoch 104/300 | Train Loss: -0.5685 | Val Loss: -0.5557
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 105/300 | Train Loss: -0.5692 | Val Loss: -0.5558
#   [Train: 0.39s | Val: 0.21s | Save: 0.00s | Total: 0.60s]
# Epoch 106/300 | Train Loss: -0.5693 | Val Loss: -0.5557
#   [Train: 0.46s | Val: 0.19s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 107/300 | Train Loss: -0.5692 | Val Loss: -0.5560
#   [Train: 0.40s | Val: 0.20s | Save: 0.00s | Total: 0.60s]
# Saved new best model.
# Epoch 108/300 | Train Loss: -0.5697 | Val Loss: -0.5562
#   [Train: 0.33s | Val: 0.18s | Save: 0.00s | Total: 0.52s]
# Saved new best model.
# Epoch 109/300 | Train Loss: -0.5691 | Val Loss: -0.5562
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 110/300 | Train Loss: -0.5685 | Val Loss: -0.5565
#   [Train: 0.42s | Val: 0.22s | Save: 0.01s | Total: 0.64s]
# Epoch 111/300 | Train Loss: -0.5694 | Val Loss: -0.5564
#   [Train: 0.43s | Val: 0.22s | Save: 0.00s | Total: 0.66s]
# Epoch 112/300 | Train Loss: -0.5695 | Val Loss: -0.5564
#   [Train: 0.37s | Val: 0.21s | Save: 0.00s | Total: 0.58s]
# Saved new best model.
# Epoch 113/300 | Train Loss: -0.5700 | Val Loss: -0.5566
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.67s]
# Epoch 114/300 | Train Loss: -0.5717 | Val Loss: -0.5566
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 115/300 | Train Loss: -0.5699 | Val Loss: -0.5567
#   [Train: 0.38s | Val: 0.20s | Save: 0.00s | Total: 0.58s]
# Saved new best model.
# Epoch 116/300 | Train Loss: -0.5712 | Val Loss: -0.5569
#   [Train: 0.46s | Val: 0.19s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 117/300 | Train Loss: -0.5699 | Val Loss: -0.5569
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 118/300 | Train Loss: -0.5704 | Val Loss: -0.5568
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 119/300 | Train Loss: -0.5714 | Val Loss: -0.5569
#   [Train: 0.38s | Val: 0.17s | Save: 0.00s | Total: 0.55s]
# Saved new best model.
# Epoch 120/300 | Train Loss: -0.5721 | Val Loss: -0.5570
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 121/300 | Train Loss: -0.5706 | Val Loss: -0.5569
#   [Train: 0.45s | Val: 0.18s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 122/300 | Train Loss: -0.5719 | Val Loss: -0.5571
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.62s]
# Epoch 123/300 | Train Loss: -0.5702 | Val Loss: -0.5571
#   [Train: 0.32s | Val: 0.18s | Save: 0.00s | Total: 0.50s]
# Epoch 124/300 | Train Loss: -0.5722 | Val Loss: -0.5570
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.58s]
# Saved new best model.
# Epoch 125/300 | Train Loss: -0.5715 | Val Loss: -0.5572
#   [Train: 0.34s | Val: 0.18s | Save: 0.00s | Total: 0.52s]
# Epoch 126/300 | Train Loss: -0.5708 | Val Loss: -0.5572
#   [Train: 0.38s | Val: 0.17s | Save: 0.00s | Total: 0.55s]
# Epoch 127/300 | Train Loss: -0.5705 | Val Loss: -0.5571
#   [Train: 0.42s | Val: 0.18s | Save: 0.00s | Total: 0.61s]
# Epoch 128/300 | Train Loss: -0.5732 | Val Loss: -0.5572
#   [Train: 0.34s | Val: 0.17s | Save: 0.00s | Total: 0.51s]
# Saved new best model.
# Epoch 129/300 | Train Loss: -0.5731 | Val Loss: -0.5572
#   [Train: 0.42s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 130/300 | Train Loss: -0.5707 | Val Loss: -0.5571
#   [Train: 0.37s | Val: 0.20s | Save: 0.00s | Total: 0.58s]
# Epoch 131/300 | Train Loss: -0.5728 | Val Loss: -0.5572
#   [Train: 0.42s | Val: 0.17s | Save: 0.00s | Total: 0.59s]
# Saved new best model.
# Epoch 132/300 | Train Loss: -0.5708 | Val Loss: -0.5573
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 133/300 | Train Loss: -0.5702 | Val Loss: -0.5572
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# Epoch 134/300 | Train Loss: -0.5713 | Val Loss: -0.5573
#   [Train: 0.42s | Val: 0.22s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 135/300 | Train Loss: -0.5700 | Val Loss: -0.5573
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 136/300 | Train Loss: -0.5708 | Val Loss: -0.5573
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Epoch 137/300 | Train Loss: -0.5721 | Val Loss: -0.5573
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# Saved new best model.
# Epoch 138/300 | Train Loss: -0.5720 | Val Loss: -0.5573
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Epoch 139/300 | Train Loss: -0.5713 | Val Loss: -0.5573
#   [Train: 0.40s | Val: 0.20s | Save: 0.00s | Total: 0.60s]
# Saved new best model.
# Epoch 140/300 | Train Loss: -0.5712 | Val Loss: -0.5574
#   [Train: 0.40s | Val: 0.19s | Save: 0.00s | Total: 0.60s]
# Saved new best model.
# Epoch 141/300 | Train Loss: -0.5709 | Val Loss: -0.5574
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# Epoch 142/300 | Train Loss: -0.5723 | Val Loss: -0.5573
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 143/300 | Train Loss: -0.5713 | Val Loss: -0.5573
#   [Train: 0.32s | Val: 0.16s | Save: 0.00s | Total: 0.49s]
# Epoch 144/300 | Train Loss: -0.5713 | Val Loss: -0.5574
#   [Train: 0.56s | Val: 0.26s | Save: 0.00s | Total: 0.82s]
# Epoch 145/300 | Train Loss: -0.5700 | Val Loss: -0.5574
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.79s]
# Epoch 146/300 | Train Loss: -0.5718 | Val Loss: -0.5574
#   [Train: 1.52s | Val: 0.28s | Save: 0.00s | Total: 1.80s]
# Epoch 147/300 | Train Loss: -0.5708 | Val Loss: -0.5573
#   [Train: 1.51s | Val: 0.26s | Save: 0.00s | Total: 1.77s]
# Epoch 148/300 | Train Loss: -0.5712 | Val Loss: -0.5574
#   [Train: 1.48s | Val: 0.27s | Save: 0.00s | Total: 1.76s]
# Epoch 149/300 | Train Loss: -0.5712 | Val Loss: -0.5574
#   [Train: 1.51s | Val: 0.27s | Save: 0.00s | Total: 1.78s]
# Epoch 150/300 | Train Loss: -0.5711 | Val Loss: -0.5574
#   [Train: 1.52s | Val: 0.30s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 151/300 | Train Loss: -0.5696 | Val Loss: -0.5576
#   [Train: 1.48s | Val: 0.28s | Save: 0.00s | Total: 1.76s]
# Saved new best model.
# Epoch 152/300 | Train Loss: -0.5709 | Val Loss: -0.5576
#   [Train: 1.52s | Val: 0.27s | Save: 0.00s | Total: 1.80s]
# Saved new best model.
# Epoch 153/300 | Train Loss: -0.5717 | Val Loss: -0.5577
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1.78s]
# Epoch 154/300 | Train Loss: -0.5724 | Val Loss: -0.5577
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.81s]
# Saved new best model.
# Epoch 155/300 | Train Loss: -0.5723 | Val Loss: -0.5578
#   [Train: 1.50s | Val: 0.26s | Save: 0.00s | Total: 1.76s]
# Epoch 156/300 | Train Loss: -0.5719 | Val Loss: -0.5576
#   [Train: 1.51s | Val: 0.27s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 157/300 | Train Loss: -0.5726 | Val Loss: -0.5580
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 158/300 | Train Loss: -0.5712 | Val Loss: -0.5581
#   [Train: 1.50s | Val: 0.26s | Save: 0.00s | Total: 1.76s]
# Saved new best model.
# Epoch 159/300 | Train Loss: -0.5729 | Val Loss: -0.5581
#   [Train: 1.49s | Val: 0.27s | Save: 0.01s | Total: 1.76s]
# Epoch 160/300 | Train Loss: -0.5735 | Val Loss: -0.5579
#   [Train: 1.52s | Val: 0.27s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 161/300 | Train Loss: -0.5741 | Val Loss: -0.5585
#   [Train: 1.49s | Val: 0.29s | Save: 0.00s | Total: 1.78s]
# Epoch 162/300 | Train Loss: -0.5719 | Val Loss: -0.5581
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.76s]
# Epoch 163/300 | Train Loss: -0.5716 | Val Loss: -0.5583
#   [Train: 1.47s | Val: 0.28s | Save: 0.00s | Total: 1.75s]
# Epoch 164/300 | Train Loss: -0.5733 | Val Loss: -0.5584
#   [Train: 1.50s | Val: 0.29s | Save: 0.00s | Total: 1.79s]
# Epoch 165/300 | Train Loss: -0.5721 | Val Loss: -0.5580
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1
#   [Train: 1.50s | Val: 0.28s | Save: 0.00s | Total: 1.79s]
# Epoch 261/300 | Train Loss: -0.5735 | Val Loss: -0.5581
#   [Train: 1.52s | Val: 0.30s | Save: 0.00s | Total: 1.82s]
# Epoch 262/300 | Train Loss: -0.5755 | Val Loss: -0.5583
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.76s]
# Epoch 263/300 | Train Loss: -0.5751 | Val Loss: -0.5581
#   [Train: 1.52s | Val: 0.29s | Save: 0.00s | Total: 1.81s]
# Epoch 264/300 | Train Loss: -0.5754 | Val Loss: -0.5580
#   [Train: 1.50s | Val: 0.28s | Save: 0.00s | Total: 1.78s]
# Epoch 265/300 | Train Loss: -0.5733 | Val Loss: -0.5580
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.79s]
# Epoch 266/300 | Train Loss: -0.5738 | Val Loss: -0.5580
#   [Train: 1.48s | Val: 0.29s | Save: 0.00s | Total: 1.78s]
# Epoch 267/300 | Train Loss: -0.5734 | Val Loss: -0.5580
#   [Train: 1.53s | Val: 0.30s | Save: 0.00s | Total: 1.83s]
# Epoch 268/300 | Train Loss: -0.5739 | Val Loss: -0.5581
#   [Train: 1.52s | Val: 0.27s | Save: 0.00s | Total: 1.80s]
# Epoch 269/300 | Train Loss: -0.5759 | Val Loss: -0.5580
#   [Train: 1.47s | Val: 0.26s | Save: 0.00s | Total: 1.73s]
# Epoch 270/300 | Train Loss: -0.5725 | Val Loss: -0.5581
#   [Train: 1.31s | Val: 0.21s | Save: 0.00s | Total: 1.52s]
# Epoch 271/300 | Train Loss: -0.5725 | Val Loss: -0.5580
#   [Train: 1.48s | Val: 0.27s | Save: 0.00s | Total: 1.76s]
# Epoch 272/300 | Train Loss: -0.5731 | Val Loss: -0.5580
#   [Train: 1.47s | Val: 0.28s | Save: 0.00s | Total: 1.75s]
# Epoch 273/300 | Train Loss: -0.5738 | Val Loss: -0.5580
#   [Train: 1.53s | Val: 0.27s | Save: 0.00s | Total: 1.80s]
# Epoch 274/300 | Train Loss: -0.5748 | Val Loss: -0.5581
#   [Train: 1.51s | Val: 0.29s | Save: 0.00s | Total: 1.81s]
# Epoch 275/300 | Train Loss: -0.5724 | Val Loss: -0.5581
#   [Train: 1.52s | Val: 0.26s | Save: 0.00s | Total: 1.78s]
# Epoch 276/300 | Train Loss: -0.5747 | Val Loss: -0.5580
#   [Train: 1.47s | Val: 0.29s | Save: 0.00s | Total: 1.76s]
# Epoch 277/300 | Train Loss: -0.5752 | Val Loss: -0.5580
#   [Train: 1.53s | Val: 0.29s | Save: 0.01s | Total: 1.83s]
# Epoch 278/300 | Train Loss: -0.5728 | Val Loss: -0.5581
#   [Train: 1.51s | Val: 0.29s | Save: 0.00s | Total: 1.80s]
# Epoch 279/300 | Train Loss: -0.5751 | Val Loss: -0.5580
#   [Train: 1.50s | Val: 0.29s | Save: 0.00s | Total: 1.79s]
# Epoch 280/300 | Train Loss: -0.5752 | Val Loss: -0.5581
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.81s]
# Epoch 281/300 | Train Loss: -0.5747 | Val Loss: -0.5580
#   [Train: 1.51s | Val: 0.29s | Save: 0.00s | Total: 1.80s]
# Epoch 282/300 | Train Loss: -0.5749 | Val Loss: -0.5580
#   [Train: 1.54s | Val: 0.29s | Save: 0.00s | Total: 1.83s]
# Epoch 283/300 | Train Loss: -0.5757 | Val Loss: -0.5580
#   [Train: 1.52s | Val: 0.27s | Save: 0.00s | Total: 1.80s]
# Epoch 284/300 | Train Loss: -0.5747 | Val Loss: -0.5580
#   [Train: 1.52s | Val: 0.27s | Save: 0.00s | Total: 1.80s]
# Epoch 285/300 | Train Loss: -0.5739 | Val Loss: -0.5580
#   [Train: 1.52s | Val: 0.29s | Save: 0.00s | Total: 1.81s]
# Epoch 286/300 | Train Loss: -0.5741 | Val Loss: -0.5580
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.80s]
# Epoch 287/300 | Train Loss: -0.5744 | Val Loss: -0.5580
#   [Train: 1.53s | Val: 0.29s | Save: 0.00s | Total: 1.82s]
# Epoch 288/300 | Train Loss: -0.5753 | Val Loss: -0.5580
#   [Train: 1.48s | Val: 0.28s | Save: 0.00s | Total: 1.76s]
# Epoch 289/300 | Train Loss: -0.5740 | Val Loss: -0.5581
#   [Train: 1.54s | Val: 0.29s | Save: 0.00s | Total: 1.83s]
# Epoch 290/300 | Train Loss: -0.5752 | Val Loss: -0.5580
#   [Train: 1.54s | Val: 0.29s | Save: 0.01s | Total: 1.83s]
# Epoch 291/300 | Train Loss: -0.5751 | Val Loss: -0.5580
#   [Train: 1.54s | Val: 0.29s | Save: 0.00s | Total: 1.83s]
# Epoch 292/300 | Train Loss: -0.5737 | Val Loss: -0.5580
#   [Train: 1.49s | Val: 0.27s | Save: 0.00s | Total: 1.77s]
# Epoch 293/300 | Train Loss: -0.5768 | Val Loss: -0.5580
#   [Train: 1.52s | Val: 0.31s | Save: 0.00s | Total: 1.84s]
# Epoch 294/300 | Train Loss: -0.5731 | Val Loss: -0.5580
#   [Train: 1.50s | Val: 0.25s | Save: 0.00s | Total: 1.75s]
# Epoch 295/300 | Train Loss: -0.5737 | Val Loss: -0.5580
#   [Train: 1.49s | Val: 0.28s | Save: 0.00s | Total: 1.78s]
# Epoch 296/300 | Train Loss: -0.5758 | Val Loss: -0.5580
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.79s]
# Epoch 297/300 | Train Loss: -0.5731 | Val Loss: -0.5580
#   [Train: 1.50s | Val: 0.27s | Save: 0.00s | Total: 1.77s]
# Epoch 298/300 | Train Loss: -0.5746 | Val Loss: -0.5580
#   [Train: 1.50s | Val: 0.26s | Save: 0.00s | Total: 1.77s]
# Epoch 299/300 | Train Loss: -0.5732 | Val Loss: -0.5580
#   [Train: 1.49s | Val: 0.29s | Save: 0.00s | Total: 1.79s]
# Epoch 300/300 | Train Loss: -0.5724 | Val Loss: -0.5580
#   [Train: 1.50s | Val: 0.27s | Save: 0.00s | Total: 1.78s]
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# No existing model found. Starting fresh...
# Saved new best model.
# Epoch 1/300 | Train Loss: 1.6028 | Val Loss: 1.1811
#   [Train: 1.53s | Val: 0.29s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 2/300 | Train Loss: 0.9836 | Val Loss: 0.7992
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.81s]
# Saved new best model.
# Epoch 3/300 | Train Loss: 0.7429 | Val Loss: 0.6650
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.81s]
# Saved new best model.
# Epoch 4/300 | Train Loss: 0.6586 | Val Loss: 0.6108
#   [Train: 1.51s | Val: 0.28s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 5/300 | Train Loss: 0.6202 | Val Loss: 0.5831
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 6/300 | Train Loss: 0.5989 | Val Loss: 0.5673
#   [Train: 1.52s | Val: 0.29s | Save: 0.00s | Total: 1.81s]
# Saved new best model.
# Epoch 7/300 | Train Loss: 0.5869 | Val Loss: 0.5578
#   [Train: 1.56s | Val: 0.29s | Save: 0.00s | Total: 1.85s]
# Saved new best model.
# Epoch 8/300 | Train Loss: 0.5806 | Val Loss: 0.5528
#   [Train: 1.54s | Val: 0.28s | Save: 0.00s | Total: 1.83s]
# Saved new best model.
# Epoch 9/300 | Train Loss: 0.5767 | Val Loss: 0.5504
#   [Train: 1.58s | Val: 0.26s | Save: 0.00s | Total: 1.85s]
# Saved new best model.
# Epoch 10/300 | Train Loss: 0.5764 | Val Loss: 0.5498
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 11/300 | Train Loss: 0.5647 | Val Loss: 0.5291
#   [Train: 1.55s | Val: 0.32s | Save: 0.00s | Total: 1.88s]
# Saved new best model.
# Epoch 12/300 | Train Loss: 0.5474 | Val Loss: 0.5124
#   [Train: 1.54s | Val: 0.29s | Save: 0.00s | Total: 1.83s]
# Saved new best model.
# Epoch 13/300 | Train Loss: 0.5336 | Val Loss: 0.5002
#   [Train: 1.57s | Val: 0.29s | Save: 0.00s | Total: 1.86s]
# Saved new best model.
# Epoch 14/300 | Train Loss: 0.5226 | Val Loss: 0.4900
#   [Train: 1.50s | Val: 0.27s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 15/300 | Train Loss: 0.5129 | Val Loss: 0.4813
#   [Train: 1.51s | Val: 0.27s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 16/300 | Train Loss: 0.5078 | Val Loss: 0.4731
#   [Train: 1.52s | Val: 0.27s | Save: 0.00s | Total: 1.79s]
# Saved new best model.
# Epoch 17/300 | Train Loss: 0.4989 | Val Loss: 0.4665
#   [Train: 1.54s | Val: 0.28s | Save: 0.00s | Total: 1.83s]
# Saved new best model.
# Epoch 18/300 | Train Loss: 0.4923 | Val Loss: 0.4611
#   [Train: 1.56s | Val: 0.30s | Save: 0.00s | Total: 1.86s]
# Saved new best model.
# Epoch 19/300 | Train Loss: 0.4855 | Val Loss: 0.4559
#   [Train: 1.56s | Val: 0.29s | Save: 0.00s | Total: 1.86s]
# Saved new best model.
# Epoch 20/300 | Train Loss: 0.4827 | Val Loss: 0.4515
#   [Train: 1.53s | Val: 0.30s | Save: 0.00s | Total: 1.83s]
# Saved new best model.
# Epoch 21/300 | Train Loss: 0.4773 | Val Loss: 0.4480
#   [Train: 1.54s | Val: 0.26s | Save: 0.00s | Total: 1.81s]
# Saved new best model.
# Epoch 22/300 | Train Loss: 0.4743 | Val Loss: 0.4451
#   [Train: 1.53s | Val: 0.29s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 23/300 | Train Loss: 0.4722 | Val Loss: 0.4428
#   [Train: 1.55s | Val: 0.28s | Save: 0.00s | Total: 1.84s]
# Saved new best model.
# Epoch 24/300 | Train Loss: 0.4699 | Val Loss: 0.4410
#   [Train: 1.59s | Val: 0.29s | Save: 0.00s | Total: 1.89s]
# Saved new best model.
# Epoch 25/300 | Train Loss: 0.4688 | Val Loss: 0.4397
#   [Train: 1.53s | Val: 0.28s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 26/300 | Train Loss: 0.4665 | Val Loss: 0.4387
#   [Train: 1.53s | Val: 0.30s | Save: 0.00s | Total: 1.83s]
# Saved new best model.
# Epoch 27/300 | Train Loss: 0.4652 | Val Loss: 0.4380
#   [Train: 1.54s | Val: 0.28s | Save: 0.00s | Total: 1.83s]
# Saved new best model.
# Epoch 28/300 | Train Loss: 0.4655 | Val Loss: 0.4377
#   [Train: 1.56s | Val: 0.28s | Save: 0.00s | Total: 1.84s]
# Saved new best model.
# Epoch 29/300 | Train Loss: 0.4664 | Val Loss: 0.4375
#   [Train: 1.57s | Val: 0.29s | Save: 0.00s | Total: 1.87s]
# Saved new best model.
# Epoch 30/300 | Train Loss: 0.4658 | Val Loss: 0.4375
#   [Train: 1.54s | Val: 0.28s | Save: 0.00s | Total: 1.82s]
# Saved new best model.
# Epoch 31/300 | Train Loss: 0.4634 | Val Loss: 0.4314
#   [Train: 1.56s | Val: 0.28s | Save: 0.00s | Total: 1.84s]
# Saved new best model.
# Epoch 32/300 | Train Loss: 0.4576 | Val Loss: 0.4255
#   [Train: 0.49s | Val: 0.21s | Save: 0.00s | Total: 0.70s]
# Saved new best model.
# Epoch 33/300 | Train Loss: 0.4513 | Val Loss: 0.4204
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.66s]
# Saved new best model.
# Epoch 34/300 | Train Loss: 0.4450 | Val Loss: 0.4143
#   [Train: 0.40s | Val: 0.22s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 35/300 | Train Loss: 0.4419 | Val Loss: 0.4096
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# Saved new best model.
# Epoch 36/300 | Train Loss: 0.4354 | Val Loss: 0.4049
#   [Train: 0.47s | Val: 0.21s | Save: 0.00s | Total: 0.68s]
# Saved new best model.
# Epoch 37/300 | Train Loss: 0.4297 | Val Loss: 0.4007
#   [Train: 0.47s | Val: 0.19s | Save: 0.00s | Total: 0.66s]
# Saved new best model.
# Epoch 38/300 | Train Loss: 0.4260 | Val Loss: 0.3971
#   [Train: 0.47s | Val: 0.22s | Save: 0.00s | Total: 0.69s]
# Saved new best model.
# Epoch 39/300 | Train Loss: 0.4239 | Val Loss: 0.3931
#   [Train: 0.48s | Val: 0.18s | Save: 0.00s | Total: 0.67s]
# Saved new best model.
# Epoch 40/300 | Train Loss: 0.4205 | Val Loss: 0.3907
#   [Train: 0.40s | Val: 0.20s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 41/300 | Train Loss: 0.4177 | Val Loss: 0.3872
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 42/300 | Train Loss: 0.4147 | Val Loss: 0.3848
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# Saved new best model.
# Epoch 43/300 | Train Loss: 0.4128 | Val Loss: 0.3818
#   [Train: 0.41s | Val: 0.22s | Save: 0.01s | Total: 0.64s]
# Saved new best model.
# Epoch 44/300 | Train Loss: 0.4090 | Val Loss: 0.3794
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# Saved new best model.
# Epoch 45/300 | Train Loss: 0.4085 | Val Loss: 0.3771
#   [Train: 0.47s | Val: 0.18s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 46/300 | Train Loss: 0.4051 | Val Loss: 0.3755
#   [Train: 0.41s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Saved new best model.
# Epoch 47/300 | Train Loss: 0.4037 | Val Loss: 0.3735
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 48/300 | Train Loss: 0.4026 | Val Loss: 0.3715
#   [Train: 0.43s | Val: 0.21s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 49/300 | Train Loss: 0.3995 | Val Loss: 0.3704
#   [Train: 0.48s | Val: 0.24s | Save: 0.00s | Total: 0.72s]
# Saved new best model.
# Epoch 50/300 | Train Loss: 0.3988 | Val Loss: 0.3690
#   [Train: 0.47s | Val: 0.22s | Save: 0.00s | Total: 0.69s]
# Saved new best model.
# Epoch 51/300 | Train Loss: 0.3992 | Val Loss: 0.3677
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.70s]
# Saved new best model.
# Epoch 52/300 | Train Loss: 0.3962 | Val Loss: 0.3668
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 53/300 | Train Loss: 0.3946 | Val Loss: 0.3658
#   [Train: 0.45s | Val: 0.24s | Save: 0.00s | Total: 0.69s]
# Saved new best model.
# Epoch 54/300 | Train Loss: 0.3955 | Val Loss: 0.3648
#   [Train: 0.45s | Val: 0.23s | Save: 0.00s | Total: 0.68s]
# Saved new best model.
# Epoch 55/300 | Train Loss: 0.3948 | Val Loss: 0.3641
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.70s]
# Saved new best model.
# Epoch 56/300 | Train Loss: 0.3926 | Val Loss: 0.3634
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.71s]
# Saved new best model.
# Epoch 57/300 | Train Loss: 0.3923 | Val Loss: 0.3629
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 58/300 | Train Loss: 0.3908 | Val Loss: 0.3623
#   [Train: 0.49s | Val: 0.21s | Save: 0.00s | Total: 0.71s]
# Saved new best model.
# Epoch 59/300 | Train Loss: 0.3903 | Val Loss: 0.3619
#   [Train: 0.44s | Val: 0.23s | Save: 0.00s | Total: 0.68s]
# Saved new best model.
# Epoch 60/300 | Train Loss: 0.3898 | Val Loss: 0.3615
#   [Train: 0.47s | Val: 0.22s | Save: 0.00s | Total: 0.71s]
# Saved new best model.
# Epoch 61/300 | Train Loss: 0.3899 | Val Loss: 0.3612
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Saved new best model.
# Epoch 62/300 | Train Loss: 0.3900 | Val Loss: 0.3610
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Saved new best model.
# Epoch 63/300 | Train Loss: 0.3921 | Val Loss: 0.3607
#   [Train: 0.45s | Val: 0.22s | Save: 0.00s | Total: 0.67s]
# Saved new best model.
# Epoch 64/300 | Train Loss: 0.3890 | Val Loss: 0.3606
#   [Train: 0.48s | Val: 0.19s | Save: 0.00s | Total: 0.68s]
# Saved new best model.
# Epoch 65/300 | Train Loss: 0.3905 | Val Loss: 0.3605
#   [Train: 0.39s | Val: 0.21s | Save: 0.00s | Total: 0.61s]
# Saved new best model.
# Epoch 66/300 | Train Loss: 0.3895 | Val Loss: 0.3604
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Saved new best model.
# Epoch 67/300 | Train Loss: 0.3884 | Val Loss: 0.3604
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Saved new best model.
# Epoch 68/300 | Train Loss: 0.3884 | Val Loss: 0.3603
#   [Train: 0.40s | Val: 0.17s | Save: 0.00s | Total: 0.57s]
# Saved new best model.
# Epoch 69/300 | Train Loss: 0.3893 | Val Loss: 0.3603
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.67s]
# Saved new best model.
# Epoch 70/300 | Train Loss: 0.3881 | Val Loss: 0.3603
#   [Train: 0.49s | Val: 0.21s | Save: 0.00s | Total: 0.69s]
# Saved new best model.
# Epoch 71/300 | Train Loss: 0.3881 | Val Loss: 0.3595
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Saved new best model.
# Epoch 72/300 | Train Loss: 0.3881 | Val Loss: 0.3560
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Saved new best model.
# Epoch 73/300 | Train Loss: 0.3833 | Val Loss: 0.3551
#   [Train: 0.44s | Val: 0.22s | Save: 0.00s | Total: 0.66s]
# Saved new best model.
# Epoch 74/300 | Train Loss: 0.3830 | Val Loss: 0.3527
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# Saved new best model.
# ...
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 202/300 | Train Loss: 2.4156 | Val Loss: 2.4166
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 203/300 | Train Loss: 2.4177 | Val Loss: 2.4290
#   [Train: 0.47s | Val: 0.21s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 204/300 | Train Loss: 2.4274 | Val Loss: 2.4181
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 205/300 | Train Loss: 2.4189 | Val Loss: 2.4156
#   [Train: 0.45s | Val: 0.19s | Save: 0.00s | Total: 0.65s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 206/300 | Train Loss: 2.4143 | Val Loss: 2.4151
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.64s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 207/300 | Train Loss: 2.4119 | Val Loss: 2.4145
#   [Train: 0.42s | Val: 0.18s | Save: 0.00s | Total: 0.61s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 208/300 | Train Loss: 2.4127 | Val Loss: 2.4153
#   [Train: 0.63s | Val: 0.20s | Save: 0.00s | Total: 0.84s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 209/300 | Train Loss: 2.4144 | Val Loss: 2.4155
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 210/300 | Train Loss: 2.4137 | Val Loss: 2.4140
#   [Train: 0.48s | Val: 0.23s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 211/300 | Train Loss: 2.4135 | Val Loss: 2.4148
#   [Train: 0.49s | Val: 0.19s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 212/300 | Train Loss: 2.4145 | Val Loss: 2.4149
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 213/300 | Train Loss: 2.4171 | Val Loss: 2.4175
#   [Train: 0.48s | Val: 0.18s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 214/300 | Train Loss: 2.4155 | Val Loss: 2.4148
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 215/300 | Train Loss: 2.4135 | Val Loss: 2.4151
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch
| Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 297/300 | Train Loss: 2.4123 | Val Loss: 2.4143
#   [Train: 0.47s | Val: 0.24s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 298/300 | Train Loss: 2.4125 | Val Loss: 2.4141
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 299/300 | Train Loss: 2.4120 | Val Loss: 2.4142
#   [Train: 0.52s | Val: 0.19s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 300/300 | Train Loss: 2.4105 | Val Loss: 2.4142
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.63s]

# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs

# %%
show_training_history(conf_dict,EXPERIMENT_DIR)

# %% [markdown]
# ## 6.2 inspect transformation function for source nodes h()

# %%
show_hdag_for_source_nodes(conf_dict,EXPERIMENT_DIR,device=device,xmin_plot=0,xmax_plot=1) # TODO for other nodes funciton
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# h() for  x1:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance
#
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(conf_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# Train loader (x1): 100%|██████████| 2/2 [00:00<00:00,  5.67it/s]
# Val loader (x1): 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# Train loader (x2): 100%|██████████| 2/2 [00:00<00:00,  3.33it/s]
# Val loader (x2): 100%|██████████| 1/1 [00:00<00:00,  4.37it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--
# Train loader (x3): 100%|██████████| 2/2 [00:00<00:00,  3.22it/s]
# Val loader (x3): 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]

# %% [markdown]
# ### Coefficient estimates

# %%
# x1-> x2, x1-> x3, x2-> x3
true_coeffs = {'x2': [2],'x3': [-0.2, 0.3]}

for node in conf_dict:
    print(f'\n----*----------*-------------*--------check LS of {node} ------------*-----------------*-------------------*--')
    
    if conf_dict[node]['node_type'] == 'source':
        print(f"Node type :source")
        continue
    
    # Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    # Load saved shifts
    shift_path = os.path.join(NODE_DIR, "linear_shifts_all_epochs.json")
    with open(shift_path, 'r') as f:
        all_shift_weights = json.load(f)

    # Sort epochs numerically
    epochs = sorted(all_shift_weights.keys(), key=lambda x: int(x.split('_')[1]))

    # Number of shifts (incoming edges) for this node
    example_epoch = all_shift_weights[epochs[0]]
    num_shifts = len(example_epoch)

    # Plot per shift (incoming edge)
    for shifts_idx in range(num_shifts):
        
        if node=='x3':
            shift_name = f"shift_{1}"
        else:
            shift_name = f"shift_{shifts_idx}"
        weights_over_time = []

        for epoch in epochs:
            weight_matrix = np.array(all_shift_weights[epoch][shift_name])  # shape: [out_features, in_features]
            avg_weight = weight_matrix.mean()
            weights_over_time.append(avg_weight)

        plt.figure()
        plt.plot(range(1, len(epochs) + 1), weights_over_time)

        # If this node has a true coefficient for this shift, draw a horizontal red line
        if node in true_coeffs:
            true_val = true_coeffs[node][shifts_idx]
            plt.axhline(y=true_val, color='r', linestyle='--', label=f"True coeff = {true_val}")
            plt.legend()

        plt.title(f"Linear Shift Weights in h({node}), ")
        plt.xlabel("Epoch")
        plt.ylabel(fr'$\hat{{\beta}}_{{{conf_dict[node]["parents"][shifts_idx]}}}$')
        plt.grid(True)
        plt.tight_layout()
        plt.show()
# Out:
# ----*----------*-------------*--------check LS of x1 ------------*-----------------*-------------------*--
# Node type :source
#
# ----*----------*-------------*--------check LS of x2 ------------*-----------------*-------------------*--
# ----*----------*-------------*--------check LS of x3 ------------*-----------------*-------------------*--

# %%
verbose = False
batch_size = 4112

x = torch.linspace(-1, 1, steps=1000).unsqueeze(1).to(device)  # (100, 1)


def f(x):
    return 0.75*np.arctan(5*(x+0.12))  
for node in conf_dict:
    print(f'\n----*----------*-------------*--------check CS of {node} ------------*-----------------*-------------------*--')

    if conf_dict[node]['node_type'] == 'source':
        print("Node type : source, not supported yet.")
        continue

    # Load model
    NODE_DIR = os.path.join(EXPERIMENT_DIR, node)
    model_path = os.path.join(NODE_DIR, "best_model.pt")

    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose).to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()

    for i, module in enumerate(tram_model.nn_shift):
        module_name = module.__class__.__name__
        if module_name == 'LinearShift':
            print(f"Module {i} ({module_name}) weights:")
            print(module.fc.weight.data)
        else:
            print(f"Module {i} ({module_name}) predictions:")
            with torch.no_grad():
                y = module(x)
plt.scatter(x.cpu().numpy(),y.cpu().numpy())
plt.scatter(x.cpu().numpy(),-f(x.cpu().numpy()),cmap="red")
plt.show()
# Out:
# ----*----------*-------------*--------check CS of x1 ------------*-----------------*-------------------*--
# Node type : source, not supported yet.
#
# ----*----------*-------------*--------check CS of x2 ------------*-----------------*-------------------*--
# Module 0 (LinearShift) weights:
# tensor([[1.9552]], device='cuda:0')
#
# ----*----------*-------------*--------check CS of x3 ------------*-----------------*-------------------*--
# Module 0 (ComplexShiftDefaultTabular) predictions:
# Module 1 (LinearShift) weights:
# tensor([[-0.2238]], device='cuda:0')
# /tmp/ipykernel_467870/2226846681.py:34: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x.cpu().numpy(),-f(x.cpu().numpy()),cmap="red")

# %% [markdown]
# # 7. Sample from Graph

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            n= 10_000,
                            batch_size = 1,
                            delete_all_previously_sampled=True,
                            verbose=True)
# Out:
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x1/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x2/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x1/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# h() for samples in  x1: 100%|██████████| 10000/10000 [00:01<00:00, 5138.50it/s]
# source node, Defaults to SI and 1 as inputs
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 331.70it/s]
# /home/bule/TramDag/utils/sampling_tram_data.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x2/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x2: 100%|██████████| 10000/10000 [00:02<00:00, 3480.80it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 329.57it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x3/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=1, out_features=32, bias=True)
#       (relu1): ReLU()
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (relu2): ReLU()
#       (fc3): Linear(in_features=32, out_features=1, bias=False)
#     )
#     (1): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x3: 100%|██████████| 10000/10000 [00:05<00:00, 1845.13it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 329.64it/s]

# %% [markdown]
# ## 7.3 Inspect Sampling

# %%
show_samples_vs_true(test_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')

# %% [markdown]
# ## 7.4 Intervention

# %%
def f(x):
    return 0.75*np.arctan(5*(x+0.12))  

intervention_df=dgp(10_000, doX=[-1.0, None, None], seed=-1)
sns.pairplot(intervention_df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            do_interventions={'x1':-1.0},
                            n= 10_000,
                            batch_size = 32,
                            delete_all_previously_sampled=True,
                            verbose=True)
# Out:
# /home/bule/TramDag/utils/sampling_tram_data.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x1/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x2/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x1/sampling
#
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x2/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x2: 100%|██████████| 313/313 [00:00<00:00, 1289.10it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 324.97it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_complexDGP_cs2/x3/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=1, out_features=32, bias=True)
#       (relu1): ReLU()
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (relu2): ReLU()
#       (fc3): Linear(in_features=32, out_features=1, bias=False)
#     )
#     (1): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x3: 100%|██████████| 313/313 [00:00<00:00, 1055.32it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:29<00:00, 335.30it/s]

# %%
show_samples_vs_true(intervention_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')
