# %%
import os
from utils.configuration import *

# %%
experiment_name = "API_tramdagpaper_exp6_1_complexDGP_cs"      ## <--- set experiment name
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"  ## <--- set log directory
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"configuration.json")

# %%
setup_configuration(experiment_name,EXPERIMENT_DIR)
# Out:
# Configuration already exists/home/bule/TramDag/dev_experiment_logs/API_tramdagpaper_exp6_1_complexDGP_cs/configuration.json

# %%
# here you need to specify which varibles are in the graph and what type they are (continous or ordinal) for the model builder 
data_type= {'x1':'continous',
            'x2':'continous',
            'x3':'continous'} 

write_data_type_to_configuration(data_type, CONF_DICT_PATH)
# Out:
# Variable 'x1' is modeled as a continuous variable. for target and predictor.
# Variable 'x2' is modeled as a continuous variable. for target and predictor.
# Variable 'x3' is modeled as a continuous variable. for target and predictor.
# Configuration updated successfully.

# %%
interactive_adj_matrix(CONF_DICT_PATH,seed=13)
# Out:
# /home/bule/TramDag/utils/configuration.py:115: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
interactive_nn_names_matrix(CONF_DICT_PATH, seed=5)

# %%
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_blobs
import pandas as pd
from scipy.special import logit


# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return 0.75*np.arctan(5*(x+0.12))  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        z2 = logit(u2)
        x2 = (z2 - 2 * x1) / 5#5#   0.42  in the trainagle strucutred cont last line is 5 for SI
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 -f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          - f(X2)        | replace h(x2|x1) with z
    # z3          = 0.63*x3 + beta3 * x1          - f(X2)        | reformulate to x2
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z3+0.2 * x1   +f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        z3 = logit(u3)
        x3 = (z3 + 0.2 * x1 + f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])
        
    #df = pd.DataFrame({'x1': x1, 'x2': x2})#, 'x3': x3})
    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df

n_obs=100_000

df = dgp(n_obs=n_obs, seed=42)

# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)
# Out:
# Setting Seed: 42

# %%
from utils.tramdag import TramDagConfig , TramDagModel

cfg = TramDagConfig.load("/home/bule/TramDag/dev_experiment_logs/API_tramdagpaper_exp6_1_complexDGP_cs/configuration.json")
cfg.plot_dag()

device='cpu'
# Out:
# /home/bule/TramDag/utils/tramdag.py:251: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
td_model = TramDagModel.from_config(cfg, set_initial_weights=False,verbose=True,debug=True,device=device,initial_data = train_df) 
# 1m52s
# Out:
# [DEBUG] TramDagModel using device: cpu
#
# [INFO] Building model for node 'x1' with settings: {'set_initial_weights': False, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2        x3
# 75220  0.729475 -0.573516 -5.786670
# 48955  0.212327 -0.198221  1.468589
# 44966  0.219109  0.129154  0.384046
# 13568  0.777640  0.816980  0.975582
# 92727  0.357308 -0.411472  0.063509
# ...         ...       ...       ...
# 6265   0.700518 -0.365170 -6.182642
# 54886  0.217960 -0.776592 -1.728733
# 76820  0.209427 -0.405457  2.565484
# 860    0.741015  0.424173 -0.742044
# 15795  0.722792 -0.405650  0.273494
#
# [80000 rows x 3 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
#
# [INFO] Building model for node 'x2' with settings: {'set_initial_weights': False, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2        x3
# 75220  0.729475 -0.573516 -5.786670
# 48955  0.212327 -0.198221  1.468589
# 44966  0.219109  0.129154  0.384046
# 13568  0.777640  0.816980  0.975582
# 92727  0.357308 -0.411472  0.063509
# ...         ...       ...       ...
# 6265   0.700518 -0.365170 -6.182642
# 54886  0.217960 -0.776592 -1.728733
# 76820  0.209427 -0.405457  2.565484
# 860    0.741015  0.424173 -0.742044
# 15795  0.722792 -0.405650  0.273494
#
# [80000 rows x 3 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20
#
# [INFO] Building model for node 'x3' with settings: {'set_initial_weights': False, 'debug': True, 'verbose': True, 'device': 'cpu', 'initial_data':              x1        x2        x3
# 75220  0.729475 -0.573516 -5.786670
# 48955  0.212327 -0.198221  1.468589
# 44966  0.219109  0.129154  0.384046
# 13568  0.777640  0.816980  0.975582
# 92727  0.357308 -0.411472  0.063509
# ...         ...       ...       ...
# 6265   0.700518 -0.365170 -6.182642
# 54886  0.217960 -0.776592 -1.728733
# 76820  0.209427 -0.405457  2.565484
# 860    0.741015  0.424173 -0.742044
# 15795  0.722792 -0.405650  0.273494
#
# [80000 rows x 3 columns]}
# [DEBUG] get_fully_specified_tram_model(): device: cpu
# [DEBUG] default_number_thetas for continuous outcomes: 20

# %%
td_model.fit(train_df, val_df,
             epochs=30,batch_size=1_000,
             verbose=False,debug=False,
             device=device,
             train_mode = "parallel")#,

#30 eps 1m 49s seq mode from start 1000 bs
#30 eps 2m 27s seq mode from start 1000 bs
# Out:
# [Parallel(n_jobs=3)]: Using backend MultiprocessingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done   3 out of   3 | elapsed:  2.5min finished
# {'x1': None, 'x2': None, 'x3': None}

# %%
td_model.get_latent( train_df)
# Out:
# [INFO] Final latent DataFrame shape: (80000, 6)
#              x1      x1_U        x2      x2_U        x3      x3_U
# 75220  0.729475  1.260334 -0.573516 -1.314436 -5.786670 -2.811833
# 48955  0.212327 -0.829351 -0.198221  0.308836  1.468589  1.146253
# 44966  0.219109 -0.781233  0.129154  1.768810  0.384046 -0.466888
# 13568  0.777640  1.961774  0.816980  4.867043  0.975582 -0.521280
# 92727  0.357308  0.067035 -0.411472 -0.604015  0.063509  0.736419
# ...         ...       ...       ...       ...       ...       ...
# 6265   0.700518  0.935417 -0.365170 -0.580809 -6.182642 -3.286594
# 54886  0.217960 -0.789407 -0.776592 -1.594929 -1.728733 -0.073192
# 76820  0.209427 -0.849805 -0.405457 -0.516364  2.565484  2.344139
# 860    0.741015  1.412352  0.424173  2.942171 -0.742044 -1.504796
# 15795  0.722792  1.177940 -0.405650 -0.743806  0.273494  0.770885
#
# [80000 rows x 6 columns]

# %%
samples, latents = td_model.sample(device='cuda')
# Out:
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/API_tramdagpaper_exp6_1_complexDGP_cs/x1/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/API_tramdagpaper_exp6_1_complexDGP_cs/x2/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/API_tramdagpaper_exp6_1_complexDGP_cs/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x1 from standard logistic distribution
# [WARNING] target_col 'x1' not in DataFrame columns — is this intended to be used as a Sampler?
# Chandrupatla root finding:  54%|█████▎    | 5372/10000 [00:16<00:14, 326.13it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 samples, latents = td_model.sample(device='cuda')
#
# File ~/TramDag/utils/tramdag.py:1123, in TramDagModel.sample(self, do_interventions, predefined_latent_samples_df, **kwargs)
#    1120     print(f"[DEBUG] sample(): device: {self.device}")
#    1122 # ---- perform sampling ----
# -> 1123 sampled_by_node, latents_by_node = sample_full_dag(
#    1124     configuration_dict=self.cfg.conf_dict,
#    1125     EXPERIMENT_DIR=EXPERIMENT_DIR,
#    1126     device=self.device,
#    1127     do_interventions=do_interventions or {},
#    1128     predefined_latent_samples_df=predefined_latent_samples_df,
#    1129     number_of_samples=settings["number_of_samples"],
#    1130     batch_size=settings["batch_size"],
#    1131     delete_all_previously_sampled=settings["delete_all_previously_sampled"],
#    1132     verbose=settings["verbose"],
#    1133     debug=settings["debug"],
#    1134     minmax_dict=self.minmax_dict,
#    1135 )
#    1137 return sampled_by_node, latents_by_node
#
# File ~/TramDag/utils/tram_data_helpers.py:994, in sample_full_dag(configuration_dict, EXPERIMENT_DIR, device, do_interventions, predefined_latent_samples_df, number_of_samples, batch_size, delete_all_previously_sampled, verbose, debug, minmax_dict)
#     991 ###*************************************************** Continous Modelled Outcome ************************************************
#     993 if is_outcome_modelled_continous(node,target_nodes_dict):
# --> 994     sampled=sample_continous_modelled_target(node,target_nodes_dict,sample_loader,tram_model,latent_sample,device=device, debug=debug,minmax_dict=minmax_dict)
#     996 ###*************************************************** Ordinal Modelled Outcome ************************************************
#     998 elif is_outcome_modelled_ordinal(node,target_nodes_dict):
#
# File ~/TramDag/utils/tram_data_helpers.py:631, in sample_continous_modelled_target(node, target_nodes_dict, sample_loader, tram_model, latent_sample, device, debug, minmax_dict)
#     621     return vectorized_object_function(
#     622         thetas_expanded,
#     623         targets,
#    (...)
#     627         k_max=min_max[1]
#     628     )
#     630 # Root finding
# --> 631 sampled = chandrupatla_root_finder(
#     632     f_vectorized,
#     633     low,
#     634     high,
#     635     max_iter=10_000,
#     636     tol=1e-12
#     637 )
#     639 if sampled is None or torch.isnan(sampled).any():
#     640     raise RuntimeError("Root finding failed: returned None or contains NaNs.")
#
# File ~/TramDag/utils/loss_continous.py:399, in chandrupatla_root_finder(f, low, high, max_iter, tol)
#     391 fallback = (
#     392     (s < torch.minimum(a, b)) |
#     393     (s > torch.maximum(a, b)) |
#     394     (torch.abs(s - b) >= torch.abs(b - c) / 2) |
#     395     (torch.abs(b - c) < tol)
#     396 )
#     397 s = torch.where(fallback, s_bisect, s)
# --> 399 fs = f(s)
#     400 c, fc = b.clone(), fb.clone()
#     402 use_lower = (fa * fs < 0)
#
# File ~/TramDag/utils/tram_data_helpers.py:621, in sample_continous_modelled_target.<locals>.f_vectorized(targets)
#     620 def f_vectorized(targets):
# --> 621     return vectorized_object_function(
#     622         thetas_expanded,
#     623         targets,
#     624         shifts,
#     625         latent_sample,
#     626         k_min=min_max[0],
#     627         k_max=min_max[1]
#     628     )
#
# File ~/TramDag/utils/loss_continous.py:418, in vectorized_object_function(thetas, targets, shifts, latent_sample, k_min, k_max)
#     415 def vectorized_object_function( thetas: torch.Tensor,targets: torch.Tensor, shifts: torch.Tensor,
#     416                                latent_sample: torch.Tensor, k_min: float, k_max: float) -> torch.Tensor:
#     417     # h(xj)-latent_sample=0 , solve for xj
# --> 418     return h_extrapolated_with_shift(thetas, targets, shifts, k_min, k_max) - latent_sample
#
# File ~/TramDag/utils/loss_continous.py:326, in h_extrapolated_with_shift(thetas, targets, shifts, k_min, k_max)
#     323 h = torch.where(mask0, h_left, t_i_exp)  # placeholder
#     325 # Right extrapolation
# --> 326 b1 = h_dag(R_tensor.expand_as(targets), thetas).unsqueeze(-1) + shifts_exp
#     327 slope1 = h_dag_dash(R_tensor.expand_as(targets), thetas).unsqueeze(-1)
#     328 h_right = slope1 * (t_i_exp - R_tensor) + b1
#
# File ~/TramDag/utils/loss_continous.py:158, in h_dag(targets, thetas)
#     150 """
#     151 Args:
#     152     targets: shape (n,)
#    (...)
#     155     Tensor: shape (n,)
#     156 """
#     157 _, b = thetas.shape
# --> 158 B = bernstein_basis(targets, b - 1)  # shape (n, b)
#     159 return torch.mean(B * thetas, dim=1)
#
# File ~/TramDag/utils/loss_continous.py:144, in bernstein_basis(tensor, M)
#     138 log_powers = (
#     139     k_values * torch.log(tensor_expanded)
#     140     + (M - k_values) * torch.log(1 - tensor_expanded)
#     141 )
#     143 # Bernstein basis in log space
# --> 144 log_bernstein = log_binomial_coeff + log_powers  # shape (B, Nodes, M+1)
#     146 return torch.exp(log_bernstein)
#
# KeyboardInterrupt:

# %%
td_model.show_samples_vs_true(train_df)

# %%
t
