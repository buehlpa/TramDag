# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "tramdagpaper_exp6_1_linearDGP_ls_2"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# they made 3 experiments:
# 1. Linear-shift DGP and linear-shift model
# 2. Complex-shift DGP and complex-shift model
# 3. Linear-shift DGP and complex-shift model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return 0.3*x  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        x2_dash = logit(u2)
        x2 = (x2_dash - 2 * x1) / 5.0
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 + f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          + f(X2)        | replace h(x2|x1) with z
    # z          = 0.63*x3 + beta3 * x1          + f(X2)        | reformulate to x2
    # x3         = (z-beta3 * x1 -f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z-beta3 * x1 -f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z+0.2 * x1   -f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        x3_dash = logit(u3)
        x3 = (x3_dash + 0.2 * x1 - f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])

    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df


df = dgp(n_obs=10_000, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")


if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=10_000)

    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")

# Get min_vals and max_vals as torch tensors
quantiles = df.quantile([0.025, 0.975])
min_vals = quantiles.loc[0.025].values.astype(np.float32)
max_vals = quantiles.loc[0.975].values.astype(np.float32)

sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Setting Seed: 42
#          x1        x2        x3
# 0  0.790178 -0.257718  0.149574
# 1  0.276383  0.055677 -5.949408
# 2  0.736578  0.053836 -1.297906
# 3  0.808237  0.022891 -4.875233
# 4  0.749825 -0.335202  2.289209

# %% [markdown]
# ## 2.1 train test split

# %%
# train
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
# Validation and test
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 8000, Validation size: 1000, Test size: 1000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous , images , ordinal
adj_matrix = np.array([
    [ "0", "ls", "ls"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "ls"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)

# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
plot_nn_names_matrix(nn_names_matrix,data_type)

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_2/tramdagpaper_exp6_1_linearDGP_ls_2_conf.json
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.08668617159128189,
#   'max': 0.8121167421340942},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift'},
#   'min': -0.9664099812507629,
#   'max': 0.5599541664123535},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls', 'x2': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift',
#    'x2': 'LinearShift'},
#   'min': -5.547372817993164,
#   'max': 6.020590782165527}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 4112
epochs = 300   # <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
use_scheduler = True

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)

    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################
    optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# No existing model found. Starting fresh...
# /home/bule/TramDag/utils/tram_model_helpers.py:362: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /home/bule/TramDag/utils/tram_model_helpers.py:378: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Saved new best model.
# Epoch 1/300 | Train Loss: 1.3545 | Val Loss: 1.2626
#   [Train: 1.24s | Val: 0.60s | Save: 0.01s | Total: 1.85s]
# /home/bule/TramDag/utils/tram_model_helpers.py:405: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Saved new best model.
# Epoch 2/300 | Train Loss: 1.2357 | Val Loss: 1.1631
#   [Train: 0.67s | Val: 0.66s | Save: 0.00s | Total: 1.33s]
# Saved new best model.
# Epoch 3/300 | Train Loss: 1.1448 | Val Loss: 1.0994
#   [Train: 0.65s | Val: 0.64s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 4/300 | Train Loss: 1.0902 | Val Loss: 1.0703
#   [Train: 0.65s | Val: 0.67s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 5/300 | Train Loss: 1.0677 | Val Loss: 1.0640
#   [Train: 0.68s | Val: 0.61s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 6/300 | Train Loss: 1.0386 | Val Loss: 0.9656
#   [Train: 0.67s | Val: 0.60s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 79/300 | Train Loss: 0.0041 | Val Loss: -0.0015
#   [Train: 0.61s | Val: 0.60s | Save: 0.00s | Total: 1.21s]
# Saved new best model.
# Epoch 80/300 | Train Loss: -0.0033 | Val Loss: -0.0089
#   [Train: 0.62s | Val: 0.63s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 81/300 | Train Loss: -0.0104 | Val Loss: -0.0160
#   [Train: 0.64s | Val: 0.62s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 82/300 | Train Loss: -0.0176 | Val Loss: -0.0229
#   [Train: 0.65s | Val: 0.61s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 83/300 | Train Loss: -0.0245 | Val Loss: -0.0295
#   [Train: 0.64s | Val: 0.62s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 84/300 | Train Loss: -0.0311 | Val Loss: -0.0359
#   [Train: 0.64s | Val: 0.59s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 85/300 | Train Loss: -0.0374 | Val Loss: -0.0422
#   [Train: 0.59s | Val: 0.62s | Save: 0.00s | Total: 1.22s]
# Saved new best model.
# Epoch 86/300 | Train Loss: -0.0437 | Val Loss: -0.0482
#   [Train: 0.69s | Val: 0.61s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 87/300 | Train Loss: -0.0495 | Val Loss: -0.0540
#   [Train: 0.62s | Val: 0.64s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 88/300 | Train Loss: -0.0554 | Val Loss: -0.0596
#   [Train: 0.65s | Val: 0.61s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 89/300 | Train Loss: -0.0610 | Val Loss: -0.0651
#   [Train: 0.65s | Val: 0.63s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 90/300 | Train Loss: -0.0663 | Val Loss: -0.0703
#   [Train: 0.75s | Val: 0.62s | Save: 0.00s | Total: 1.37s]
# Saved new best model.
# Epoch 91/300 | Train Loss: -0.0714 | Val Loss: -0.0753
#   [Train: 0.63s | Val: 0.55s | Save: 0.00s | Total: 1.19s]
# Saved new best model.
# Epoch 92/300 | Train Loss: -0.0765 | Val Loss: -0.0803
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 93/300 | Train Loss: -0.0815 | Val Loss: -0.0849
#   [Train: 0.63s | Val: 0.63s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 94/300 | Train Loss: -0.0860 | Val Loss: -0.0895
#   [Train: 0.60s | Val: 0.60s | Save: 0.00s | Total: 1.21s]
# Saved new best model.
# Epoch 95/300 | Train Loss: -0.0905 | Val Loss: -0.0939
#   [Train: 0.66s | Val: 0.64s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 96/300 | Train Loss: -0.0949 | Val Loss: -0.0982
#   [Train: 0.65s | Val: 0.61s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 97/300 | Train Loss: -0.0991 | Val Loss: -0.1023
#   [Train: 0.67s | Val: 0.63s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 98/300 | Train Loss: -0.1032 | Val Loss: -0.1062
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 99/300 | Train Loss: -0.1072 | Val Loss: -0.1100
#   [Train: 0.64s | Val: 0.61s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 100/300 | Train Loss: -0.1108 | Val Loss: -0.1137
#   [Train: 0.63s | Val: 0.63s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 101/300 | Train Loss: -0.1146 | Val Loss: -0.1172
#   [Train: 0.67s | Val: 0.62s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 102/300 | Train Loss: -0.1180 | Val Loss: -0.1207
#   [Train: 0.63s | Val: 0.63s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 103/300 | Train Loss: -0.1216 | Val Loss: -0.1239
#   [Train: 0.61s | Val: 0.60s | Save: 0.00s | Total: 1.21s]
# Saved new best model.
# Epoch 104/300 | Train Loss: -0.1247 | Val Loss: -0.1271
#   [Train: 0.62s | Val: 0.60s | Save: 0.01s | Total: 1.23s]
# Saved new best model.
# Epoch 105/300 | Train Loss: -0.1277 | Val Loss: -0.1301
#   [Train: 0.62s | Val: 0.60s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 106/300 | Train Loss: -0.1308 | Val Loss: -0.1329
#   [Train: 0.64s | Val: 0.59s | Save: 0.01s | Total: 1.24s]
# Saved new best model.
# Epoch 107/300 | Train Loss: -0.1336 | Val Loss: -0.1358
#   [Train: 0.65s | Val: 0.60s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 108/300 | Train Loss: -0.1366 | Val Loss: -0.1385
#   [Train: 0.67s | Val: 0.61s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 109/300 | Train Loss: -0.1390 | Val Loss: -0.1412
#   [Train: 0.66s | Val: 0.62s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 110/300 | Train Loss: -0.1417 | Val Loss: -0.1436
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 111/300 | Train Loss: -0.1441 | Val Loss: -0.1459
#   [Train: 0.62s | Val: 0.61s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 112/300 | Train Loss: -0.1465 | Val Loss: -0.1482
#   [Train: 0.66s | Val: 0.64s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 113/300 | Train Loss: -0.1487 | Val Loss: -0.1505
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 114/300 | Train Loss: -0.1511 | Val Loss: -0.1525
#   [Train: 0.63s | Val: 0.63s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 115/300 | Train Loss: -0.1531 | Val Loss: -0.1545
#   [Train: 0.54s | Val: 0.59s | Save: 0.00s | Total: 1.14s]
# Saved new best model.
# Epoch 116/300 | Train Loss: -0.1550 | Val Loss: -0.1564
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 117/300 | Train Loss: -0.1567 | Val Loss: -0.1583
#   [Train: 0.65s | Val: 0.61s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 118/300 | Train Loss: -0.1586 | Val Loss: -0.1599
#   [Train: 0.64s | Val: 0.63s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 119/300 | Train Loss: -0.1602 | Val Loss: -0.1616
#   [Train: 0.62s | Val: 0.62s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 120/300 | Train Loss: -0.1620 | Val Loss: -0.1631
#   [Train: 0.64s | Val: 0.67s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 121/300 | Train Loss: -0.1635 | Val Loss: -0.1646
#   [Train: 0.64s | Val: 0.61s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 122/300 | Train Loss: -0.1650 | Val Loss: -0.1660
#   [Train: 0.63s | Val: 0.59s | Save: 0.00s | Total: 1.22s]
# Saved new best model.
# Epoch 123/300 | Train Loss: -0.1664 | Val Loss: -0.1673
#   [Train: 0.64s | Val: 0.62s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 124/300 | Train Loss: -0.1674 | Val Loss: -0.1686
#   [Train: 0.66s | Val: 0.61s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 125/300 | Train Loss: -0.1690 | Val Loss: -0.1698
#   [Train: 0.66s | Val: 0.59s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 126/300 | Train Loss: -0.1699 | Val Loss: -0.1709
#   [Train: 0.63s | Val: 0.65s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 127/300 | Train Loss: -0.1713 | Val Loss: -0.1719
#   [Train: 0.64s | Val: 0.61s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 128/300 | Train Loss: -0.1722 | Val Loss: -0.1729
#   [Train: 0.62s | Val: 0.64s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 129/300 | Train Loss: -0.1731 | Val Loss: -0.1738
#   [Train: 0.68s | Val: 0.61s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 130/300 | Train Loss: -0.1739 | Val Loss: -0.1747
#   [Train: 0.61s | Val: 0.61s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 131/300 | Train Loss: -0.1746 | Val Loss: -0.1754
#   [Train: 0.65s | Val: 0.63s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 132/300 | Train Loss: -0.1754 | Val Loss: -0.1761
#   [Train: 0.67s | Val: 0.60s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 133/300 | Train Loss: -0.1763 | Val Loss: -0.1768
#   [Train: 0.61s | Val: 0.61s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 134/300 | Train Loss: -0.1769 | Val Loss: -0.1774
#   [Train: 0.66s | Val: 0.66s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 135/300 | Train Loss: -0.1775 | Val Loss: -0.1780
#   [Train: 0.63s | Val: 0.61s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 136/300 | Train Loss: -0.1781 | Val Loss: -0.1785
#   [Train: 0.64s | Val: 0.61s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 137/300 | Train Loss: -0.1786 | Val Loss: -0.1789
#   [Train: 0.63s | Val: 0.62s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 138/300 | Train Loss: -0.1790 | Val Loss: -0.1793
#   [Train: 0.66s | Val: 0.58s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 139/300 | Train Loss: -0.1796 | Val Loss: -0.1797
#   [Train: 0.65s | Val: 0.64s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 140/300 | Train Loss: -0.1798 | Val Loss: -0.1800
#   [Train: 0.64s | Val: 0.60s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 141/300 | Train Loss: -0.1802 | Val Loss: -0.1803
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 142/300 | Train Loss: -0.1805 | Val Loss: -0.1806
#   [Train: 0.63s | Val: 0.62s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 143/300 | Train Loss: -0.1806 | Val Loss: -0.1808
#   [Train: 0.71s | Val: 0.61s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 144/300 | Train Loss: -0.1808 | Val Loss: -0.1810
#   [Train: 0.63s | Val: 0.63s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 145/300 | Train Loss: -0.1809 | Val Loss: -0.1812
#   [Train: 0.64s | Val: 0.61s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 146/300 | Train Loss: -0.1811 | Val Loss: -0.1812
#   [Train: 0.65s | Val: 0.62s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 147/300 | Train Loss: -0.1814 | Val Loss: -0.1814
#   [Train: 0.67s | Val: 0.62s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 148/300 | Train Loss: -0.1814 | Val Loss: -0.1814
#   [Train: 0.63s | Val: 0.62s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 149/300 | Train Loss: -0.1814 | Val Loss: -0.1816
#   [Train: 0.70s | Val: 0.60s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 150/300 | Train Loss: -0.1815 | Val Loss: -0.1816
#   [Train: 0.64s | Val: 0.60s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 151/300 | Train Loss: -0.1818 | Val Loss: -0.1816
#   [Train: 0.64s | Val: 0.60s | Save: 0.00s | Total: 1.25s]
# Epoch 152/300 | Train Loss: -0.1816 | Val Loss: -0.1816
#   [Train: 0.63s | Val: 0.67s | Save: 0.00s | Total: 1.30s]
# Epoch 153/300 | Train Loss: -0.1815 | Val Loss: -0.1816
#   [Train: 0.64s | Val: 0.63s | Save: 0.00s | Total: 1.28s]
# Epoch 154/300 | Train Loss: -0.1815 | Val Loss: -0.1816
#   [Train: 0.65s | Val: 0.61s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 155/300 | Train Loss: -0.1816 | Val Loss: -0.1816
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 156/300 | Train Loss: -0.1825 | Val Loss: -0.1853
#   [Train: 0.67s | Val: 0.61s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 157/300 | Train Loss: -0.1863 | Val Loss: -0.1889
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 158/300 | Train Loss: -0.1899 | Val Loss: -0.1925
#   [Train: 0.68s | Val: 0.64s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 159/300 | Train Loss: -0.1934 | Val Loss: -0.1960
#   [Train: 0.62s | Val: 0.63s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 160/300 | Train Loss: -0.1968 | Val Loss: -0.1995
#   [Train: 0.64s | Val: 0.63s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 161/300 | Train Loss: -0.2004 | Val Loss: -0.2029
#   [Train: 0.67s | Val: 0.66s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 162/300 | Train Loss: -0.2037 | Val Loss: -0.2064
#   [Train: 0.62s | Val: 0.64s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 163/300 | Train Loss: -0.2073 | Val Loss: -0.2096
#   [Train: 0.65s | Val: 0.62s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 164/300 | Train Loss: -0.2105 | Val Loss: -0.2130
#   [Train: 0.64s | Val: 0.64s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 165/300 | Train Loss: -0.2136 | Val Loss: -0.2161
#   [Train: 0.67s | Val: 0.61s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 166/300 | Train Loss: -0.2169 | Val Loss: -0.2193
#   [Train: 0.66s | Val: 0.68s | Save: 0.00s | Total: 1.35s]
# Saved new best model.
# Epoch 167/300 | Train Loss: -0.2200 | Val Loss: -0.2225
#   [Train: 0.61s | Val: 0.59s | Save: 0.00s | Total: 1.20s]
# Saved new best model.
# Epoch 168/300 | Train Loss: -0.2233 | Val Loss: -0.2254
#   [Train: 0.63s | Val: 0.64s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 169/300 | Train Loss: -0.2261 | Val Loss: -0.2284
#   [Train: 0.64s | Val: 0.65s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 170/300 | Train Loss: -0.2292 | Val Loss: -0.2313
#   [Train: 0.65s | Val: 0.64s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 171/300 | Train Loss: -0.2318 | Val Loss: -0.2342
#   [Train: 0.68s | Val: 0.62s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 172/300 | Train Loss: -0.2351 | Val Loss: -0.2370
#   [Train: 0.65s | Val: 0.63s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 173/300 | Train Loss: -0.2377 | Val Loss: -0.2398
#   [Train: 0.62s | Val: 0.64s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 174/300 | Train Loss: -0.2404 | Val Loss: -0.2426
#   [Train: 0.69s | Val: 0.57s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 175/300 | Train Loss: -0.2432 | Val Loss: -0.2453
#   [Train: 0.64s | Val: 0.60s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 176/300 | Train Loss: -0.2458 | Val Loss: -0.2479
#   [Train: 0.68s | Val: 0.60s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 177/300 | Train Loss: -0.2485 | Val Loss: -0.2504
#   [Train: 0.64s | Val: 0.62s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 178/300 | Train Loss: -0.2510 | Val Loss: -0.2529
#   [Train: 0.66s | Val: 0.62s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 179/300 | Train Loss: -0.2536 | Val Loss: -0.2554
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 180/300 | Train Loss: -0.2561 | Val Loss: -0.2578
#   [Train: 0.65s | Val: 0.61s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 181/300 | Train Loss: -0.2584 | Val Loss: -0.2602
#   [Train: 0.67s | Val: 0.61s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 182/300 | Train Loss: -0.2607 | Val Loss: -0.2625
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 183/300 | Train Loss: -0.2630 | Val Loss: -0.2649
#   [Train: 0.68s | Val: 0.63s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 184/300 | Train Loss: -0.2655 | Val Loss: -0.2671
#   [Train: 0.66s | Val: 0.64s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 185/300 | Train Loss: -0.2677 | Val Loss: -0.2692
#   [Train: 0.67s | Val: 0.61s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 186/300 | Train Loss: -0.2699 | Val Loss: -0.2714
#   [Train: 0.65s | Val: 0.64s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 187/300 | Train Loss: -0.2721 | Val Loss: -0.2735
#   [Train: 0.65s | Val: 0.67s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 188/300 | Train Loss: -0.2739 | Val Loss: -0.2756
#   [Train: 0.63s | Val: 0.61s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 189/300 | Train Loss: -0.2761 | Val Loss: -0.2777
#   [Train: 0.62s | Val: 0.64s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 190/300 | Train Loss: -0.2780 | Val Loss: -0.2797
#   [Train: 0.64s | Val: 0.65s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 191/300 | Train Loss: -0.2803 | Val Loss: -0.2815
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 192/300 | Train Loss: -0.2820 | Val Loss: -0.2835
#   [Train: 0.66s | Val: 0.66s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 193/300 | Train Loss: -0.2842 | Val Loss: -0.2853
#   [Train: 0.65s | Val: 0.62s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 194/300 | Train Loss: -0.2856 | Val Loss: -0.2872
#   [Train: 0.68s | Val: 0.61s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 195/300 | Train Loss: -0.2878 | Val Loss: -0.2890
#   [Train: 0.63s | Val: 0.60s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 196/300 | Train Loss: -0.2895 | Val Loss: -0.2907
#   [Train: 0.69s | Val: 0.68s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 197/300 | Train Loss: -0.2912 | Val Loss: -0.2924
#   [Train: 0.63s | Val: 0.62s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 198/300 | Train Loss: -0.2930 | Val Loss: -0.2941
#   [Train: 0.64s | Val: 0.64s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 199/300 | Train Loss: -0.2946 | Val Loss: -0.2957
#   [Train: 0.61s | Val: 0.61s | Save: 0.00s | Total: 1.22s]
# Saved new best model.
# Epoch 200/300 | Train Loss: -0.2963 | Val Loss: -0.2974
#   [Train: 0.70s | Val: 0.64s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 201/300 | Train Loss: -0.2978 | Val Loss: -0.2990
#   [Train: 0.63s | Val: 0.67s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 202/300 | Train Loss: -0.2995 | Val Loss: -0.3005
#   [Train: 0.63s | Val: 0.59s | Save: 0.01s | Total: 1.23s]
# Saved new best model.
# Epoch 203/300 | Train Loss: -0.3009 | Val Loss: -0.3020
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 204/300 | Train Loss: -0.3025 | Val Loss: -0.3035
#   [Train: 0.67s | Val: 0.60s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 205/300 | Train Loss: -0.3038 | Val Loss: -0.3050
#   [Train: 0.66s | Val: 0.69s | Save: 0.00s | Total: 1.35s]
# Saved new best model.
# Epoch 206/300 | Train Loss: -0.3053 | Val Loss: -0.3064
#   [Train: 0.64s | Val: 0.61s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 207/300 | Train Loss: -0.3067 | Val Loss: -0.3079
#   [Train: 0.64s | Val: 0.62s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 208/300 | Train Loss: -0.3084 | Val Loss: -0.3093
#   [Train: 0.66s | Val: 0.63s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 209/300 | Train Loss: -0.3096 | Val Loss: -0.3106
#   [Train: 0.65s | Val: 0.60s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 210/300 | Train Loss: -0.3111 | Val Loss: -0.3119
#   [Train: 0.64s | Val: 0.64s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 211/300 | Train Loss: -0.3122 | Val Loss: -0.3132
#   [Train: 0.67s | Val: 0.60s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 212/300 | Train Loss: -0.3133 | Val Loss: -0.3144
#   [Train: 0.61s | Val: 0.63s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 213/300 | Train Loss: -0.3146 | Val Loss: -0.3156
#   [Train: 0.61s | Val: 0.63s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 214/300 | Train Loss: -0.3159 | Val Loss: -0.3168
#   [Train: 0.64s | Val: 0.61s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 215/300 | Train Loss: -0.3172 | Val Loss: -0.3180
#   [Train: 0.60s | Val: 0.60s | Save: 0.01s | Total: 1.21s]
# Saved new best model.
# Epoch 216/300 | Train Loss: -0.3183 | Val Loss: -0.3191
#   [Train: 0.65s | Val: 0.63s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 217/300 | Train Loss: -0.3194 | Val Loss: -0.3204
#   [Train: 0.67s | Val: 0.62s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 218/300 | Train Loss: -0.3205 | Val Loss: -0.3214
#   [Train: 0.63s | Val: 0.60s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 219/300 | Train Loss: -0.3216 | Val Loss: -0.3224
#   [Train: 0.64s | Val: 0.63s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 220/300 | Train Loss: -0.3227 | Val Loss: -0.3235
#   [Train: 0.65s | Val: 0.65s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 221/300 | Train Loss: -0.3237 | Val Loss: -0.3246
#   [Train: 0.63s | Val: 0.62s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 222/300 | Train Loss: -0.3250 | Val Loss: -0.3255
#   [Train: 0.66s | Val: 0.61s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 223/300 | Train Loss: -0.3259 | Val Loss: -0.3265
#   [Train: 0.63s | Val: 0.62s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 224/300 | Train Loss: -0.3269 | Val Loss: -0.3275
#   [Train: 0.64s | Val: 0.63s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 225/300 | Train Loss: -0.3277 | Val Loss: -0.3285
#   [Train: 0.60s | Val: 0.62s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 226/300 | Train Loss: -0.3287 | Val Loss: -0.3293
#   [Train: 0.63s | Val: 0.63s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 227/300 | Train Loss: -0.3298 | Val Loss: -0.3302
#   [Train: 0.71s | Val: 0.64s | Save: 0.00s | Total: 1.35s]
# Saved new best model.
# Epoch 228/300 | Train Loss: -0.3302 | Val Loss: -0.3311
#   [Train: 0.66s | Val: 0.64s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 229/300 | Train Loss: -0.3313 | Val Loss: -0.3319
#   [Train: 0.68s | Val: 0.62s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 230/300 | Train Loss: -0.3320 | Val Loss: -0.3328
#   [Train: 0.68s | Val: 0.61s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 231/300 | Train Loss: -0.3331 | Val Loss: -0.3336
#   [Train: 0.70s | Val: 0.60s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 232/300 | Train Loss: -0.3338 | Val Loss: -0.3344
#   [Train: 0.64s | Val: 0.63s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 233/300 | Train Loss: -0.3344 | Val Loss: -0.3352
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 234/300 | Train Loss: -0.3351 | Val Loss: -0.3359
#   [Train: 0.68s | Val: 0.65s | Save: 0.00s | Total: 1.34s]
# Saved new best model.
# Epoch 235/300 | Train Loss: -0.3361 | Val Loss: -0.3366
#   [Train: 0.63s | Val: 0.58s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 236/300 | Train Loss: -0.3368 | Val Loss: -0.3374
#   [Train: 0.69s | Val: 0.63s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 237/300 | Train Loss: -0.3374 | Val Loss: -0.3381
#   [Train: 0.63s | Val: 0.62s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 238/300 | Train Loss: -0.3385 | Val Loss: -0.3387
#   [Train: 0.75s | Val: 0.62s | Save: 0.00s | Total: 1.37s]
# Saved new best model.
# Epoch 239/300 | Train Loss: -0.3390 | Val Loss: -0.3394
#   [Train: 0.65s | Val: 0.67s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 240/300 | Train Loss: -0.3398 | Val Loss: -0.3402
#   [Train: 0.66s | Val: 0.61s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 241/300 | Train Loss: -0.3403 | Val Loss: -0.3408
#   [Train: 0.63s | Val: 0.66s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 242/300 | Train Loss: -0.3408 | Val Loss: -0.3413
#   [Train: 0.62s | Val: 0.60s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 243/300 | Train Loss: -0.3414 | Val Loss: -0.3420
#   [Train: 0.64s | Val: 0.63s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 244/300 | Train Loss: -0.3420 | Val Loss: -0.3426
#   [Train: 0.63s | Val: 0.60s | Save: 0.01s | Total: 1.24s]
# Saved new best model.
# Epoch 245/300 | Train Loss: -0.3429 | Val Loss: -0.3431
#   [Train: 0.63s | Val: 0.65s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 246/300 | Train Loss: -0.3433 | Val Loss: -0.3436
#   [Train: 0.65s | Val: 0.67s | Save: 0.00s | Total: 1.32s]
# Saved new best model.
# Epoch 247/300 | Train Loss: -0.3437 | Val Loss: -0.3442
#   [Train: 0.65s | Val: 0.64s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 248/300 | Train Loss: -0.3445 | Val Loss: -0.3447
#   [Train: 0.67s | Val: 0.62s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 249/300 | Train Loss: -0.3448 | Val Loss: -0.3452
#   [Train: 0.65s | Val: 0.62s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 250/300 | Train Loss: -0.3454 | Val Loss: -0.3458
#   [Train: 0.63s | Val: 0.67s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 251/300 | Train Loss: -0.3459 | Val Loss: -0.3463
#   [Train: 0.60s | Val: 0.62s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 252/300 | Train Loss: -0.3464 | Val Loss: -0.3468
#   [Train: 0.63s | Val: 0.66s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 253/300 | Train Loss: -0.3469 | Val Loss: -0.3472
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 254/300 | Train Loss: -0.3475 | Val Loss: -0.3477
#   [Train: 0.67s | Val: 0.60s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 255/300 | Train Loss: -0.3478 | Val Loss: -0.3481
#   [Train: 0.64s | Val: 0.66s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 256/300 | Train Loss: -0.3481 | Val Loss: -0.3484
#   [Train: 0.65s | Val: 0.60s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 257/300 | Train Loss: -0.3485 | Val Loss: -0.3488
#   [Train: 0.65s | Val: 0.68s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 258/300 | Train Loss: -0.3488 | Val Loss: -0.3492
#   [Train: 0.63s | Val: 0.60s | Save: 0.01s | Total: 1.24s]
# Saved new best model.
# Epoch 259/300 | Train Loss: -0.3496 | Val Loss: -0.3497
#   [Train: 0.64s | Val: 0.63s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 260/300 | Train Loss: -0.3498 | Val Loss: -0.3499
#   [Train: 0.63s | Val: 0.64s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 261/300 | Train Loss: -0.3500 | Val Loss: -0.3503
#   [Train: 0.61s | Val: 0.61s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 262/300 | Train Loss: -0.3505 | Val Loss: -0.3506
#   [Train: 0.65s | Val: 0.59s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 263/300 | Train Loss: -0.3510 | Val Loss: -0.3510
#   [Train: 0.62s | Val: 0.67s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 264/300 | Train Loss: -0.3512 | Val Loss: -0.3513
#   [Train: 0.62s | Val: 0.61s | Save: 0.01s | Total: 1.24s]
# Saved new best model.
# Epoch 265/300 | Train Loss: -0.3517 | Val Loss: -0.3516
#   [Train: 0.60s | Val: 0.62s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 266/300 | Train Loss: -0.3516 | Val Loss: -0.3519
#   [Train: 0.63s | Val: 0.63s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 267/300 | Train Loss: -0.3517 | Val Loss: -0.3521
#   [Train: 0.63s | Val: 0.51s | Save: 0.00s | Total: 1.14s]
# Saved new best model.
# Epoch 268/300 | Train Loss: -0.3522 | Val Loss: -0.3524
#   [Train: 0.65s | Val: 0.62s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 269/300 | Train Loss: -0.3527 | Val Loss: -0.3527
#   [Train: 0.69s | Val: 0.61s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 270/300 | Train Loss: -0.3528 | Val Loss: -0.3530
#   [Train: 0.63s | Val: 0.62s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 271/300 | Train Loss: -0.3532 | Val Loss: -0.3532
#   [Train: 0.61s | Val: 0.62s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 272/300 | Train Loss: -0.3532 | Val Loss: -0.3535
#   [Train: 0.64s | Val: 0.58s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 273/300 | Train Loss: -0.3533 | Val Loss: -0.3537
#   [Train: 0.66s | Val: 0.63s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 274/300 | Train Loss: -0.3539 | Val Loss: -0.3538
#   [Train: 0.61s | Val: 0.62s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 275/300 | Train Loss: -0.3539 | Val Loss: -0.3541
#   [Train: 0.69s | Val: 0.64s | Save: 0.00s | Total: 1.33s]
# Saved new best model.
# Epoch 276/300 | Train Loss: -0.3543 | Val Loss: -0.3542
#   [Train: 0.64s | Val: 0.63s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 277/300 | Train Loss: -0.3544 | Val Loss: -0.3544
#   [Train: 0.64s | Val: 0.62s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 278/300 | Train Loss: -0.3544 | Val Loss: -0.3546
#   [Train: 0.64s | Val: 0.65s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 279/300 | Train Loss: -0.3547 | Val Loss: -0.3548
#   [Train: 0.67s | Val: 0.61s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 280/300 | Train Loss: -0.3549 | Val Loss: -0.3550
#   [Train: 0.65s | Val: 0.63s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 281/300 | Train Loss: -0.3549 | Val Loss: -0.3551
#   [Train: 0.63s | Val: 0.62s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 282/300 | Train Loss: -0.3551 | Val Loss: -0.3552
#   [Train: 0.65s | Val: 0.67s | Save: 0.00s | Total: 1.33s]
# Saved new best model.
# Epoch 283/300 | Train Loss: -0.3552 | Val Loss: -0.3553
#   [Train: 0.60s | Val: 0.60s | Save: 0.00s | Total: 1.20s]
# Saved new best model.
# Epoch 284/300 | Train Loss: -0.3554 | Val Loss: -0.3554
#   [Train: 0.67s | Val: 0.60s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 285/300 | Train Loss: -0.3557 | Val Loss: -0.3557
#   [Train: 0.62s | Val: 0.65s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 286/300 | Train Loss: -0.3558 | Val Loss: -0.3557
#   [Train: 0.70s | Val: 0.61s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 287/300 | Train Loss: -0.3556 | Val Loss: -0.3557
#   [Train: 0.61s | Val: 0.63s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 288/300 | Train Loss: -0.3560 | Val Loss: -0.3559
#   [Train: 0.69s | Val: 0.62s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 289/300 | Train Loss: -0.3559 | Val Loss: -0.3559
#   [Train: 0.63s | Val: 0.61s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 290/300 | Train Loss: -0.3562 | Val Loss: -0.3561
#   [Train: 0.65s | Val: 0.63s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 291/300 | Train Loss: -0.3561 | Val Loss: -0.3561
#   [Train: 0.64s | Val: 0.64s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 292/300 | Train Loss: -0.3561 | Val Loss: -0.3562
#   [Train: 0.66s | Val: 0.61s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 293/300 | Train Loss: -0.3562 | Val Loss: -0.3563
#   [Train: 0.70s | Val: 0.65s | Save: 0.00s | Total: 1.35s]
# Saved new best model.
# Epoch 294/300 | Train Loss: -0.3565 | Val Loss: -0.3563
#   [Train: 0.67s | Val: 0.63s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 295/300 | Train Loss: -0.3563 | Val Loss: -0.3563
#   [Train: 0.65s | Val: 0.62s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 296/300 | Train Loss: -0.3563 | Val Loss: -0.3564
#   [Train: 0.64s | Val: 0.66s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 297/300 | Train Loss: -0.3565 | Val Loss: -0.3565
#   [Train: 0.68s | Val: 0.67s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 298/300 | Train Loss: -0.3566 | Val Loss: -0.3565
#   [Train: 0.66s | Val: 0.60s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 299/300 | Train Loss: -0.3567 | Val Loss: -0.3566
#   [Train: 0.63s | Val: 0.62s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 300/300 | Train Loss: -0.3567 | Val Loss: -0.3566
#   [Train: 0.63s | Val: 0.63s | Save: 0.01s | Total: 1.26s]
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# No existing model found. Starting fresh...
# Saved new best model.
# Epoch 1/300 | Train Loss: 1503.1253 | Val Loss: 373.6094
#   [Train: 0.72s | Val: 0.36s | Save: 0.01s | Total: 1.08s]
# Epoch 2/300 | Train Loss: 1503.1252 | Val Loss: 373.6094
#   [Train: 0.70s | Val: 0.34s | Save: 0.00s | Total: 1.04s]
# Epoch 3/300 | Train Loss: 1503.1251 | Val Loss: 373.6094
#   [Train: 0.77s | Val: 0.40s | Save: 0.00s | Total: 1.17s]
# Epoch 4/300 | Train Loss: 1503.1252 | Val Loss: 373.6094
#   [Train: 0.75s | Val: 0.44s | Save: 0.00s | Total: 1.19s]
# Epoch 5/300 | Train Loss: 1503.1252 | Val Loss: 373.6094
#   [Train: 0.72s | Val: 0.38s | Save: 0.00s | Total: 1.10s]
# Saved new best model.
# Epoch 6/300 | Train Loss: 1503.1254 | Val Loss: 324.8166
#   [Train: 0.72s | Val: 0.35s | Save: 0.00s | Total: 1.08s]
# Saved new best model.
# Epoch 7/300 | Train Loss: 1212.4772 | Val Loss: 230.5593
#   [Train: 0.75s | Val: 0.37s | Save: 0.00s | Total: 1.12s]
# Saved new best model.
# Epoch 8/300 | Train Loss: 840.8288 | Val Loss: 144.5249
#   [Train: 0.75s | Val: 0.38s | Save: 0.00s | Total: 1.13s]
# Saved new best model.
# Epoch 9/300 | Train Loss: 504.3560 | Val Loss: 70.1570
#   [Train: 0.76s | Val: 0.37s | Save: 0.00s | Total: 1.13s]
# Saved new best model.
# Epoch 10/300 | Train Loss: 219.5718 | Val Loss: 10.0033
# %%
show_hdag_for_source_nodes(conf_dict,EXPERIMENT_DIR,device=device,xmin_plot=0,xmax_plot=1)
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# h() for  x1:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance
#
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(conf_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# Train loader (x1): 100%|██████████| 2/2 [00:00<00:00,  3.14it/s]
# Val loader (x1): 100%|██████████| 2/2 [00:00<00:00,  3.04it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# Train loader (x2): 100%|██████████| 2/2 [00:00<00:00,  2.64it/s]
# Val loader (x2): 100%|██████████| 1/1 [00:00<00:00,  2.57it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--
# Train loader (x3): 100%|██████████| 2/2 [00:00<00:00,  2.48it/s]
# Val loader (x3): 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]

# %% [markdown]
# ### Coefficients

# %%
conf_dict
EXPERIMENT_DIR
train_df
val_df
device

verbose=False


batch_size = 4112
for node in conf_dict:
    print(f'\n----*----------*-------------*--------check CS of {node} ------------*-----------------*-------------------*--')
    if node != 'x2':
        print('not x2')
        continue
    #### 0. Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    
    ##### 1. Load model 
    model_path = os.path.join(NODE_DIR, "best_model.pt")
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose)
    tram_model = tram_model.to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()

    ##### 2. Dataloader
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=verbose)
    
    #### 3. Forward Pass
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    h_train_list, h_val_list = [], []
    y_pred_list=[]
    with torch.no_grad():
        print("\nProcessing training data...")
        for x, y in tqdm(train_loader, desc=f"Train loader ({node})", total=len(train_loader)):
            y = y.to(device)
            int_input, shift_list = preprocess_inputs(x, device=device)
            
            y_pred = tram_model(int_input=int_input, shift_input=shift_list)
            print(y_pred)
            print(len(shift_list[0]))
            
            break
            # for pred_entry, shift_in in zip(y_pred, shift_list):
            #     pred_entry['shift_out'] = pred_entry['shift_out'] / shift_in  # elementwise division
            #     y_pred_list.append(y_pred)
            
            
            
            
            
            # h_train, _ = contram_nll(y_pred, y, min_max=min_max, return_h=True)
            # h_train_list.extend(h_train.cpu().numpy())
        # print("\nProcessing validation data...")
        # for x, y in tqdm(val_loader, desc=f"Val loader ({node})", total=len(val_loader)):
        #     y = y.to(device)
        #     int_input, shift_list = preprocess_inputs(x, device=device)
        #     y_pred = tram_model(int_input=int_input, shift_input=shift_list)
        #     h_val, _ = contram_nll(y_pred, y, min_max=min_max, return_h=True)
        #     h_val_list.extend(h_val.cpu().numpy())

# shift_outs = [entry['shift_out'][0].cpu().numpy() for entry in y_pred_list]
# shift_outs_combined = np.vstack(shift_outs)

# y_pred_list
# Out:
# ----*----------*-------------*--------check CS of x1 ------------*-----------------*-------------------*--
# not x2
#
# ----*----------*-------------*--------check CS of x2 ------------*-----------------*-------------------*--
#
# Processing training data...
# Train loader (x2):   0%|          | 0/2 [00:00<?, ?it/s]
# {'int_out': tensor([[1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         ...,
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00]], device='cuda:0'), 'shift_out': [tensor([[-0.0035],
#         [-0.0039],
#         [-0.0011],
#         ...,
#         [-0.0019],
#         [-0.0013],
#         [-0.0007]], device='cuda:0')]}
# 4112
#
# ----*----------*-------------*--------check CS of x3 ------------*-----------------*-------------------*--
# not x2

# %%
shift_outs = [entry['shift_out'][0].cpu().numpy() for entry in y_pred_list]
shift_outs_combined = np.vstack(shift_outs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 shift_outs = [entry['shift_out'][0].cpu().numpy() for entry in y_pred_list]
# ----> 2 shift_outs_combined = np.vstack(shift_outs)
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/numpy/_core/shape_base.py:287, in vstack(tup, dtype, casting)
#     285 if not isinstance(arrs, tuple):
#     286     arrs = (arrs,)
# --> 287 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: need at least one array to concatenate

# %%
shift_list
# Out:
# [tensor([[0.7913],
#          [0.7501],
#          [0.1965],
#          ...,
#          [0.7365],
#          [0.2734],
#          [0.7410]], device='cuda:0')]

# %%
shift_outs = [entry['shift_out'][0].cpu().numpy() for entry in y_pred_list]
shift_outs_combined = np.vstack(shift_outs)

print(len(shift_outs_combined))
plt.figure(figsize=(8, 6))
plt.hist(shift_outs_combined, bins=50, edgecolor='black')
plt.title("Histogram of Shift Outs Values")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# 8000
