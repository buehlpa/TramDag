# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "tramdagpaper_exp6_1_linearDGP_ls"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# they made 3 experiments:
# 1. Linear-shift DGP and linear-shift model
# 2. Complex-shift DGP and complex-shift model
# 3. Linear-shift DGP and complex-shift model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return 0.3*x  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        x2_dash = logit(u2)
        x2 = (x2_dash - 2 * x1) / 5.0
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 + f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          + f(X2)        | replace h(x2|x1) with z
    # z          = 0.63*x3 + beta3 * x1          + f(X2)        | reformulate to x2
    # x3         = (z-beta3 * x1 -f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z-beta3 * x1 -f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z+0.2 * x1   -f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        x3_dash = logit(u3)
        x3 = (x3_dash + 0.2 * x1 - f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])

    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df


df = dgp(n_obs=10_000, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")


if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=10_000)

    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")

# Get min_vals and max_vals as torch tensors
quantiles = df.quantile([0.025, 0.975])
min_vals = quantiles.loc[0.025].values.astype(np.float32)
max_vals = quantiles.loc[0.975].values.astype(np.float32)

sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Setting Seed: 42
# Loaded data from /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls/tramdagpaper_exp6_1_linearDGP_ls.csv

# %% [markdown]
# ## 2.1 train test split

# %%
# train
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
# Validation and test
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 8000, Validation size: 1000, Test size: 1000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous , images , ordinal
adj_matrix = np.array([
    [ "0", "ls", "ls"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "ls"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)

# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
plot_nn_names_matrix(nn_names_matrix,data_type)

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls/tramdagpaper_exp6_1_linearDGP_ls_conf.json
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.08668617159128189,
#   'max': 0.8121167421340942},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift'},
#   'min': -0.9664099812507629,
#   'max': 0.5599541664123535},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls', 'x2': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift',
#    'x2': 'LinearShift'},
#   'min': -5.547372817993164,
#   'max': 6.020590782165527}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 4112
epochs = 1000   # <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
use_scheduler = True

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)

    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################
    optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 1000...
# Node x1 already trained for 1000 epochs. Skipping.
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# Existing model found. Loading weights and history...
# Continuing training from epoch 1000...
# Node x2 already trained for 1000 epochs. Skipping.
#
# ----*----------*-------------*--------------- Node: x3 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0-1): 2 x LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# Existing model found. Loading weights and history...
# Continuing training from epoch 361...
# /home/bule/TramDag/utils/tram_model_helpers.py:360: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /home/bule/TramDag/utils/tram_model_helpers.py:376: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 362/1000 | Train Loss: 19.7952 | Val Loss: 2.4586
#   [Train: 1.43s | Val: 0.43s | Save: 0.01s | Total: 1.87s]
# /home/bule/TramDag/utils/tram_model_helpers.py:403: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Epoch 363/1000 | Train Loss: 19.7949 | Val Loss: 2.4586
#   [Train: 0.79s | Val: 0.39s | Save: 0.00s | Total: 1.18s]
# Epoch 364/1000 | Train Loss: 19.7964 | Val Loss: 2.4586
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 365/1000 | Train Loss: 19.7965 | Val Loss: 2.4586
#   [Train: 0.80s | Val: 0.37s | Save: 0.00s | Total: 1.17s]
# Epoch 366/1000 | Train Loss: 19.7955 | Val Loss: 2.4586
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 367/1000 | Train Loss: 19.7955 | Val Loss: 68.6590
#   [Train: 0.87s | Val: 0.41s | Save: 0.00s | Total: 1.29s]
# Epoch 368/1000 | Train Loss: 243.7211 | Val Loss: 36.3739
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 369/1000 | Train Loss: 66.2918 | Val Loss: 13.1783
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 370/1000 | Train Loss: 65.2961 | Val Loss: 2.9977
#   [Train: 0.82s | Val: 0.41s | Save: 0.00s | Total: 1.23s]
# Epoch 371/1000 | Train Loss: 20.8235 | Val Loss: 22.0663
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 372/1000 | Train Loss: 63.3013 | Val Loss: 14.1477
#   [Train: 0.82s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 373/1000 | Train Loss: 22.0999 | Val Loss: 2.5626
#   [Train: 0.83s | Val: 0.40s | Save: 0.00s | Total: 1.24s]
# Epoch 374/1000 | Train Loss: 19.3766 | Val Loss: 2.4899
#   [Train: 0.86s | Val: 0.39s | Save: 0.01s | Total: 1.25s]
# Epoch 375/1000 | Train Loss: 19.1266 | Val Loss: 2.8547
#   [Train: 0.83s | Val: 0.37s | Save: 0.00s | Total: 1.21s]
# Epoch 376/1000 | Train Loss: 13.3936 | Val Loss: 3.3219
#   [Train: 0.84s | Val: 0.40s | Save: 0.00s | Total: 1.24s]
# Epoch 377/1000 | Train Loss: 38.6231 | Val Loss: 38.2533
#   [Train: 0.83s | Val: 0.38s | Save: 0.00s | Total: 1.22s]
# Epoch 378/1000 | Train Loss: 136.9228 | Val Loss: 34.9536
#   [Train: 0.84s | Val: 0.38s | Save: 0.00s | Total: 1.22s]
# Epoch 379/1000 | Train Loss: 93.6726 | Val Loss: 3.3828
#   [Train: 0.84s | Val: 0.42s | Save: 0.01s | Total: 1.27s]
# Epoch 380/1000 | Train Loss: 63.0088 | Val Loss: 35.8549
#   [Train: 0.83s | Val: 0.41s | Save: 0.00s | Total: 1.24s]
# Epoch 381/1000 | Train Loss: 172.4814 | Val Loss: 38.8808
#   [Train: 0.79s | Val: 0.39s | Save: 0.00s | Total: 1.19s]
# Epoch 382/1000 | Train Loss: 157.7578 | Val Loss: 16.8958
#   [Train: 0.83s | Val: 0.43s | Save: 0.00s | Total: 1.26s]
# Epoch 383/1000 | Train Loss: 52.3481 | Val Loss: 22.1666
#   [Train: 0.80s | Val: 0.40s | Save: 0.00s | Total: 1.20s]
# Epoch 384/1000 | Train Loss: 91.6327 | Val Loss: 39.6420
#   [Train: 0.83s | Val: 0.41s | Save: 0.00s | Total: 1.25s]
# Epoch 385/1000 | Train Loss: 137.0760 | Val Loss: 34.5480
#   [Train: 0.83s | Val: 0.43s | Save: 0.00s | Total: 1.26s]
# Epoch 386/1000 | Train Loss: 100.9670 | Val Loss: 15.3888
#   [Train: 0.81s | Val: 0.40s | Save: 0.00s | Total: 1.21s]
# Epoch 387/1000 | Train Loss: 32.3207 | Val Loss: 5.4727
#   [Train: 0.82s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 388/1000 | Train Loss: 45.8956 | Val Loss: 7.7720
#   [Train: 0.83s | Val: 0.39s | Save: 0.00s | Total: 1.22s]
# Epoch 389/1000 | Train Loss: 49.9497 | Val Loss: 5.6211
#   [Train: 0.81s | Val: 0.40s | Save: 0.00s | Total: 1.21s]
# Epoch 390/1000 | Train Loss: 33.1235 | Val Loss: 4.1827
#   [Train: 0.83s | Val: 0.39s | Save: 0.00s | Total: 1.23s]
# Epoch 391/1000 | Train Loss: 6.4002 | Val Loss: 9.0570
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 392/1000 | Train Loss: 17.5020 | Val Loss: 10.1776
#   [Train: 0.85s | Val: 0.38s | Save: 0.00s | Total: 1.23s]
# Epoch 393/1000 | Train Loss: 18.5035 | Val Loss: 8.5064
#   [Train: 0.83s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 394/1000 | Train Loss: 11.4124 | Val Loss: 6.6320
#   [Train: 0.82s | Val: 0.38s | Save: 0.00s | Total: 1.21s]
# Epoch 395/1000 | Train Loss: 12.9079 | Val Loss: 5.7634
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 396/1000 | Train Loss: 5.7288 | Val Loss: 5.6487
#   [Train: 0.85s | Val: 0.37s | Save: 0.00s | Total: 1.22s]
# Epoch 397/1000 | Train Loss: 10.3902 | Val Loss: 2.7033
#   [Train: 0.90s | Val: 0.41s | Save: 0.00s | Total: 1.32s]
# Epoch 398/1000 | Train Loss: 25.5609 | Val Loss: 2.5452
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 399/1000 | Train Loss: 17.5698 | Val Loss: 13.7721
#   [Train: 0.84s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 400/1000 | Train Loss: 23.9672 | Val Loss: 3.9278
#   [Train: 0.82s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 401/1000 | Train Loss: 39.0146 | Val Loss: 3.2499
#   [Train: 0.79s | Val: 0.38s | Save: 0.00s | Total: 1.17s]
# Epoch 402/1000 | Train Loss: 22.9143 | Val Loss: 11.4877
#   [Train: 0.78s | Val: 0.38s | Save: 0.00s | Total: 1.16s]
# Epoch 403/1000 | Train Loss: 23.7610 | Val Loss: 3.6298
#   [Train: 0.80s | Val: 0.38s | Save: 0.00s | Total: 1.19s]
# Epoch 404/1000 | Train Loss: 8.0364 | Val Loss: 9.5500
#   [Train: 0.87s | Val: 0.39s | Save: 0.01s | Total: 1.26s]
# Epoch 405/1000 | Train Loss: 23.0826 | Val Loss: 12.9006
#   [Train: 0.80s | Val: 0.39s | Save: 0.00s | Total: 1.20s]
# Epoch 406/1000 | Train Loss: 26.5476 | Val Loss: 3.2381
#   [Train: 0.83s | Val: 0.37s | Save: 0.01s | Total: 1.21s]
# Epoch 407/1000 | Train Loss: 12.1773 | Val Loss: 6.9814
#   [Train: 0.83s | Val: 0.39s | Save: 0.00s | Total: 1.22s]
# Epoch 408/1000 | Train Loss: 16.7219 | Val Loss: 9.5068
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 409/1000 | Train Loss: 25.6427 | Val Loss: 2.4973
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 410/1000 | Train Loss: 18.2443 | Val Loss: 4.0114
#   [Train: 0.84s | Val: 0.38s | Save: 0.00s | Total: 1.22s]
# Epoch 411/1000 | Train Loss: 23.3001 | Val Loss: 6.4834
#   [Train: 0.82s | Val: 0.44s | Save: 0.01s | Total: 1.27s]
# Epoch 412/1000 | Train Loss: 30.1690 | Val Loss: 2.6820
#   [Train: 0.70s | Val: 0.40s | Save: 0.00s | Total: 1.10s]
# Epoch 413/1000 | Train Loss: 21.2644 | Val Loss: 3.2098
#   [Train: 0.82s | Val: 0.43s | Save: 0.00s | Total: 1.25s]
# Epoch 414/1000 | Train Loss: 14.5401 | Val Loss: 6.0510
#   [Train: 0.80s | Val: 0.36s | Save: 0.01s | Total: 1.17s]
# Epoch 415/1000 | Train Loss: 4.1640 | Val Loss: 2.7893
#   [Train: 0.79s | Val: 0.40s | Save: 0.01s | Total: 1.19s]
# Epoch 416/1000 | Train Loss: 12.6869 | Val Loss: 6.5389
#   [Train: 0.79s | Val: 0.37s | Save: 0.00s | Total: 1.16s]
# Epoch 417/1000 | Train Loss: 17.1770 | Val Loss: 12.7164
#   [Train: 0.84s | Val: 0.35s | Save: 0.01s | Total: 1.19s]
# Epoch 418/1000 | Train Loss: 25.2049 | Val Loss: 5.0451
#   [Train: 0.80s | Val: 0.40s | Save: 0.01s | Total: 1.20s]
# Epoch 419/1000 | Train Loss: 4.9851 | Val Loss: 3.6647
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 420/1000 | Train Loss: 6.3285 | Val Loss: 6.2970
#   [Train: 0.79s | Val: 0.39s | Save: 0.00s | Total: 1.18s]
# Epoch 421/1000 | Train Loss: 11.4468 | Val Loss: 7.5464
#   [Train: 0.83s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 422/1000 | Train Loss: 5.6336 | Val Loss: 2.7637
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 423/1000 | Train Loss: 16.4635 | Val Loss: 2.6548
#   [Train: 0.77s | Val: 0.39s | Save: 0.01s | Total: 1.16s]
# Epoch 424/1000 | Train Loss: 23.3100 | Val Loss: 4.5260
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 425/1000 | Train Loss: 8.5877 | Val Loss: 6.5543
#   [Train: 0.84s | Val: 0.41s | Save: 0.00s | Total: 1.25s]
# Epoch 426/1000 | Train Loss: 9.4168 | Val Loss: 5.4912
#   [Train: 0.83s | Val: 0.46s | Save: 0.01s | Total: 1.30s]
# Epoch 427/1000 | Train Loss: 24.0060 | Val Loss: 6.5970
#   [Train: 0.83s | Val: 0.44s | Save: 0.00s | Total: 1.27s]
# Epoch 428/1000 | Train Loss: 9.0177 | Val Loss: 5.8567
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 429/1000 | Train Loss: 4.6332 | Val Loss: 5.0163
#   [Train: 0.82s | Val: 0.42s | Save: 0.00s | Total: 1.24s]
# Epoch 430/1000 | Train Loss: 7.1162 | Val Loss: 5.3511
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 431/1000 | Train Loss: 16.9299 | Val Loss: 4.8384
#   [Train: 0.80s | Val: 0.38s | Save: 0.00s | Total: 1.19s]
# Epoch 432/1000 | Train Loss: 7.5682 | Val Loss: 4.9484
#   [Train: 0.80s | Val: 0.39s | Save: 0.00s | Total: 1.20s]
# Epoch 433/1000 | Train Loss: 9.2940 | Val Loss: 4.8386
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 434/1000 | Train Loss: 17.1200 | Val Loss: 4.9488
#   [Train: 0.88s | Val: 0.39s | Save: 0.01s | Total: 1.28s]
# Epoch 435/1000 | Train Loss: 7.1652 | Val Loss: 4.9489
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 436/1000 | Train Loss: 5.2436 | Val Loss: 4.9489
#   [Train: 0.82s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 437/1000 | Train Loss: 30.6506 | Val Loss: 3.5680
#   [Train: 0.83s | Val: 0.40s | Save: 0.00s | Total: 1.24s]
# Epoch 438/1000 | Train Loss: 34.3384 | Val Loss: 4.8947
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 439/1000 | Train Loss: 19.5618 | Val Loss: 10.7924
#   [Train: 0.80s | Val: 0.41s | Save: 0.00s | Total: 1.21s]
# Epoch 440/1000 | Train Loss: 9.8908 | Val Loss: 2.5148
#   [Train: 0.82s | Val: 0.38s | Save: 0.00s | Total: 1.21s]
# Epoch 441/1000 | Train Loss: 9.7909 | Val Loss: 16.5496
#   [Train: 0.81s | Val: 0.40s | Save: 0.00s | Total: 1.22s]
# Epoch 442/1000 | Train Loss: 50.8813 | Val Loss: 14.5030
#   [Train: 0.87s | Val: 0.39s | Save: 0.01s | Total: 1.27s]
# Epoch 443/1000 | Train Loss: 22.9250 | Val Loss: 2.6118
#   [Train: 0.84s | Val: 0.38s | Save: 0.00s | Total: 1.22s]
# Epoch 444/1000 | Train Loss: 31.3788 | Val Loss: 2.5337
#   [Train: 0.85s | Val: 0.39s | Save: 0.01s | Total: 1.24s]
# Epoch 445/1000 | Train Loss: 17.6197 | Val Loss: 2.7049
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 446/1000 | Train Loss: 15.5544 | Val Loss: 3.9225
#   [Train: 0.83s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 447/1000 | Train Loss: 22.5036 | Val Loss: 5.7531
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 448/1000 | Train Loss: 23.0389 | Val Loss: 5.9952
#   [Train: 0.80s | Val: 0.40s | Save: 0.00s | Total: 1.20s]
# Epoch 449/1000 | Train Loss: 32.1039 | Val Loss: 11.2483
#   [Train: 0.86s | Val: 0.40s | Save: 0.00s | Total: 1.27s]
# Epoch 450/1000 | Train Loss: 30.8193 | Val Loss: 10.8758
#   [Train: 0.87s | Val: 0.39s | Save: 0.01s | Total: 1.26s]
# Epoch 451/1000 | Train Loss: 5.9278 | Val Loss: 12.8351
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 452/1000 | Train Loss: 82.5142 | Val Loss: 18.0908
#   [Train: 0.85s | Val: 0.39s | Save: 0.00s | Total: 1.25s]
# Epoch 453/1000 | Train Loss: 77.0784 | Val Loss: 3.2079
#   [Train: 0.82s | Val: 0.42s | Save: 0.01s | Total: 1.24s]
# Epoch 454/1000 | Train Loss: 48.2519 | Val Loss: 30.5719
#   [Train: 0.68s | Val: 0.38s | Save: 0.01s | Total: 1.07s]
# Epoch 455/1000 | Train Loss: 106.8071 | Val Loss: 28.9926
#   [Train: 0.83s | Val: 0.39s | Save: 0.00s | Total: 1.23s]
# Epoch 456/1000 | Train Loss: 76.2923 | Val Loss: 4.3641
#   [Train: 0.82s | Val: 0.39s | Save: 0.00s | Total: 1.22s]
# Epoch 457/1000 | Train Loss: 18.2478 | Val Loss: 4.4111
#   [Train: 0.82s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 458/1000 | Train Loss: 24.2977 | Val Loss: 12.8207
#   [Train: 0.84s | Val: 0.39s | Save: 0.00s | Total: 1.24s]
# Epoch 459/1000 | Train Loss: 37.9989 | Val Loss: 13.9004
#   [Train: 0.78s | Val: 0.39s | Save: 0.00s | Total: 1.17s]
# Epoch 460/1000 | Train Loss: 27.4009 | Val Loss: 4.1054
#   [Train: 0.85s | Val: 0.46s | Save: 0.00s | Total: 1.31s]
# Epoch 461/1000 | Train Loss: 11.4892 | Val Loss: 6.0441
#   [Train: 0.81s | Val: 0.44s | Save: 0.00s | Total: 1.25s]
# Epoch 462/1000 | Train Loss: 18.1442 | Val Loss: 3.5304
#   [Train: 0.85s | Val: 0.41s | Save: 0.01s | Total: 1.27s]
# Epoch 463/1000 | Train Loss: 21.4365 | Val Loss: 11.4747
#   [Train: 0.81s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 464/1000 | Train Loss: 31.2603 | Val Loss: 11.7057
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 465/1000 | Train Loss: 31.0909 | Val Loss: 2.9677
#   [Train: 0.84s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 466/1000 | Train Loss: 26.2922 | Val Loss: 3.8402
#   [Train: 0.84s | Val: 0.37s | Save: 0.00s | Total: 1.22s]
# Epoch 467/1000 | Train Loss: 8.6344 | Val Loss: 4.9982
#   [Train: 0.88s | Val: 0.41s | Save: 0.01s | Total: 1.29s]
# Epoch 468/1000 | Train Loss: 18.2769 | Val Loss: 3.6213
#   [Train: 0.82s | Val: 0.40s | Save: 0.00s | Total: 1.23s]
# Epoch 469/1000 | Train Loss: 23.5770 | Val Loss: 8.8256
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 470/1000 | Train Loss: 19.0293 | Val Loss: 8.4051
#   [Train: 0.78s | Val: 0.40s | Save: 0.00s | Total: 1.18s]
# Epoch 471/1000 | Train Loss: 23.6561 | Val Loss: 2.6044
#   [Train: 0.83s | Val: 0.38s | Save: 0.00s | Total: 1.21s]
# Epoch 472/1000 | Train Loss: 15.7761 | Val Loss: 9.0406
#   [Train: 0.79s | Val: 0.41s | Save: 0.00s | Total: 1.20s]
# Epoch 473/1000 | Train Loss: 19.1031 | Val Loss: 7.9929
#   [Train: 0.84s | Val: 0.39s | Save: 0.00s | Total: 1.23s]
# Epoch 474/1000 | Train Loss: 9.3415 | Val Loss: 2.6144
#   [Train: 0.81s | Val: 0.44s | Save: 0.01s | Total: 1.26s]
# Epoch 475/1000 | Train Loss: 16.7663 | Val Loss: 7.8186
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 476/1000 | Train Loss: 41.6071 | Val Loss: 20.6444
#   [Train: 0.83s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 477/1000 | Train Loss: 62.4052 | Val Loss: 17.0899
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 478/1000 | Train Loss: 35.5444 | Val Loss: 2.7312
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 479/1000 | Train Loss: 23.5402 | Val Loss: 4.6163
#   [Train: 0.80s | Val: 0.36s | Save: 0.01s | Total: 1.17s]
# Epoch 480/1000 | Train Loss: 31.5923 | Val Loss: 3.7955
#   [Train: 0.81s | Val: 0.39s | Save: 0.00s | Total: 1.21s]
# Epoch 481/1000 | Train Loss: 8.1162 | Val Loss: 9.4618
#   [Train: 0.83s | Val: 0.43s | Save: 0.01s | Total: 1.27s]
# Epoch 482/1000 | Train Loss: 19.2473 | Val Loss: 8.2294
#   [Train: 0.88s | Val: 0.39s | Save: 0.01s | Total: 1.28s]
# Epoch 483/1000 | Train Loss: 24.1690 | Val Loss: 3.0491
#   [Train: 0.83s | Val: 0.38s | Save: 0.00s | Total: 1.22s]
# Epoch 484/1000 | Train Loss: 15.4811 | Val Loss: 3.1032
#   [Train: 0.87s | Val: 0.45s | Save: 0.00s | Total: 1.32s]
# Epoch 485/1000 | Train Loss: 10.8651 | Val Loss: 4.0212
#   [Train: 0.81s | Val: 0.43s | Save: 0.00s | Total: 1.25s]
# Epoch 486/1000 | Train Loss: 12.3882 | Val Loss: 5.9026
#   [Train: 0.82s | Val: 0.38s | Save: 0.00s | Total: 1.20s]
# Epoch 487/1000 | Train Loss: 19.7458 | Val Loss: 7.6445
#   [Train: 0.79s | Val: 0.41s | Save: 0.00s | Total: 1.20s]
# Epoch 488/1000 | Train Loss: 10.6233 | Val Loss: 4.9064
#   [Train: 0.81s | Val: 0.39s | Save: 0.00s | Total: 1.20s]
# Epoch 489/1000 | Train Loss: 15.3301 | Val Loss: 2.9791
#   [Train: 0.85s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 490/1000 | Train Loss: 9.4920 | Val Loss: 6.1353
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 491/1000 | Train Loss: 16.9653 | Val Loss: 11.7187
#   [Train: 0.86s | Val: 0.39s | Save: 0.00s | Total: 1.25s]
# Epoch 492/1000 | Train Loss: 26.7274 | Val Loss: 10.1278
#   [Train: 0.82s | Val: 0.40s | Save: 0.00s | Total: 1.22s]
# Epoch 493/1000 | Train Loss: 16.8770 | Val Loss: 5.0174
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 494/1000 | Train Loss: 16.9386 | Val Loss: 2.9858
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 495/1000 | Train Loss: 27.3051 | Val Loss: 3.0273
#   [Train: 0.83s | Val: 0.39s | Save: 0.00s | Total: 1.23s]
# Epoch 496/1000 | Train Loss: 23.1071 | Val Loss: 3.2289
#   [Train: 0.81s | Val: 0.40s | Save: 0.00s | Total: 1.22s]
# Epoch 497/1000 | Train Loss: 6.5105 | Val Loss: 7.7838
#   [Train: 0.84s | Val: 0.41s | Save: 0.00s | Total: 1.25s]
# Epoch 498/1000 | Train Loss: 14.1367 | Val Loss: 9.6893
#   [Train: 0.81s | Val: 0.40s | Save: 0.00s | Total: 1.22s]
# Epoch 499/1000 | Train Loss: 17.8703 | Val Loss: 8.0199
#   [Train: 0.83s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 500/1000 | Train Loss: 11.0888 | Val Loss: 5.4350
#   [Train: 0.83s | Val: 0.37s | Save: 0.00s | Total: 1.20s]
# Epoch 501/1000 | Train Loss: 6.6133 | Val Loss: 3.1377
#   [Train: 0.81s | Val: 0.39s | Save: 0.00s | Total: 1.21s]
# Epoch 502/1000 | Train Loss: 11.0945 | Val Loss: 3.2029
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 503/1000 | Train Loss: 8.6821 | Val Loss: 4.5495
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 504/1000 | Train Loss: 7.9336 | Val Loss: 5.7706
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 505/1000 | Train Loss: 15.8069 | Val Loss: 7.3078
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 506/1000 | Train Loss: 9.7494 | Val Loss: 7.3083
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 507/1000 | Train Loss: 11.4646 | Val Loss: 7.0351
#   [Train: 0.80s | Val: 0.44s | Save: 0.01s | Total: 1.24s]
# Epoch 508/1000 | Train Loss: 7.6576 | Val Loss: 6.1722
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 509/1000 | Train Loss: 4.1274 | Val Loss: 5.1667
#   [Train: 0.81s | Val: 0.41s | Save: 0.00s | Total: 1.22s]
# Epoch 510/1000 | Train Loss: 9.3041 | Val Loss: 4.3862
#   [Train: 0.80s | Val: 0.41s | Save: 0.01s | Total: 1.22s]
# Epoch 511/1000 | Train Loss: 10.0861 | Val Loss: 4.0175
#   [Train: 0.85s | Val: 0.39s | Save: 0.01s | Total: 1.25s]
# Epoch 512/1000 | Train Loss: 6.5941 | Val Loss: 3.8974
#   [Train: 0.80s | Val: 0.38s | Save: 0.00s | Total: 1.19s]
# Epoch 513/1000 | Train Loss: 8.8463 | Val Loss: 3.8544
#   [Train: 0.80s | Val: 0.37s | Save: 0.00s | Total: 1.18s]
# Epoch 514/1000 | Train Loss: 6.7154 | Val Loss: 3.8974
#   [Train: 0.79s | Val: 0.38s | Save: 0.01s | Total: 1.18s]
# Epoch 515/1000 | Train Loss: 7.0829 | Val Loss: 3.8974
#   [Train: 0.80s | Val: 0.46s | Save: 0.01s | Total: 1.26s]
# Epoch 516/1000 | Train Loss: 20.6716 | Val Loss: 3.8974
#   [Train: 0.81s | Val: 0.39s | Save: 0.00s | Total: 1.20s]
# Epoch 517/1000 | Train Loss: 24.2878 | Val Loss: 23.4139
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 518/1000 | Train Loss: 69.4903 | Val Loss: 12.2305
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 519/1000 | Train Loss: 24.8367 | Val Loss: 10.4120
#   [Train: 0.85s | Val: 0.41s | Save: 0.01s | Total: 1.27s]
# Epoch 520/1000 | Train Loss: 58.5984 | Val Loss: 2.8145
#   [Train: 0.83s | Val: 0.42s | Save: 0.01s | Total: 1.25s]
# Epoch 521/1000 | Train Loss: 30.0620 | Val Loss: 19.5285
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 522/1000 | Train Loss: 54.3174 | Val Loss: 8.6673
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 523/1000 | Train Loss: 31.1855 | Val Loss: 13.7555
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 524/1000 | Train Loss: 72.1125 | Val Loss: 4.9089
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 525/1000 | Train Loss: 35.2771 | Val Loss: 16.0777
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 526/1000 | Train Loss: 40.6843 | Val Loss: 5.5572
#   [Train: 0.87s | Val: 0.41s | Save: 0.01s | Total: 1.29s]
# Epoch 527/1000 | Train Loss: 5.4476 | Val Loss: 5.3699
#   [Train: 0.82s | Val: 0.42s | Save: 0.01s | Total: 1.25s]
# Epoch 528/1000 | Train Loss: 5.4715 | Val Loss: 8.5921
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 529/1000 | Train Loss: 9.3273 | Val Loss: 3.2701
#   [Train: 0.83s | Val: 0.45s | Save: 0.00s | Total: 1.28s]
# Epoch 530/1000 | Train Loss: 27.6438 | Val Loss: 5.2928
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 531/1000 | Train Loss: 8.0756 | Val Loss: 10.1782
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 532/1000 | Train Loss: 17.1704 | Val Loss: 2.6700
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Epoch 533/1000 | Train Loss: 22.6188 | Val Loss: 5.3835
#   [Train: 0.84s | Val: 0.39s | Save: 0.00s | Total: 1.24s]
# Epoch 534/1000 | Train Loss: 3.3212 | Val Loss: 6.5035
#   [Train: 0.86s | Val: 0.40s | Save: 0.01s | Total: 1.26s]
# Epoch 535/1000 | Train Loss: 23.7949 | Val Loss: 2.6634
#   [Train: 0.80s | Val: 0.38s | Save: 0.00s | Total: 1.18s]
# Epoch 536/1000 | Train Loss: 10.5279 | Val Loss: 9.3732
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 537/1000 | Train Loss: 31.4133 | Val Loss: 3.6252
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 538/1000 | Train Loss: 29.9560 | Val Loss: 10.6714
#   [Train: 0.81s | Val: 0.39s | Save: 0.00s | Total: 1.20s]
# Epoch 539/1000 | Train Loss: 9.2735 | Val Loss: 8.5634
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 540/1000 | Train Loss: 60.5785 | Val Loss: 9.0592
#   [Train: 0.84s | Val: 0.41s | Save: 0.00s | Total: 1.26s]
# Epoch 541/1000 | Train Loss: 36.3152 | Val Loss: 16.4768
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 542/1000 | Train Loss: 59.4443 | Val Loss: 22.9361
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 543/1000 | Train Loss: 58.0729 | Val Loss: 3.3613
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 544/1000 | Train Loss: 19.0770 | Val Loss: 2.7589
#   [Train: 0.85s | Val: 0.42s | Save: 0.01s | Total: 1.27s]
# Epoch 545/1000 | Train Loss: 15.7262 | Val Loss: 9.1355
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 546/1000 | Train Loss: 11.9655 | Val Loss: 4.2583
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 547/1000 | Train Loss: 13.6102 | Val Loss: 9.5303
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 548/1000 | Train Loss: 10.4268 | Val Loss: 2.7555
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.26s]
# Epoch 549/1000 | Train Loss: 20.0106 | Val Loss: 6.1059
#   [Train: 0.83s | Val: 0.42s | Save: 0.01s | Total: 1.26s]
# Epoch 550/1000 | Train Loss: 16.6624 | Val Loss: 3.1383
#   [Train: 0.84s | Val: 0.43s | Save: 0.01s | Total: 1.28s]
# Epoch 551/1000 | Train Loss: 14.5667 | Val Loss: 15.8485
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.19s]
# Epoch 552/1000 | Train Loss: 50.7110 | Val Loss: 16.5181
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 553/1000 | Train Loss: 28.7722 | Val Loss: 7.0652
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 554/1000 | Train Loss: 59.5215 | Val Loss: 12.8416
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 555/1000 | Train Loss: 57.8619 | Val Loss: 6.0104
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 556/1000 | Train Loss: 29.4361 | Val Loss: 22.9225
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 557/1000 | Train Loss: 68.4421 | Val Loss: 13.3150
#   [Train: 0.84s | Val: 0.40s | Save: 0.00s | Total: 1.24s]
# Epoch 558/1000 | Train Loss: 19.8088 | Val Loss: 5.9208
#   [Train: 0.80s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 559/1000 | Train Loss: 40.4895 | Val Loss: 2.9824
#   [Train: 0.89s | Val: 0.49s | Save: 0.01s | Total: 1.39s]
# Epoch 560/1000 | Train Loss: 23.8861 | Val Loss: 19.1137
#   [Train: 0.92s | Val: 0.47s | Save: 0.01s | Total: 1.40s]
# Epoch 561/1000 | Train Loss: 53.9500 | Val Loss: 10.4791
#   [Train: 0.87s | Val: 0.47s | Save: 0.01s | Total: 1.35s]
# Epoch 562/1000 | Train Loss: 17.6645 | Val Loss: 7.2895
#   [Train: 0.96s | Val: 0.43s | Save: 0.01s | Total: 1.40s]
# Epoch 563/1000 | Train Loss: 46.0989 | Val Loss: 2.6680
#   [Train: 0.94s | Val: 0.37s | Save: 0.01s | Total: 1.32s]
# Epoch 564/1000 | Train Loss: 20.3223 | Val Loss: 17.6941
#   [Train: 0.91s | Val: 0.46s | Save: 0.01s | Total: 1.38s]
# Epoch 565/1000 | Train Loss: 48.6315 | Val Loss: 9.7306
#   [Train: 0.87s | Val: 0.45s | Save: 0.00s | Total: 1.33s]
# Epoch 566/1000 | Train Loss: 28.9126 | Val Loss: 7.1401
#   [Train: 0.88s | Val: 0.48s | Save: 0.01s | Total: 1.37s]
# Epoch 567/1000 | Train Loss: 45.2882 | Val Loss: 2.6831
#   [Train: 0.75s | Val: 0.36s | Save: 0.01s | Total: 1.12s]
# Epoch 568/1000 | Train Loss: 23.8361 | Val Loss: 17.0727
#   [Train: 0.80s | Val: 0.44s | Save: 0.01s | Total: 1.24s]
# Epoch 569/1000 | Train Loss: 46.2292 | Val Loss: 9.4669
#   [Train: 0.89s | Val: 0.45s | Save: 0.01s | Total: 1.34s]
# Epoch 570/1000 | Train Loss: 16.9100 | Val Loss: 6.7566
#   [Train: 0.86s | Val: 0.42s | Save: 0.01s | Total: 1.29s]
# Epoch 571/1000 | Train Loss: 43.4873 | Val Loss: 2.7048
#   [Train: 0.79s | Val: 0.46s | Save: 0.01s | Total: 1.25s]
# Epoch 572/1000 | Train Loss: 32.7429 | Val Loss: 16.3652
#   [Train: 0.85s | Val: 0.50s | Save: 0.01s | Total: 1.36s]
# Epoch 573/1000 | Train Loss: 43.3856 | Val Loss: 9.0502
#   [Train: 0.79s | Val: 0.40s | Save: 0.01s | Total: 1.20s]
# Epoch 574/1000 | Train Loss: 16.2320 | Val Loss: 2.6710
#   [Train: 0.84s | Val: 0.38s | Save: 0.00s | Total: 1.22s]
# Epoch 575/1000 | Train Loss: 20.1485 | Val Loss: 3.8565
#   [Train: 0.74s | Val: 0.42s | Save: 0.01s | Total: 1.16s]
# Epoch 576/1000 | Train Loss: 30.3638 | Val Loss: 15.0303
#   [Train: 0.86s | Val: 0.42s | Save: 0.01s | Total: 1.29s]
# Epoch 577/1000 | Train Loss: 35.9182 | Val Loss: 5.7465
#   [Train: 0.89s | Val: 0.40s | Save: 0.01s | Total: 1.29s]
# Epoch 578/1000 | Train Loss: 4.4629 | Val Loss: 3.5992
#   [Train: 0.83s | Val: 0.48s | Save: 0.01s | Total: 1.32s]
# Epoch 579/1000 | Train Loss: 6.8191 | Val Loss: 7.6528
#   [Train: 0.89s | Val: 0.40s | Save: 0.01s | Total: 1.30s]
# Epoch 580/1000 | Train Loss: 4.6436 | Val Loss: 2.7889
#   [Train: 0.87s | Val: 0.40s | Save: 0.01s | Total: 1.27s]
# Epoch 581/1000 | Train Loss: 9.6557 | Val Loss: 10.6181
#   [Train: 0.80s | Val: 0.42s | Save: 0.01s | Total: 1.23s]
# Epoch 582/1000 | Train Loss: 25.5892 | Val Loss: 8.7641
#   [Train: 0.79s | Val: 0.38s | Save: 0.01s | Total: 1.17s]
# Epoch 583/1000 | Train Loss: 20.5724 | Val Loss: 2.9978
#   [Train: 0.84s | Val: 0.42s | Save: 0.01s | Total: 1.26s]
# Epoch 584/1000 | Train Loss: 20.2010 | Val Loss: 7.5643
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 585/1000 | Train Loss: 12.8693 | Val Loss: 5.7235
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 586/1000 | Train Loss: 10.1737 | Val Loss: 2.6939
#   [Train: 0.80s | Val: 0.36s | Save: 0.01s | Total: 1.17s]
# Epoch 587/1000 | Train Loss: 12.9497 | Val Loss: 10.8993
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 588/1000 | Train Loss: 28.4388 | Val Loss: 11.0289
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 589/1000 | Train Loss: 17.5520 | Val Loss: 3.3523
#   [Train: 0.85s | Val: 0.41s | Save: 0.01s | Total: 1.27s]
# Epoch 590/1000 | Train Loss: 12.5514 | Val Loss: 4.3426
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 591/1000 | Train Loss: 13.7068 | Val Loss: 11.3204
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.19s]
# Epoch 592/1000 | Train Loss: 20.3296 | Val Loss: 3.1225
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 593/1000 | Train Loss: 14.1629 | Val Loss: 3.3087
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Epoch 594/1000 | Train Loss: 22.5208 | Val Loss: 3.2257
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 595/1000 | Train Loss: 9.5912 | Val Loss: 8.8821
#   [Train: 0.86s | Val: 0.40s | Save: 0.01s | Total: 1.27s]
# Epoch 596/1000 | Train Loss: 10.7648 | Val Loss: 2.6814
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 597/1000 | Train Loss: 21.5072 | Val Loss: 2.6981
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 598/1000 | Train Loss: 9.6746 | Val Loss: 8.6756
#   [Train: 0.78s | Val: 0.38s | Save: 0.01s | Total: 1.17s]
# Epoch 599/1000 | Train Loss: 12.8843 | Val Loss: 3.6432
#   [Train: 0.80s | Val: 0.38s | Save: 0.00s | Total: 1.18s]
# Epoch 600/1000 | Train Loss: 15.1608 | Val Loss: 2.7643
#   [Train: 0.83s | Val: 0.42s | Save: 0.01s | Total: 1.26s]
# Epoch 601/1000 | Train Loss: 15.0554 | Val Loss: 8.6585
#   [Train: 0.85s | Val: 0.39s | Save: 0.01s | Total: 1.25s]
# Epoch 602/1000 | Train Loss: 19.2080 | Val Loss: 9.4080
#   [Train: 0.79s | Val: 0.40s | Save: 0.01s | Total: 1.19s]
# Epoch 603/1000 | Train Loss: 14.7545 | Val Loss: 3.9984
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.26s]
# Epoch 604/1000 | Train Loss: 7.9583 | Val Loss: 4.4635
#   [Train: 0.79s | Val: 0.37s | Save: 0.01s | Total: 1.17s]
# Epoch 605/1000 | Train Loss: 3.5134 | Val Loss: 6.4152
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 606/1000 | Train Loss: 4.8147 | Val Loss: 4.2881
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 607/1000 | Train Loss: 6.9647 | Val Loss: 4.5881
#   [Train: 0.86s | Val: 0.38s | Save: 0.01s | Total: 1.24s]
# Epoch 608/1000 | Train Loss: 5.6117 | Val Loss: 5.0388
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 609/1000 | Train Loss: 17.0580 | Val Loss: 10.0127
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 610/1000 | Train Loss: 17.1176 | Val Loss: 4.2030
#   [Train: 0.80s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 611/1000 | Train Loss: 12.7138 | Val Loss: 2.8281
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 612/1000 | Train Loss: 18.9047 | Val Loss: 5.2999
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 613/1000 | Train Loss: 6.0135 | Val Loss: 6.9662
#   [Train: 0.80s | Val: 0.37s | Save: 0.01s | Total: 1.18s]
# Epoch 614/1000 | Train Loss: 6.0302 | Val Loss: 3.5321
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 615/1000 | Train Loss: 5.8656 | Val Loss: 5.9824
#   [Train: 0.84s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 616/1000 | Train Loss: 8.6028 | Val Loss: 6.1011
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 617/1000 | Train Loss: 4.7876 | Val Loss: 4.7513
#   [Train: 0.83s | Val: 0.42s | Save: 0.01s | Total: 1.25s]
# Epoch 618/1000 | Train Loss: 3.6822 | Val Loss: 4.9138
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 619/1000 | Train Loss: 5.3379 | Val Loss: 4.7342
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 620/1000 | Train Loss: 3.0499 | Val Loss: 4.8463
#   [Train: 0.84s | Val: 0.43s | Save: 0.01s | Total: 1.28s]
# Epoch 621/1000 | Train Loss: 6.0839 | Val Loss: 5.5622
#   [Train: 0.80s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 622/1000 | Train Loss: 14.3847 | Val Loss: 6.2746
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 623/1000 | Train Loss: 9.6006 | Val Loss: 3.7590
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 624/1000 | Train Loss: 8.1532 | Val Loss: 4.5018
#   [Train: 0.82s | Val: 0.37s | Save: 0.01s | Total: 1.19s]
# Epoch 625/1000 | Train Loss: 3.2125 | Val Loss: 6.6689
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.26s]
# Epoch 626/1000 | Train Loss: 7.6392 | Val Loss: 5.2665
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.19s]
# Epoch 627/1000 | Train Loss: 6.9508 | Val Loss: 3.0341
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 628/1000 | Train Loss: 9.6061 | Val Loss: 4.9929
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 629/1000 | Train Loss: 5.6930 | Val Loss: 7.0680
#   [Train: 0.79s | Val: 0.42s | Save: 0.01s | Total: 1.22s]
# Epoch 630/1000 | Train Loss: 6.8266 | Val Loss: 4.1357
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 631/1000 | Train Loss: 11.6180 | Val Loss: 2.9466
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 632/1000 | Train Loss: 12.4068 | Val Loss: 3.4050
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 633/1000 | Train Loss: 8.9937 | Val Loss: 6.0468
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 634/1000 | Train Loss: 6.0632 | Val Loss: 5.5379
#   [Train: 0.81s | Val: 0.42s | Save: 0.01s | Total: 1.24s]
# Epoch 635/1000 | Train Loss: 6.8005 | Val Loss: 3.5323
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 636/1000 | Train Loss: 6.6184 | Val Loss: 4.9537
#   [Train: 0.77s | Val: 0.40s | Save: 0.01s | Total: 1.17s]
# Epoch 637/1000 | Train Loss: 9.5399 | Val Loss: 7.8961
#   [Train: 0.81s | Val: 0.42s | Save: 0.01s | Total: 1.23s]
# Epoch 638/1000 | Train Loss: 11.8132 | Val Loss: 6.4294
#   [Train: 0.83s | Val: 0.44s | Save: 0.01s | Total: 1.28s]
# Epoch 639/1000 | Train Loss: 5.3619 | Val Loss: 3.8206
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 640/1000 | Train Loss: 7.3769 | Val Loss: 3.3399
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 641/1000 | Train Loss: 7.8577 | Val Loss: 4.7616
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 642/1000 | Train Loss: 13.1960 | Val Loss: 7.5613
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 643/1000 | Train Loss: 11.2269 | Val Loss: 6.9138
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 644/1000 | Train Loss: 6.3313 | Val Loss: 4.2769
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 645/1000 | Train Loss: 12.4615 | Val Loss: 2.7365
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 646/1000 | Train Loss: 15.6451 | Val Loss: 2.7591
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 647/1000 | Train Loss: 13.0164 | Val Loss: 3.7944
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 648/1000 | Train Loss: 5.7369 | Val Loss: 6.3550
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 649/1000 | Train Loss: 7.1973 | Val Loss: 6.7371
#   [Train: 0.81s | Val: 0.37s | Save: 0.01s | Total: 1.19s]
# Epoch 650/1000 | Train Loss: 8.1032 | Val Loss: 5.8841
#   [Train: 0.80s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 651/1000 | Train Loss: 6.6662 | Val Loss: 5.0200
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 652/1000 | Train Loss: 7.9545 | Val Loss: 4.3591
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 653/1000 | Train Loss: 7.3984 | Val Loss: 3.6300
#   [Train: 0.85s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 654/1000 | Train Loss: 6.8348 | Val Loss: 3.9821
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 655/1000 | Train Loss: 13.6391 | Val Loss: 4.1157
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 656/1000 | Train Loss: 9.5231 | Val Loss: 4.7048
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 657/1000 | Train Loss: 4.2812 | Val Loss: 4.8486
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 658/1000 | Train Loss: 6.7529 | Val Loss: 5.3054
#   [Train: 0.77s | Val: 0.39s | Save: 0.01s | Total: 1.17s]
# Epoch 659/1000 | Train Loss: 4.2773 | Val Loss: 5.4608
#   [Train: 0.73s | Val: 0.39s | Save: 0.02s | Total: 1.15s]
# Epoch 660/1000 | Train Loss: 8.7737 | Val Loss: 5.2066
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 661/1000 | Train Loss: 2.7511 | Val Loss: 5.0170
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.19s]
# Epoch 662/1000 | Train Loss: 4.8988 | Val Loss: 4.8169
#   [Train: 0.79s | Val: 0.36s | Save: 0.01s | Total: 1.16s]
# Epoch 663/1000 | Train Loss: 8.3677 | Val Loss: 4.7751
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Epoch 664/1000 | Train Loss: 11.6001 | Val Loss: 4.8271
#   [Train: 0.79s | Val: 0.40s | Save: 0.01s | Total: 1.19s]
# Epoch 665/1000 | Train Loss: 14.0676 | Val Loss: 4.8271
#   [Train: 0.84s | Val: 0.43s | Save: 0.01s | Total: 1.28s]
# Epoch 666/1000 | Train Loss: 5.3485 | Val Loss: 4.7332
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 667/1000 | Train Loss: 3.1099 | Val Loss: 4.7332
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 668/1000 | Train Loss: 4.1126 | Val Loss: 4.8271
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 669/1000 | Train Loss: 6.1541 | Val Loss: 4.7849
#   [Train: 0.80s | Val: 0.42s | Save: 0.01s | Total: 1.23s]
# Epoch 670/1000 | Train Loss: 2.7519 | Val Loss: 4.8271
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Epoch 671/1000 | Train Loss: 8.5907 | Val Loss: 4.8778
#   [Train: 0.80s | Val: 0.41s | Save: 0.01s | Total: 1.22s]
# Epoch 672/1000 | Train Loss: 7.6139 | Val Loss: 4.8778
#   [Train: 0.78s | Val: 0.41s | Save: 0.01s | Total: 1.20s]
# Epoch 673/1000 | Train Loss: 5.3458 | Val Loss: 4.8778
#   [Train: 0.88s | Val: 0.41s | Save: 0.01s | Total: 1.29s]
# Epoch 674/1000 | Train Loss: 3.1044 | Val Loss: 4.8778
#   [Train: 0.81s | Val: 0.42s | Save: 0.01s | Total: 1.23s]
# Epoch 675/1000 | Train Loss: 13.9559 | Val Loss: 4.8778
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 676/1000 | Train Loss: 9.3365 | Val Loss: 4.8778
#   [Train: 0.83s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 677/1000 | Train Loss: 24.0683 | Val Loss: 13.7650
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 678/1000 | Train Loss: 22.2246 | Val Loss: 6.8053
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 679/1000 | Train Loss: 54.0981 | Val Loss: 7.7755
#   [Train: 0.83s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 680/1000 | Train Loss: 29.3634 | Val Loss: 18.6428
#   [Train: 0.80s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 681/1000 | Train Loss: 68.4051 | Val Loss: 23.9380
#   [Train: 0.86s | Val: 0.40s | Save: 0.01s | Total: 1.27s]
# Epoch 682/1000 | Train Loss: 60.0024 | Val Loss: 2.6796
#   [Train: 0.81s | Val: 0.41s | Save: 0.01s | Total: 1.22s]
# Epoch 683/1000 | Train Loss: 29.2200 | Val Loss: 4.3492
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 684/1000 | Train Loss: 18.8333 | Val Loss: 9.7089
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 685/1000 | Train Loss: 19.1787 | Val Loss: 2.7921
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 686/1000 | Train Loss: 13.6001 | Val Loss: 8.7706
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 687/1000 | Train Loss: 14.4199 | Val Loss: 2.7207
#   [Train: 0.82s | Val: 0.37s | Save: 0.01s | Total: 1.20s]
# Epoch 688/1000 | Train Loss: 19.1652 | Val Loss: 7.5696
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.24s]
# Epoch 689/1000 | Train Loss: 10.5030 | Val Loss: 4.6904
#   [Train: 0.78s | Val: 0.39s | Save: 0.01s | Total: 1.18s]
# Epoch 690/1000 | Train Loss: 5.7131 | Val Loss: 8.0250
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# Epoch 691/1000 | Train Loss: 8.1801 | Val Loss: 3.4002
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 692/1000 | Train Loss: 26.3144 | Val Loss: 6.3786
#   [Train: 0.87s | Val: 0.40s | Save: 0.01s | Total: 1.28s]
# Epoch 693/1000 | Train Loss: 6.3460 | Val Loss: 3.7122
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 694/1000 | Train Loss: 3.1858 | Val Loss: 8.8904
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 695/1000 | Train Loss: 8.7741 | Val Loss: 4.5061
#   [Train: 0.79s | Val: 0.38s | Save: 0.01s | Total: 1.17s]
# Epoch 696/1000 | Train Loss: 34.5735 | Val Loss: 3.5635
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 697/1000 | Train Loss: 6.2057 | Val Loss: 7.4919
#   [Train: 0.88s | Val: 0.40s | Save: 0.01s | Total: 1.28s]
# Epoch 698/1000 | Train Loss: 21.8420 | Val Loss: 3.4910
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 699/1000 | Train Loss: 16.9535 | Val Loss: 9.5049
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.26s]
# Epoch 700/1000 | Train Loss: 13.9209 | Val Loss: 3.8055
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 701/1000 | Train Loss: 32.5009 | Val Loss: 3.0435
#   [Train: 0.78s | Val: 0.39s | Save: 0.01s | Total: 1.17s]
# Epoch 702/1000 | Train Loss: 15.5224 | Val Loss: 16.4109
#   [Train: 0.78s | Val: 0.39s | Save: 0.01s | Total: 1.18s]
# Epoch 703/1000 | Train Loss: 38.0323 | Val Loss: 2.6877
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 704/1000 | Train Loss: 22.4917 | Val Loss: 3.1685
#   [Train: 0.80s | Val: 0.40s | Save: 0.01s | Total: 1.20s]
# Epoch 705/1000 | Train Loss: 23.6681 | Val Loss: 16.7986
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 706/1000 | Train Loss: 39.6147 | Val Loss: 2.7205
#   [Train: 0.86s | Val: 0.42s | Save: 0.01s | Total: 1.28s]
# Epoch 707/1000 | Train Loss: 20.5193 | Val Loss: 3.4605
#   [Train: 0.86s | Val: 0.36s | Save: 0.01s | Total: 1.24s]
# Epoch 708/1000 | Train Loss: 14.3906 | Val Loss: 6.8073
#   [Train: 0.80s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 709/1000 | Train Loss: 6.2118 | Val Loss: 3.5542
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.18s]
# Epoch 710/1000 | Train Loss: 28.3585 | Val Loss: 4.9487
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 711/1000 | Train Loss: 36.2541 | Val Loss: 23.4281
#   [Train: 0.83s | Val: 0.42s | Save: 0.01s | Total: 1.26s]
# Epoch 712/1000 | Train Loss: 69.7790 | Val Loss: 11.0969
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 713/1000 | Train Loss: 38.4612 | Val Loss: 12.2138
#   [Train: 0.83s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 714/1000 | Train Loss: 66.2663 | Val Loss: 4.4778
#   [Train: 0.86s | Val: 0.40s | Save: 0.01s | Total: 1.27s]
# Epoch 715/1000 | Train Loss: 19.0547 | Val Loss: 16.0317
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 716/1000 | Train Loss: 41.6910 | Val Loss: 5.2512
#   [Train: 0.81s | Val: 0.37s | Save: 0.01s | Total: 1.19s]
# Epoch 717/1000 | Train Loss: 4.3212 | Val Loss: 3.1407
#   [Train: 0.81s | Val: 0.39s | Save: 0.00s | Total: 1.21s]
# Epoch 718/1000 | Train Loss: 19.4934 | Val Loss: 10.6969
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 719/1000 | Train Loss: 26.9254 | Val Loss: 6.2079
#   [Train: 0.86s | Val: 0.40s | Save: 0.01s | Total: 1.26s]
# Epoch 720/1000 | Train Loss: 26.4819 | Val Loss: 10.5081
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 721/1000 | Train Loss: 54.1618 | Val Loss: 3.4064
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 722/1000 | Train Loss: 32.5290 | Val Loss: 25.8594
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 723/1000 | Train Loss: 83.8394 | Val Loss: 17.7899
#   [Train: 0.84s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 724/1000 | Train Loss: 31.8531 | Val Loss: 3.6705
#   [Train: 0.87s | Val: 0.39s | Save: 0.01s | Total: 1.26s]
# Epoch 725/1000 | Train Loss: 26.8099 | Val Loss: 6.4632
#   [Train: 0.66s | Val: 0.43s | Save: 0.01s | Total: 1.09s]
# Epoch 726/1000 | Train Loss: 7.1312 | Val Loss: 2.7450
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 727/1000 | Train Loss: 16.5055 | Val Loss: 8.9140
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 728/1000 | Train Loss: 16.9581 | Val Loss: 3.0727
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 729/1000 | Train Loss: 9.2558 | Val Loss: 7.2339
#   [Train: 0.78s | Val: 0.42s | Save: 0.01s | Total: 1.20s]
# Epoch 730/1000 | Train Loss: 5.0535 | Val Loss: 2.9991
#   [Train: 0.81s | Val: 0.37s | Save: 0.01s | Total: 1.19s]
# Epoch 731/1000 | Train Loss: 19.3772 | Val Loss: 9.2475
#   [Train: 0.80s | Val: 0.43s | Save: 0.01s | Total: 1.24s]
# Epoch 732/1000 | Train Loss: 19.8069 | Val Loss: 4.0316
#   [Train: 0.85s | Val: 0.38s | Save: 0.01s | Total: 1.24s]
# Epoch 733/1000 | Train Loss: 4.5353 | Val Loss: 8.1394
#   [Train: 0.80s | Val: 0.42s | Save: 0.01s | Total: 1.23s]
# Epoch 734/1000 | Train Loss: 8.7590 | Val Loss: 3.6017
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 735/1000 | Train Loss: 28.9068 | Val Loss: 4.1814
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 736/1000 | Train Loss: 8.0330 | Val Loss: 10.0296
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 737/1000 | Train Loss: 19.3765 | Val Loss: 2.8217
#   [Train: 0.80s | Val: 0.40s | Save: 0.01s | Total: 1.20s]
# Epoch 738/1000 | Train Loss: 13.6518 | Val Loss: 7.4119
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 739/1000 | Train Loss: 9.2009 | Val Loss: 3.0376
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 740/1000 | Train Loss: 6.0269 | Val Loss: 8.8878
#   [Train: 0.82s | Val: 0.45s | Save: 0.01s | Total: 1.28s]
# Epoch 741/1000 | Train Loss: 10.7972 | Val Loss: 4.0579
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 742/1000 | Train Loss: 33.8790 | Val Loss: 2.7844
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 743/1000 | Train Loss: 25.1724 | Val Loss: 16.6538
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 744/1000 | Train Loss: 42.2189 | Val Loss: 4.5056
#   [Train: 0.86s | Val: 0.38s | Save: 0.01s | Total: 1.25s]
# Epoch 745/1000 | Train Loss: 8.5568 | Val Loss: 4.1408
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 746/1000 | Train Loss: 28.8563 | Val Loss: 15.0373
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 747/1000 | Train Loss: 32.1517 | Val Loss: 2.8698
#   [Train: 0.80s | Val: 0.41s | Save: 0.01s | Total: 1.22s]
# Epoch 748/1000 | Train Loss: 27.4345 | Val Loss: 2.7742
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 749/1000 | Train Loss: 20.4530 | Val Loss: 12.0205
#   [Train: 0.87s | Val: 0.39s | Save: 0.01s | Total: 1.27s]
# Epoch 750/1000 | Train Loss: 21.4243 | Val Loss: 3.5756
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 751/1000 | Train Loss: 33.3822 | Val Loss: 2.9720
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 752/1000 | Train Loss: 15.8892 | Val Loss: 11.8544
#   [Train: 0.84s | Val: 0.37s | Save: 0.01s | Total: 1.22s]
# Epoch 753/1000 | Train Loss: 21.4059 | Val Loss: 3.2514
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 754/1000 | Train Loss: 29.8814 | Val Loss: 2.7512
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 755/1000 | Train Loss: 20.0543 | Val Loss: 13.3201
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 756/1000 | Train Loss: 27.8051 | Val Loss: 2.7522
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 757/1000 | Train Loss: 21.6810 | Val Loss: 3.2465
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 758/1000 | Train Loss: 16.0884 | Val Loss: 14.3320
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 759/1000 | Train Loss: 31.0740 | Val Loss: 2.7540
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 760/1000 | Train Loss: 21.3188 | Val Loss: 3.0517
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.23s]
# ...
# Epoch 861/1000 | Train Loss: 5.5269 | Val Loss: 8.6325
#   [Train: 0.80s | Val: 0.40s | Save: 0.01s | Total: 1.20s]
# Epoch 862/1000 | Train Loss: 19.6917 | Val Loss: 7.9716
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 863/1000 | Train Loss: 7.2179 | Val Loss: 2.9011
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 864/1000 | Train Loss: 23.0301 | Val Loss: 2.8392
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 865/1000 | Train Loss: 12.1097 | Val Loss: 8.2987
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 866/1000 | Train Loss: 19.1268 | Val Loss: 8.5101
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 867/1000 | Train Loss: 10.4309 | Val Loss: 2.7456
#   [Train: 0.78s | Val: 0.38s | Save: 0.01s | Total: 1.16s]
# Epoch 868/1000 | Train Loss: 17.5374 | Val Loss: 2.7651
#   [Train: 0.84s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 869/1000 | Train Loss: 7.9404 | Val Loss: 8.1224
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 870/1000 | Train Loss: 16.7165 | Val Loss: 6.7620
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 871/1000 | Train Loss: 10.2476 | Val Loss: 2.7922
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 872/1000 | Train Loss: 10.9447 | Val Loss: 5.5187
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 873/1000 | Train Loss: 6.1794 | Val Loss: 4.6969
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 874/1000 | Train Loss: 3.6205 | Val Loss: 3.2966
#   [Train: 0.78s | Val: 0.40s | Save: 0.01s | Total: 1.19s]
# Epoch 875/1000 | Train Loss: 6.9359 | Val Loss: 4.2734
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 876/1000 | Train Loss: 11.5376 | Val Loss: 6.9521
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.19s]
# Epoch 877/1000 | Train Loss: 7.8512 | Val Loss: 3.4797
#   [Train: 0.79s | Val: 0.38s | Save: 0.01s | Total: 1.17s]
# Epoch 878/1000 | Train Loss: 5.3716 | Val Loss: 5.0178
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 879/1000 | Train Loss: 4.3083 | Val Loss: 4.2537
#   [Train: 0.82s | Val: 0.43s | Save: 0.01s | Total: 1.26s]
# Epoch 880/1000 | Train Loss: 9.6232 | Val Loss: 2.7881
#   [Train: 0.80s | Val: 0.41s | Save: 0.01s | Total: 1.22s]
# Epoch 881/1000 | Train Loss: 9.5360 | Val Loss: 6.4293
#   [Train: 0.80s | Val: 0.37s | Save: 0.01s | Total: 1.19s]
# Epoch 882/1000 | Train Loss: 10.7536 | Val Loss: 6.2845
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 883/1000 | Train Loss: 4.1163 | Val Loss: 2.7992
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 884/1000 | Train Loss: 12.6599 | Val Loss: 3.6809
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 885/1000 | Train Loss: 2.7551 | Val Loss: 7.2288
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 886/1000 | Train Loss: 11.6428 | Val Loss: 4.9348
#   [Train: 0.84s | Val: 0.37s | Save: 0.01s | Total: 1.22s]
# Epoch 887/1000 | Train Loss: 4.5667 | Val Loss: 3.0264
#   [Train: 0.85s | Val: 0.38s | Save: 0.01s | Total: 1.24s]
# Epoch 888/1000 | Train Loss: 6.7363 | Val Loss: 6.1117
#   [Train: 0.84s | Val: 0.44s | Save: 0.01s | Total: 1.29s]
# Epoch 889/1000 | Train Loss: 8.6916 | Val Loss: 5.4178
#   [Train: 0.91s | Val: 0.38s | Save: 0.01s | Total: 1.30s]
# Epoch 890/1000 | Train Loss: 6.6768 | Val Loss: 3.5964
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 891/1000 | Train Loss: 6.3017 | Val Loss: 3.5728
#   [Train: 0.82s | Val: 0.42s | Save: 0.01s | Total: 1.26s]
# Epoch 892/1000 | Train Loss: 4.1137 | Val Loss: 5.9680
#   [Train: 0.80s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Epoch 893/1000 | Train Loss: 8.9932 | Val Loss: 5.8752
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 894/1000 | Train Loss: 5.0084 | Val Loss: 3.0292
#   [Train: 0.83s | Val: 0.38s | Save: 0.01s | Total: 1.22s]
# Epoch 895/1000 | Train Loss: 10.8726 | Val Loss: 3.0558
#   [Train: 0.82s | Val: 0.37s | Save: 0.01s | Total: 1.19s]
# Epoch 896/1000 | Train Loss: 5.9462 | Val Loss: 6.4416
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 897/1000 | Train Loss: 9.0130 | Val Loss: 5.0860
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 898/1000 | Train Loss: 2.7151 | Val Loss: 3.1850
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 899/1000 | Train Loss: 7.5940 | Val Loss: 4.3732
#   [Train: 0.87s | Val: 0.39s | Save: 0.01s | Total: 1.27s]
# Epoch 900/1000 | Train Loss: 12.3703 | Val Loss: 8.2535
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 901/1000 | Train Loss: 15.2411 | Val Loss: 5.7538
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 902/1000 | Train Loss: 2.8921 | Val Loss: 2.7935
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 903/1000 | Train Loss: 13.7319 | Val Loss: 2.8738
#   [Train: 0.85s | Val: 0.38s | Save: 0.01s | Total: 1.24s]
# Epoch 904/1000 | Train Loss: 7.4603 | Val Loss: 6.3347
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.19s]
# Epoch 905/1000 | Train Loss: 10.9651 | Val Loss: 7.1497
#   [Train: 0.83s | Val: 0.42s | Save: 0.01s | Total: 1.27s]
# Epoch 906/1000 | Train Loss: 8.5848 | Val Loss: 3.3582
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.19s]
# Epoch 907/1000 | Train Loss: 9.3754 | Val Loss: 2.8206
#   [Train: 0.80s | Val: 0.46s | Save: 0.01s | Total: 1.27s]
# Epoch 908/1000 | Train Loss: 9.4195 | Val Loss: 5.0904
#   [Train: 0.98s | Val: 0.43s | Save: 0.01s | Total: 1.42s]
# Epoch 909/1000 | Train Loss: 5.9905 | Val Loss: 6.1998
#   [Train: 0.86s | Val: 0.45s | Save: 0.01s | Total: 1.31s]
# Epoch 910/1000 | Train Loss: 7.4181 | Val Loss: 4.2093
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 911/1000 | Train Loss: 9.5883 | Val Loss: 2.9276
#   [Train: 0.80s | Val: 0.38s | Save: 0.01s | Total: 1.19s]
# Epoch 912/1000 | Train Loss: 8.7826 | Val Loss: 4.4674
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 913/1000 | Train Loss: 4.8724 | Val Loss: 6.3487
#   [Train: 0.83s | Val: 0.41s | Save: 0.01s | Total: 1.25s]
# Epoch 914/1000 | Train Loss: 6.9973 | Val Loss: 4.0150
#   [Train: 0.90s | Val: 0.39s | Save: 0.01s | Total: 1.30s]
# Epoch 915/1000 | Train Loss: 4.5738 | Val Loss: 3.4445
#   [Train: 0.84s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 916/1000 | Train Loss: 4.3253 | Val Loss: 5.3822
#   [Train: 0.79s | Val: 0.41s | Save: 0.01s | Total: 1.21s]
# Epoch 917/1000 | Train Loss: 6.5454 | Val Loss: 5.8206
#   [Train: 0.88s | Val: 0.46s | Save: 0.01s | Total: 1.36s]
# Epoch 918/1000 | Train Loss: 5.8852 | Val Loss: 3.9310
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 919/1000 | Train Loss: 5.7886 | Val Loss: 3.2105
#   [Train: 0.85s | Val: 0.43s | Save: 0.01s | Total: 1.29s]
# Epoch 920/1000 | Train Loss: 6.3285 | Val Loss: 4.6950
#   [Train: 0.88s | Val: 0.40s | Save: 0.01s | Total: 1.28s]
# Epoch 921/1000 | Train Loss: 4.8395 | Val Loss: 5.6881
#   [Train: 0.83s | Val: 0.44s | Save: 0.01s | Total: 1.28s]
# Epoch 922/1000 | Train Loss: 7.3777 | Val Loss: 4.5692
#   [Train: 0.84s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 923/1000 | Train Loss: 2.7830 | Val Loss: 4.1365
#   [Train: 0.79s | Val: 0.40s | Save: 0.01s | Total: 1.20s]
# Epoch 924/1000 | Train Loss: 4.7260 | Val Loss: 4.0995
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.21s]
# Epoch 925/1000 | Train Loss: 4.2060 | Val Loss: 4.6332
#   [Train: 0.80s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 926/1000 | Train Loss: 4.0886 | Val Loss: 5.1916
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.22s]
# Epoch 927/1000 | Train Loss: 7.6939 | Val Loss: 4.2261
#   [Train: 0.81s | Val: 0.36s | Save: 0.01s | Total: 1.18s]
# Epoch 928/1000 | Train Loss: 2.8308 | Val Loss: 4.4723
#   [Train: 0.84s | Val: 0.37s | Save: 0.01s | Total: 1.22s]
# Epoch 929/1000 | Train Loss: 2.7377 | Val Loss: 4.5680
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 930/1000 | Train Loss: 3.4221 | Val Loss: 4.4834
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.21s]
# Epoch 931/1000 | Train Loss: 3.1568 | Val Loss: 4.0596
#   [Train: 0.82s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 932/1000 | Train Loss: 6.7063 | Val Loss: 4.5152
#   [Train: 0.78s | Val: 0.39s | Save: 0.01s | Total: 1.18s]
# Epoch 933/1000 | Train Loss: 4.6150 | Val Loss: 4.0303
#   [Train: 0.88s | Val: 0.39s | Save: 0.01s | Total: 1.28s]
# Epoch 934/1000 | Train Loss: 5.8255 | Val Loss: 3.9556
#   [Train: 0.81s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 935/1000 | Train Loss: 4.3231 | Val Loss: 4.5162
#   [Train: 0.82s | Val: 0.43s | Save: 0.01s | Total: 1.26s]
# Epoch 936/1000 | Train Loss: 5.3958 | Val Loss: 4.8272
#   [Train: 0.85s | Val: 0.38s | Save: 0.01s | Total: 1.24s]
# Epoch 937/1000 | Train Loss: 4.4480 | Val Loss: 4.7399
#   [Train: 0.89s | Val: 0.39s | Save: 0.01s | Total: 1.29s]
# Epoch 938/1000 | Train Loss: 5.5593 | Val Loss: 4.9640
#   [Train: 0.97s | Val: 0.40s | Save: 0.01s | Total: 1.37s]
# Epoch 939/1000 | Train Loss: 3.0666 | Val Loss: 4.0938
#   [Train: 0.79s | Val: 0.39s | Save: 0.01s | Total: 1.18s]
# Epoch 940/1000 | Train Loss: 3.2173 | Val Loss: 4.0345
#   [Train: 0.82s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# Epoch 941/1000 | Train Loss: 5.4879 | Val Loss: 4.0200
#   [Train: 0.85s | Val: 0.39s | Save: 0.01s | Total: 1.25s]
# Epoch 942/1000 | Train Loss: 3.6935 | Val Loss: 4.7738
#   [Train: 0.83s | Val: 0.31s | Save: 0.01s | Total: 1.14s]
# Epoch 943/1000 | Train Loss: 7.5342 | Val Loss: 4.7575
#   [Train: 0.70s | Val: 0.41s | Save: 0.01s | Total: 1.12s]
# Epoch 944/1000 | Train Loss: 4.2423 | Val Loss: 4.5339
#   [Train: 0.91s | Val: 0.42s | Save: 0.01s | Total: 1.34s]
# Epoch 945/1000 | Train Loss: 3.1246 | Val Loss: 4.5173
#   [Train: 0.89s | Val: 0.42s | Save: 0.01s | Total: 1.32s]
# Epoch 946/1000 | Train Loss: 2.7020 | Val Loss: 4.2551
#   [Train: 0.86s | Val: 0.48s | Save: 0.01s | Total: 1.35s]
# Epoch 947/1000 | Train Loss: 2.8302 | Val Loss: 4.3011
#   [Train: 0.85s | Val: 0.39s | Save: 0.01s | Total: 1.25s]
# Epoch 948/1000 | Train Loss: 3.0404 | Val Loss: 4.3700
#   [Train: 0.85s | Val: 0.46s | Save: 0.01s | Total: 1.31s]
# Epoch 949/1000 | Train Loss: 3.2754 | Val Loss: 4.4607
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 950/1000 | Train Loss: 4.6325 | Val Loss: 4.8114
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 951/1000 | Train Loss: 5.7497 | Val Loss: 4.4447
#   [Train: 0.83s | Val: 0.43s | Save: 0.01s | Total: 1.27s]
# Epoch 952/1000 | Train Loss: 2.8630 | Val Loss: 4.3813
#   [Train: 0.81s | Val: 0.39s | Save: 0.01s | Total: 1.20s]
# Epoch 953/1000 | Train Loss: 3.6986 | Val Loss: 4.4285
#   [Train: 0.83s | Val: 0.44s | Save: 0.01s | Total: 1.28s]
# Epoch 954/1000 | Train Loss: 2.7074 | Val Loss: 4.2999
#   [Train: 0.84s | Val: 0.48s | Save: 0.01s | Total: 1.32s]
# Epoch 955/1000 | Train Loss: 3.1230 | Val Loss: 4.2577
#   [Train: 0.86s | Val: 0.39s | Save: 0.01s | Total: 1.26s]
# Epoch 956/1000 | Train Loss: 3.4140 | Val Loss: 4.3033
#   [Train: 0.82s | Val: 0.42s | Save: 0.01s | Total: 1.25s]
# Epoch 957/1000 | Train Loss: 2.9086 | Val Loss: 4.5707
#   [Train: 0.83s | Val: 0.42s | Save: 0.01s | Total: 1.26s]
# Epoch 958/1000 | Train Loss: 3.4186 | Val Loss: 4.5265
#   [Train: 0.79s | Val: 0.42s | Save: 0.01s | Total: 1.22s]
# Epoch 959/1000 | Train Loss: 6.5084 | Val Loss: 4.7129
#   [Train: 0.81s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Epoch 960/1000 | Train Loss: 4.9212 | Val Loss: 4.6924
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.26s]
# Epoch 961/1000 | Train Loss: 3.0117 | Val Loss: 4.4230
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 962/1000 | Train Loss: 6.8123 | Val Loss: 4.2725
#   [Train: 0.83s | Val: 0.45s | Save: 0.01s | Total: 1.29s]
# Epoch 963/1000 | Train Loss: 3.3768 | Val Loss: 4.0637
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.27s]
# Epoch 964/1000 | Train Loss: 4.1891 | Val Loss: 4.1475
#   [Train: 0.75s | Val: 0.40s | Save: 0.01s | Total: 1.16s]
# Epoch 965/1000 | Train Loss: 5.0692 | Val Loss: 4.2982
#   [Train: 0.81s | Val: 0.43s | Save: 0.01s | Total: 1.25s]
# Epoch 966/1000 | Train Loss: 2.7380 | Val Loss: 4.3681
#   [Train: 0.87s | Val: 0.45s | Save: 0.01s | Total: 1.33s]
# Epoch 967/1000 | Train Loss: 2.7468 | Val Loss: 4.4596
#   [Train: 0.86s | Val: 0.42s | Save: 0.01s | Total: 1.29s]
# Epoch 968/1000 | Train Loss: 2.6966 | Val Loss: 4.5014
#   [Train: 0.87s | Val: 0.43s | Save: 0.01s | Total: 1.31s]
# Epoch 969/1000 | Train Loss: 3.3592 | Val Loss: 4.4142
#   [Train: 0.87s | Val: 0.40s | Save: 0.01s | Total: 1.28s]
# Epoch 970/1000 | Train Loss: 2.8721 | Val Loss: 4.4384
#   [Train: 0.93s | Val: 0.43s | Save: 0.01s | Total: 1.37s]
# Epoch 971/1000 | Train Loss: 3.4227 | Val Loss: 4.4618
#   [Train: 0.82s | Val: 0.45s | Save: 0.01s | Total: 1.28s]
# Epoch 972/1000 | Train Loss: 2.7137 | Val Loss: 4.4383
#   [Train: 0.83s | Val: 0.40s | Save: 0.01s | Total: 1.24s]
# Epoch 973/1000 | Train Loss: 4.5458 | Val Loss: 4.3049
#   [Train: 0.77s | Val: 0.41s | Save: 0.01s | Total: 1.20s]
# Epoch 974/1000 | Train Loss: 2.7970 | Val Loss: 4.2861
#   [Train: 0.94s | Val: 0.45s | Save: 0.01s | Total: 1.40s]
# Epoch 975/1000 | Train Loss: 2.9074 | Val Loss: 4.3273
#   [Train: 0.86s | Val: 0.41s | Save: 0.01s | Total: 1.28s]
# Epoch 976/1000 | Train Loss: 3.0303 | Val Loss: 4.3506
#   [Train: 0.84s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 977/1000 | Train Loss: 5.3952 | Val Loss: 4.3317
#   [Train: 0.82s | Val: 0.37s | Save: 0.01s | Total: 1.20s]
# Epoch 978/1000 | Train Loss: 5.2480 | Val Loss: 4.3976
#   [Train: 0.83s | Val: 0.46s | Save: 0.01s | Total: 1.31s]
# Epoch 979/1000 | Train Loss: 3.3104 | Val Loss: 4.3734
#   [Train: 0.84s | Val: 0.41s | Save: 0.01s | Total: 1.26s]
# Epoch 980/1000 | Train Loss: 3.0032 | Val Loss: 4.3975
#   [Train: 0.83s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 981/1000 | Train Loss: 2.8995 | Val Loss: 4.3975
#   [Train: 0.80s | Val: 0.44s | Save: 0.01s | Total: 1.25s]
# Epoch 982/1000 | Train Loss: 5.2297 | Val Loss: 4.4208
#   [Train: 0.95s | Val: 0.44s | Save: 0.01s | Total: 1.40s]
# Epoch 983/1000 | Train Loss: 2.7368 | Val Loss: 4.4208
#   [Train: 0.89s | Val: 0.44s | Save: 0.01s | Total: 1.34s]
# Epoch 984/1000 | Train Loss: 2.7339 | Val Loss: 4.4208
#   [Train: 0.82s | Val: 0.42s | Save: 0.01s | Total: 1.25s]
# Epoch 985/1000 | Train Loss: 2.7011 | Val Loss: 4.4208
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.23s]
# Epoch 986/1000 | Train Loss: 3.6197 | Val Loss: 4.4206
#   [Train: 0.83s | Val: 0.41s | Save: 0.01s | Total: 1.24s]
# Epoch 987/1000 | Train Loss: 2.7044 | Val Loss: 4.4206
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 988/1000 | Train Loss: 2.8337 | Val Loss: 4.4204
#   [Train: 0.78s | Val: 0.39s | Save: 0.01s | Total: 1.17s]
# Epoch 989/1000 | Train Loss: 3.3076 | Val Loss: 4.4203
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 990/1000 | Train Loss: 2.8034 | Val Loss: 4.4203
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 991/1000 | Train Loss: 2.9010 | Val Loss: 4.4203
#   [Train: 0.82s | Val: 0.39s | Save: 0.01s | Total: 1.22s]
# Epoch 992/1000 | Train Loss: 6.0325 | Val Loss: 4.4203
#   [Train: 0.80s | Val: 0.40s | Save: 0.02s | Total: 1.22s]
# Epoch 993/1000 | Train Loss: 2.8160 | Val Loss: 4.4203
#   [Train: 0.87s | Val: 0.41s | Save: 0.01s | Total: 1.29s]
# Epoch 994/1000 | Train Loss: 2.7062 | Val Loss: 4.4203
#   [Train: 0.81s | Val: 0.38s | Save: 0.01s | Total: 1.20s]
# Epoch 995/1000 | Train Loss: 4.7066 | Val Loss: 4.4203
#   [Train: 0.85s | Val: 0.40s | Save: 0.01s | Total: 1.25s]
# Epoch 996/1000 | Train Loss: 3.2833 | Val Loss: 4.4203
#   [Train: 0.82s | Val: 0.40s | Save: 0.01s | Total: 1.23s]
# Epoch 997/1000 | Train Loss: 16.9699 | Val Loss: 3.1077
#   [Train: 0.85s | Val: 0.41s | Save: 0.01s | Total: 1.27s]
# Epoch 998/1000 | Train Loss: 15.8225 | Val Loss: 8.9311
#   [Train: 0.86s | Val: 0.39s | Save: 0.01s | Total: 1.26s]
# Epoch 999/1000 | Train Loss: 10.1076 | Val Loss: 2.8562
#   [Train: 0.84s | Val: 0.43s | Save: 0.01s | Total: 1.28s]
# Epoch 1000/1000 | Train Loss: 19.5938 | Val Loss: 8.6495
#   [Train: 0.99s | Val: 0.45s | Save: 0.01s | Total: 1.46s]

# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs
