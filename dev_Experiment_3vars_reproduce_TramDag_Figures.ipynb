# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "tramdagpaper_exp6_1_linearDGP_ls_2"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# they made 3 experiments:
# 1. Linear-shift DGP and linear-shift model
# 2. Complex-shift DGP and complex-shift model
# 3. Linear-shift DGP and complex-shift model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return 0.3*x  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        x2_dash = logit(u2)
        x2 = (x2_dash - 2 * x1) / 5.0
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 + f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          + f(X2)        | replace h(x2|x1) with z
    # z          = 0.63*x3 + beta3 * x1          + f(X2)        | reformulate to x2
    # x3         = (z-beta3 * x1 -f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z-beta3 * x1 -f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z+0.2 * x1   -f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        x3_dash = logit(u3)
        x3 = (x3_dash + 0.2 * x1 - f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])

    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df


df = dgp(n_obs=10_000, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")


if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=10_000)

    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")


sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Setting Seed: 42
# Loaded data from /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_2/tramdagpaper_exp6_1_linearDGP_ls_2.csv

# %% [markdown]
# ## 2.1 train test split

# %%
# train
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
# Validation and test
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)


# Get min_vals and max_vals as torch tensors
quantiles = train_df.quantile([0.025, 0.975])
min_vals = quantiles.loc[0.025].values.astype(np.float32)
max_vals = quantiles.loc[0.975].values.astype(np.float32)



print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 8000, Validation size: 1000, Test size: 1000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous , images , ordinal
adj_matrix = np.array([
    [ "0", "ls", "ls"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "ls"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)

# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
plot_nn_names_matrix(nn_names_matrix,data_type)

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_2/tramdagpaper_exp6_1_linearDGP_ls_2_conf.json
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.08668617159128189,
#   'max': 0.8121167421340942},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift'},
#   'min': -0.9664099812507629,
#   'max': 0.5599541664123535},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls', 'x2': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift',
#    'x2': 'LinearShift'},
#   'min': -5.547372817993164,
#   'max': 6.020590782165527}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 4112
epochs = 1000   # <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
use_scheduler = True

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)

    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################
    optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 300...
# /home/bule/TramDag/utils/tram_model_helpers.py:362: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# /home/bule/TramDag/utils/tram_model_helpers.py:378: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Saved new best model.
# Epoch 301/1000 | Train Loss: -0.3574 | Val Loss: -0.3609
#   [Train: 1.18s | Val: 0.54s | Save: 0.00s | Total: 1.73s]
# /home/bule/TramDag/utils/tram_model_helpers.py:405: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Saved new best model.
# Epoch 302/1000 | Train Loss: -0.3618 | Val Loss: -0.3642
#   [Train: 0.69s | Val: 0.55s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 303/1000 | Train Loss: -0.3650 | Val Loss: -0.3665
#   [Train: 0.67s | Val: 0.64s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 304/1000 | Train Loss: -0.3669 | Val Loss: -0.3675
#   [Train: 0.66s | Val: 0.67s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 305/1000 | Train Loss: -0.3678 | Val Loss: -0.3678
#   [Train: 0.77s | Val: 0.70s | Save: 0.01s | Total: 1.47s]
# Saved new best model.
# Epoch 306/1000 | Train Loss: -0.3687 | Val Loss: -0.3715
#   [Train: 0.66s | Val: 0.71s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 307/1000 | Train Loss: -0.3724 | Val Loss: -0.3748
#   [Train: 0.74s | Val: 0.68s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 308/1000 | Train Loss: -0.3757 | Val Loss: -0.3779
#   [Train: 0.77s | Val: 0.88s | Save: 0.00s | Total: 1.65s]
# Saved new best model.
# Epoch 309/1000 | Train Loss: -0.3786 | Val Loss: -0.3806
#   [Train: 0.68s | Val: 0.68s | Save: 0.00s | Total: 1.37s]
# Saved new best model.
# Epoch 310/1000 | Train Loss: -0.3810 | Val Loss: -0.3826
#   [Train: 0.68s | Val: 0.65s | Save: 0.00s | Total: 1.34s]
# Saved new best model.
# Epoch 311/1000 | Train Loss: -0.3830 | Val Loss: -0.3842
#   [Train: 0.83s | Val: 0.58s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 312/1000 | Train Loss: -0.3846 | Val Loss: -0.3852
#   [Train: 0.67s | Val: 0.64s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 313/1000 | Train Loss: -0.3853 | Val Loss: -0.3857
#   [Train: 0.72s | Val: 0.58s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 314/1000 | Train Loss: -0.3858 | Val Loss: -0.3859
#   [Train: 0.71s | Val: 0.65s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 315/1000 | Train Loss: -0.3860 | Val Loss: -0.3860
#   [Train: 0.70s | Val: 0.67s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 316/1000 | Train Loss: -0.3866 | Val Loss: -0.3891
#   [Train: 0.57s | Val: 0.55s | Save: 0.00s | Total: 1.12s]
# Saved new best model.
# Epoch 317/1000 | Train Loss: -0.3895 | Val Loss: -0.3921
#   [Train: 0.59s | Val: 0.58s | Save: 0.00s | Total: 1.17s]
# Saved new best model.
# Epoch 318/1000 | Train Loss: -0.3931 | Val Loss: -0.3950
#   [Train: 0.69s | Val: 0.58s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 319/1000 | Train Loss: -0.3958 | Val Loss: -0.3978
#   [Train: 0.65s | Val: 0.70s | Save: 0.00s | Total: 1.36s]
# Saved new best model.
# Epoch 320/1000 | Train Loss: -0.3986 | Val Loss: -0.4003
#   [Train: 0.74s | Val: 0.62s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 321/1000 | Train Loss: -0.4011 | Val Loss: -0.4027
#   [Train: 0.86s | Val: 0.76s | Save: 0.01s | Total: 1.62s]
# Saved new best model.
# Epoch 322/1000 | Train Loss: -0.4033 | Val Loss: -0.4048
#   [Train: 0.81s | Val: 0.74s | Save: 0.00s | Total: 1.56s]
# Saved new best model.
# Epoch 323/1000 | Train Loss: -0.4053 | Val Loss: -0.4066
#   [Train: 0.70s | Val: 0.60s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 324/1000 | Train Loss: -0.4070 | Val Loss: -0.4083
#   [Train: 0.79s | Val: 0.64s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 325/1000 | Train Loss: -0.4085 | Val Loss: -0.4098
#   [Train: 0.71s | Val: 0.60s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 326/1000 | Train Loss: -0.4104 | Val Loss: -0.4109
#   [Train: 0.76s | Val: 0.62s | Save: 0.00s | Total: 1.39s]
# Saved new best model.
# Epoch 327/1000 | Train Loss: -0.4111 | Val Loss: -0.4120
#   [Train: 0.75s | Val: 0.75s | Save: 0.01s | Total: 1.50s]
# Saved new best model.
# Epoch 328/1000 | Train Loss: -0.4124 | Val Loss: -0.4129
#   [Train: 0.69s | Val: 0.64s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 329/1000 | Train Loss: -0.4131 | Val Loss: -0.4135
#   [Train: 0.66s | Val: 0.89s | Save: 0.01s | Total: 1.56s]
# Saved new best model.
# Epoch 330/1000 | Train Loss: -0.4137 | Val Loss: -0.4139
#   [Train: 1.30s | Val: 0.96s | Save: 0.01s | Total: 2.27s]
# Saved new best model.
# Epoch 331/1000 | Train Loss: -0.4141 | Val Loss: -0.4143
#   [Train: 0.80s | Val: 0.79s | Save: 0.01s | Total: 1.60s]
# Saved new best model.
# Epoch 332/1000 | Train Loss: -0.4145 | Val Loss: -0.4145
#   [Train: 0.72s | Val: 0.92s | Save: 0.01s | Total: 1.64s]
# Saved new best model.
# Epoch 333/1000 | Train Loss: -0.4145 | Val Loss: -0.4146
#   [Train: 1.01s | Val: 0.77s | Save: 0.00s | Total: 1.78s]
# Saved new best model.
# Epoch 334/1000 | Train Loss: -0.4144 | Val Loss: -0.4146
#   [Train: 0.70s | Val: 0.76s | Save: 0.00s | Total: 1.46s]
# Saved new best model.
# Epoch 335/1000 | Train Loss: -0.4147 | Val Loss: -0.4146
#   [Train: 0.76s | Val: 0.76s | Save: 0.00s | Total: 1.52s]
# Saved new best model.
# Epoch 336/1000 | Train Loss: -0.4151 | Val Loss: -0.4170
#   [Train: 0.76s | Val: 0.67s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 337/1000 | Train Loss: -0.4176 | Val Loss: -0.4194
#   [Train: 0.68s | Val: 0.62s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 338/1000 | Train Loss: -0.4199 | Val Loss: -0.4218
#   [Train: 0.68s | Val: 0.67s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 339/1000 | Train Loss: -0.4224 | Val Loss: -0.4240
#   [Train: 0.69s | Val: 0.64s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 340/1000 | Train Loss: -0.4247 | Val Loss: -0.4262
#   [Train: 0.66s | Val: 0.59s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 341/1000 | Train Loss: -0.4264 | Val Loss: -0.4283
#   [Train: 0.72s | Val: 0.61s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 342/1000 | Train Loss: -0.4287 | Val Loss: -0.4303
#   [Train: 0.59s | Val: 0.63s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 343/1000 | Train Loss: -0.4308 | Val Loss: -0.4323
#   [Train: 0.71s | Val: 0.62s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 344/1000 | Train Loss: -0.4327 | Val Loss: -0.4340
#   [Train: 0.66s | Val: 0.72s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 345/1000 | Train Loss: -0.4346 | Val Loss: -0.4359
#   [Train: 0.68s | Val: 0.67s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 346/1000 | Train Loss: -0.4363 | Val Loss: -0.4376
#   [Train: 0.76s | Val: 0.58s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 347/1000 | Train Loss: -0.4381 | Val Loss: -0.4391
#   [Train: 0.71s | Val: 0.67s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 348/1000 | Train Loss: -0.4393 | Val Loss: -0.4406
#   [Train: 0.66s | Val: 0.59s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 349/1000 | Train Loss: -0.4412 | Val Loss: -0.4420
#   [Train: 0.72s | Val: 0.63s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 350/1000 | Train Loss: -0.4424 | Val Loss: -0.4433
#   [Train: 0.75s | Val: 0.69s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 351/1000 | Train Loss: -0.4438 | Val Loss: -0.4446
#   [Train: 0.72s | Val: 0.67s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 352/1000 | Train Loss: -0.4448 | Val Loss: -0.4457
#   [Train: 0.70s | Val: 0.64s | Save: 0.00s | Total: 1.35s]
# Saved new best model.
# Epoch 353/1000 | Train Loss: -0.4460 | Val Loss: -0.4467
#   [Train: 0.69s | Val: 0.75s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 354/1000 | Train Loss: -0.4470 | Val Loss: -0.4477
#   [Train: 0.70s | Val: 0.74s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 355/1000 | Train Loss: -0.4479 | Val Loss: -0.4486
#   [Train: 0.69s | Val: 0.56s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 356/1000 | Train Loss: -0.4486 | Val Loss: -0.4493
#   [Train: 0.62s | Val: 0.63s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 357/1000 | Train Loss: -0.4496 | Val Loss: -0.4502
#   [Train: 0.76s | Val: 0.70s | Save: 0.01s | Total: 1.46s]
# Saved new best model.
# Epoch 358/1000 | Train Loss: -0.4504 | Val Loss: -0.4508
#   [Train: 0.68s | Val: 1.00s | Save: 0.01s | Total: 1.68s]
# Saved new best model.
# Epoch 359/1000 | Train Loss: -0.4511 | Val Loss: -0.4514
#   [Train: 0.67s | Val: 0.58s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 360/1000 | Train Loss: -0.4517 | Val Loss: -0.4520
#   [Train: 0.78s | Val: 0.55s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 361/1000 | Train Loss: -0.4522 | Val Loss: -0.4524
#   [Train: 0.56s | Val: 0.71s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 362/1000 | Train Loss: -0.4527 | Val Loss: -0.4528
#   [Train: 0.73s | Val: 0.57s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 363/1000 | Train Loss: -0.4530 | Val Loss: -0.4531
#   [Train: 0.67s | Val: 0.69s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 364/1000 | Train Loss: -0.4532 | Val Loss: -0.4534
#   [Train: 0.62s | Val: 0.62s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 365/1000 | Train Loss: -0.4536 | Val Loss: -0.4537
#   [Train: 0.62s | Val: 0.68s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 366/1000 | Train Loss: -0.4538 | Val Loss: -0.4539
#   [Train: 0.74s | Val: 0.62s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 367/1000 | Train Loss: -0.4540 | Val Loss: -0.4541
#   [Train: 0.70s | Val: 0.69s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 368/1000 | Train Loss: -0.4542 | Val Loss: -0.4542
#   [Train: 0.62s | Val: 0.55s | Save: 0.01s | Total: 1.18s]
# Saved new best model.
# Epoch 369/1000 | Train Loss: -0.4543 | Val Loss: -0.4544
#   [Train: 0.70s | Val: 0.56s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 370/1000 | Train Loss: -0.4546 | Val Loss: -0.4544
#   [Train: 0.71s | Val: 0.69s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 371/1000 | Train Loss: -0.4546 | Val Loss: -0.4544
#   [Train: 0.59s | Val: 0.62s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 372/1000 | Train Loss: -0.4545 | Val Loss: -0.4545
#   [Train: 0.86s | Val: 0.67s | Save: 0.01s | Total: 1.54s]
# Saved new best model.
# Epoch 373/1000 | Train Loss: -0.4544 | Val Loss: -0.4545
#   [Train: 0.73s | Val: 0.74s | Save: 0.01s | Total: 1.47s]
# Saved new best model.
# Epoch 374/1000 | Train Loss: -0.4546 | Val Loss: -0.4545
#   [Train: 0.71s | Val: 0.67s | Save: 0.01s | Total: 1.38s]
# Epoch 375/1000 | Train Loss: -0.4548 | Val Loss: -0.4545
#   [Train: 0.71s | Val: 0.72s | Save: 0.00s | Total: 1.43s]
# Saved new best model.
# Epoch 376/1000 | Train Loss: -0.4546 | Val Loss: -0.4560
#   [Train: 0.72s | Val: 0.68s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 377/1000 | Train Loss: -0.4563 | Val Loss: -0.4574
#   [Train: 0.68s | Val: 0.73s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 378/1000 | Train Loss: -0.4576 | Val Loss: -0.4589
#   [Train: 0.73s | Val: 0.84s | Save: 0.00s | Total: 1.57s]
# Saved new best model.
# Epoch 379/1000 | Train Loss: -0.4594 | Val Loss: -0.4603
#   [Train: 0.97s | Val: 0.92s | Save: 0.01s | Total: 1.90s]
# Saved new best model.
# Epoch 380/1000 | Train Loss: -0.4611 | Val Loss: -0.4616
#   [Train: 0.79s | Val: 0.69s | Save: 0.01s | Total: 1.48s]
# Saved new best model.
# Epoch 381/1000 | Train Loss: -0.4620 | Val Loss: -0.4630
#   [Train: 0.74s | Val: 0.75s | Save: 0.01s | Total: 1.49s]
# Saved new best model.
# Epoch 382/1000 | Train Loss: -0.4633 | Val Loss: -0.4643
#   [Train: 0.89s | Val: 0.79s | Save: 0.01s | Total: 1.68s]
# Saved new best model.
# Epoch 383/1000 | Train Loss: -0.4645 | Val Loss: -0.4655
#   [Train: 0.93s | Val: 0.71s | Save: 0.01s | Total: 1.65s]
# Saved new best model.
# Epoch 384/1000 | Train Loss: -0.4658 | Val Loss: -0.4667
#   [Train: 0.72s | Val: 0.62s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 385/1000 | Train Loss: -0.4670 | Val Loss: -0.4679
#   [Train: 0.64s | Val: 0.74s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 386/1000 | Train Loss: -0.4680 | Val Loss: -0.4690
#   [Train: 0.69s | Val: 0.68s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 387/1000 | Train Loss: -0.4692 | Val Loss: -0.4701
#   [Train: 0.72s | Val: 0.67s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 388/1000 | Train Loss: -0.4703 | Val Loss: -0.4711
#   [Train: 0.92s | Val: 0.84s | Save: 0.01s | Total: 1.77s]
# Saved new best model.
# Epoch 389/1000 | Train Loss: -0.4713 | Val Loss: -0.4720
#   [Train: 0.85s | Val: 0.67s | Save: 0.01s | Total: 1.52s]
# Saved new best model.
# Epoch 390/1000 | Train Loss: -0.4724 | Val Loss: -0.4730
#   [Train: 0.72s | Val: 0.68s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 391/1000 | Train Loss: -0.4732 | Val Loss: -0.4740
#   [Train: 0.68s | Val: 0.70s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 392/1000 | Train Loss: -0.4745 | Val Loss: -0.4748
#   [Train: 0.72s | Val: 0.60s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 393/1000 | Train Loss: -0.4752 | Val Loss: -0.4758
#   [Train: 0.64s | Val: 0.66s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 394/1000 | Train Loss: -0.4763 | Val Loss: -0.4766
#   [Train: 0.75s | Val: 0.70s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 395/1000 | Train Loss: -0.4767 | Val Loss: -0.4774
#   [Train: 0.70s | Val: 0.70s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 396/1000 | Train Loss: -0.4776 | Val Loss: -0.4782
#   [Train: 1.00s | Val: 0.68s | Save: 0.01s | Total: 1.69s]
# Saved new best model.
# Epoch 397/1000 | Train Loss: -0.4782 | Val Loss: -0.4789
#   [Train: 0.70s | Val: 0.68s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 398/1000 | Train Loss: -0.4791 | Val Loss: -0.4796
#   [Train: 0.69s | Val: 0.66s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 399/1000 | Train Loss: -0.4797 | Val Loss: -0.4804
#   [Train: 0.80s | Val: 0.70s | Save: 0.01s | Total: 1.50s]
# Saved new best model.
# Epoch 400/1000 | Train Loss: -0.4805 | Val Loss: -0.4810
#   [Train: 0.68s | Val: 0.73s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 401/1000 | Train Loss: -0.4813 | Val Loss: -0.4816
#   [Train: 0.67s | Val: 0.70s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 402/1000 | Train Loss: -0.4819 | Val Loss: -0.4822
#   [Train: 0.67s | Val: 0.72s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 403/1000 | Train Loss: -0.4823 | Val Loss: -0.4828
#   [Train: 0.73s | Val: 0.62s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 404/1000 | Train Loss: -0.4831 | Val Loss: -0.4834
#   [Train: 0.65s | Val: 0.65s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 405/1000 | Train Loss: -0.4838 | Val Loss: -0.4840
#   [Train: 0.73s | Val: 0.67s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 406/1000 | Train Loss: -0.4842 | Val Loss: -0.4846
#   [Train: 0.71s | Val: 0.68s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 407/1000 | Train Loss: -0.4844 | Val Loss: -0.4851
#   [Train: 0.64s | Val: 0.69s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 408/1000 | Train Loss: -0.4848 | Val Loss: -0.4856
#   [Train: 0.72s | Val: 0.65s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 409/1000 | Train Loss: -0.4857 | Val Loss: -0.4860
#   [Train: 0.68s | Val: 0.65s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 410/1000 | Train Loss: -0.4861 | Val Loss: -0.4865
#   [Train: 0.65s | Val: 0.68s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 411/1000 | Train Loss: -0.4867 | Val Loss: -0.4869
#   [Train: 0.71s | Val: 0.63s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 412/1000 | Train Loss: -0.4871 | Val Loss: -0.4874
#   [Train: 0.65s | Val: 0.63s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 413/1000 | Train Loss: -0.4874 | Val Loss: -0.4877
#   [Train: 0.65s | Val: 0.64s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 414/1000 | Train Loss: -0.4876 | Val Loss: -0.4881
#   [Train: 0.66s | Val: 0.54s | Save: 0.01s | Total: 1.20s]
# Saved new best model.
# Epoch 415/1000 | Train Loss: -0.4884 | Val Loss: -0.4885
#   [Train: 0.60s | Val: 0.69s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 416/1000 | Train Loss: -0.4889 | Val Loss: -0.4888
#   [Train: 0.64s | Val: 0.68s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 417/1000 | Train Loss: -0.4889 | Val Loss: -0.4892
#   [Train: 0.73s | Val: 0.62s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 418/1000 | Train Loss: -0.4893 | Val Loss: -0.4895
#   [Train: 0.71s | Val: 0.71s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 419/1000 | Train Loss: -0.4898 | Val Loss: -0.4899
#   [Train: 0.67s | Val: 0.61s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 420/1000 | Train Loss: -0.4896 | Val Loss: -0.4901
#   [Train: 0.68s | Val: 0.74s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 421/1000 | Train Loss: -0.4903 | Val Loss: -0.4903
#   [Train: 0.94s | Val: 0.70s | Save: 0.01s | Total: 1.64s]
# Saved new best model.
# Epoch 422/1000 | Train Loss: -0.4905 | Val Loss: -0.4906
#   [Train: 0.69s | Val: 0.56s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 423/1000 | Train Loss: -0.4907 | Val Loss: -0.4908
#   [Train: 0.67s | Val: 0.66s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 424/1000 | Train Loss: -0.4909 | Val Loss: -0.4912
#   [Train: 0.68s | Val: 0.68s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 425/1000 | Train Loss: -0.4914 | Val Loss: -0.4914
#   [Train: 0.83s | Val: 0.72s | Save: 0.01s | Total: 1.56s]
# Saved new best model.
# Epoch 426/1000 | Train Loss: -0.4912 | Val Loss: -0.4914
#   [Train: 0.68s | Val: 0.66s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 427/1000 | Train Loss: -0.4916 | Val Loss: -0.4917
#   [Train: 0.71s | Val: 0.79s | Save: 0.01s | Total: 1.51s]
# Saved new best model.
# Epoch 428/1000 | Train Loss: -0.4917 | Val Loss: -0.4919
#   [Train: 0.62s | Val: 0.63s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 429/1000 | Train Loss: -0.4923 | Val Loss: -0.4921
#   [Train: 0.71s | Val: 0.79s | Save: 0.01s | Total: 1.51s]
# Saved new best model.
# Epoch 430/1000 | Train Loss: -0.4921 | Val Loss: -0.4923
#   [Train: 0.73s | Val: 0.66s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 431/1000 | Train Loss: -0.4923 | Val Loss: -0.4923
#   [Train: 0.67s | Val: 0.65s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 432/1000 | Train Loss: -0.4925 | Val Loss: -0.4925
#   [Train: 0.72s | Val: 0.69s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 433/1000 | Train Loss: -0.4927 | Val Loss: -0.4927
#   [Train: 0.66s | Val: 0.56s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 434/1000 | Train Loss: -0.4929 | Val Loss: -0.4927
#   [Train: 0.70s | Val: 0.63s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 435/1000 | Train Loss: -0.4927 | Val Loss: -0.4929
#   [Train: 0.69s | Val: 0.59s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 436/1000 | Train Loss: -0.4927 | Val Loss: -0.4929
#   [Train: 0.70s | Val: 0.65s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 437/1000 | Train Loss: -0.4929 | Val Loss: -0.4930
#   [Train: 0.67s | Val: 0.58s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 438/1000 | Train Loss: -0.4933 | Val Loss: -0.4931
#   [Train: 0.71s | Val: 0.70s | Save: 0.00s | Total: 1.41s]
# Saved new best model.
# Epoch 439/1000 | Train Loss: -0.4931 | Val Loss: -0.4932
#   [Train: 0.78s | Val: 0.64s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 440/1000 | Train Loss: -0.4932 | Val Loss: -0.4932
#   [Train: 0.66s | Val: 0.67s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 441/1000 | Train Loss: -0.4930 | Val Loss: -0.4934
#   [Train: 0.67s | Val: 0.70s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 442/1000 | Train Loss: -0.4935 | Val Loss: -0.4934
#   [Train: 0.68s | Val: 0.66s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 443/1000 | Train Loss: -0.4935 | Val Loss: -0.4934
#   [Train: 0.74s | Val: 0.70s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 444/1000 | Train Loss: -0.4935 | Val Loss: -0.4934
#   [Train: 0.64s | Val: 0.67s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 445/1000 | Train Loss: -0.4936 | Val Loss: -0.4934
#   [Train: 0.65s | Val: 0.75s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 446/1000 | Train Loss: -0.4935 | Val Loss: -0.4934
#   [Train: 0.73s | Val: 0.66s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 447/1000 | Train Loss: -0.4933 | Val Loss: -0.4934
#   [Train: 0.77s | Val: 0.57s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 448/1000 | Train Loss: -0.4935 | Val Loss: -0.4936
#   [Train: 0.65s | Val: 0.66s | Save: 0.01s | Total: 1.32s]
# Epoch 449/1000 | Train Loss: -0.4934 | Val Loss: -0.4936
#   [Train: 0.72s | Val: 0.67s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 450/1000 | Train Loss: -0.4937 | Val Loss: -0.4936
#   [Train: 0.71s | Val: 0.66s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 451/1000 | Train Loss: -0.4935 | Val Loss: -0.4936
#   [Train: 0.73s | Val: 0.68s | Save: 0.01s | Total: 1.42s]
# Epoch 452/1000 | Train Loss: -0.4936 | Val Loss: -0.4936
#   [Train: 0.61s | Val: 0.65s | Save: 0.01s | Total: 1.27s]
# Epoch 453/1000 | Train Loss: -0.4936 | Val Loss: -0.4936
#   [Train: 0.65s | Val: 0.62s | Save: 0.01s | Total: 1.28s]
# Epoch 454/1000 | Train Loss: -0.4937 | Val Loss: -0.4936
#   [Train: 0.70s | Val: 0.69s | Save: 0.01s | Total: 1.40s]
# Epoch 455/1000 | Train Loss: -0.4938 | Val Loss: -0.4936
#   [Train: 0.75s | Val: 0.72s | Save: 0.00s | Total: 1.48s]
# Saved new best model.
# Epoch 456/1000 | Train Loss: -0.4939 | Val Loss: -0.4942
#   [Train: 0.70s | Val: 0.73s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 457/1000 | Train Loss: -0.4944 | Val Loss: -0.4949
#   [Train: 0.68s | Val: 0.57s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 458/1000 | Train Loss: -0.4952 | Val Loss: -0.4955
#   [Train: 0.70s | Val: 0.68s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 459/1000 | Train Loss: -0.4957 | Val Loss: -0.4962
#   [Train: 0.66s | Val: 0.66s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 460/1000 | Train Loss: -0.4968 | Val Loss: -0.4968
#   [Train: 0.72s | Val: 0.65s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 461/1000 | Train Loss: -0.4971 | Val Loss: -0.4975
#   [Train: 0.68s | Val: 0.62s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 462/1000 | Train Loss: -0.4980 | Val Loss: -0.4981
#   [Train: 0.71s | Val: 0.67s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 463/1000 | Train Loss: -0.4983 | Val Loss: -0.4987
#   [Train: 0.67s | Val: 0.67s | Save: 0.02s | Total: 1.36s]
# Saved new best model.
# Epoch 464/1000 | Train Loss: -0.4988 | Val Loss: -0.4993
#   [Train: 0.72s | Val: 0.69s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 465/1000 | Train Loss: -0.4995 | Val Loss: -0.4999
#   [Train: 0.63s | Val: 0.66s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 466/1000 | Train Loss: -0.5002 | Val Loss: -0.5005
#   [Train: 0.76s | Val: 0.65s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 467/1000 | Train Loss: -0.5009 | Val Loss: -0.5011
#   [Train: 0.69s | Val: 0.64s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 468/1000 | Train Loss: -0.5011 | Val Loss: -0.5017
#   [Train: 0.72s | Val: 0.62s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 469/1000 | Train Loss: -0.5019 | Val Loss: -0.5023
#   [Train: 0.70s | Val: 0.62s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 470/1000 | Train Loss: -0.5024 | Val Loss: -0.5029
#   [Train: 0.70s | Val: 0.56s | Save: 0.01s | Total: 1.27s]
# Saved new best model.
# Epoch 471/1000 | Train Loss: -0.5035 | Val Loss: -0.5035
#   [Train: 0.74s | Val: 0.72s | Save: 0.01s | Total: 1.47s]
# Saved new best model.
# Epoch 472/1000 | Train Loss: -0.5032 | Val Loss: -0.5039
#   [Train: 0.73s | Val: 0.64s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 473/1000 | Train Loss: -0.5041 | Val Loss: -0.5045
#   [Train: 0.66s | Val: 0.71s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 474/1000 | Train Loss: -0.5049 | Val Loss: -0.5050
#   [Train: 0.72s | Val: 0.68s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 475/1000 | Train Loss: -0.5050 | Val Loss: -0.5056
#   [Train: 0.70s | Val: 0.65s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 476/1000 | Train Loss: -0.5059 | Val Loss: -0.5060
#   [Train: 0.68s | Val: 0.72s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 477/1000 | Train Loss: -0.5062 | Val Loss: -0.5066
#   [Train: 0.68s | Val: 0.76s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 478/1000 | Train Loss: -0.5069 | Val Loss: -0.5070
#   [Train: 0.68s | Val: 0.66s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 479/1000 | Train Loss: -0.5072 | Val Loss: -0.5075
#   [Train: 0.66s | Val: 0.68s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 480/1000 | Train Loss: -0.5079 | Val Loss: -0.5079
#   [Train: 0.71s | Val: 0.65s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 481/1000 | Train Loss: -0.5083 | Val Loss: -0.5084
#   [Train: 0.78s | Val: 0.71s | Save: 0.01s | Total: 1.50s]
# Saved new best model.
# Epoch 482/1000 | Train Loss: -0.5088 | Val Loss: -0.5088
#   [Train: 0.69s | Val: 0.71s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 483/1000 | Train Loss: -0.5090 | Val Loss: -0.5094
#   [Train: 0.61s | Val: 0.61s | Save: 0.01s | Total: 1.23s]
# Saved new best model.
# Epoch 484/1000 | Train Loss: -0.5097 | Val Loss: -0.5098
#   [Train: 0.71s | Val: 0.98s | Save: 0.01s | Total: 1.70s]
# Saved new best model.
# Epoch 485/1000 | Train Loss: -0.5099 | Val Loss: -0.5101
#   [Train: 0.69s | Val: 0.76s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 486/1000 | Train Loss: -0.5103 | Val Loss: -0.5106
#   [Train: 0.68s | Val: 0.63s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 487/1000 | Train Loss: -0.5107 | Val Loss: -0.5110
#   [Train: 0.70s | Val: 0.67s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 488/1000 | Train Loss: -0.5111 | Val Loss: -0.5114
#   [Train: 0.56s | Val: 0.62s | Save: 0.01s | Total: 1.19s]
# Saved new best model.
# Epoch 489/1000 | Train Loss: -0.5115 | Val Loss: -0.5119
#   [Train: 0.57s | Val: 0.60s | Save: 0.01s | Total: 1.18s]
# Saved new best model.
# Epoch 490/1000 | Train Loss: -0.5120 | Val Loss: -0.5123
#   [Train: 0.86s | Val: 0.73s | Save: 0.01s | Total: 1.60s]
# Saved new best model.
# Epoch 491/1000 | Train Loss: -0.5122 | Val Loss: -0.5126
#   [Train: 0.69s | Val: 0.73s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 492/1000 | Train Loss: -0.5128 | Val Loss: -0.5130
#   [Train: 0.73s | Val: 0.66s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 493/1000 | Train Loss: -0.5133 | Val Loss: -0.5134
#   [Train: 0.72s | Val: 0.71s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 494/1000 | Train Loss: -0.5138 | Val Loss: -0.5137
#   [Train: 0.56s | Val: 0.69s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 495/1000 | Train Loss: -0.5133 | Val Loss: -0.5140
#   [Train: 0.73s | Val: 0.69s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 496/1000 | Train Loss: -0.5141 | Val Loss: -0.5144
#   [Train: 0.70s | Val: 0.73s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 497/1000 | Train Loss: -0.5149 | Val Loss: -0.5147
#   [Train: 0.72s | Val: 0.66s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 498/1000 | Train Loss: -0.5146 | Val Loss: -0.5151
#   [Train: 0.73s | Val: 0.62s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 499/1000 | Train Loss: -0.5150 | Val Loss: -0.5154
#   [Train: 0.73s | Val: 0.74s | Save: 0.01s | Total: 1.49s]
# Saved new best model.
# Epoch 500/1000 | Train Loss: -0.5156 | Val Loss: -0.5158
#   [Train: 0.76s | Val: 0.74s | Save: 0.01s | Total: 1.51s]
# Saved new best model.
# Epoch 501/1000 | Train Loss: -0.5160 | Val Loss: -0.5161
#   [Train: 0.67s | Val: 0.71s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 502/1000 | Train Loss: -0.5163 | Val Loss: -0.5164
#   [Train: 0.71s | Val: 0.64s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 503/1000 | Train Loss: -0.5165 | Val Loss: -0.5166
#   [Train: 0.69s | Val: 0.62s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 504/1000 | Train Loss: -0.5166 | Val Loss: -0.5170
#   [Train: 0.88s | Val: 0.65s | Save: 0.01s | Total: 1.54s]
# Saved new best model.
# Epoch 505/1000 | Train Loss: -0.5171 | Val Loss: -0.5173
#   [Train: 0.69s | Val: 0.74s | Save: 0.00s | Total: 1.44s]
# Saved new best model.
# Epoch 506/1000 | Train Loss: -0.5177 | Val Loss: -0.5176
#   [Train: 0.67s | Val: 0.68s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 507/1000 | Train Loss: -0.5179 | Val Loss: -0.5178
#   [Train: 0.69s | Val: 0.68s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 508/1000 | Train Loss: -0.5183 | Val Loss: -0.5181
#   [Train: 0.71s | Val: 0.68s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 509/1000 | Train Loss: -0.5182 | Val Loss: -0.5184
#   [Train: 0.72s | Val: 0.67s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 510/1000 | Train Loss: -0.5185 | Val Loss: -0.5186
#   [Train: 0.66s | Val: 0.69s | Save: 0.02s | Total: 1.38s]
# Saved new best model.
# Epoch 511/1000 | Train Loss: -0.5187 | Val Loss: -0.5190
#   [Train: 0.75s | Val: 0.76s | Save: 0.01s | Total: 1.52s]
# Saved new best model.
# Epoch 512/1000 | Train Loss: -0.5187 | Val Loss: -0.5191
#   [Train: 0.73s | Val: 0.65s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 513/1000 | Train Loss: -0.5193 | Val Loss: -0.5195
#   [Train: 0.84s | Val: 0.83s | Save: 0.01s | Total: 1.67s]
# Saved new best model.
# Epoch 514/1000 | Train Loss: -0.5196 | Val Loss: -0.5198
#   [Train: 0.68s | Val: 0.72s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 515/1000 | Train Loss: -0.5197 | Val Loss: -0.5199
#   [Train: 0.74s | Val: 0.65s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 516/1000 | Train Loss: -0.5205 | Val Loss: -0.5201
#   [Train: 0.82s | Val: 0.66s | Save: 0.01s | Total: 1.49s]
# Saved new best model.
# Epoch 517/1000 | Train Loss: -0.5200 | Val Loss: -0.5204
#   [Train: 0.74s | Val: 0.79s | Save: 0.01s | Total: 1.53s]
# Saved new best model.
# Epoch 518/1000 | Train Loss: -0.5206 | Val Loss: -0.5206
#   [Train: 0.69s | Val: 0.66s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 519/1000 | Train Loss: -0.5205 | Val Loss: -0.5209
#   [Train: 0.71s | Val: 0.66s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 520/1000 | Train Loss: -0.5211 | Val Loss: -0.5211
#   [Train: 0.75s | Val: 0.68s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 521/1000 | Train Loss: -0.5213 | Val Loss: -0.5213
#   [Train: 0.70s | Val: 0.69s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 522/1000 | Train Loss: -0.5214 | Val Loss: -0.5215
#   [Train: 0.76s | Val: 0.68s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 523/1000 | Train Loss: -0.5215 | Val Loss: -0.5217
#   [Train: 0.65s | Val: 0.62s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 524/1000 | Train Loss: -0.5214 | Val Loss: -0.5219
#   [Train: 0.67s | Val: 0.76s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 525/1000 | Train Loss: -0.5221 | Val Loss: -0.5221
#   [Train: 0.73s | Val: 0.66s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 526/1000 | Train Loss: -0.5222 | Val Loss: -0.5223
#   [Train: 0.72s | Val: 0.69s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 527/1000 | Train Loss: -0.5225 | Val Loss: -0.5225
#   [Train: 0.74s | Val: 0.80s | Save: 0.01s | Total: 1.56s]
# Saved new best model.
# Epoch 528/1000 | Train Loss: -0.5228 | Val Loss: -0.5227
#   [Train: 0.77s | Val: 0.66s | Save: 0.01s | Total: 1.43s]
# Saved new best model.
# Epoch 529/1000 | Train Loss: -0.5224 | Val Loss: -0.5228
#   [Train: 0.71s | Val: 0.64s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 530/1000 | Train Loss: -0.5231 | Val Loss: -0.5230
#   [Train: 0.62s | Val: 0.67s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 531/1000 | Train Loss: -0.5232 | Val Loss: -0.5232
#   [Train: 0.74s | Val: 0.61s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 532/1000 | Train Loss: -0.5231 | Val Loss: -0.5233
#   [Train: 0.70s | Val: 0.66s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 533/1000 | Train Loss: -0.5231 | Val Loss: -0.5235
#   [Train: 0.69s | Val: 0.67s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 534/1000 | Train Loss: -0.5235 | Val Loss: -0.5236
#   [Train: 0.70s | Val: 0.64s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 535/1000 | Train Loss: -0.5236 | Val Loss: -0.5238
#   [Train: 0.72s | Val: 0.79s | Save: 0.01s | Total: 1.52s]
# Saved new best model.
# Epoch 536/1000 | Train Loss: -0.5237 | Val Loss: -0.5240
#   [Train: 0.74s | Val: 0.70s | Save: 0.01s | Total: 1.46s]
# Saved new best model.
# Epoch 537/1000 | Train Loss: -0.5242 | Val Loss: -0.5241
#   [Train: 0.61s | Val: 0.60s | Save: 0.01s | Total: 1.21s]
# Saved new best model.
# Epoch 538/1000 | Train Loss: -0.5242 | Val Loss: -0.5243
#   [Train: 0.66s | Val: 0.55s | Save: 0.01s | Total: 1.21s]
# Saved new best model.
# Epoch 539/1000 | Train Loss: -0.5247 | Val Loss: -0.5244
#   [Train: 0.69s | Val: 0.65s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 540/1000 | Train Loss: -0.5245 | Val Loss: -0.5245
#   [Train: 0.67s | Val: 0.67s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 541/1000 | Train Loss: -0.5249 | Val Loss: -0.5247
#   [Train: 0.75s | Val: 0.66s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 542/1000 | Train Loss: -0.5246 | Val Loss: -0.5249
#   [Train: 0.68s | Val: 0.67s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 543/1000 | Train Loss: -0.5249 | Val Loss: -0.5250
#   [Train: 0.71s | Val: 0.73s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 544/1000 | Train Loss: -0.5252 | Val Loss: -0.5250
#   [Train: 0.69s | Val: 0.66s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 545/1000 | Train Loss: -0.5253 | Val Loss: -0.5252
#   [Train: 0.77s | Val: 0.73s | Save: 0.01s | Total: 1.51s]
# Saved new best model.
# Epoch 546/1000 | Train Loss: -0.5255 | Val Loss: -0.5253
#   [Train: 0.68s | Val: 0.58s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 547/1000 | Train Loss: -0.5253 | Val Loss: -0.5255
#   [Train: 0.69s | Val: 0.70s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 548/1000 | Train Loss: -0.5256 | Val Loss: -0.5255
#   [Train: 0.67s | Val: 0.64s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 549/1000 | Train Loss: -0.5254 | Val Loss: -0.5256
#   [Train: 0.65s | Val: 0.66s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 550/1000 | Train Loss: -0.5260 | Val Loss: -0.5258
#   [Train: 0.66s | Val: 0.75s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 551/1000 | Train Loss: -0.5256 | Val Loss: -0.5258
#   [Train: 0.67s | Val: 0.71s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 552/1000 | Train Loss: -0.5259 | Val Loss: -0.5259
#   [Train: 0.67s | Val: 0.66s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 553/1000 | Train Loss: -0.5260 | Val Loss: -0.5261
#   [Train: 0.69s | Val: 0.72s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 554/1000 | Train Loss: -0.5261 | Val Loss: -0.5261
#   [Train: 0.67s | Val: 0.68s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 555/1000 | Train Loss: -0.5264 | Val Loss: -0.5262
#   [Train: 0.77s | Val: 0.64s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 556/1000 | Train Loss: -0.5260 | Val Loss: -0.5263
#   [Train: 0.73s | Val: 0.62s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 557/1000 | Train Loss: -0.5264 | Val Loss: -0.5264
#   [Train: 0.72s | Val: 0.69s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 558/1000 | Train Loss: -0.5266 | Val Loss: -0.5265
#   [Train: 0.59s | Val: 0.73s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 559/1000 | Train Loss: -0.5269 | Val Loss: -0.5265
#   [Train: 0.71s | Val: 0.73s | Save: 0.01s | Total: 1.46s]
# Saved new best model.
# Epoch 560/1000 | Train Loss: -0.5265 | Val Loss: -0.5267
#   [Train: 0.80s | Val: 0.66s | Save: 0.01s | Total: 1.47s]
# Saved new best model.
# Epoch 561/1000 | Train Loss: -0.5264 | Val Loss: -0.5267
#   [Train: 0.66s | Val: 0.69s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 562/1000 | Train Loss: -0.5269 | Val Loss: -0.5268
#   [Train: 0.75s | Val: 0.65s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 563/1000 | Train Loss: -0.5268 | Val Loss: -0.5268
#   [Train: 0.66s | Val: 0.72s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 564/1000 | Train Loss: -0.5269 | Val Loss: -0.5270
#   [Train: 0.66s | Val: 0.65s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 565/1000 | Train Loss: -0.5269 | Val Loss: -0.5270
#   [Train: 0.64s | Val: 0.65s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 566/1000 | Train Loss: -0.5266 | Val Loss: -0.5271
#   [Train: 0.65s | Val: 0.68s | Save: 0.02s | Total: 1.34s]
# Saved new best model.
# Epoch 567/1000 | Train Loss: -0.5272 | Val Loss: -0.5271
#   [Train: 0.67s | Val: 0.56s | Save: 0.01s | Total: 1.23s]
# Saved new best model.
# Epoch 568/1000 | Train Loss: -0.5272 | Val Loss: -0.5271
#   [Train: 0.58s | Val: 0.74s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 569/1000 | Train Loss: -0.5274 | Val Loss: -0.5273
#   [Train: 0.69s | Val: 0.76s | Save: 0.01s | Total: 1.45s]
# Saved new best model.
# Epoch 570/1000 | Train Loss: -0.5273 | Val Loss: -0.5273
#   [Train: 0.69s | Val: 0.65s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 571/1000 | Train Loss: -0.5276 | Val Loss: -0.5273
#   [Train: 0.67s | Val: 0.64s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 572/1000 | Train Loss: -0.5274 | Val Loss: -0.5274
#   [Train: 0.66s | Val: 0.70s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 573/1000 | Train Loss: -0.5274 | Val Loss: -0.5274
#   [Train: 0.70s | Val: 0.67s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 574/1000 | Train Loss: -0.5276 | Val Loss: -0.5274
#   [Train: 0.71s | Val: 0.72s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 575/1000 | Train Loss: -0.5272 | Val Loss: -0.5276
#   [Train: 0.71s | Val: 0.75s | Save: 0.01s | Total: 1.47s]
# Saved new best model.
# Epoch 576/1000 | Train Loss: -0.5274 | Val Loss: -0.5276
#   [Train: 0.62s | Val: 0.57s | Save: 0.01s | Total: 1.19s]
# Epoch 577/1000 | Train Loss: -0.5276 | Val Loss: -0.5276
#   [Train: 0.67s | Val: 0.67s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 578/1000 | Train Loss: -0.5279 | Val Loss: -0.5276
#   [Train: 0.84s | Val: 0.68s | Save: 0.01s | Total: 1.53s]
# Saved new best model.
# Epoch 579/1000 | Train Loss: -0.5277 | Val Loss: -0.5277
#   [Train: 0.77s | Val: 0.64s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 580/1000 | Train Loss: -0.5280 | Val Loss: -0.5277
#   [Train: 0.67s | Val: 0.63s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 581/1000 | Train Loss: -0.5277 | Val Loss: -0.5277
#   [Train: 0.65s | Val: 0.71s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 582/1000 | Train Loss: -0.5278 | Val Loss: -0.5277
#   [Train: 0.68s | Val: 0.69s | Save: 0.01s | Total: 1.38s]
# Epoch 583/1000 | Train Loss: -0.5277 | Val Loss: -0.5277
#   [Train: 0.65s | Val: 0.68s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 584/1000 | Train Loss: -0.5279 | Val Loss: -0.5279
#   [Train: 0.67s | Val: 0.66s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 585/1000 | Train Loss: -0.5275 | Val Loss: -0.5279
#   [Train: 0.67s | Val: 0.73s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 586/1000 | Train Loss: -0.5281 | Val Loss: -0.5279
#   [Train: 0.64s | Val: 0.68s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 587/1000 | Train Loss: -0.5277 | Val Loss: -0.5279
#   [Train: 0.67s | Val: 0.72s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 588/1000 | Train Loss: -0.5279 | Val Loss: -0.5279
#   [Train: 0.69s | Val: 0.64s | Save: 0.01s | Total: 1.34s]
# Epoch 589/1000 | Train Loss: -0.5279 | Val Loss: -0.5279
#   [Train: 0.59s | Val: 0.54s | Save: 0.01s | Total: 1.13s]
# Saved new best model.
# Epoch 590/1000 | Train Loss: -0.5281 | Val Loss: -0.5280
#   [Train: 0.66s | Val: 0.62s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 591/1000 | Train Loss: -0.5278 | Val Loss: -0.5280
#   [Train: 0.95s | Val: 0.63s | Save: 0.01s | Total: 1.59s]
# Saved new best model.
# Epoch 592/1000 | Train Loss: -0.5281 | Val Loss: -0.5280
#   [Train: 0.70s | Val: 0.69s | Save: 0.01s | Total: 1.40s]
# Epoch 593/1000 | Train Loss: -0.5283 | Val Loss: -0.5280
#   [Train: 0.68s | Val: 0.72s | Save: 0.01s | Total: 1.41s]
# Saved new best model.
# Epoch 594/1000 | Train Loss: -0.5282 | Val Loss: -0.5280
#   [Train: 0.66s | Val: 0.55s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 595/1000 | Train Loss: -0.5278 | Val Loss: -0.5280
#   [Train: 0.69s | Val: 0.66s | Save: 0.01s | Total: 1.37s]
# Epoch 596/1000 | Train Loss: -0.5284 | Val Loss: -0.5280
#   [Train: 0.57s | Val: 0.64s | Save: 0.01s | Total: 1.22s]
# Epoch 597/1000 | Train Loss: -0.5281 | Val Loss: -0.5280
#   [Train: 0.70s | Val: 0.65s | Save: 0.01s | Total: 1.36s]
# Epoch 598/1000 | Train Loss: -0.5281 | Val Loss: -0.5280
#   [Train: 0.68s | Val: 0.82s | Save: 0.01s | Total: 1.51s]
# Epoch 599/1000 | Train Loss: -0.5281 | Val Loss: -0.5280
#   [Train: 0.76s | Val: 0.67s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 600/1000 | Train Loss: -0.5282 | Val Loss: -0.5280
#   [Train: 0.65s | Val: 0.69s | Save: 0.01s | Total: 1.35s]
# Epoch 601/1000 | Train Loss: -0.5281 | Val Loss: -0.5280
#   [Train: 0.73s | Val: 0.62s | Save: 0.01s | Total: 1.36s]
# Epoch 602/1000 | Train Loss: -0.5283 | Val Loss: -0.5280
#   [Train: 0.69s | Val: 0.61s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 603/1000 | Train Loss: -0.5281 | Val Loss: -0.5280
#   [Train: 0.71s | Val: 0.62s | Save: 0.01s | Total: 1.34s]
# Epoch 604/1000 | Train Loss: -0.5283 | Val Loss: -0.5280
#   [Train: 0.66s | Val: 0.69s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 605/1000 | Train Loss: -0.5281 | Val Loss: -0.5281
#   [Train: 0.64s | Val: 0.66s | Save: 0.01s | Total: 1.31s]
# Epoch 606/1000 | Train Loss: -0.5283 | Val Loss: -0.5281
#   [Train: 0.61s | Val: 0.60s | Save: 0.01s | Total: 1.21s]
# Saved new best model.
# Epoch 607/1000 | Train Loss: -0.5283 | Val Loss: -0.5282
#   [Train: 0.69s | Val: 0.62s | Save: 0.01s | Total: 1.32s]
# Saved new best model.
# Epoch 608/1000 | Train Loss: -0.5281 | Val Loss: -0.5282
#   [Train: 0.70s | Val: 0.78s | Save: 0.01s | Total: 1.49s]
# Epoch 609/1000 | Train Loss: -0.5281 | Val Loss: -0.5282
#   [Train: 0.72s | Val: 0.66s | Save: 0.01s | Total: 1.39s]
# Epoch 610/1000 | Train Loss: -0.5282 | Val Loss: -0.5282
#   [Train: 0.74s | Val: 0.66s | Save: 0.01s | Total: 1.40s]
# Epoch 611/1000 | Train Loss: -0.5283 | Val Loss: -0.5282
#   [Train: 0.76s | Val: 0.65s | Save: 0.01s | Total: 1.42s]
# Epoch 612/1000 | Train Loss: -0.5284 | Val Loss: -0.5282
#   [Train: 0.69s | Val: 0.67s | Save: 0.01s | Total: 1.37s]
# Epoch 613/1000 | Train Loss: -0.5281 | Val Loss: -0.5282
#   [Train: 0.70s | Val: 0.75s | Save: 0.01s | Total: 1.45s]
# Epoch 614/1000 | Train Loss: -0.5285 | Val Loss: -0.5282
#   [Train: 0.66s | Val: 0.62s | Save: 0.01s | Total: 1.29s]
# Epoch 615/1000 | Train Loss: -0.5283 | Val Loss: -0.5282
#   [Train: 0.61s | Val: 0.69s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 616/1000 | Train Loss: -0.5284 | Val Loss: -0.5284
#   [Train: 0.74s | Val: 0.63s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 617/1000 | Train Loss: -0.5283 | Val Loss: -0.5287
#   [Train: 0.71s | Val: 0.70s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 618/1000 | Train Loss: -0.5289 | Val Loss: -0.5291
#   [Train: 0.71s | Val: 0.65s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 619/1000 | Train Loss: -0.5296 | Val Loss: -0.5294
#   [Train: 0.86s | Val: 0.69s | Save: 0.01s | Total: 1.57s]
# Saved new best model.
# Epoch 620/1000 | Train Loss: -0.5296 | Val Loss: -0.5296
#   [Train: 0.88s | Val: 0.69s | Save: 0.01s | Total: 1.58s]
# Saved new best model.
# Epoch 621/1000 | Train Loss: -0.5296 | Val Loss: -0.5299
#   [Train: 0.68s | Val: 0.67s | Save: 0.01s | Total: 1.35s]
# Saved new best model.
# Epoch 622/1000 | Train Loss: -0.5302 | Val Loss: -0.5302
#   [Train: 0.70s | Val: 0.66s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 623/1000 | Train Loss: -0.5301 | Val Loss: -0.5305
#   [Train: 0.56s | Val: 0.60s | Save: 0.01s | Total: 1.16s]
# Saved new best model.
# Epoch 624/1000 | Train Loss: -0.5309 | Val Loss: -0.5308
#   [Train: 0.66s | Val: 0.67s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 625/1000 | Train Loss: -0.5312 | Val Loss: -0.5311
#   [Train: 0.65s | Val: 0.71s | Save: 0.01s | Total: 1.38s]
# Saved new best model.
# Epoch 626/1000 | Train Loss: -0.5311 | Val Loss: -0.5314
#   [Train: 0.67s | Val: 0.67s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 627/1000 | Train Loss: -0.5316 | Val Loss: -0.5315
#   [Train: 0.67s | Val: 0.58s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 628/1000 | Train Loss: -0.5319 | Val Loss: -0.5318
#   [Train: 0.57s | Val: 0.60s | Save: 0.01s | Total: 1.18s]
# Saved new best model.
# Epoch 629/1000 | Train Loss: -0.5321 | Val Loss: -0.5321
#   [Train: 0.72s | Val: 0.61s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 630/1000 | Train Loss: -0.5323 | Val Loss: -0.5324
#   [Train: 0.66s | Val: 0.64s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 631/1000 | Train Loss: -0.5325 | Val Loss: -0.5326
#   [Train: 0.73s | Val: 0.68s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 632/1000 | Train Loss: -0.5326 | Val Loss: -0.5329
#   [Train: 0.66s | Val: 0.63s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 633/1000 | Train Loss: -0.5330 | Val Loss: -0.5332
#   [Train: 0.71s | Val: 0.71s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 634/1000 | Train Loss: -0.5335 | Val Loss: -0.5334
#   [Train: 0.69s | Val: 0.69s | Save: 0.01s | Total: 1.40s]
# Saved new best model.
# Epoch 635/1000 | Train Loss: -0.5332 | Val Loss: -0.5336
#   [Train: 0.69s | Val: 0.62s | Save: 0.02s | Total: 1.33s]
# Saved new best model.
# Epoch 636/1000 | Train Loss: -0.5341 | Val Loss: -0.5339
#   [Train: 0.67s | Val: 0.72s | Save: 0.02s | Total: 1.40s]
# Saved new best model.
# Epoch 637/1000 | Train Loss: -0.5340 | Val Loss: -0.5341
#   [Train: 0.80s | Val: 0.67s | Save: 0.01s | Total: 1.48s]
# Saved new best model.
# Epoch 638/1000 | Train Loss: -0.5345 | Val Loss: -0.5344
#   [Train: 0.70s | Val: 0.64s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 639/1000 | Train Loss: -0.5345 | Val Loss: -0.5346
#   [Train: 0.64s | Val: 0.64s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 640/1000 | Train Loss: -0.5345 | Val Loss: -0.5348
#   [Train: 0.58s | Val: 0.52s | Save: 0.01s | Total: 1.11s]
# Saved new best model.
# Epoch 641/1000 | Train Loss: -0.5346 | Val Loss: -0.5351
#   [Train: 0.65s | Val: 0.62s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 642/1000 | Train Loss: -0.5351 | Val Loss: -0.5352
#   [Train: 0.71s | Val: 0.63s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 643/1000 | Train Loss: -0.5355 | Val Loss: -0.5355
#   [Train: 0.65s | Val: 0.70s | Save: 0.01s | Total: 1.36s]
# Saved new best model.
# Epoch 644/1000 | Train Loss: -0.5353 | Val Loss: -0.5357
#   [Train: 0.64s | Val: 0.63s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# ...
# Epoch 591/1000 | Train Loss: 3.1649 | Val Loss: 3.0283
# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs

# %%
show_training_history(conf_dict,EXPERIMENT_DIR)

# %% [markdown]
# ## 6.2 inspect transformation function for source nodes h()

# %%
show_hdag_for_source_nodes(conf_dict,EXPERIMENT_DIR,device=device,xmin_plot=0,xmax_plot=1)
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# h() for  x1:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance
#
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(conf_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# Train loader (x1): 100%|██████████| 2/2 [00:00<00:00,  3.60it/s]
# Val loader (x1): 100%|██████████| 2/2 [00:00<00:00,  4.24it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# Train loader (x2): 100%|██████████| 2/2 [00:00<00:00,  2.77it/s]
# Val loader (x2): 100%|██████████| 1/1 [00:00<00:00,  2.99it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--
# Train loader (x3): 100%|██████████| 2/2 [00:00<00:00,  2.37it/s]
# Val loader (x3): 100%|██████████| 1/1 [00:00<00:00,  2.56it/s]

# %% [markdown]
# ### Coefficients

# %%
conf_dict
EXPERIMENT_DIR
train_df
val_df
device

verbose=False


batch_size = 4112
for node in conf_dict:
    print(f'\n----*----------*-------------*--------check CS of {node} ------------*-----------------*-------------------*--')
    if node != 'x2':
        print('not x2')
        continue
    #### 0. Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    
    ##### 1. Load model 
    model_path = os.path.join(NODE_DIR, "best_model.pt")
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose)
    tram_model = tram_model.to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()

    ##### 2. Dataloader
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=verbose)
    
    #### 3. Forward Pass
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    h_train_list, h_val_list = [], []
    y_pred_list=[]
    with torch.no_grad():
        print("\nProcessing training data...")
        for x, y in tqdm(train_loader, desc=f"Train loader ({node})", total=len(train_loader)):
            y = y.to(device)
            int_input, shift_list = preprocess_inputs(x, device=device)
            
            y_pred = tram_model(int_input=int_input, shift_input=shift_list)
            print(y_pred)
            print(len(shift_list[0]))
            
            break
            # for pred_entry, shift_in in zip(y_pred, shift_list):
            #     pred_entry['shift_out'] = pred_entry['shift_out'] / shift_in  # elementwise division
            #     y_pred_list.append(y_pred)
            
            
            
            
            
            # h_train, _ = contram_nll(y_pred, y, min_max=min_max, return_h=True)
            # h_train_list.extend(h_train.cpu().numpy())
        # print("\nProcessing validation data...")
        # for x, y in tqdm(val_loader, desc=f"Val loader ({node})", total=len(val_loader)):
        #     y = y.to(device)
        #     int_input, shift_list = preprocess_inputs(x, device=device)
        #     y_pred = tram_model(int_input=int_input, shift_input=shift_list)
        #     h_val, _ = contram_nll(y_pred, y, min_max=min_max, return_h=True)
        #     h_val_list.extend(h_val.cpu().numpy())

# shift_outs = [entry['shift_out'][0].cpu().numpy() for entry in y_pred_list]
# shift_outs_combined = np.vstack(shift_outs)

# y_pred_list
# Out:
# ----*----------*-------------*--------check CS of x1 ------------*-----------------*-------------------*--
# not x2
#
# ----*----------*-------------*--------check CS of x2 ------------*-----------------*-------------------*--
#
# Processing training data...
# Train loader (x2):   0%|          | 0/2 [00:00<?, ?it/s]
# {'int_out': tensor([[1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         ...,
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00],
#         [1.0654e-03, 5.4694e+00, 2.7662e+00,  ..., 9.3591e+00, 8.9867e+00,
#          9.2311e+00]], device='cuda:0'), 'shift_out': [tensor([[-0.0014],
#         [-0.0039],
#         [-0.0012],
#         ...,
#         [-0.0039],
#         [-0.0043],
#         [-0.0006]], device='cuda:0')]}
# 4112
#
# ----*----------*-------------*--------check CS of x3 ------------*-----------------*-------------------*--
# not x2

# %%
shift_outs = [entry['shift_out'][0].cpu().numpy() for entry in y_pred_list]
shift_outs_combined = np.vstack(shift_outs)

print(len(shift_outs_combined))
plt.figure(figsize=(8, 6))
plt.hist(shift_outs_combined, bins=50, edgecolor='black')
plt.title("Histogram of Shift Outs Values")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 2
#       1 shift_outs = [entry['shift_out'][0].cpu().numpy() for entry in y_pred_list]
# ----> 2 shift_outs_combined = np.vstack(shift_outs)
#       4 print(len(shift_outs_combined))
#       5 plt.figure(figsize=(8, 6))
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/numpy/_core/shape_base.py:287, in vstack(tup, dtype, casting)
#     285 if not isinstance(arrs, tuple):
#     286     arrs = (arrs,)
# --> 287 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: need at least one array to concatenate
