# %% [markdown]
# ## First EXP with UKB
# - julian provided data from UKB, a plausible DAG and Functions from lit.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 0)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## UKB Data

# %%
full_ukb_df=pd.read_csv('/nasdata/UKB/TRAM_DAG_jd_oct25.csv')
# Out:
# /tmp/ipykernel_595705/327719548.py:1: DtypeWarning: Columns (43,47,51,75,104,105,108,109,113,141,142,143,147,149,150,151,155,157,158,159,161,162,163,333,335,337,339,341,343,345,347,376,377,378,379,399,405,406,407,417,419,421,423,435) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_ukb_df=pd.read_csv('/nasdata/UKB/TRAM_DAG_jd_oct25.csv')

# %%
list(full_ukb_df.columns)
# Out:
# ['Date of attending assessment centre | Instance 0',
#  'Date of attending assessment centre | Instance 1',
#  'Date of attending assessment centre | Instance 2',
#  'Date of attending assessment centre | Instance 3',
#  'Year of birth',
#  'Sex',
#  'Systolic blood pressure, automated reading | Instance 0 | Array 0',
#  'Systolic blood pressure, automated reading | Instance 0 | Array 1',
#  'Systolic blood pressure, automated reading | Instance 1 | Array 0',
#  'Systolic blood pressure, automated reading | Instance 1 | Array 1',
#  'Systolic blood pressure, automated reading | Instance 2 | Array 0',
#  'Systolic blood pressure, automated reading | Instance 2 | Array 1',
#  'Systolic blood pressure, automated reading | Instance 3 | Array 0',
#  'Systolic blood pressure, automated reading | Instance 3 | Array 1',
#  'Diastolic blood pressure, automated reading | Instance 0 | Array 0',
#  'Diastolic blood pressure, automated reading | Instance 0 | Array 1',
#  'Diastolic blood pressure, automated reading | Instance 1 | Array 0',
#  'Diastolic blood pressure, automated reading | Instance 1 | Array 1',
#  'Diastolic blood pressure, automated reading | Instance 2 | Array 0',
#  'Diastolic blood pressure, automated reading | Instance 2 | Array 1',
#  'Diastolic blood pressure, automated reading | Instance 3 | Array 0',
#  'Diastolic blood pressure, automated reading | Instance 3 | Array 1',
#  'Cholesterol | Instance 0',
#  'Cholesterol | Instance 1',
#  'HDL cholesterol | Instance 0',
#  'HDL cholesterol | Instance 1',
#  'LDL direct | Instance 0',
#  'LDL direct | Instance 1',
#  'Triglycerides | Instance 0',
#  'Triglycerides | Instance 1',
#  'Pack years of smoking | Instance 0',
#  'Pack years of smoking | Instance 1',
#  'Pack years of smoking | Instance 2',
#  'Pack years of smoking | Instance 3',
#  'Smoking status | Instance 0',
#  'Smoking status | Instance 1',
#  'Smoking status | Instance 2',
#  'Smoking status | Instance 3',
#  'Glycated haemoglobin (HbA1c) | Instance 0',
#  'Glycated haemoglobin (HbA1c) | Instance 1',
#  'IPAQ activity group | Instance 0',
#  'IPAQ activity group | Instance 1',
#  'IPAQ activity group | Instance 2',
#  'IPAQ activity group | Instance 3',
#  'At or above moderate/vigorous recommendation | Instance 0',
#  'At or above moderate/vigorous recommendation | Instance 1',
#  'At or above moderate/vigorous recommendation | Instance 2',
#  'At or above moderate/vigorous recommendation | Instance 3',
#  'At or above moderate/vigorous/walking recommendation | Instance 0',
#  'At or above moderate/vigorous/walking recommendation | Instance 1',
#  'At or above moderate/vigorous/walking recommendation | Instance 2',
#  'At or above moderate/vigorous/walking recommendation | Instance 3',
#  'MET minutes per week for walking | Instance 0',
#  'MET minutes per week for walking | Instance 1',
#  'MET minutes per week for walking | Instance 2',
#  'MET minutes per week for walking | Instance 3',
#  'MET minutes per week for moderate activity | Instance 0',
#  'MET minutes per week for moderate activity | Instance 1',
#  'MET minutes per week for moderate activity | Instance 2',
#  'MET minutes per week for moderate activity | Instance 3',
#  'MET minutes per week for vigorous activity | Instance 0',
#  'MET minutes per week for vigorous activity | Instance 1',
#  'MET minutes per week for vigorous activity | Instance 2',
#  'MET minutes per week for vigorous activity | Instance 3',
#  'Summed MET minutes per week for all activity | Instance 0',
#  'Summed MET minutes per week for all activity | Instance 1',
#  'Summed MET minutes per week for all activity | Instance 2',
#  'Summed MET minutes per week for all activity | Instance 3',
#  'Medication for cholesterol, blood pressure or diabetes | Instance 0',
#  'Medication for cholesterol, blood pressure or diabetes | Instance 1',
#  'Medication for cholesterol, blood pressure or diabetes | Instance 2',
#  'Medication for cholesterol, blood pressure or diabetes | Instance 3',
#  'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones | Instance 0',
#  'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones | Instance 1',
#  'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones | Instance 2',
#  'Medication for cholesterol, blood pressure, diabetes, or take exogenous hormones | Instance 3',
#  'Date of death | Instance 0',
#  'Underlying (primary) cause of death: ICD10 | Instance 0',
#  'Date of ischaemic stroke',
#  'Date of stroke',
#  'Date of intracerebral haemorrhage',
#  'Date of subarachnoid haemorrhage',
#  'Date of myocardial infarction',
#  'Date I48 first reported (atrial fibrillation and flutter)',
#  'Body mass index (BMI) | Instance 0',
#  'Body mass index (BMI) | Instance 1',
#  'Body mass index (BMI) | Instance 2',
#  'Body mass index (BMI) | Instance 3',
#  'Waist circumference | Instance 0',
#  'Waist circumference | Instance 1',
#  'Waist circumference | Instance 2',
#  'Waist circumference | Instance 3',
#  'Hip circumference | Instance 0',
#  'Hip circumference | Instance 1',
#  'Hip circumference | Instance 2',
#  'Hip circumference | Instance 3',
#  'Weight | Instance 0',
#  'Weight | Instance 1',
#  'Weight | Instance 2',
#  'Weight | Instance 3',
#  'Townsend deprivation index at recruitment',
#  'Date I10 first reported (essential (primary) hypertension)',
#  'Date I11 first reported (hypertensive heart disease)',
#  'Date I12 first reported (hypertensive renal disease)',
#  'Date I13 first reported (hypertensive heart and renal disease)',
#  'Date I15 first reported (secondary hypertension)',
#  'Date E10 first reported (insulin-dependent diabetes mellitus)',
#  'Date E11 first reported (non-insulin-dependent diabetes mellitus)',
#  'Date E12 first reported (malnutrition-related diabetes mellitus)',
#  'Date E13 first reported (other specified diabetes mellitus)',
#  'Date E14 first reported (unspecified diabetes mellitus)',
#  'Date I25 first reported (chronic ischaemic heart disease)',
#  'Date I70 first reported (atherosclerosis)',
#  'Date I74 first reported (arterial embolism and thrombosis)',
#  'Date E78 first reported (disorders of lipoprotein metabolism and other lipidaemias)',
#  'Date I50 first reported (heart failure)',
#  'C-reactive protein | Instance 0',
#  'C-reactive protein | Instance 1',
#  'Creatinine | Instance 0',
#  'Creatinine | Instance 1',
#  'Oestradiol | Instance 0',
#  'Oestradiol | Instance 1',
#  'Testosterone | Instance 0',
#  'Testosterone | Instance 1',
#  'SHBG | Instance 0',
#  'SHBG | Instance 1',
#  'Calcium | Instance 0',
#  'Calcium | Instance 1',
#  'Cystatin C | Instance 0',
#  'Cystatin C | Instance 1',
#  'Glucose | Instance 0',
#  'Glucose | Instance 1',
#  'Lipoprotein A | Instance 0',
#  'Lipoprotein A | Instance 1',
#  'Phosphate | Instance 0',
#  'Phosphate | Instance 1',
#  'Apolipoprotein A | Instance 0',
#  'Apolipoprotein A | Instance 1',
#  'Apolipoprotein B | Instance 0',
#  'Apolipoprotein B | Instance 1',
#  'Age when periods started (menarche) | Instance 0',
#  'Age when periods started (menarche) | Instance 1',
#  'Age when periods started (menarche) | Instance 2',
#  'Age when periods started (menarche) | Instance 3',
#  'Had menopause | Instance 0',
#  'Had menopause | Instance 1',
#  'Had menopause | Instance 2',
#  'Had menopause | Instance 3',
#  'Age at menopause (last menstrual period) | Instance 0',
#  'Age at menopause (last menstrual period) | Instance 1',
#  'Age at menopause (last menstrual period) | Instance 2',
#  'Age at menopause (last menstrual period) | Instance 3',
#  'Ever used hormone-replacement therapy (HRT) | Instance 0',
#  'Ever used hormone-replacement therapy (HRT) | Instance 1',
#  'Ever used hormone-replacement therapy (HRT) | Instance 2',
#  'Ever used hormone-replacement therapy (HRT) | Instance 3',
#  'Age started hormone-replacement therapy (HRT) | Instance 0',
#  'Age started hormone-replacement therapy (HRT) | Instance 1',
#  'Age started hormone-replacement therapy (HRT) | Instance 2',
#  'Age started hormone-replacement therapy (HRT) | Instance 3',
#  'Age last used hormone-replacement therapy (HRT) | Instance 0',
#  'Age last used hormone-replacement therapy (HRT) | Instance 1',
#  'Age last used hormone-replacement therapy (HRT) | Instance 2',
#  'Age last used hormone-replacement therapy (HRT) | Instance 3',
#  'Alcohol intake frequency. | Instance 0',
#  'Alcohol intake frequency. | Instance 1',
#  'Alcohol intake frequency. | Instance 2',
#  'Alcohol intake frequency. | Instance 3',
#  'LV end diastolic volume | Instance 2',
#  'LV end diastolic volume | Instance 3',
#  'LV end systolic volume | Instance 2',
#  'LV end systolic volume | Instance 3',
#  'LV stroke volume | Instance 2',
#  'LV stroke volume | Instance 3',
#  'LV ejection fraction | Instance 2',
#  'LV ejection fraction | Instance 3',
#  'LV cardiac output | Instance 2',
#  'LV cardiac output | Instance 3',
#  'LV myocardial mass | Instance 2',
#  'LV myocardial mass | Instance 3',
#  'RV end diastolic volume | Instance 2',
#  'RV end diastolic volume | Instance 3',
#  'RV end systolic volume | Instance 2',
#  'RV end systolic volume | Instance 3',
#  'RV stroke volume | Instance 2',
#  'RV stroke volume | Instance 3',
#  'RV ejection fraction | Instance 2',
#  'RV ejection fraction | Instance 3',
#  'LA maximum volume | Instance 2',
#  'LA maximum volume | Instance 3',
#  'LA minimum volume | Instance 2',
#  'LA minimum volume | Instance 3',
#  'LA stroke volume | Instance 2',
#  'LA stroke volume | Instance 3',
#  'LA ejection fraction | Instance 2',
#  'LA ejection fraction | Instance 3',
#  'RA maximum volume | Instance 2',
#  'RA maximum volume | Instance 3',
#  'RA minimum volume | Instance 2',
#  'RA minimum volume | Instance 3',
#  'RA stroke volume | Instance 2',
#  'RA stroke volume | Instance 3',
#  'RA ejection fraction | Instance 2',
#  'RA ejection fraction | Instance 3',
#  'Ascending aorta maximum area | Instance 2',
#  'Ascending aorta maximum area | Instance 3',
#  'Ascending aorta minimum area | Instance 2',
#  'Ascending aorta minimum area | Instance 3',
#  'Ascending aorta distensibility | Instance 2',
#  'Ascending aorta distensibility | Instance 3',
#  'Descending aorta maximum area | Instance 2',
#  'Descending aorta maximum area | Instance 3',
#  'Descending aorta minimum area | Instance 2',
#  'Descending aorta minimum area | Instance 3',
#  'Descending aorta distensibility | Instance 2',
#  'Descending aorta distensibility | Instance 3',
#  'LV mean myocardial wall thickness AHA 1 | Instance 2',
#  'LV mean myocardial wall thickness AHA 1 | Instance 3',
#  'LV mean myocardial wall thickness AHA 2 | Instance 2',
#  'LV mean myocardial wall thickness AHA 2 | Instance 3',
#  'LV mean myocardial wall thickness AHA 3 | Instance 2',
#  'LV mean myocardial wall thickness AHA 3 | Instance 3',
#  'LV mean myocardial wall thickness AHA 4 | Instance 2',
#  'LV mean myocardial wall thickness AHA 4 | Instance 3',
#  'LV mean myocardial wall thickness AHA 5 | Instance 2',
#  'LV mean myocardial wall thickness AHA 5 | Instance 3',
#  'LV mean myocardial wall thickness AHA 6 | Instance 2',
#  'LV mean myocardial wall thickness AHA 6 | Instance 3',
#  'LV mean myocardial wall thickness AHA 7 | Instance 2',
#  'LV mean myocardial wall thickness AHA 7 | Instance 3',
#  'LV mean myocardial wall thickness AHA 8 | Instance 2',
#  'LV mean myocardial wall thickness AHA 8 | Instance 3',
#  'LV mean myocardial wall thickness AHA 9 | Instance 2',
#  'LV mean myocardial wall thickness AHA 9 | Instance 3',
#  'LV mean myocardial wall thickness AHA 10 | Instance 2',
#  'LV mean myocardial wall thickness AHA 10 | Instance 3',
#  'LV mean myocardial wall thickness AHA 11 | Instance 2',
#  'LV mean myocardial wall thickness AHA 11 | Instance 3',
#  'LV mean myocardial wall thickness AHA 12 | Instance 2',
#  'LV mean myocardial wall thickness AHA 12 | Instance 3',
#  'LV mean myocardial wall thickness AHA 13 | Instance 2',
#  'LV mean myocardial wall thickness AHA 13 | Instance 3',
#  'LV mean myocardial wall thickness AHA 14 | Instance 2',
#  'LV mean myocardial wall thickness AHA 14 | Instance 3',
#  'LV mean myocardial wall thickness AHA 15 | Instance 2',
#  'LV mean myocardial wall thickness AHA 15 | Instance 3',
#  'LV mean myocardial wall thickness AHA 16 | Instance 2',
#  'LV mean myocardial wall thickness AHA 16 | Instance 3',
#  'LV mean myocardial wall thickness global | Instance 2',
#  'LV mean myocardial wall thickness global | Instance 3',
#  'LV circumferential strain AHA 1 | Instance 2',
#  'LV circumferential strain AHA 1 | Instance 3',
#  'LV circumferential strain AHA 2 | Instance 2',
#  'LV circumferential strain AHA 2 | Instance 3',
#  'LV circumferential strain AHA 3 | Instance 2',
#  'LV circumferential strain AHA 3 | Instance 3',
#  'LV circumferential strain AHA 4 | Instance 2',
#  'LV circumferential strain AHA 4 | Instance 3',
#  'LV circumferential strain AHA 5 | Instance 2',
#  'LV circumferential strain AHA 5 | Instance 3',
#  'LV circumferential strain AHA 6 | Instance 2',
#  'LV circumferential strain AHA 6 | Instance 3',
#  'LV circumferential strain AHA 7 | Instance 2',
#  'LV circumferential strain AHA 7 | Instance 3',
#  'LV circumferential strain AHA 8 | Instance 2',
#  'LV circumferential strain AHA 8 | Instance 3',
#  'LV circumferential strain AHA 9 | Instance 2',
#  'LV circumferential strain AHA 9 | Instance 3',
#  'LV circumferential strain AHA 10 | Instance 2',
#  'LV circumferential strain AHA 10 | Instance 3',
#  'LV circumferential strain AHA 11 | Instance 2',
#  'LV circumferential strain AHA 11 | Instance 3',
#  'LV circumferential strain AHA 12 | Instance 2',
#  'LV circumferential strain AHA 12 | Instance 3',
#  'LV circumferential strain AHA 13 | Instance 2',
#  'LV circumferential strain AHA 13 | Instance 3',
#  'LV circumferential strain AHA 14 | Instance 2',
#  'LV circumferential strain AHA 14 | Instance 3',
#  'LV circumferential strain AHA 15 | Instance 2',
#  'LV circumferential strain AHA 15 | Instance 3',
#  'LV circumferential strain AHA 16 | Instance 2',
#  'LV circumferential strain AHA 16 | Instance 3',
#  'LV circumferential strain global | Instance 2',
#  'LV circumferential strain global | Instance 3',
#  'LV radial strain AHA 1 | Instance 2',
#  'LV radial strain AHA 1 | Instance 3',
#  'LV radial strain AHA 2 | Instance 2',
#  'LV radial strain AHA 2 | Instance 3',
#  'LV radial strain AHA 3 | Instance 2',
#  'LV radial strain AHA 3 | Instance 3',
#  'LV radial strain AHA 4 | Instance 2',
#  'LV radial strain AHA 4 | Instance 3',
#  'LV radial strain AHA 5 | Instance 2',
#  'LV radial strain AHA 5 | Instance 3',
#  'LV radial strain AHA 6 | Instance 2',
#  'LV radial strain AHA 6 | Instance 3',
#  'LV radial strain AHA 7 | Instance 2',
#  'LV radial strain AHA 7 | Instance 3',
#  'LV radial strain AHA 8 | Instance 2',
#  'LV radial strain AHA 8 | Instance 3',
#  'LV radial strain AHA 9 | Instance 2',
#  'LV radial strain AHA 9 | Instance 3',
#  'LV radial strain AHA 10 | Instance 2',
#  'LV radial strain AHA 10 | Instance 3',
#  'LV radial strain AHA 11 | Instance 2',
#  'LV radial strain AHA 11 | Instance 3',
#  'LV radial strain AHA 12 | Instance 2',
#  'LV radial strain AHA 12 | Instance 3',
#  'LV radial strain AHA 13 | Instance 2',
#  'LV radial strain AHA 13 | Instance 3',
#  'LV radial strain AHA 14 | Instance 2',
#  'LV radial strain AHA 14 | Instance 3',
#  'LV radial strain AHA 15 | Instance 2',
#  'LV radial strain AHA 15 | Instance 3',
#  'LV radial strain AHA 16 | Instance 2',
#  'LV radial strain AHA 16 | Instance 3',
#  'LV radial strain global | Instance 2',
#  'LV radial strain global | Instance 3',
#  'LV longitudinal strain Segment 1 | Instance 2',
#  'LV longitudinal strain Segment 1 | Instance 3',
#  'LV longitudinal strain Segment 2 | Instance 2',
#  'LV longitudinal strain Segment 2 | Instance 3',
#  'LV longitudinal strain Segment 3 | Instance 2',
#  'LV longitudinal strain Segment 3 | Instance 3',
#  'LV longitudinal strain Segment 4 | Instance 2',
#  'LV longitudinal strain Segment 4 | Instance 3',
#  'LV longitudinal strain Segment 5 | Instance 2',
#  'LV longitudinal strain Segment 5 | Instance 3',
#  'LV longitudinal strain Segment 6 | Instance 2',
#  'LV longitudinal strain Segment 6 | Instance 3',
#  'LV longitudinal strain global | Instance 2',
#  'LV longitudinal strain global | Instance 3',
#  'Cooked vegetable intake | Instance 0',
#  'Cooked vegetable intake | Instance 1',
#  'Cooked vegetable intake | Instance 2',
#  'Cooked vegetable intake | Instance 3',
#  'Salad / raw vegetable intake | Instance 0',
#  'Salad / raw vegetable intake | Instance 1',
#  'Salad / raw vegetable intake | Instance 2',
#  'Salad / raw vegetable intake | Instance 3',
#  'Fresh fruit intake | Instance 0',
#  'Fresh fruit intake | Instance 1',
#  'Fresh fruit intake | Instance 2',
#  'Fresh fruit intake | Instance 3',
#  'Dried fruit intake | Instance 0',
#  'Dried fruit intake | Instance 1',
#  'Dried fruit intake | Instance 2',
#  'Dried fruit intake | Instance 3',
#  'Oily fish intake | Instance 0',
#  'Oily fish intake | Instance 1',
#  'Oily fish intake | Instance 2',
#  'Oily fish intake | Instance 3',
#  'Non-oily fish intake | Instance 0',
#  'Non-oily fish intake | Instance 1',
#  'Non-oily fish intake | Instance 2',
#  'Non-oily fish intake | Instance 3',
#  'Processed meat intake | Instance 0',
#  'Processed meat intake | Instance 1',
#  'Processed meat intake | Instance 2',
#  'Processed meat intake | Instance 3',
#  'Poultry intake | Instance 0',
#  'Poultry intake | Instance 1',
#  'Poultry intake | Instance 2',
#  'Poultry intake | Instance 3',
#  'Beef intake | Instance 0',
#  'Beef intake | Instance 1',
#  'Beef intake | Instance 2',
#  'Beef intake | Instance 3',
#  'Lamb/mutton intake | Instance 0',
#  'Lamb/mutton intake | Instance 1',
#  'Lamb/mutton intake | Instance 2',
#  'Lamb/mutton intake | Instance 3',
#  'Pork intake | Instance 0',
#  'Pork intake | Instance 1',
#  'Pork intake | Instance 2',
#  'Pork intake | Instance 3',
#  'Age when last ate meat | Instance 0',
#  'Age when last ate meat | Instance 1',
#  'Age when last ate meat | Instance 2',
#  'Age when last ate meat | Instance 3',
#  'Never eat eggs, dairy, wheat, sugar | Instance 0',
#  'Never eat eggs, dairy, wheat, sugar | Instance 1',
#  'Never eat eggs, dairy, wheat, sugar | Instance 2',
#  'Never eat eggs, dairy, wheat, sugar | Instance 3',
#  'Cheese intake | Instance 0',
#  'Cheese intake | Instance 1',
#  'Cheese intake | Instance 2',
#  'Cheese intake | Instance 3',
#  'Milk type used | Instance 0',
#  'Milk type used | Instance 1',
#  'Milk type used | Instance 2',
#  'Milk type used | Instance 3',
#  'Spread type | Instance 0',
#  'Spread type | Instance 1',
#  'Spread type | Instance 2',
#  'Spread type | Instance 3',
#  'Non-butter spread type details | Instance 0',
#  'Non-butter spread type details | Instance 1',
#  'Non-butter spread type details | Instance 2',
#  'Non-butter spread type details | Instance 3',
#  'Bread type | Instance 0',
#  'Bread type | Instance 1',
#  'Bread type | Instance 2',
#  'Bread type | Instance 3',
#  'Cereal intake | Instance 0',
#  'Cereal intake | Instance 1',
#  'Cereal intake | Instance 2',
#  'Cereal intake | Instance 3',
#  'Cereal type | Instance 0',
#  'Cereal type | Instance 1',
#  'Cereal type | Instance 2',
#  'Cereal type | Instance 3',
#  'Salt added to food | Instance 0',
#  'Salt added to food | Instance 1',
#  'Salt added to food | Instance 2',
#  'Salt added to food | Instance 3',
#  'Tea intake | Instance 0',
#  'Tea intake | Instance 1',
#  'Tea intake | Instance 2',
#  'Tea intake | Instance 3',
#  'Coffee intake | Instance 0',
#  'Coffee intake | Instance 1',
#  'Coffee intake | Instance 2',
#  'Coffee intake | Instance 3',
#  'Coffee type | Instance 0',
#  'Coffee type | Instance 1',
#  'Coffee type | Instance 2',
#  'Coffee type | Instance 3',
#  'Hot drink temperature | Instance 0',
#  'Hot drink temperature | Instance 1',
#  'Hot drink temperature | Instance 2',
#  'Hot drink temperature | Instance 3',
#  'Water intake | Instance 0',
#  'Water intake | Instance 1',
#  'Water intake | Instance 2',
#  'Water intake | Instance 3',
#  'Major dietary changes in the last 5 years | Instance 0',
#  'Major dietary changes in the last 5 years | Instance 1',
#  'Major dietary changes in the last 5 years | Instance 2',
#  'Major dietary changes in the last 5 years | Instance 3',
#  'Variation in diet | Instance 0',
#  'Variation in diet | Instance 1',
#  'Variation in diet | Instance 2',
#  'Variation in diet | Instance 3']

# %% [markdown]
# ### AGE

# %%
full_ukb_df['Age_baseline | Instance 0'] = pd.to_datetime(full_ukb_df['Date of attending assessment centre | Instance 0']).dt.year - full_ukb_df['Year of birth']
full_ukb_df['Age_baseline | Instance 0'].head()
# Out:
# 0    64
# 1    66
# 2    67
# 3    50
# 4    44
# Name: Age_baseline | Instance 0, dtype: int64

# %% [markdown]
# ### Blood Pressure

# %%
full_ukb_df['Avg_sys_blood_Array_0_1 | Instance 0']=(full_ukb_df['Systolic blood pressure, automated reading | Instance 0 | Array 0']+full_ukb_df['Systolic blood pressure, automated reading | Instance 0 | Array 1'])/2
full_ukb_df['Avg_sys_blood_Array_0_1 | Instance 0'].head()
# Out:
# 0    137.0
# 1    134.5
# 2    150.0
# 3    152.5
# 4    119.5
# Name: Avg_sys_blood_Array_0_1 | Instance 0, dtype: float64

# %% [markdown]
# ### Sex

# %%
full_ukb_df['Sex'].head()
# Out:
# 0      Male
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# Name: Sex, dtype: object

# %% [markdown]
# ###  Lipid Profile

# %%
full_ukb_df['LDL direct | Instance 0'].head()
# Out:
# 0    4.059
# 1    3.388
# 2    3.311
# 3    3.478
# 4    2.930
# Name: LDL direct | Instance 0, dtype: float64

# %% [markdown]
# ###  Blood Glucose

# %%
full_ukb_df['Glycated haemoglobin (HbA1c) | Instance 0'].head()
# Out:
# 0    39.0
# 1    39.6
# 2    36.5
# 3    31.3
# 4    37.9
# Name: Glycated haemoglobin (HbA1c) | Instance 0, dtype: float64

# %% [markdown]
# ### Excercise

# %%
full_ukb_df['Summed MET minutes per week for all activity | Instance 0'].head()
# Out:
# 0    5799.0
# 1    4958.0
# 2       NaN
# 3    1496.0
# 4     396.0
# Name: Summed MET minutes per week for all activity | Instance 0, dtype: float64

# %% [markdown]
# ## Combine

# %%
# information from Julian and mappings for variables to KISS
variable_mapping = [
    ["Age", "age", "40 – 70", "years", "Age_baseline | Instance 0"],
    ["Sex", "sex", "0 = Female, 1 = Male", "binary", "Sex"],
    ["Exercise", "exercise", "0 – 20 000", "MET-min/week", "Summed MET minutes per week for all activity | Instance 0"],
    ["Lipid Profile", "lipid", "0 – 10", "mmol/L", "LDL direct | Instance 0"],
    ["Blood Glucose", "glucose", "15 – 500", "mmol/mol", "Glycated haemoglobin (HbA1c) | Instance 0"],
    ["Blood Pressure", "bp", "80 – 200", "mmHg",
     "Avg_sys_blood_Array_0_1 | Instance 0"],
]

df_vars = pd.DataFrame(variable_mapping, columns=["Variable", "Symbol", "Range", "Unit / Levels", "Original Variable"])
df_vars
# Out:
#          Variable    Symbol                 Range Unit / Levels  \
# 0             Age       age               40 – 70         years
# 1             Sex       sex  0 = Female, 1 = Male        binary
# 2        Exercise  exercise            0 – 20 000  MET-min/week
# 3   Lipid Profile     lipid                0 – 10        mmol/L
# 4   Blood Glucose   glucose              15 – 500      mmol/mol
# 5  Blood Pressure        bp              80 – 200          mmHg
#
#                                            Original Variable
# 0                                  Age_baseline | Instance 0
# 1                                                        Sex
# 2  Summed MET minutes per week for all activity | Instance 0
# 3                                    LDL direct | Instance 0
# 4                  Glycated haemoglobin (HbA1c) | Instance 0
# 5                       Avg_sys_blood_Array_0_1 | Instance 0

# %%
# subset of UKB with the selectred cols
ukb_subset=full_ukb_df[['Age_baseline | Instance 0','Sex','Avg_sys_blood_Array_0_1 | Instance 0','LDL direct | Instance 0','Glycated haemoglobin (HbA1c) | Instance 0','Summed MET minutes per week for all activity | Instance 0']]

# create mapping dictionary from 'Original Variable' to 'Symbol' , rename columns of ukb_subset accordingly
rename_map = dict(zip(df_vars["Original Variable"], df_vars["Symbol"]))

ukb_subset = ukb_subset.rename(columns=rename_map)
ukb_subset.head()
# Out:
#    age     sex     bp  lipid  glucose  exercise
# 0   64    Male  137.0  4.059     39.0    5799.0
# 1   66    Male  134.5  3.388     39.6    4958.0
# 2   67    Male  150.0  3.311     36.5       NaN
# 3   50    Male  152.5  3.478     31.3    1496.0
# 4   44  Female  119.5  2.930     37.9     396.0

# %% [markdown]
# ### trransformations and manipulation

# %%
ukb_subset.dropna(inplace=False)

ukb_subset['sex'] = ukb_subset['sex'].map({'Male': 1, 'Female': 0})
ukb_subset['age'] = ukb_subset['age'].astype(float)

ukb_subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501931 entries, 0 to 501930
# Data columns (total 6 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   age       501931 non-null  float64
#  1   sex       501931 non-null  int64
#  2   bp        456435 non-null  float64
#  3   lipid     468175 non-null  float64
#  4   glucose   465980 non-null  float64
#  5   exercise  384831 non-null  float64
# dtypes: float64(5), int64(1)
# memory usage: 23.0 MB

# %%
ukb_subset.describe()
# Out:
#                  age            sex             bp          lipid  \
# count  501931.000000  501931.000000  456435.000000  468175.000000
# mean       57.043618       0.456035     137.782788       3.556376
# std         8.102636       0.498064      18.626290       0.870037
# min        38.000000       0.000000      65.000000       0.266000
# 25%        51.000000       0.000000     124.500000       2.944000
# 50%        58.000000       0.000000     136.000000       3.516000
# 75%        64.000000       1.000000     149.500000       4.117000
# max        73.000000       1.000000     253.500000       9.797000
#
#              glucose       exercise
# count  465980.000000  384831.000000
# mean       36.132487    2644.953106
# std         6.777457    2653.212517
# min        15.000000       0.000000
# 25%        32.800000     813.000000
# 50%        35.200000    1786.000000
# 75%        37.900000    3564.000000
# max       515.200000   19278.000000

# %%
ukb_subset.to_csv('UKB_subset_jd_oct25.csv', index=False)

# %%
sns.pairplot(ukb_subset)

# %% [markdown]
# ## Source Nodes distributions

# %%
ukb_subset['age'].hist(bins=100)
# Out:
# <Axes: >

# %%
plt.hist(ukb_subset['age'], bins=100, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Empirical Age Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.hist(ukb_subset['age'], bins=100, edgecolor='black')
#       2 plt.xlabel('Age')
#       3 plt.ylabel('Count')
#
# NameError: name 'plt' is not defined

# %%
sum(ukb_subset['sex']==1)/len(ukb_subset)
0.4560347936270125
# Out:
# 0.4560347936270125

# %% [markdown]
# ## Simulate

# %%
def simulate_dag(n_obs=1000, doX=None, seed=None):
    """
    Simulate data according to the DAG 'Effect of exercise on CVRF'
    with optional interventions (do-operations).

    Parameters
    ----------
    n_obs : int
        Number of observations to generate.
    doX : dict or None
        Optional interventions, e.g. {'sex':1, 'exercise':10000}.
        Fixes variables to constants before propagation.
    seed : int or None
        Random seed.

    Returns
    -------
    pd.DataFrame
        Simulated dataset.
    """
    if seed is not None:
        np.random.seed(seed)

    if doX is None:
        doX = {}

    # --- 1. exogenous variables ---
    
    #  age
    # age = np.full(n_obs, doX['age']) if 'age' in doX else np.random.uniform(40, 70, n_obs)
    age = ukb_subset['age'].sample(n=n_obs, replace=True).to_numpy() # direct sampling from empirical distribution
    
    p=0.4560347936270125                                               # proportion form empirical distribution
    sex = np.full(n_obs, doX['sex']) if 'sex' in doX else np.random.binomial(1, p, n_obs)

    #exercise 
    if 'exercise' in doX:
        exercise = np.full(n_obs, doX['exercise'])
    else:
        exercise = 9000 + 200 * sex - 100 * age + np.random.normal(0, 800, n_obs)
        # exercise = np.clip(exercise, 0, 20000)

    # lipid profile 
    if 'lipid' in doX:
        lipid = np.full(n_obs, doX['lipid'])
    else:
        lipid = -2.5 + 0.5 * sex + 0.1 * age - 0.0001 * exercise + np.random.normal(0, 0.3, n_obs)
        # lipid = np.clip(lipid, 0, 10)

    # blood glucose 
    if 'glucose' in doX:
        glucose = np.full(n_obs, doX['glucose'])
    else:
        glucose = 35 + 2 * sex + 0.1 * age - 0.03 * age * sex - 0.001 * exercise + np.random.normal(0, 10, n_obs)
        # glucose = np.clip(glucose, 15, 500)

    # blood pressure 
    if 'bp' in doX:
        bp = np.full(n_obs, doX['bp'])
    else:
        bp = 60 + 5 * sex * 0.8 * age + 1.1 * glucose + 3 * lipid - 0.005 * exercise + np.random.normal(0, 5, n_obs)
        # bp = np.clip(bp, 80, 200)

    return pd.DataFrame({
        'age': age,
        'sex': sex,
        'exercise': exercise,
        'lipid': lipid,
        'glucose': glucose,
        'bp': bp
    })

# %%
import seaborn as sns
df_simulated = simulate_dag(1000, doX=None, seed=42)
print(df_simulated.head())
# Out:
#     age  sex     exercise     lipid    glucose          bp
# 0  58.0    1  3197.851450  3.321234  51.876439  342.549372
# 1  64.0    1  3113.667624  4.156021  26.949614  337.004592
# 2  70.0    0  1848.882650  4.567570  36.384113   97.936930
# 3  70.0    1  2642.458621  4.550463  37.194393  391.024872
# 4  52.0    0  3773.050778  2.978990  42.479186   95.999241

# %%
sns.pairplot(df_simulated)

# %%
df_simulated.describe()
# Out:
#                age          sex     exercise        lipid      glucose  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     56.948000     0.456000  3378.201032     3.076419    37.590329
# std       8.363088     0.498309  1131.763461     0.992435    10.138374
# min      40.000000     0.000000   133.984343     0.629518     7.571086
# 25%      50.000000     0.000000  2550.000351     2.293142    30.836854
# 50%      58.000000     0.000000  3343.448286     3.202748    37.231882
# 75%      64.000000     1.000000  4181.916100     3.890882    44.602263
# max      70.000000     1.000000  6571.902109     5.143646    65.373679
#
#                 bp
# count  1000.000000
# mean    197.788263
# std     117.780431
# min      46.009901
# 25%      92.256680
# 50%     115.887326
# 75%     322.453552
# max     407.123044
