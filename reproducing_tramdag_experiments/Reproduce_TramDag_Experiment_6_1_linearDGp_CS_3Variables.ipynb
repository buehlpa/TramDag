# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
device = torch.device('cuda')
print("Train with GPU support.")
else:
device = torch.device('cpu')
print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "tramdagpaper_exp6_1_linearDGP_cs"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# they made 3 experiments:
# 1. Linear-shift DGP and linear-shift model
# 2. Complex-shift DGP and complex-shift model
# 3. Linear-shift DGP and complex-shift model <------------------

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return -0.3*x  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        z2 = logit(u2)
        x2 = (z2 - 2 * x1) / 5#5#   0.42  in the trainagle strucutred cont last line is 5 for SI
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 -f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          - f(X2)        | replace h(x2|x1) with z
    # z3          = 0.63*x3 + beta3 * x1          - f(X2)        | reformulate to x2
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z3+0.2 * x1   +f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        z3 = logit(u3)
        x3 = (z3 + 0.2 * x1 + f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])
        
    #df = pd.DataFrame({'x1': x1, 'x2': x2})#, 'x3': x3})
    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df

n_obs=10_000

df = dgp(n_obs=n_obs, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")


if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=n_obs)

    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")


sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Setting Seed: 42
#          x1        x2        x3
# 0  0.790178 -0.257718  0.149574
# 1  0.276383  0.055677 -5.949408
# 2  0.736578  0.053836 -1.297906
# 3  0.808237  0.022891 -4.875233
# 4  0.749825 -0.335202  2.289209

# %% [markdown]
# ## 2.1 train test split

# %%
# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# 2. Compute quantiles from training data
quantiles = train_df.quantile([0.05, 0.95])
min_vals = quantiles.loc[0.05]
max_vals = quantiles.loc[0.95]

# 3. Normalize all sets using training quantiles
def normalize_with_quantiles(df, min_vals, max_vals):
    return (df - min_vals) / (max_vals - min_vals)

# train_df = normalize_with_quantiles(train_df, min_vals, max_vals)
# val_df = normalize_with_quantiles(val_df, min_vals, max_vals)
# test_df = normalize_with_quantiles(test_df, min_vals, max_vals)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 8000, Validation size: 1000, Test size: 1000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous , images , ordinal
# data_type={'x1':'cont','x2':'cont'}  # continous , images , ordinal

adj_matrix = np.array([
    [ "0", "ls", "ls"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "cs"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)

# adj_matrix = np.array([
#     [ "0", "ls"],  # A -> B (cs), A -> C (ls)
#     [ "0", "0" ]  # B -> D (ls)  # C -> D (cs)
# ], object)


# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
# nn_names_matrix[1,2]='ComplexShiftCustomTabular'
plot_nn_names_matrix(nn_names_matrix,data_type)
# Out:
# *************
#  Model has Complex intercepts and Coomplex shifts , please add your Model to the modelzoo
# ************

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/tramdagpaper_exp6_1_linearDGP_cs2_conf.json
# /tmp/ipykernel_622397/1695834966.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
# /tmp/ipykernel_622397/1695834966.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['max']=max_vals[i].tolist()
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.1205322246468743,
#   'max': 0.794692622870355},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift'},
#   'min': -0.8142888901184293,
#   'max': 0.4238437120810543},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls', 'x2': 'cs'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift',
#    'x2': 'ComplexShiftDefaultTabular'},
#   'min': -4.421199142423371,
#   'max': 4.916709870336174}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3']#['x2']#'x1','x2']#,'x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 512#4112
epochs = 1000# <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
learning_rate=0.01
use_scheduler =  False

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)
    #tram_model =get_fully_specified_tram_model_hardcoded_init_weights_for_si(node, conf_dict, verbose=True).to(device)


    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################.
    
    ## <---------- TODO use standard SGD and no scheduler
    # optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    # optimizer = torch.optim.AdamW(
    # tram_model.parameters(),
    # lr=1e-3,           # ← two orders of magnitude smaller
    # eps=1e-8,
    # weight_decay=1e-2
    # )   
    optimizer =torch.optim.Adam(tram_model.parameters(), lr=learning_rate)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
        #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer,max_lr=1e-3, total_steps=epochs * len(train_loader),pct_start=0.1, anneal_strategy="cos"       # pick your sweet-spot

    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR,
            save_linear_shifts=True
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 600...
# Epoch 601/1000 | Train Loss: -0.5740 | Val Loss: -0.5582
#   [Train: 0.46s | Val: 0.18s | Save: 0.00s | Total: 0.65s]
# Epoch 602/1000 | Train Loss: -0.5731 | Val Loss: -0.5583
#   [Train: 0.33s | Val: 0.19s | Save: 0.01s | Total: 0.53s]
# Epoch 603/1000 | Train Loss: -0.5739 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.63s]
# Epoch 604/1000 | Train Loss: -0.5741 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.20s | Save: 0.01s | Total: 0.60s]
# Epoch 605/1000 | Train Loss: -0.5733 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# Epoch 606/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.61s]
# Epoch 607/1000 | Train Loss: -0.5742 | Val Loss: -0.5582
#   [Train: 0.46s | Val: 0.21s | Save: 0.01s | Total: 0.68s]
# Epoch 608/1000 | Train Loss: -0.5733 | Val Loss: -0.5583
#   [Train: 0.37s | Val: 0.21s | Save: 0.00s | Total: 0.58s]
# Epoch 609/1000 | Train Loss: -0.5738 | Val Loss: -0.5583
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 610/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.19s | Save: 0.01s | Total: 0.59s]
# Epoch 611/1000 | Train Loss: -0.5732 | Val Loss: -0.5583
#   [Train: 0.49s | Val: 0.20s | Save: 0.00s | Total: 0.70s]
# Epoch 612/1000 | Train Loss: -0.5729 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.18s | Save: 0.01s | Total: 0.60s]
# Epoch 613/1000 | Train Loss: -0.5741 | Val Loss: -0.5583
#   [Train: 0.47s | Val: 0.18s | Save: 0.01s | Total: 0.66s]
# Epoch 614/1000 | Train Loss: -0.5736 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.61s]
# Epoch 615/1000 | Train Loss: -0.5745 | Val Loss: -0.5583
#   [Train: 0.43s | Val: 0.18s | Save: 0.01s | Total: 0.62s]
# Epoch 616/1000 | Train Loss: -0.5730 | Val Loss: -0.5584
#   [Train: 0.45s | Val: 0.18s | Save: 0.01s | Total: 0.64s]
# Epoch 617/1000 | Train Loss: -0.5748 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.18s | Save: 0.00s | Total: 0.57s]
# Epoch 618/1000 | Train Loss: -0.5744 | Val Loss: -0.5583
#   [Train: 0.47s | Val: 0.21s | Save: 0.00s | Total: 0.68s]
# Epoch 619/1000 | Train Loss: -0.5741 | Val Loss: -0.5584
#   [Train: 0.44s | Val: 0.23s | Save: 0.00s | Total: 0.67s]
# Epoch 620/1000 | Train Loss: -0.5744 | Val Loss: -0.5584
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# Epoch 621/1000 | Train Loss: -0.5721 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.22s | Save: 0.01s | Total: 0.67s]
# Epoch 622/1000 | Train Loss: -0.5753 | Val Loss: -0.5583
#   [Train: 0.48s | Val: 0.23s | Save: 0.00s | Total: 0.72s]
# Epoch 623/1000 | Train Loss: -0.5751 | Val Loss: -0.5584
#   [Train: 0.45s | Val: 0.23s | Save: 0.00s | Total: 0.68s]
# Epoch 624/1000 | Train Loss: -0.5735 | Val Loss: -0.5584
#   [Train: 0.41s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Epoch 625/1000 | Train Loss: -0.5747 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 626/1000 | Train Loss: -0.5749 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.20s | Save: 0.01s | Total: 0.61s]
# Epoch 627/1000 | Train Loss: -0.5715 | Val Loss: -0.5584
#   [Train: 0.47s | Val: 0.21s | Save: 0.01s | Total: 0.68s]
# Epoch 628/1000 | Train Loss: -0.5716 | Val Loss: -0.5582
#   [Train: 0.45s | Val: 0.24s | Save: 0.01s | Total: 0.69s]
# Saved new best model.
# Epoch 629/1000 | Train Loss: -0.5743 | Val Loss: -0.5585
#   [Train: 0.42s | Val: 0.19s | Save: 0.00s | Total: 0.62s]
# Epoch 630/1000 | Train Loss: -0.5721 | Val Loss: -0.5583
#   [Train: 0.33s | Val: 0.19s | Save: 0.00s | Total: 0.53s]
# Epoch 631/1000 | Train Loss: -0.5740 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 632/1000 | Train Loss: -0.5736 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Epoch 633/1000 | Train Loss: -0.5729 | Val Loss: -0.5584
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Epoch 634/1000 | Train Loss: -0.5736 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.21s | Save: 0.01s | Total: 0.66s]
# Epoch 635/1000 | Train Loss: -0.5740 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.18s | Save: 0.00s | Total: 0.59s]
# Saved new best model.
# Epoch 636/1000 | Train Loss: -0.5739 | Val Loss: -0.5585
#   [Train: 0.42s | Val: 0.22s | Save: 0.00s | Total: 0.63s]
# Epoch 637/1000 | Train Loss: -0.5745 | Val Loss: -0.5584
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 638/1000 | Train Loss: -0.5751 | Val Loss: -0.5584
#   [Train: 0.44s | Val: 0.21s | Save: 0.01s | Total: 0.66s]
# Epoch 639/1000 | Train Loss: -0.5733 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Epoch 640/1000 | Train Loss: -0.5733 | Val Loss: -0.5584
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.67s]
# Epoch 641/1000 | Train Loss: -0.5748 | Val Loss: -0.5584
#   [Train: 0.45s | Val: 0.22s | Save: 0.00s | Total: 0.68s]
# Epoch 642/1000 | Train Loss: -0.5749 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.21s | Save: 0.01s | Total: 0.61s]
# Epoch 643/1000 | Train Loss: -0.5746 | Val Loss: -0.5584
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# Epoch 644/1000 | Train Loss: -0.5742 | Val Loss: -0.5584
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# Epoch 645/1000 | Train Loss: -0.5746 | Val Loss: -0.5583
#   [Train: 0.47s | Val: 0.24s | Save: 0.00s | Total: 0.71s]
# Epoch 646/1000 | Train Loss: -0.5725 | Val Loss: -0.5582
#   [Train: 0.47s | Val: 0.18s | Save: 0.01s | Total: 0.66s]
# Epoch 647/1000 | Train Loss: -0.5732 | Val Loss: -0.5584
#   [Train: 0.35s | Val: 0.22s | Save: 0.01s | Total: 0.58s]
# Epoch 648/1000 | Train Loss: -0.5738 | Val Loss: -0.5584
#   [Train: 0.45s | Val: 0.21s | Save: 0.01s | Total: 0.67s]
# Epoch 649/1000 | Train Loss: -0.5742 | Val Loss: -0.5584
#   [Train: 0.35s | Val: 0.19s | Save: 0.01s | Total: 0.55s]
# Epoch 650/1000 | Train Loss: -0.5735 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Epoch 651/1000 | Train Loss: -0.5754 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.21s | Save: 0.00s | Total: 0.63s]
# Epoch 652/1000 | Train Loss: -0.5731 | Val Loss: -0.5584
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 653/1000 | Train Loss: -0.5742 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.20s | Save: 0.01s | Total: 0.63s]
# Epoch 654/1000 | Train Loss: -0.5753 | Val Loss: -0.5584
#   [Train: 0.42s | Val: 0.21s | Save: 0.00s | Total: 0.63s]
# Epoch 655/1000 | Train Loss: -0.5758 | Val Loss: -0.5583
#   [Train: 0.46s | Val: 0.22s | Save: 0.00s | Total: 0.69s]
# Epoch 656/1000 | Train Loss: -0.5736 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.19s | Save: 0.00s | Total: 0.65s]
# Epoch 657/1000 | Train Loss: -0.5751 | Val Loss: -0.5585
#   [Train: 0.41s | Val: 0.23s | Save: 0.00s | Total: 0.64s]
# Epoch 658/1000 | Train Loss: -0.5741 | Val Loss: -0.5584
#   [Train: 0.43s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 659/1000 | Train Loss: -0.5733 | Val Loss: -0.5584
#   [Train: 0.44s | Val: 0.22s | Save: 0.01s | Total: 0.66s]
# Epoch 660/1000 | Train Loss: -0.5734 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.22s | Save: 0.00s | Total: 0.67s]
# Epoch 661/1000 | Train Loss: -0.5735 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.60s]
# Epoch 662/1000 | Train Loss: -0.5736 | Val Loss: -0.5582
#   [Train: 0.46s | Val: 0.20s | Save: 0.01s | Total: 0.67s]
# Epoch 663/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.19s | Save: 0.01s | Total: 0.64s]
# Epoch 664/1000 | Train Loss: -0.5723 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.19s | Save: 0.00s | Total: 0.60s]
# Epoch 665/1000 | Train Loss: -0.5741 | Val Loss: -0.5584
#   [Train: 0.50s | Val: 0.24s | Save: 0.01s | Total: 0.75s]
# Epoch 666/1000 | Train Loss: -0.5741 | Val Loss: -0.5584
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.68s]
# Epoch 667/1000 | Train Loss: -0.5734 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.22s | Save: 0.01s | Total: 0.67s]
# Epoch 668/1000 | Train Loss: -0.5759 | Val Loss: -0.5584
#   [Train: 0.42s | Val: 0.22s | Save: 0.00s | Total: 0.64s]
# Epoch 669/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.49s | Val: 0.23s | Save: 0.01s | Total: 0.72s]
# Epoch 670/1000 | Train Loss: -0.5723 | Val Loss: -0.5582
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 671/1000 | Train Loss: -0.5742 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.18s | Save: 0.00s | Total: 0.59s]
# Epoch 672/1000 | Train Loss: -0.5746 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.18s | Save: 0.00s | Total: 0.61s]
# Epoch 673/1000 | Train Loss: -0.5738 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.18s | Save: 0.01s | Total: 0.63s]
# Epoch 674/1000 | Train Loss: -0.5742 | Val Loss: -0.5584
#   [Train: 0.42s | Val: 0.22s | Save: 0.01s | Total: 0.65s]
# Epoch 675/1000 | Train Loss: -0.5735 | Val Loss: -0.5582
#   [Train: 0.49s | Val: 0.17s | Save: 0.01s | Total: 0.66s]
# Epoch 676/1000 | Train Loss: -0.5723 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.18s | Save: 0.00s | Total: 0.59s]
# Epoch 677/1000 | Train Loss: -0.5738 | Val Loss: -0.5585
#   [Train: 0.33s | Val: 0.18s | Save: 0.00s | Total: 0.52s]
# Epoch 678/1000 | Train Loss: -0.5732 | Val Loss: -0.5584
#   [Train: 0.33s | Val: 0.19s | Save: 0.00s | Total: 0.52s]
# Epoch 679/1000 | Train Loss: -0.5752 | Val Loss: -0.5584
#   [Train: 0.40s | Val: 0.19s | Save: 0.01s | Total: 0.59s]
# Epoch 680/1000 | Train Loss: -0.5750 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.19s | Save: 0.01s | Total: 0.61s]
# Epoch 681/1000 | Train Loss: -0.5729 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Epoch 682/1000 | Train Loss: -0.5751 | Val Loss: -0.5584
#   [Train: 0.40s | Val: 0.23s | Save: 0.01s | Total: 0.63s]
# Epoch 683/1000 | Train Loss: -0.5731 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.67s]
# Epoch 684/1000 | Train Loss: -0.5745 | Val Loss: -0.5584
#   [Train: 0.44s | Val: 0.22s | Save: 0.00s | Total: 0.66s]
# Epoch 685/1000 | Train Loss: -0.5735 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.19s | Save: 0.01s | Total: 0.61s]
# Epoch 686/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.21s | Save: 0.01s | Total: 0.67s]
# Epoch 687/1000 | Train Loss: -0.5731 | Val Loss: -0.5582
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# Epoch 688/1000 | Train Loss: -0.5736 | Val Loss: -0.5584
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 689/1000 | Train Loss: -0.5754 | Val Loss: -0.5585
#   [Train: 0.45s | Val: 0.19s | Save: 0.01s | Total: 0.65s]
# Epoch 690/1000 | Train Loss: -0.5746 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.22s | Save: 0.01s | Total: 0.64s]
# Epoch 691/1000 | Train Loss: -0.5737 | Val Loss: -0.5584
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.63s]
# Epoch 692/1000 | Train Loss: -0.5741 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 693/1000 | Train Loss: -0.5760 | Val Loss: -0.5584
#   [Train: 0.45s | Val: 0.21s | Save: 0.01s | Total: 0.67s]
# Epoch 694/1000 | Train Loss: -0.5747 | Val Loss: -0.5583
#   [Train: 0.46s | Val: 0.20s | Save: 0.01s | Total: 0.66s]
# Epoch 695/1000 | Train Loss: -0.5747 | Val Loss: -0.5584
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.66s]
# Epoch 696/1000 | Train Loss: -0.5724 | Val Loss: -0.5584
#   [Train: 0.39s | Val: 0.22s | Save: 0.00s | Total: 0.62s]
# Epoch 697/1000 | Train Loss: -0.5750 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.20s | Save: 0.01s | Total: 0.62s]
# Epoch 698/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.47s | Val: 0.22s | Save: 0.01s | Total: 0.70s]
# Epoch 699/1000 | Train Loss: -0.5745 | Val Loss: -0.5583
#   [Train: 0.38s | Val: 0.21s | Save: 0.00s | Total: 0.59s]
# Epoch 700/1000 | Train Loss: -0.5728 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 701/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 702/1000 | Train Loss: -0.5734 | Val Loss: -0.5583
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.69s]
# Epoch 703/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Epoch 704/1000 | Train Loss: -0.5740 | Val Loss: -0.5584
#   [Train: 0.40s | Val: 0.20s | Save: 0.00s | Total: 0.60s]
# Epoch 705/1000 | Train Loss: -0.5747 | Val Loss: -0.5585
#   [Train: 0.45s | Val: 0.23s | Save: 0.00s | Total: 0.68s]
# Epoch 706/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.37s | Val: 0.20s | Save: 0.00s | Total: 0.57s]
# Epoch 707/1000 | Train Loss: -0.5732 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.23s | Save: 0.01s | Total: 0.64s]
# Epoch 708/1000 | Train Loss: -0.5752 | Val Loss: -0.5583
#   [Train: 0.43s | Val: 0.22s | Save: 0.00s | Total: 0.65s]
# Epoch 709/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 710/1000 | Train Loss: -0.5751 | Val Loss: -0.5584
#   [Train: 0.40s | Val: 0.20s | Save: 0.01s | Total: 0.61s]
# Epoch 711/1000 | Train Loss: -0.5731 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 712/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.21s | Save: 0.01s | Total: 0.67s]
# Epoch 713/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.21s | Save: 0.01s | Total: 0.67s]
# Epoch 714/1000 | Train Loss: -0.5738 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 715/1000 | Train Loss: -0.5739 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 716/1000 | Train Loss: -0.5738 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.19s | Save: 0.01s | Total: 0.64s]
# Epoch 717/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.21s | Save: 0.01s | Total: 0.66s]
# Epoch 718/1000 | Train Loss: -0.5733 | Val Loss: -0.5583
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.69s]
# Epoch 719/1000 | Train Loss: -0.5747 | Val Loss: -0.5582
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.70s]
# Epoch 720/1000 | Train Loss: -0.5733 | Val Loss: -0.5584
#   [Train: 0.35s | Val: 0.20s | Save: 0.01s | Total: 0.56s]
# Epoch 721/1000 | Train Loss: -0.5728 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.22s | Save: 0.00s | Total: 0.66s]
# Epoch 722/1000 | Train Loss: -0.5743 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.20s | Save: 0.01s | Total: 0.63s]
# Epoch 723/1000 | Train Loss: -0.5727 | Val Loss: -0.5584
#   [Train: 0.37s | Val: 0.20s | Save: 0.00s | Total: 0.57s]
# Epoch 724/1000 | Train Loss: -0.5746 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.19s | Save: 0.01s | Total: 0.60s]
# Epoch 725/1000 | Train Loss: -0.5733 | Val Loss: -0.5584
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 726/1000 | Train Loss: -0.5727 | Val Loss: -0.5582
#   [Train: 0.42s | Val: 0.20s | Save: 0.01s | Total: 0.62s]
# Epoch 727/1000 | Train Loss: -0.5725 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.19s | Save: 0.00s | Total: 0.64s]
# Epoch 728/1000 | Train Loss: -0.5759 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.21s | Save: 0.00s | Total: 0.60s]
# Epoch 729/1000 | Train Loss: -0.5726 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.21s | Save: 0.00s | Total: 0.63s]
# Epoch 730/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.22s | Save: 0.01s | Total: 0.65s]
# Epoch 731/1000 | Train Loss: -0.5736 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 732/1000 | Train Loss: -0.5731 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.19s | Save: 0.00s | Total: 0.59s]
# Epoch 733/1000 | Train Loss: -0.5749 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.19s | Save: 0.01s | Total: 0.64s]
# Epoch 734/1000 | Train Loss: -0.5748 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Epoch 735/1000 | Train Loss: -0.5733 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.23s | Save: 0.00s | Total: 0.66s]
# Epoch 736/1000 | Train Loss: -0.5748 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.21s | Save: 0.01s | Total: 0.63s]
# Epoch 737/1000 | Train Loss: -0.5727 | Val Loss: -0.5582
#   [Train: 0.42s | Val: 0.22s | Save: 0.00s | Total: 0.65s]
# Epoch 738/1000 | Train Loss: -0.5749 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.23s | Save: 0.01s | Total: 0.65s]
# Epoch 739/1000 | Train Loss: -0.5735 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.23s | Save: 0.01s | Total: 0.66s]
# Epoch 740/1000 | Train Loss: -0.5747 | Val Loss: -0.5583
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.70s]
# Epoch 741/1000 | Train Loss: -0.5748 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.21s | Save: 0.00s | Total: 0.63s]
# Epoch 742/1000 | Train Loss: -0.5733 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.22s | Save: 0.01s | Total: 0.66s]
# Epoch 743/1000 | Train Loss: -0.5735 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.24s | Save: 0.00s | Total: 0.68s]
# Epoch 744/1000 | Train Loss: -0.5742 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.22s | Save: 0.00s | Total: 0.63s]
# Epoch 745/1000 | Train Loss: -0.5747 | Val Loss: -0.5583
#   [Train: 0.46s | Val: 0.22s | Save: 0.01s | Total: 0.69s]
# Epoch 746/1000 | Train Loss: -0.5745 | Val Loss: -0.5584
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.63s]
# Epoch 747/1000 | Train Loss: -0.5719 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.25s | Save: 0.00s | Total: 0.69s]
# Epoch 748/1000 | Train Loss: -0.5752 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.21s | Save: 0.00s | Total: 0.63s]
# Epoch 749/1000 | Train Loss: -0.5756 | Val Loss: -0.5583
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 750/1000 | Train Loss: -0.5746 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.63s]
# Epoch 751/1000 | Train Loss: -0.5739 | Val Loss: -0.5582
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# Epoch 752/1000 | Train Loss: -0.5748 | Val Loss: -0.5582
#   [Train: 0.38s | Val: 0.17s | Save: 0.01s | Total: 0.56s]
# Epoch 753/1000 | Train Loss: -0.5745 | Val Loss: -0.5582
#   [Train: 0.38s | Val: 0.18s | Save: 0.00s | Total: 0.57s]
# Epoch 754/1000 | Train Loss: -0.5753 | Val Loss: -0.5584
#   [Train: 0.39s | Val: 0.20s | Save: 0.01s | Total: 0.60s]
# Epoch 755/1000 | Train Loss: -0.5750 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.19s | Save: 0.01s | Total: 0.64s]
# Epoch 756/1000 | Train Loss: -0.5739 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 757/1000 | Train Loss: -0.5747 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.21s | Save: 0.00s | Total: 0.61s]
# Epoch 758/1000 | Train Loss: -0.5734 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.20s | Save: 0.01s | Total: 0.62s]
# Epoch 759/1000 | Train Loss: -0.5754 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.20s | Save: 0.01s | Total: 0.65s]
# Epoch 760/1000 | Train Loss: -0.5753 | Val Loss: -0.5582
#   [Train: 0.49s | Val: 0.21s | Save: 0.01s | Total: 0.71s]
# Epoch 761/1000 | Train Loss: -0.5746 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# Epoch 762/1000 | Train Loss: -0.5737 | Val Loss: -0.5583
#   [Train: 0.44s | Val: 0.21s | Save: 0.01s | Total: 0.65s]
# Epoch 763/1000 | Train Loss: -0.5754 | Val Loss: -0.5582
#   [Train: 0.48s | Val: 0.21s | Save: 0.01s | Total: 0.69s]
# Epoch 764/1000 | Train Loss: -0.5750 | Val Loss: -0.5583
#   [Train: 0.43s | Val: 0.19s | Save: 0.01s | Total: 0.63s]
# Epoch 765/1000 | Train Loss: -0.5740 | Val Loss: -0.5583
#   [Train: 0.40s | Val: 0.18s | Save: 0.00s | Total: 0.59s]
# Epoch 766/1000 | Train Loss: -0.5743 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.64s]
# Epoch 767/1000 | Train Loss: -0.5732 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.18s | Save: 0.00s | Total: 0.62s]
# Epoch 768/1000 | Train Loss: -0.5759 | Val Loss: -0.5583
#   [Train: 0.45s | Val: 0.18s | Save: 0.00s | Total: 0.63s]
# Epoch 769/1000 | Train Loss: -0.5749 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 770/1000 | Train Loss: -0.5735 | Val Loss: -0.5582
#   [Train: 0.38s | Val: 0.19s | Save: 0.01s | Total: 0.57s]
# Epoch 771/1000 | Train Loss: -0.5719 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.18s | Save: 0.01s | Total: 0.62s]
# Epoch 772/1000 | Train Loss: -0.5733 | Val Loss: -0.5583
#   [Train: 0.41s | Val: 0.20s | Save: 0.01s | Total: 0.62s]
# Epoch 773/1000 | Train Loss: -0.5742 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.64s]
# Epoch 774/1000 | Train Loss: -0.5763 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.17s | Save: 0.01s | Total: 0.59s]
# Epoch 775/1000 | Train Loss: -0.5741 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.18s | Save: 0.00s | Total: 0.59s]
# Epoch 776/1000 | Train Loss: -0.5746 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.19s | Save: 0.01s | Total: 0.64s]
# Epoch 777/1000 | Train Loss: -0.5742 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.19s | Save: 0.01s | Total: 0.61s]
# Epoch 778/1000 | Train Loss: -0.5734 | Val Loss: -0.5582
#   [Train: 0.42s | Val: 0.19s | Save: 0.01s | Total: 0.61s]
# Epoch 779/1000 | Train Loss: -0.5752 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 780/1000 | Train Loss: -0.5739 | Val Loss: -0.5581
#   [Train: 0.37s | Val: 0.20s | Save: 0.01s | Total: 0.58s]
# Epoch 781/1000 | Train Loss: -0.5750 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 782/1000 | Train Loss: -0.5752 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 783/1000 | Train Loss: -0.5752 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.63s]
# Epoch 784/1000 | Train Loss: -0.5738 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.20s | Save: 0.01s | Total: 0.65s]
# Epoch 785/1000 | Train Loss: -0.5756 | Val Loss: -0.5583
#   [Train: 0.39s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# Epoch 786/1000 | Train Loss: -0.5752 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Epoch 787/1000 | Train Loss: -0.5726 | Val Loss: -0.5581
#   [Train: 0.38s | Val: 0.20s | Save: 0.01s | Total: 0.59s]
# Epoch 788/1000 | Train Loss: -0.5743 | Val Loss: -0.5582
#   [Train: 0.40s | Val: 0.19s | Save: 0.01s | Total: 0.59s]
# Epoch 789/1000 | Train Loss: -0.5755 | Val Loss: -0.5582
#   [Train: 0.46s | Val: 0.22s | Save: 0.00s | Total: 0.68s]
# Epoch 790/1000 | Train Loss: -0.5735 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.23s | Save: 0.01s | Total: 0.67s]
# Epoch 791/1000 | Train Loss: -0.5738 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.65s]
# Epoch 792/1000 | Train Loss: -0.5735 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.22s | Save: 0.00s | Total: 0.64s]
# Epoch 793/1000 | Train Loss: -0.5748 | Val Loss: -0.5583
#   [Train: 0.43s | Val: 0.21s | Save: 0.00s | Total: 0.64s]
# Epoch 794/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.38s | Val: 0.19s | Save: 0.00s | Total: 0.57s]
# Epoch 795/1000 | Train Loss: -0.5748 | Val Loss: -0.5581
#   [Train: 0.31s | Val: 0.18s | Save: 0.00s | Total: 0.50s]
# Epoch 796/1000 | Train Loss: -0.5751 | Val Loss: -0.5581
#   [Train: 0.45s | Val: 0.19s | Save: 0.01s | Total: 0.64s]
# Epoch 797/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.45s | Val: 0.19s | Save: 0.01s | Total: 0.65s]
# Epoch 798/1000 | Train Loss: -0.5737 | Val Loss: -0.5582
#   [Train: 0.38s | Val: 0.21s | Save: 0.00s | Total: 0.60s]
# Epoch 799/1000 | Train Loss: -0.5750 | Val Loss: -0.5583
#   [Train: 0.42s | Val: 0.24s | Save: 0.00s | Total: 0.66s]
# Epoch 800/1000 | Train Loss: -0.5728 | Val Loss: -0.5582
#   [Train: 0.42s | Val: 0.20s | Save: 0.01s | Total: 0.62s]
# Epoch 801/1000 | Train Loss: -0.5739 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.18s | Save: 0.00s | Total: 0.63s]
# Epoch 802/1000 | Train Loss: -0.5743 | Val Loss: -0.5581
#   [Train: 0.32s | Val: 0.19s | Save: 0.01s | Total: 0.51s]
# Epoch 803/1000 | Train Loss: -0.5731 | Val Loss: -0.5582
#   [Train: 0.46s | Val: 0.20s | Save: 0.01s | Total: 0.67s]
# Epoch 804/1000 | Train Loss: -0.5739 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.20s | Save: 0.01s | Total: 0.65s]
# Epoch 805/1000 | Train Loss: -0.5750 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.18s | Save: 0.01s | Total: 0.66s]
# Epoch 806/1000 | Train Loss: -0.5730 | Val Loss: -0.5583
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.66s]
# Epoch 807/1000 | Train Loss: -0.5763 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.21s | Save: 0.01s | Total: 0.66s]
# Epoch 808/1000 | Train Loss: -0.5735 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.23s | Save: 0.00s | Total: 0.67s]
# Epoch 809/1000 | Train Loss: -0.5753 | Val Loss: -0.5582
#   [Train: 0.48s | Val: 0.19s | Save: 0.00s | Total: 0.67s]
# Epoch 810/1000 | Train Loss: -0.5745 | Val Loss: -0.5581
#   [Train: 0.34s | Val: 0.19s | Save: 0.01s | Total: 0.53s]
# Epoch 811/1000 | Train Loss: -0.5741 | Val Loss: -0.5581
#   [Train: 0.43s | Val: 0.18s | Save: 0.00s | Total: 0.62s]
# Epoch 812/1000 | Train Loss: -0.5755 | Val Loss: -0.5582
#   [Train: 0.40s | Val: 0.18s | Save: 0.01s | Total: 0.59s]
# Epoch 813/1000 | Train Loss: -0.5733 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.20s | Save: 0.01s | Total: 0.67s]
# Epoch 814/1000 | Train Loss: -0.5742 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.18s | Save: 0.01s | Total: 0.59s]
# Epoch 815/1000 | Train Loss: -0.5752 | Val Loss: -0.5582
#   [Train: 0.40s | Val: 0.20s | Save: 0.00s | Total: 0.60s]
# Epoch 816/1000 | Train Loss: -0.5746 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.19s | Save: 0.01s | Total: 0.62s]
# Epoch 817/1000 | Train Loss: -0.5757 | Val Loss: -0.5582
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# Epoch 818/1000 | Train Loss: -0.5729 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 819/1000 | Train Loss: -0.5726 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# Epoch 820/1000 | Train Loss: -0.5756 | Val Loss: -0.5582
#   [Train: 0.37s | Val: 0.21s | Save: 0.00s | Total: 0.59s]
# Epoch 821/1000 | Train Loss: -0.5755 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.19s | Save: 0.01s | Total: 0.61s]
# Epoch 822/1000 | Train Loss: -0.5733 | Val Loss: -0.5581
#   [Train: 0.45s | Val: 0.20s | Save: 0.01s | Total: 0.65s]
# Epoch 823/1000 | Train Loss: -0.5731 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Epoch 824/1000 | Train Loss: -0.5758 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Epoch 825/1000 | Train Loss: -0.5721 | Val Loss: -0.5582
#   [Train: 0.42s | Val: 0.22s | Save: 0.01s | Total: 0.65s]
# Epoch 826/1000 | Train Loss: -0.5744 | Val Loss: -0.5582
#   [Train: 0.44s | Val: 0.22s | Save: 0.00s | Total: 0.66s]
# Epoch 827/1000 | Train Loss: -0.5744 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.21s | Save: 0.01s | Total: 0.66s]
# Epoch 828/1000 | Train Loss: -0.5731 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.24s | Save: 0.00s | Total: 0.72s]
# Epoch 829/1000 | Train Loss: -0.5745 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.63s]
# Epoch 830/1000 | Train Loss: -0.5734 | Val Loss: -0.5582
#   [Train: 0.45s | Val: 0.22s | Save: 0.01s | Total: 0.68s]
# Epoch 831/1000 | Train Loss: -0.5737 | Val Loss: -0.5582
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.62s]
# Epoch 832/1000 | Train Loss: -0.5758 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.21s | Save: 0.01s | Total: 0.69s]
# Epoch 833/1000 | Train Loss: -0.5729 | Val Loss: -0.5582
#   [Train: 0.45s | Val: 0.19s | Save: 0.01s | Total: 0.65s]
# Epoch 834/1000 | Train Loss: -0.5732 | Val Loss: -0.5582
#   [Train: 0.46s | Val: 0.22s | Save: 0.00s | Total: 0.68s]
# Epoch 835/1000 | Train Loss: -0.5744 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.22s | Save: 0.01s | Total: 0.69s]
# Epoch 836/1000 | Train Loss: -0.5745 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.21s | Save: 0.01s | Total: 0.65s]
# Epoch 837/1000 | Train Loss: -0.5733 | Val Loss: -0.5581
#   [Train: 0.43s | Val: 0.22s | Save: 0.01s | Total: 0.66s]
# Epoch 838/1000 | Train Loss: -0.5749 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.21s | Save: 0.01s | Total: 0.69s]
# Epoch 839/1000 | Train Loss: -0.5742 | Val Loss: -0.5581
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.58s]
# Epoch 840/1000 | Train Loss: -0.5750 | Val Loss: -0.5581
#   [Train: 0.40s | Val: 0.21s | Save: 0.01s | Total: 0.61s]
# Epoch 841/1000 | Train Loss: -0.5729 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.62s]
# Epoch 842/1000 | Train Loss: -0.5747 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 843/1000 | Train Loss: -0.5742 | Val Loss: -0.5581
#   [Train: 0.43s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 844/1000 | Train Loss: -0.5742 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 845/1000 | Train Loss: -0.5737 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.19s | Save: 0.01s | Total: 0.66s]
# Epoch 846/1000 | Train Loss: -0.5733 | Val Loss: -0.5580
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.61s]
# Epoch 847/1000 | Train Loss: -0.5751 | Val Loss: -0.5582
#   [Train: 0.40s | Val: 0.17s | Save: 0.01s | Total: 0.59s]
# Epoch 848/1000 | Train Loss: -0.5725 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.19s | Save: 0.01s | Total: 0.63s]
# Epoch 849/1000 | Train Loss: -0.5744 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 850/1000 | Train Loss: -0.5736 | Val Loss: -0.5581
#   [Train: 0.34s | Val: 0.18s | Save: 0.01s | Total: 0.53s]
# Epoch 851/1000 | Train Loss: -0.5736 | Val Loss: -0.5581
#   [Train: 0.35s | Val: 0.19s | Save: 0.00s | Total: 0.55s]
# Epoch 852/1000 | Train Loss: -0.5735 | Val Loss: -0.5581
#   [Train: 0.40s | Val: 0.19s | Save: 0.01s | Total: 0.60s]
# Epoch 853/1000 | Train Loss: -0.5751 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 854/1000 | Train Loss: -0.5743 | Val Loss: -0.5582
#   [Train: 0.43s | Val: 0.22s | Save: 0.00s | Total: 0.65s]
# Epoch 855/1000 | Train Loss: -0.5750 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.19s | Save: 0.00s | Total: 0.65s]
# Epoch 856/1000 | Train Loss: -0.5751 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# Epoch 857/1000 | Train Loss: -0.5763 | Val Loss: -0.5581
#   [Train: 0.45s | Val: 0.19s | Save: 0.00s | Total: 0.64s]
# Epoch 858/1000 | Train Loss: -0.5733 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.23s | Save: 0.00s | Total: 0.66s]
# Epoch 859/1000 | Train Loss: -0.5717 | Val Loss: -0.5581
#   [Train: 0.40s | Val: 0.20s | Save: 0.01s | Total: 0.60s]
# Epoch 860/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.39s | Val: 0.22s | Save: 0.01s | Total: 0.61s]
# Epoch 861/1000 | Train Loss: -0.5740 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.19s | Save: 0.01s | Total: 0.62s]
# Epoch 862/1000 | Train Loss: -0.5763 | Val Loss: -0.5581
#   [Train: 0.45s | Val: 0.24s | Save: 0.00s | Total: 0.69s]
# Epoch 863/1000 | Train Loss: -0.5746 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.20s | Save: 0.01s | Total: 0.65s]
# Epoch 864/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.64s]
# Epoch 865/1000 | Train Loss: -0.5748 | Val Loss: -0.5580
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Epoch 866/1000 | Train Loss: -0.5727 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.22s | Save: 0.00s | Total: 0.63s]
# Epoch 867/1000 | Train Loss: -0.5738 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.66s]
# Epoch 868/1000 | Train Loss: -0.5746 | Val Loss: -0.5582
#   [Train: 0.50s | Val: 0.23s | Save: 0.00s | Total: 0.73s]
# Epoch 869/1000 | Train Loss: -0.5732 | Val Loss: -0.5580
#   [Train: 0.46s | Val: 0.20s | Save: 0.01s | Total: 0.67s]
# Epoch 870/1000 | Train Loss: -0.5760 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.22s | Save: 0.01s | Total: 0.69s]
# Epoch 871/1000 | Train Loss: -0.5749 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.20s | Save: 0.01s | Total: 0.63s]
# Epoch 872/1000 | Train Loss: -0.5736 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.21s | Save: 0.00s | Total: 0.68s]
# Epoch 873/1000 | Train Loss: -0.5750 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.22s | Save: 0.01s | Total: 0.67s]
# Epoch 874/1000 | Train Loss: -0.5731 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 875/1000 | Train Loss: -0.5751 | Val Loss: -0.5581
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.59s]
# Epoch 876/1000 | Train Loss: -0.5749 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.19s | Save: 0.00s | Total: 0.65s]
# Epoch 877/1000 | Train Loss: -0.5724 | Val Loss: -0.5581
#   [Train: 0.39s | Val: 0.18s | Save: 0.00s | Total: 0.58s]
# Epoch 878/1000 | Train Loss: -0.5761 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.21s | Save: 0.01s | Total: 0.66s]
# Epoch 879/1000 | Train Loss: -0.5751 | Val Loss: -0.5581
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# Epoch 880/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 881/1000 | Train Loss: -0.5726 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 882/1000 | Train Loss: -0.5741 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 883/1000 | Train Loss: -0.5729 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Epoch 884/1000 | Train Loss: -0.5762 | Val Loss: -0.5581
#   [Train: 0.43s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 885/1000 | Train Loss: -0.5739 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.23s | Save: 0.01s | Total: 0.68s]
# Epoch 886/1000 | Train Loss: -0.5749 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.23s | Save: 0.00s | Total: 0.69s]
# Epoch 887/1000 | Train Loss: -0.5737 | Val Loss: -0.5581
#   [Train: 0.40s | Val: 0.21s | Save: 0.01s | Total: 0.62s]
# Epoch 888/1000 | Train Loss: -0.5739 | Val Loss: -0.5581
#   [Train: 0.45s | Val: 0.20s | Save: 0.01s | Total: 0.66s]
# Epoch 889/1000 | Train Loss: -0.5748 | Val Loss: -0.5581
#   [Train: 0.38s | Val: 0.18s | Save: 0.00s | Total: 0.56s]
# Epoch 890/1000 | Train Loss: -0.5748 | Val Loss: -0.5580
#   [Train: 0.41s | Val: 0.17s | Save: 0.01s | Total: 0.58s]
# Epoch 891/1000 | Train Loss: -0.5752 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Epoch 892/1000 | Train Loss: -0.5760 | Val Loss: -0.5580
#   [Train: 0.36s | Val: 0.19s | Save: 0.01s | Total: 0.55s]
# Epoch 893/1000 | Train Loss: -0.5757 | Val Loss: -0.5581
#   [Train: 0.40s | Val: 0.27s | Save: 0.00s | Total: 0.67s]
# Epoch 894/1000 | Train Loss: -0.5755 | Val Loss: -0.5581
#   [Train: 0.44s | Val: 0.18s | Save: 0.00s | Total: 0.62s]
# Epoch 895/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.22s | Save: 0.00s | Total: 0.64s]
# Epoch 896/1000 | Train Loss: -0.5746 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.20s | Save: 0.01s | Total: 0.65s]
# Epoch 897/1000 | Train Loss: -0.5734 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 898/1000 | Train Loss: -0.5762 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# Epoch 899/1000 | Train Loss: -0.5738 | Val Loss: -0.5581
#   [Train: 0.46s | Val: 0.21s | Save: 0.01s | Total: 0.67s]
# Epoch 900/1000 | Train Loss: -0.5761 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.23s | Save: 0.01s | Total: 0.67s]
# Epoch 901/1000 | Train Loss: -0.5770 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.23s | Save: 0.01s | Total: 0.65s]
# Epoch 902/1000 | Train Loss: -0.5728 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 903/1000 | Train Loss: -0.5754 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# Epoch 904/1000 | Train Loss: -0.5737 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.62s]
# Epoch 905/1000 | Train Loss: -0.5736 | Val Loss: -0.5581
#   [Train: 0.37s | Val: 0.18s | Save: 0.00s | Total: 0.55s]
# Epoch 906/1000 | Train Loss: -0.5754 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.22s | Save: 0.01s | Total: 0.67s]
# Epoch 907/1000 | Train Loss: -0.5734 | Val Loss: -0.5580
#   [Train: 0.47s | Val: 0.21s | Save: 0.00s | Total: 0.68s]
# Epoch 908/1000 | Train Loss: -0.5720 | Val Loss: -0.5581
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# Epoch 909/1000 | Train Loss: -0.5744 | Val Loss: -0.5580
#   [Train: 0.38s | Val: 0.22s | Save: 0.00s | Total: 0.61s]
# Epoch 910/1000 | Train Loss: -0.5766 | Val Loss: -0.5580
#   [Train: 0.38s | Val: 0.20s | Save: 0.00s | Total: 0.58s]
# Epoch 911/1000 | Train Loss: -0.5757 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.21s | Save: 0.01s | Total: 0.63s]
# Epoch 912/1000 | Train Loss: -0.5750 | Val Loss: -0.5581
#   [Train: 0.36s | Val: 0.20s | Save: 0.01s | Total: 0.57s]
# Epoch 913/1000 | Train Loss: -0.5751 | Val Loss: -0.5580
#   [Train: 0.38s | Val: 0.19s | Save: 0.01s | Total: 0.57s]
# Epoch 914/1000 | Train Loss: -0.5757 | Val Loss: -0.5581
#   [Train: 0.39s | Val: 0.17s | Save: 0.00s | Total: 0.57s]
# Epoch 915/1000 | Train Loss: -0.5744 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.22s | Save: 0.00s | Total: 0.65s]
# Epoch 916/1000 | Train Loss: -0.5734 | Val Loss: -0.5580
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.67s]
# Epoch 917/1000 | Train Loss: -0.5732 | Val Loss: -0.5580
#   [Train: 0.36s | Val: 0.21s | Save: 0.00s | Total: 0.57s]
# Epoch 918/1000 | Train Loss: -0.5751 | Val Loss: -0.5581
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 919/1000 | Train Loss: -0.5745 | Val Loss: -0.5580
#   [Train: 0.40s | Val: 0.22s | Save: 0.01s | Total: 0.63s]
# Epoch 920/1000 | Train Loss: -0.5759 | Val Loss: -0.5580
#   [Train: 0.40s | Val: 0.22s | Save: 0.01s | Total: 0.63s]
# Epoch 921/1000 | Train Loss: -0.5745 | Val Loss: -0.5579
#   [Train: 0.38s | Val: 0.24s | Save: 0.01s | Total: 0.62s]
# Epoch 922/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.24s | Save: 0.01s | Total: 0.67s]
# Epoch 923/1000 | Train Loss: -0.5750 | Val Loss: -0.5581
#   [Train: 0.34s | Val: 0.20s | Save: 0.01s | Total: 0.55s]
# Epoch 924/1000 | Train Loss: -0.5742 | Val Loss: -0.5580
#   [Train: 0.40s | Val: 0.21s | Save: 0.01s | Total: 0.61s]
# Epoch 925/1000 | Train Loss: -0.5737 | Val Loss: -0.5579
#   [Train: 0.45s | Val: 0.23s | Save: 0.00s | Total: 0.68s]
# Epoch 926/1000 | Train Loss: -0.5735 | Val Loss: -0.5580
#   [Train: 0.36s | Val: 0.18s | Save: 0.01s | Total: 0.54s]
# Epoch 927/1000 | Train Loss: -0.5740 | Val Loss: -0.5580
#   [Train: 0.36s | Val: 0.19s | Save: 0.01s | Total: 0.55s]
# Epoch 928/1000 | Train Loss: -0.5751 | Val Loss: -0.5580
#   [Train: 0.46s | Val: 0.21s | Save: 0.01s | Total: 0.67s]
# Epoch 929/1000 | Train Loss: -0.5738 | Val Loss: -0.5579
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.59s]
# Epoch 930/1000 | Train Loss: -0.5737 | Val Loss: -0.5581
#   [Train: 0.35s | Val: 0.18s | Save: 0.01s | Total: 0.53s]
# Epoch 931/1000 | Train Loss: -0.5769 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# Epoch 932/1000 | Train Loss: -0.5755 | Val Loss: -0.5579
#   [Train: 0.33s | Val: 0.18s | Save: 0.01s | Total: 0.52s]
# Epoch 933/1000 | Train Loss: -0.5749 | Val Loss: -0.5580
#   [Train: 0.45s | Val: 0.19s | Save: 0.01s | Total: 0.65s]
# Epoch 934/1000 | Train Loss: -0.5738 | Val Loss: -0.5581
#   [Train: 0.42s | Val: 0.20s | Save: 0.01s | Total: 0.63s]
# Epoch 935/1000 | Train Loss: -0.5717 | Val Loss: -0.5580
#   [Train: 0.45s | Val: 0.19s | Save: 0.01s | Total: 0.64s]
# Epoch 936/1000 | Train Loss: -0.5753 | Val Loss: -0.5580
#   [Train: 0.41s | Val: 0.22s | Save: 0.00s | Total: 0.63s]
# Epoch 937/1000 | Train Loss: -0.5742 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.21s | Save: 0.00s | Total: 0.63s]
# Epoch 938/1000 | Train Loss: -0.5760 | Val Loss: -0.5580
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.59s]
# Epoch 939/1000 | Train Loss: -0.5755 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# Epoch 940/1000 | Train Loss: -0.5753 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# Epoch 941/1000 | Train Loss: -0.5753 | Val Loss: -0.5580
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 942/1000 | Train Loss: -0.5734 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.21s | Save: 0.01s | Total: 0.65s]
# Epoch 943/1000 | Train Loss: -0.5761 | Val Loss: -0.5580
#   [Train: 0.41s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Epoch 944/1000 | Train Loss: -0.5732 | Val Loss: -0.5580
#   [Train: 0.38s | Val: 0.20s | Save: 0.00s | Total: 0.59s]
# Epoch 945/1000 | Train Loss: -0.5740 | Val Loss: -0.5579
#   [Train: 0.39s | Val: 0.23s | Save: 0.01s | Total: 0.63s]
# Epoch 946/1000 | Train Loss: -0.5747 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.21s | Save: 0.00s | Total: 0.62s]
# Epoch 947/1000 | Train Loss: -0.5755 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.22s | Save: 0.01s | Total: 0.64s]
# Epoch 948/1000 | Train Loss: -0.5716 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.62s]
# Epoch 949/1000 | Train Loss: -0.5741 | Val Loss: -0.5580
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.59s]
# Epoch 950/1000 | Train Loss: -0.5753 | Val Loss: -0.5580
#   [Train: 0.41s | Val: 0.19s | Save: 0.00s | Total: 0.60s]
# Epoch 951/1000 | Train Loss: -0.5745 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.19s | Save: 0.01s | Total: 0.61s]
# Epoch 952/1000 | Train Loss: -0.5754 | Val Loss: -0.5579
#   [Train: 0.47s | Val: 0.21s | Save: 0.01s | Total: 0.69s]
# Epoch 953/1000 | Train Loss: -0.5743 | Val Loss: -0.5579
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.69s]
# Epoch 954/1000 | Train Loss: -0.5742 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.20s | Save: 0.00s | Total: 0.64s]
# Epoch 955/1000 | Train Loss: -0.5765 | Val Loss: -0.5580
#   [Train: 0.40s | Val: 0.21s | Save: 0.00s | Total: 0.61s]
# Epoch 956/1000 | Train Loss: -0.5738 | Val Loss: -0.5579
#   [Train: 0.36s | Val: 0.20s | Save: 0.00s | Total: 0.56s]
# Epoch 957/1000 | Train Loss: -0.5753 | Val Loss: -0.5581
#   [Train: 0.41s | Val: 0.20s | Save: 0.00s | Total: 0.61s]
# Epoch 958/1000 | Train Loss: -0.5761 | Val Loss: -0.5580
#   [Train: 0.41s | Val: 0.17s | Save: 0.00s | Total: 0.59s]
# Epoch 959/1000 | Train Loss: -0.5752 | Val Loss: -0.5579
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 960/1000 | Train Loss: -0.5734 | Val Loss: -0.5579
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.58s]
# Epoch 961/1000 | Train Loss: -0.5763 | Val Loss: -0.5578
#   [Train: 0.43s | Val: 0.22s | Save: 0.01s | Total: 0.65s]
# Epoch 962/1000 | Train Loss: -0.5740 | Val Loss: -0.5580
#   [Train: 0.38s | Val: 0.23s | Save: 0.01s | Total: 0.61s]
# Epoch 963/1000 | Train Loss: -0.5747 | Val Loss: -0.5580
#   [Train: 0.35s | Val: 0.19s | Save: 0.01s | Total: 0.54s]
# Epoch 964/1000 | Train Loss: -0.5762 | Val Loss: -0.5579
#   [Train: 0.35s | Val: 0.20s | Save: 0.01s | Total: 0.56s]
# Epoch 965/1000 | Train Loss: -0.5752 | Val Loss: -0.5580
#   [Train: 0.46s | Val: 0.23s | Save: 0.00s | Total: 0.69s]
# Epoch 966/1000 | Train Loss: -0.5734 | Val Loss: -0.5579
#   [Train: 0.40s | Val: 0.22s | Save: 0.00s | Total: 0.62s]
# Epoch 967/1000 | Train Loss: -0.5726 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.19s | Save: 0.01s | Total: 0.62s]
# Epoch 968/1000 | Train Loss: -0.5750 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.21s | Save: 0.01s | Total: 0.65s]
# Epoch 969/1000 | Train Loss: -0.5734 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.23s | Save: 0.00s | Total: 0.66s]
# Epoch 970/1000 | Train Loss: -0.5772 | Val Loss: -0.5579
#   [Train: 0.38s | Val: 0.22s | Save: 0.00s | Total: 0.60s]
# Epoch 971/1000 | Train Loss: -0.5737 | Val Loss: -0.5577
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.68s]
# Epoch 972/1000 | Train Loss: -0.5743 | Val Loss: -0.5579
#   [Train: 0.46s | Val: 0.22s | Save: 0.01s | Total: 0.68s]
# Epoch 973/1000 | Train Loss: -0.5749 | Val Loss: -0.5580
#   [Train: 0.46s | Val: 0.20s | Save: 0.01s | Total: 0.67s]
# Epoch 974/1000 | Train Loss: -0.5742 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.23s | Save: 0.01s | Total: 0.66s]
# Epoch 975/1000 | Train Loss: -0.5762 | Val Loss: -0.5579
#   [Train: 0.46s | Val: 0.23s | Save: 0.00s | Total: 0.69s]
# Epoch 976/1000 | Train Loss: -0.5740 | Val Loss: -0.5580
#   [Train: 0.46s | Val: 0.18s | Save: 0.01s | Total: 0.65s]
# Epoch 977/1000 | Train Loss: -0.5726 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.62s]
# Epoch 978/1000 | Train Loss: -0.5744 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.19s | Save: 0.00s | Total: 0.64s]
# Epoch 979/1000 | Train Loss: -0.5760 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# Epoch 980/1000 | Train Loss: -0.5723 | Val Loss: -0.5580
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# Epoch 981/1000 | Train Loss: -0.5742 | Val Loss: -0.5578
#   [Train: 0.42s | Val: 0.20s | Save: 0.01s | Total: 0.63s]
# Epoch 982/1000 | Train Loss: -0.5763 | Val Loss: -0.5580
#   [Train: 0.46s | Val: 0.19s | Save: 0.01s | Total: 0.66s]
# Epoch 983/1000 | Train Loss: -0.5749 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.22s | Save: 0.00s | Total: 0.66s]
# Epoch 984/1000 | Train Loss: -0.5742 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.24s | Save: 0.01s | Total: 0.66s]
# Epoch 985/1000 | Train Loss: -0.5750 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.63s]
# Epoch 986/1000 | Train Loss: -0.5735 | Val Loss: -0.5579
#   [Train: 0.41s | Val: 0.19s | Save: 0.01s | Total: 0.60s]
# Epoch 987/1000 | Train Loss: -0.5753 | Val Loss: -0.5580
#   [Train: 0.42s | Val: 0.22s | Save: 0.01s | Total: 0.64s]
# Epoch 988/1000 | Train Loss: -0.5752 | Val Loss: -0.5580
#   [Train: 0.41s | Val: 0.22s | Save: 0.00s | Total: 0.63s]
# Epoch 989/1000 | Train Loss: -0.5752 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.65s]
# Epoch 990/1000 | Train Loss: -0.5733 | Val Loss: -0.5579
#   [Train: 0.40s | Val: 0.21s | Save: 0.01s | Total: 0.62s]
# Epoch 991/1000 | Train Loss: -0.5767 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.24s | Save: 0.01s | Total: 0.68s]
# Epoch 992/1000 | Train Loss: -0.5742 | Val Loss: -0.5579
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# Epoch 993/1000 | Train Loss: -0.5748 | Val Loss: -0.5579
#   [Train: 0.47s | Val: 0.21s | Save: 0.00s | Total: 0.69s]
# Epoch 994/1000 | Train Loss: -0.5738 | Val Loss: -0.5579
#   [Train: 0.37s | Val: 0.20s | Save: 0.01s | Total: 0.58s]
# Epoch 995/1000 | Train Loss: -0.5738 | Val Loss: -0.5580
#   [Train: 0.37s | Val: 0.18s | Save: 0.01s | Total: 0.56s]
# Epoch 996/1000 | Train Loss: -0.5744 | Val Loss: -0.5580
#   [Train: 0.44s | Val: 0.18s | Save: 0.00s | Total: 0.63s]
# Epoch 997/1000 | Train Loss: -0.5745 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.19s | Save: 0.01s | Total: 0.63s]
# Epoch 998/1000 | Train Loss: -0.5748 | Val Loss: -0.5580
#   [Train: 0.43s | Val: 0.22s | Save: 0.01s | Total: 0.67s]
# Epoch 999/1000 | Train Loss: -0.5726 | Val Loss: -0.5579
#   [Train: 0.43s | Val: 0.19s | Save: 0.00s | Total: 0.63s]
# Epoch 1000/1000 | Train Loss: -0.5739 | Val Loss: -0.5579
#   [Train: 0.40s | Val: 0.19s | Save: 0.01s | Total: 0.59s]
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# Existing model found. Loading weights and history...
# Continuing training from epoch 600...
# Epoch 601/1000 | Train Loss: 0.3608 | Val Loss: 0.3305
#   [Train: 0.37s | Val: 0.19s | Save: 0.00s | Total: 0.57s]
# Saved new best model.
# Epoch 602/1000 | Train Loss: 0.3609 | Val Loss: 0.3303
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.68s]
# Epoch 603/1000 | Train Loss: 0.3603 | Val Loss: 0.3305
#   [Train: 0.41s | Val: 0.24s | Save: 0.00s | Total: 0.66s]
# Saved new best model.
# Epoch 604/1000 | Train Loss: 0.3621 | Val Loss: 0.3303
#   [Train: 0.47s | Val: 0.23s | Save: 0.01s | Total: 0.73s]
# Epoch 605/1000 | Train Loss: 0.3601 | Val Loss: 0.3305
#   [Train: 0.45s | Val: 0.22s | Save: 0.00s | Total: 0.68s]
# ...
# Epoch 902/1000 | Train Loss: 2.4104 | Val Loss: 2.4119
#   [Train: 0.49s | Val: 0.20s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 903/1000 | Train Loss: 2.4102 | Val Loss: 2.4120
#   [Train: 0.48s | Val: 0.19s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 904/1000 | Train Loss: 2.4108 | Val Loss: 2.4127
#   [Train: 0.51s | Val: 0.21s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 905/1000 | Train Loss: 2.4140 | Val Loss: 2.4158
#   [Train: 0.46s | Val: 0.23s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 906/1000 | Train Loss: 2.4126 | Val Loss: 2.4161
#   [Train: 0.47s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 907/1000 | Train Loss: 2.4122 | Val Loss: 2.4127
#   [Train: 0.53s | Val: 0.21s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 908/1000 | Train Loss: 2.4109 | Val Loss: 2.4144
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 909/1000 | Train Loss: 2.4136 | Val Loss: 2.4121
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 910/1000 | Train Loss: 2.4140 | Val Loss: 2.4124
#   [Train: 0.47s | Val: 0.23s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 911/1000 | Train Loss: 2.4106 | Val Loss: 2.4119
#   [Train: 0.47s | Val: 0.23s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 912/1000 | Train Loss: 2.4105 | Val Loss: 2.4131
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 913/1000 | Train Loss: 2.4134 | Val Loss: 2.4130
#   [Train: 0.51s | Val: 0.25s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 914/1000 | Train Loss: 2.4115 | Val Loss: 2.4119
#   [Train: 0.52s | Val: 0.20s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 915/1000 | Train Loss: 2.4124 | Val Loss: 2.4126
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 916/1000 | Train Loss: 2.4136 | Val Loss: 2.4122
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 917/1000 | Train Loss: 2.4107 | Val Loss: 2.4127
#   [Train: 0.41s | Val: 0.21s | Save: 0.01s | Total: 0.64s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 918/1000 | Train Loss: 2.4112 | Val Loss: 2.4144
#   [Train: 0.49s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 919/1000 | Train Loss: 2.4130 | Val Loss: 2.4118
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 920/1000 | Train Loss: 2.4117 | Val Loss: 2.4119
#   [Train: 0.49s | Val: 0.23s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 921/1000 | Train Loss: 2.4099 | Val Loss: 2.4130
#   [Train: 0.52s | Val: 0.24s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 922/1000 | Train Loss: 2.4115 | Val Loss: 2.4132
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 923/1000 | Train Loss: 2.4133 | Val Loss: 2.4122
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 924/1000 | Train Loss: 2.4138 | Val Loss: 2.4124
#   [Train: 0.48s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 925/1000 | Train Loss: 2.4110 | Val Loss: 2.4120
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 926/1000 | Train Loss: 2.4123 | Val Loss: 2.4127
#   [Train: 0.50s | Val: 0.24s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 927/1000 | Train Loss: 2.4125 | Val Loss: 2.4122
#   [Train: 0.53s | Val: 0.25s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 928/1000 | Train Loss: 2.4113 | Val Loss: 2.4130
#   [Train: 0.47s | Val: 0.21s | Save: 0.01s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 929/1000 | Train Loss: 2.4117 | Val Loss: 2.4122
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 930/1000 | Train Loss: 2.4100 | Val Loss: 2.4136
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 931/1000 | Train Loss: 2.4130 | Val Loss: 2.4128
#   [Train: 0.47s | Val: 0.23s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 932/1000 | Train Loss: 2.4121 | Val Loss: 2.4121
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 933/1000 | Train Loss: 2.4091 | Val Loss: 2.4122
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 934/1000 | Train Loss: 2.4115 | Val Loss: 2.4126
#   [Train: 0.53s | Val: 0.25s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 935/1000 | Train Loss: 2.4107 | Val Loss: 2.4130
#   [Train: 0.51s | Val: 0.20s | Save: 0.01s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 936/1000 | Train Loss: 2.4099 | Val Loss: 2.4121
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 937/1000 | Train Loss: 2.4124 | Val Loss: 2.4130
#   [Train: 0.48s | Val: 0.24s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 938/1000 | Train Loss: 2.4123 | Val Loss: 2.4127
#   [Train: 0.49s | Val: 0.21s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 939/1000 | Train Loss: 2.4109 | Val Loss: 2.4133
#   [Train: 0.52s | Val: 0.24s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 940/1000 | Train Loss: 2.4125 | Val Loss: 2.4137
#   [Train: 0.49s | Val: 0.25s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 941/1000 | Train Loss: 2.4126 | Val Loss: 2.4128
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 942/1000 | Train Loss: 2.4127 | Val Loss: 2.4121
#   [Train: 0.53s | Val: 0.25s | Save: 0.01s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 943/1000 | Train Loss: 2.4116 | Val Loss: 2.4157
#   [Train: 0.54s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 944/1000 | Train Loss: 2.4131 | Val Loss: 2.4127
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 945/1000 | Train Loss: 2.4139 | Val Loss: 2.4136
#   [Train: 0.52s | Val: 0.20s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 946/1000 | Train Loss: 2.4127 | Val Loss: 2.4135
#   [Train: 0.54s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 947/1000 | Train Loss: 2.4132 | Val Loss: 2.4127
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 948/1000 | Train Loss: 2.4116 | Val Loss: 2.4135
#   [Train: 0.54s | Val: 0.21s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 949/1000 | Train Loss: 2.4107 | Val Loss: 2.4122
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 950/1000 | Train Loss: 2.4121 | Val Loss: 2.4123
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 951/1000 | Train Loss: 2.4130 | Val Loss: 2.4120
#   [Train: 0.56s | Val: 0.19s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 952/1000 | Train Loss: 2.4131 | Val Loss: 2.4149
#   [Train: 0.48s | Val: 0.21s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 953/1000 | Train Loss: 2.4116 | Val Loss: 2.4125
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 954/1000 | Train Loss: 2.4101 | Val Loss: 2.4123
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 955/1000 | Train Loss: 2.4115 | Val Loss: 2.4121
#   [Train: 0.44s | Val: 0.23s | Save: 0.01s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 956/1000 | Train Loss: 2.4116 | Val Loss: 2.4125
#   [Train: 0.56s | Val: 0.21s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 957/1000 | Train Loss: 2.4121 | Val Loss: 2.4136
#   [Train: 0.57s | Val: 0.22s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 958/1000 | Train Loss: 2.4126 | Val Loss: 2.4129
#   [Train: 0.49s | Val: 0.21s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 959/1000 | Train Loss: 2.4130 | Val Loss: 2.4119
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 960/1000 | Train Loss: 2.4110 | Val Loss: 2.4139
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 961/1000 | Train Loss: 2.4135 | Val Loss: 2.4129
#   [Train: 0.50s | Val: 0.23s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 962/1000 | Train Loss: 2.4132 | Val Loss: 2.4120
#   [Train: 0.48s | Val: 0.22s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 963/1000 | Train Loss: 2.4100 | Val Loss: 2.4121
#   [Train: 0.39s | Val: 0.20s | Save: 0.01s | Total: 0.61s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 964/1000 | Train Loss: 2.4101 | Val Loss: 2.4141
#   [Train: 0.40s | Val: 0.20s | Save: 0.00s | Total: 0.62s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 965/1000 | Train Loss: 2.4132 | Val Loss: 2.4119
#   [Train: 0.48s | Val: 0.19s | Save: 0.01s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 966/1000 | Train Loss: 2.4127 | Val Loss: 2.4124
#   [Train: 0.51s | Val: 0.20s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 967/1000 | Train Loss: 2.4150 | Val Loss: 2.4120
#   [Train: 0.49s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 968/1000 | Train Loss: 2.4107 | Val Loss: 2.4131
#   [Train: 0.46s | Val: 0.19s | Save: 0.01s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 969/1000 | Train Loss: 2.4109 | Val Loss: 2.4130
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 970/1000 | Train Loss: 2.4147 | Val Loss: 2.4119
#   [Train: 0.53s | Val: 0.22s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 971/1000 | Train Loss: 2.4132 | Val Loss: 2.4126
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 972/1000 | Train Loss: 2.4131 | Val Loss: 2.4127
#   [Train: 0.50s | Val: 0.23s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 973/1000 | Train Loss: 2.4114 | Val Loss: 2.4120
#   [Train: 0.52s | Val: 0.19s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 974/1000 | Train Loss: 2.4115 | Val Loss: 2.4121
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 975/1000 | Train Loss: 2.4107 | Val Loss: 2.4135
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 976/1000 | Train Loss: 2.4125 | Val Loss: 2.4119
#   [Train: 0.45s | Val: 0.18s | Save: 0.00s | Total: 0.66s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 977/1000 | Train Loss: 2.4150 | Val Loss: 2.4123
#   [Train: 0.49s | Val: 0.21s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 978/1000 | Train Loss: 2.4113 | Val Loss: 2.4130
#   [Train: 0.62s | Val: 0.19s | Save: 0.01s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 979/1000 | Train Loss: 2.4122 | Val Loss: 2.4140
#   [Train: 0.67s | Val: 0.22s | Save: 0.00s | Total: 0.91s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 980/1000 | Train Loss: 2.4124 | Val Loss: 2.4120
#   [Train: 0.73s | Val: 0.20s | Save: 0.00s | Total: 0.95s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 981/1000 | Train Loss: 2.4123 | Val Loss: 2.4125
#   [Train: 0.71s | Val: 0.47s | Save: 0.00s | Total: 1.39s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 982/1000 | Train Loss: 2.4122 | Val Loss: 2.4131
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 983/1000 | Train Loss: 2.4141 | Val Loss: 2.4121
#   [Train: 0.49s | Val: 0.20s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 984/1000 | Train Loss: 2.4124 | Val Loss: 2.4118
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 985/1000 | Train Loss: 2.4131 | Val Loss: 2.4129
#   [Train: 0.47s | Val: 0.22s | Save: 0.01s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 986/1000 | Train Loss: 2.4118 | Val Loss: 2.4123
#   [Train: 0.52s | Val: 0.24s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 987/1000 | Train Loss: 2.4121 | Val Loss: 2.4124
#   [Train: 0.49s | Val: 0.24s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 988/1000 | Train Loss: 2.4097 | Val Loss: 2.4137
#   [Train: 0.55s | Val: 0.20s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 989/1000 | Train Loss: 2.4120 | Val Loss: 2.4135
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 990/1000 | Train Loss: 2.4104 | Val Loss: 2.4122
#   [Train: 0.46s | Val: 0.22s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 991/1000 | Train Loss: 2.4137 | Val Loss: 2.4120
#   [Train: 0.39s | Val: 0.19s | Save: 0.00s | Total: 0.61s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 992/1000 | Train Loss: 2.4102 | Val Loss: 2.4124
#   [Train: 0.49s | Val: 0.21s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 993/1000 | Train Loss: 2.4120 | Val Loss: 2.4130
#   [Train: 0.45s | Val: 0.24s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 994/1000 | Train Loss: 2.4121 | Val Loss: 2.4120
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 995/1000 | Train Loss: 2.4128 | Val Loss: 2.4133
#   [Train: 0.47s | Val: 0.24s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 996/1000 | Train Loss: 2.4111 | Val Loss: 2.4122
#   [Train: 0.47s | Val: 0.22s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 997/1000 | Train Loss: 2.4112 | Val Loss: 2.4124
#   [Train: 0.53s | Val: 0.24s | Save: 0.01s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 998/1000 | Train Loss: 2.4111 | Val Loss: 2.4126
#   [Train: 0.51s | Val: 0.25s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 999/1000 | Train Loss: 2.4115 | Val Loss: 2.4125
#   [Train: 0.58s | Val: 0.22s | Save: 0.01s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 1000/1000 | Train Loss: 2.4134 | Val Loss: 2.4120
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]

# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs

# %%
show_training_history(conf_dict,EXPERIMENT_DIR)

# %% [markdown]
# ## 6.2 inspect transformation function for source nodes h()

# %%
show_hdag_for_source_nodes(conf_dict,EXPERIMENT_DIR,device=device,xmin_plot=0,xmax_plot=1) # TODO for other nodes funciton
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# h() for  x1:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance
#
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(conf_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# Train loader (x1): 100%|██████████| 2/2 [00:00<00:00,  5.33it/s]
# Val loader (x1): 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# Train loader (x2): 100%|██████████| 2/2 [00:00<00:00,  5.57it/s]
# Val loader (x2): 100%|██████████| 1/1 [00:00<00:00,  4.73it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--
# Train loader (x3): 100%|██████████| 2/2 [00:00<00:00,  2.95it/s]
# Val loader (x3): 100%|██████████| 1/1 [00:00<00:00,  4.25it/s]

# %% [markdown]
# ### Coefficient estimates

# %%
# x1-> x2, x1-> x3, x2-> x3
true_coeffs = {'x2': [2],'x3': [-0.2, 0.3]}

for node in conf_dict:
    print(f'\n----*----------*-------------*--------check LS of {node} ------------*-----------------*-------------------*--')
    
    if conf_dict[node]['node_type'] == 'source':
        print(f"Node type :source")
        continue
    
    # Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    # Load saved shifts
    shift_path = os.path.join(NODE_DIR, "linear_shifts_all_epochs.json")
    with open(shift_path, 'r') as f:
        all_shift_weights = json.load(f)

    # Sort epochs numerically
    epochs = sorted(all_shift_weights.keys(), key=lambda x: int(x.split('_')[1]))

    # Number of shifts (incoming edges) for this node
    example_epoch = all_shift_weights[epochs[0]]
    num_shifts = len(example_epoch)

    # Plot per shift (incoming edge)
    for shifts_idx in range(num_shifts):
        
        if node=='x3':
            shift_name = f"shift_{1}"
        else:
            shift_name = f"shift_{shifts_idx}"
        weights_over_time = []

        for epoch in epochs:
            weight_matrix = np.array(all_shift_weights[epoch][shift_name])  # shape: [out_features, in_features]
            avg_weight = weight_matrix.mean()
            weights_over_time.append(avg_weight)

        plt.figure()
        plt.plot(range(1, len(epochs) + 1), weights_over_time)

        # If this node has a true coefficient for this shift, draw a horizontal red line
        if node in true_coeffs:
            true_val = true_coeffs[node][shifts_idx]
            plt.axhline(y=true_val, color='r', linestyle='--', label=f"True coeff = {true_val}")
            plt.legend()

        plt.title(f"Linear Shift Weights in h({node}), ")
        plt.xlabel("Epoch")
        plt.ylabel(fr'$\hat{{\beta}}_{{{conf_dict[node]["parents"][shifts_idx]}}}$')
        plt.grid(True)
        plt.tight_layout()
        plt.show()
# Out:
# ----*----------*-------------*--------check LS of x1 ------------*-----------------*-------------------*--
# Node type :source
#
# ----*----------*-------------*--------check LS of x2 ------------*-----------------*-------------------*--
# ----*----------*-------------*--------check LS of x3 ------------*-----------------*-------------------*--

# %%
verbose = False
batch_size = 4112

x = torch.linspace(-1, 1, steps=1000).unsqueeze(1).to(device)  # (100, 1)


def f(x):
    return -0.3*x  

for node in conf_dict:
    print(f'\n----*----------*-------------*--------check CS of {node} ------------*-----------------*-------------------*--')

    if conf_dict[node]['node_type'] == 'source':
        print("Node type : source, not supported yet.")
        continue

    # Load model
    NODE_DIR = os.path.join(EXPERIMENT_DIR, node)
    model_path = os.path.join(NODE_DIR, "best_model.pt")

    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose).to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()

    for i, module in enumerate(tram_model.nn_shift):
        module_name = module.__class__.__name__
        if module_name == 'LinearShift':
            print(f"Module {i} ({module_name}) weights:")
            print(module.fc.weight.data)
        else:
            print(f"Module {i} ({module_name}) predictions:")
            with torch.no_grad():
                y = module(x)
plt.scatter(x.cpu().numpy(),y.cpu().numpy())
plt.scatter(x.cpu().numpy(),-f(x.cpu().numpy()),cmap="red")
plt.show()
# Out:
# ----*----------*-------------*--------check CS of x1 ------------*-----------------*-------------------*--
# Node type : source, not supported yet.
#
# ----*----------*-------------*--------check CS of x2 ------------*-----------------*-------------------*--
# Module 0 (LinearShift) weights:
# tensor([[1.9511]], device='cuda:0')
#
# ----*----------*-------------*--------check CS of x3 ------------*-----------------*-------------------*--
# Module 0 (ComplexShiftDefaultTabular) predictions:
# Module 1 (LinearShift) weights:
# tensor([[-0.2186]], device='cuda:0')
# /tmp/ipykernel_622397/1953398127.py:35: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x.cpu().numpy(),-f(x.cpu().numpy()),cmap="red")

# %% [markdown]
# # 7. Sample from Graph

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            n= 10_000,
                            batch_size = 1,
                            delete_all_previously_sampled=True,
                            verbose=True)
# Out:
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x1/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x2/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x1/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# h() for samples in  x1: 100%|██████████| 10000/10000 [00:01<00:00, 5378.48it/s]
# source node, Defaults to SI and 1 as inputs
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:31<00:00, 319.72it/s]
# /home/bule/TramDag/utils/sampling_tram_data.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x2/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x2: 100%|██████████| 10000/10000 [00:02<00:00, 3334.94it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:31<00:00, 319.37it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x3/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=1, out_features=32, bias=True)
#       (relu1): ReLU()
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (relu2): ReLU()
#       (fc3): Linear(in_features=32, out_features=1, bias=False)
#     )
#     (1): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x3: 100%|██████████| 10000/10000 [00:05<00:00, 1852.69it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 330.64it/s]

# %% [markdown]
# ## 7.3 Inspect Sampling

# %%
show_samples_vs_true(test_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')

# %% [markdown]
# ## 7.4 Intervention

# %%
def f(x):
    return -0.3*x  

intervention_df=dgp(10_000, doX=[-1.0, None, None], seed=-1)
sns.pairplot(intervention_df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            do_interventions={'x1':-1.0},
                            n= 10_000,
                            batch_size = 32,
                            delete_all_previously_sampled=True,
                            verbose=True)
# Out:
# /home/bule/TramDag/utils/sampling_tram_data.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x1/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x2/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x1/sampling
#
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x2/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x2:   0%|          | 0/313 [00:00<?, ?it/s]
# h() for samples in  x2: 100%|██████████| 313/313 [00:00<00:00, 1594.98it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 327.72it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_cs2/x3/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=1, out_features=32, bias=True)
#       (relu1): ReLU()
#       (fc2): Linear(in_features=32, out_features=32, bias=True)
#       (relu2): ReLU()
#       (fc3): Linear(in_features=32, out_features=1, bias=False)
#     )
#     (1): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x3: 100%|██████████| 313/313 [00:00<00:00, 1056.76it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:29<00:00, 336.40it/s]

# %%
show_samples_vs_true(intervention_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')
