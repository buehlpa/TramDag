# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "interactions_small"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data

# %%
# TODO develop meaningful experiment for interactions



# Fz(z)=Fy(y)
# Fz(h(y|x))=Fy(y)    | z= h(y|x)

# Generate x2

# h(y|x1,x2,x3,x4,x5)= Bernsteinpol(x1,x2) +f2(x2,x3) + f3(x4, x2) + beta * x5        | bernsteinpol is just linearized assumed with a constant factor say 0.42
# h(y|x1,x2,x3,x4,x5)= Bernsteinpol(x1,x2) +f2(x2,x3) + f3(x4, x2) + beta * x5                                          | replace h(y|..) with z
# z                  = 0.42*x2 + beta2 * x1                                           | reformulate to x2
# x2                 = (z-beta2 * x1 )/0.42                                           | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
# x2                 = (z-beta2 * x1 )/0.42                                           | set beta = 2 (on the edge of the graph)
# x2                 = (z-2 * x1 )/0.42

# %%
from scipy.special import logit
from mpl_toolkits.mplot3d import Axes3D


# Define the functions used in the DGP
def f1(x1, x2):
    return np.sin(np.pi * x1) * np.cos(np.pi * x2)

def f2(x2, x3):
    return np.exp(-((x2 - 1)**2 + (x3 - 1)**2))

def f3(x4, x2):
    return (x4 * x2) / (1 + x4**2 + x2**2)

def dgp_continuous_interactions(n_obs=10_000, seed=42):
    np.random.seed(seed)

    # Independent variables
    x1 = np.random.uniform(0, 2, size=n_obs)
    x2 = np.random.uniform(0, 2, size=n_obs)
    x3 = np.random.uniform(0, 2, size=n_obs)
    x4 = np.random.uniform(0, 2, size=n_obs)
    x5 = np.random.normal(0, 1, size=n_obs)
    x6 = np.random.uniform(0, 2, size=n_obs)
    x7 = np.random.normal(0, 1, size=n_obs)

    # Response variable with interactions
    y = f1(x1, x2) + f2(x3, x4) + f3(x5, x6) + 1.5 * x7

    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3, 'x4': x4, 'x5': x5, 'x6': x6, 'x7': x7, 'x8': y})
    return df

# Generate data
df = dgp_continuous_interactions()

# Visualize the 3 interaction functions
fig = plt.figure(figsize=(18, 5))

# f1(x1, x2)
ax = fig.add_subplot(131, projection='3d')
x = np.linspace(0, 2, 50)
y = np.linspace(0, 2, 50)
X, Y = np.meshgrid(x, y)
Z = f1(X, Y)
ax.plot_surface(X, Y, Z, alpha=0.8)
ax.set_title("f1(x1, x2) = sin(pi*x1)*cos(pi*x2)")
ax.set_xlabel("x1")
ax.set_ylabel("x2")
ax.set_zlabel("f1")

# f2(x2, x3)
ax = fig.add_subplot(132, projection='3d')
X, Y = np.meshgrid(x, y)
Z = f2(X, Y)
ax.plot_surface(X, Y, Z, alpha=0.8)
ax.set_title("f2(x2, x3) = exp(-((x2-1)^2 + (x3-1)^2))")
ax.set_xlabel("x2")
ax.set_ylabel("x3")
ax.set_zlabel("f2")

# f3(x4, x2)
ax = fig.add_subplot(133, projection='3d')
X, Y = np.meshgrid(x, y)
Z = f3(X, Y)
ax.plot_surface(X, Y, Z, alpha=0.8)
ax.set_title("f3(x4, x2) = (x4*x2)/(1+x4^2+x2^2)")
ax.set_xlabel("x4")
ax.set_ylabel("x2")
ax.set_zlabel("f3")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2.1 train test split

# %%
# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# 2. Compute quantiles from training data
quantiles = train_df.quantile([0.05, 0.95])
min_vals = quantiles.loc[0.05]
max_vals = quantiles.loc[0.95]

# 3. Normalize all sets using training quantiles
def normalize_with_quantiles(df, min_vals, max_vals):
    return (df - min_vals) / (max_vals - min_vals)

train_df = normalize_with_quantiles(train_df, min_vals, max_vals)
val_df = normalize_with_quantiles(val_df, min_vals, max_vals)
test_df = normalize_with_quantiles(test_df, min_vals, max_vals)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 8000, Validation size: 1000, Test size: 1000

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# --- Editable Parameters ---
variable_names = ['x1', 'x2', 'x3', 'x4'] #, 'x4', 'x5', 'x6', 'x7', 'x8']
data_type={'x1':'cont','x2':'cont','x3':'cont','x4':'cont'}#,'x4':'cont','x5':'cont','x6':'cont','x7':'cont','x8':'cont'}  # continous , images , ordinal

# x4~CS(x1,x2)+LS(x3)
interactive_adj_matrix(variable_names, data_type,experiment_dir=EXPERIMENT_DIR, seed=5)
# Out:
# Found existing matrix at /home/bule/TramDag/dev_experiment_logs/interactions_small/adj_matrix.npy. plotting...

# %%
variable_names = ['x1', 'x2', 'x3','x4', 'x5', 'x6', 'x7', 'x8']
data_type={'x1':'cont','x2':'cont','x3':'cont','x4':'cont','x5':'cont','x6':'cont','x7':'cont','x8':'cont'}  # continous , images , ordinal

# %%
adj_matrix=np.array([['0', '0', '0', '0', '0', '0', 'ci', 'ci71'],
                     ['0', '0', '0', '0', '0', '0', 'cs', 'ci72'],
                     ['0', '0', '0', '0', '0', '0', 'cs', 'cs71'],
                     ['0', '0', '0', '0', '0', '0', 'cs', 'cs712'],
                     ['0', '0', '0', '0', '0', '0', '0', 'cs81'],
                     ['0', '0', '0', '0', '0', '0', '0', 'cs82'],
                     ['0', '0', '0', '0', '0', '0', '0', 'ls'],
                     ['0', '0', '0', '0', '0', '0', '0', '0']])

# %%
plot_dag(adj_matrix, data_type,seed=21)
# Out:
# /tmp/ipykernel_1796617/2067962321.py:84: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
def plot_dag(adj_matrix, data_type, seed=42, use_spring=True):
    """
    Plot the DAG with Source, Sink, and Intermediate nodes.

    Parameters:
    - adj_matrix: square upper‐triangular numpy array of edge labels (strings)
    - data_type: dict mapping node labels to types (keys are node names), 
                 length must match adj_matrix.shape[0]
    - seed: int, random seed for layout
    - use_spring: bool, if True use networkx.spring_layout; 
                  if False try Graphviz “dot” (falls back to spring)
    """
    import networkx as nx
    import matplotlib.pyplot as plt
    from matplotlib.patches import Patch

    # assume validate_adj_matrix and create_nx_graph are defined elsewhere
    if not validate_adj_matrix(adj_matrix):
        raise ValueError("Invalid adjacency matrix.")
    if len(data_type) != adj_matrix.shape[0]:
        raise ValueError("data_type must match adjacency matrix size.")

    node_labels = list(data_type.keys())
    G, edge_labels = create_nx_graph(adj_matrix, node_labels)

    # classify nodes
    sources       = {n for n in G.nodes if G.in_degree(n) == 0}
    sinks         = {n for n in G.nodes if G.out_degree(n) == 0}
    intermediates = set(G.nodes) - sources - sinks

    # assign node colors
    node_colors = [
        "green" if n in sources
        else "red" if n in sinks
        else "lightblue"
        for n in G.nodes
    ]

    # choose layout
    if use_spring:
        pos = nx.spring_layout(G, seed=seed, k=1.5, iterations=100)
    else:
        try:
            pos = nx.nx_agraph.graphviz_layout(G, prog="dot")
        except (ImportError, nx.NetworkXException):
            pos = nx.spring_layout(G, seed=seed, k=1.5, iterations=100)

    # draw nodes and edges
    plt.figure(figsize=(8, 6))
    nx.draw(
        G, pos,
        with_labels=True,
        node_color=node_colors,
        edge_color="gray",
        node_size=2500,
        arrowsize=20
    )

    # draw edge labels colored by prefix
    for (u, v), lbl in edge_labels.items():
        color = (
            "blue"  if lbl.startswith("ci")
            else "red"   if lbl.startswith("ls")
            else "green" if lbl.startswith("cs")
            else "black"
        )
        nx.draw_networkx_edge_labels(
            G, pos,
            edge_labels={(u, v): lbl},
            font_color=color,
            font_size=12
        )

    # build legend
    legend_items = [
        Patch(facecolor="green",     edgecolor="black", label="Source"),
        Patch(facecolor="red",       edgecolor="black", label="Sink"),
        Patch(facecolor="lightblue", edgecolor="black", label="Intermediate")
    ]
    plt.legend(handles=legend_items, loc="upper right", frameon=True)

    plt.title("TRAM DAG")
    plt.axis("off")
    plt.tight_layout()
    plt.show()

# %%
adj_matrix = np.load(os.path.join(EXPERIMENT_DIR, "adj_matrix.npy"),allow_pickle=True)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
# nn_names_matrix[1,2]='ComplexShiftCustomTabular'
plot_nn_names_matrix(nn_names_matrix,data_type)
# Out:
# *************
#  Model has Complex intercepts and Complex shifts, please add your Model to the modelzoo
# *************

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/interactions_small/interactions_small_conf.json
# /tmp/ipykernel_1796617/1695834966.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
# /tmp/ipykernel_1796617/1695834966.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['max']=max_vals[i].tolist()
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.1023280003906143,
#   'max': 1.895380529733125},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.09848326169895154,
#   'max': 1.9048444463462053},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.10592383041862734,
#   'max': 1.9012680218740785},
#  'x4': {'Modelnr': 3,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2', 'x3'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont', 'x3': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'cs11', 'x2': 'cs12', 'x3': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'ComplexShiftDefaultTabular11',
#    'x2': 'ComplexShiftDefaultTabular12',
#    'x3': 'LinearShift'},
#   'min': 0.0972050026910846,
#   'max': 1.8981168018175927}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3','x4','x5','x6','x7','x8']#['x2']#'x1','x2']#,'x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 512#4112
epochs = 500# <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
learning_rate=0.1
use_scheduler =  False

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)
    #tram_model =get_fully_specified_tram_model_hardcoded_init_weights_for_si(node, conf_dict, verbose=True).to(device)

    _, ordered_transformation_terms_in_h, _=ordered_parents(node, conf_dict)
    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################.
    
    ## <---------- TODO use standard SGD and no scheduler
    # optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    # optimizer = torch.optim.AdamW(
    # tram_model.parameters(),
    # lr=1e-3,           # ← two orders of magnitude smaller
    # eps=1e-8,
    # weight_decay=1e-2
    # )   
    optimizer =torch.optim.Adam(tram_model.parameters(), lr=learning_rate)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
        #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer,max_lr=1e-3, total_steps=epochs * len(train_loader),pct_start=0.1, anneal_strategy="cos"       # pick your sweet-spot

    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR,
            ordered_transformation_terms_in_h,
            save_linear_shifts=True
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 500...
# Node x1 already trained for 500 epochs. Skipping.
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 500...
# Node x2 already trained for 500 epochs. Skipping.
#
# ----*----------*-------------*--------------- Node: x3 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# Existing model found. Loading weights and history...
# Continuing training from epoch 500...
# Node x3 already trained for 500 epochs. Skipping.
#
# ----*----------*-------------*--------------- Node: x4 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=2, out_features=64, bias=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (fc2): Linear(in_features=64, out_features=128, bias=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (fc3): Linear(in_features=128, out_features=64, bias=True)
#       (relu3): ReLU()
#       (dropout3): Dropout(p=0.3, inplace=False)
#       (fc4): Linear(in_features=64, out_features=1, bias=False)
#     )
#     (1): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# No existing model found. Starting fresh...
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 1/500 | Train Loss: 6.4548 | Val Loss: 1.5656
#   [Train: 0.80s | Val: 0.21s | Save: 0.00s | Total: 1.02s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 2/500 | Train Loss: 1.3798 | Val Loss: 1.2004
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 3/500 | Train Loss: 1.1290 | Val Loss: 1.0481
#   [Train: 0.52s | Val: 0.22s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 4/500 | Train Loss: 1.0352 | Val Loss: 0.9855
#   [Train: 0.53s | Val: 0.22s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 5/500 | Train Loss: 0.9900 | Val Loss: 0.9505
#   [Train: 0.55s | Val: 0.22s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 6/500 | Train Loss: 0.9618 | Val Loss: 0.9261
#   [Train: 0.53s | Val: 0.22s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 7/500 | Train Loss: 0.9392 | Val Loss: 0.9067
#   [Train: 0.53s | Val: 0.24s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 8/500 | Train Loss: 0.9199 | Val Loss: 0.8903
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 9/500 | Train Loss: 0.9035 | Val Loss: 0.8761
#   [Train: 0.49s | Val: 0.23s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 10/500 | Train Loss: 0.8891 | Val Loss: 0.8632
#   [Train: 0.51s | Val: 0.24s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 11/500 | Train Loss: 0.8755 | Val Loss: 0.8514
#   [Train: 0.50s | Val: 0.20s | Save: 0.01s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 12/500 | Train Loss: 0.8644 | Val Loss: 0.8409
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 13/500 | Train Loss: 0.8531 | Val Loss: 0.8311
#   [Train: 0.52s | Val: 0.23s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 14/500 | Train Loss: 0.8434 | Val Loss: 0.8218
#   [Train: 0.55s | Val: 0.22s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 15/500 | Train Loss: 0.8342 | Val Loss: 0.8134
#   [Train: 0.49s | Val: 0.23s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 16/500 | Train Loss: 0.8251 | Val Loss: 0.8057
#   [Train: 0.58s | Val: 0.24s | Save: 0.00s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 17/500 | Train Loss: 0.8170 | Val Loss: 0.7985
#   [Train: 0.57s | Val: 0.24s | Save: 0.01s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 18/500 | Train Loss: 0.8094 | Val Loss: 0.7915
#   [Train: 0.44s | Val: 0.22s | Save: 0.00s | Total: 0.66s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 19/500 | Train Loss: 0.8023 | Val Loss: 0.7848
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 20/500 | Train Loss: 0.7955 | Val Loss: 0.7790
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 21/500 | Train Loss: 0.7894 | Val Loss: 0.7732
#   [Train: 0.49s | Val: 0.23s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 22/500 | Train Loss: 0.7835 | Val Loss: 0.7682
#   [Train: 0.56s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 23/500 | Train Loss: 0.7781 | Val Loss: 0.7631
#   [Train: 0.50s | Val: 0.22s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 24/500 | Train Loss: 0.7728 | Val Loss: 0.7586
#   [Train: 0.54s | Val: 0.20s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 25/500 | Train Loss: 0.7682 | Val Loss: 0.7545
#   [Train: 0.56s | Val: 0.22s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 26/500 | Train Loss: 0.7639 | Val Loss: 0.7501
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 27/500 | Train Loss: 0.7588 | Val Loss: 0.7467
#   [Train: 0.56s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 28/500 | Train Loss: 0.7550 | Val Loss: 0.7427
#   [Train: 0.53s | Val: 0.25s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 29/500 | Train Loss: 0.7512 | Val Loss: 0.7402
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 30/500 | Train Loss: 0.7472 | Val Loss: 0.7360
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 31/500 | Train Loss: 0.7439 | Val Loss: 0.7341
#   [Train: 0.50s | Val: 0.23s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 32/500 | Train Loss: 0.7407 | Val Loss: 0.7303
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 33/500 | Train Loss: 0.7376 | Val Loss: 0.7291
#   [Train: 0.57s | Val: 0.26s | Save: 0.00s | Total: 0.84s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 34/500 | Train Loss: 0.7346 | Val Loss: 0.7254
#   [Train: 0.57s | Val: 0.21s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 35/500 | Train Loss: 0.7316 | Val Loss: 0.7228
#   [Train: 0.55s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 36/500 | Train Loss: 0.7293 | Val Loss: 0.7211
#   [Train: 0.56s | Val: 0.23s | Save: 0.01s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 37/500 | Train Loss: 0.7266 | Val Loss: 0.7190
#   [Train: 0.55s | Val: 0.22s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 38/500 | Train Loss: 0.7249 | Val Loss: 0.7172
#   [Train: 0.53s | Val: 0.23s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 39/500 | Train Loss: 0.7226 | Val Loss: 0.7163
#   [Train: 0.54s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 40/500 | Train Loss: 0.7205 | Val Loss: 0.7140
#   [Train: 0.57s | Val: 0.24s | Save: 0.01s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 41/500 | Train Loss: 0.7186 | Val Loss: 0.7130
#   [Train: 0.56s | Val: 0.21s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 42/500 | Train Loss: 0.7165 | Val Loss: 0.7112
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 43/500 | Train Loss: 0.7145 | Val Loss: 0.7099
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 44/500 | Train Loss: 0.7133 | Val Loss: 0.7080
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 45/500 | Train Loss: 0.7117 | Val Loss: 0.7093
#   [Train: 0.57s | Val: 0.22s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 46/500 | Train Loss: 0.7103 | Val Loss: 0.7063
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 47/500 | Train Loss: 0.7091 | Val Loss: 0.7049
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 48/500 | Train Loss: 0.7081 | Val Loss: 0.7033
#   [Train: 0.50s | Val: 0.25s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 49/500 | Train Loss: 0.7060 | Val Loss: 0.7034
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 50/500 | Train Loss: 0.7063 | Val Loss: 0.7019
#   [Train: 0.52s | Val: 0.24s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 51/500 | Train Loss: 0.7044 | Val Loss: 0.7009
#   [Train: 0.57s | Val: 0.24s | Save: 0.01s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 52/500 | Train Loss: 0.7030 | Val Loss: 0.7002
#   [Train: 0.51s | Val: 0.25s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 53/500 | Train Loss: 0.7024 | Val Loss: 0.6999
#   [Train: 0.54s | Val: 0.23s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 54/500 | Train Loss: 0.7010 | Val Loss: 0.6984
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 55/500 | Train Loss: 0.7008 | Val Loss: 0.6982
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 56/500 | Train Loss: 0.7001 | Val Loss: 0.6978
#   [Train: 0.55s | Val: 0.22s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 57/500 | Train Loss: 0.6989 | Val Loss: 0.6979
#   [Train: 0.55s | Val: 0.20s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 58/500 | Train Loss: 0.6985 | Val Loss: 0.6967
#   [Train: 0.53s | Val: 0.20s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 59/500 | Train Loss: 0.6975 | Val Loss: 0.6958
#   [Train: 0.53s | Val: 0.22s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 60/500 | Train Loss: 0.6967 | Val Loss: 0.6956
#   [Train: 0.55s | Val: 0.23s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 61/500 | Train Loss: 0.6963 | Val Loss: 0.6957
#   [Train: 0.55s | Val: 0.23s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 62/500 | Train Loss: 0.6958 | Val Loss: 0.6948
#   [Train: 0.53s | Val: 0.21s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 63/500 | Train Loss: 0.6954 | Val Loss: 0.6943
#   [Train: 0.51s | Val: 0.20s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 64/500 | Train Loss: 0.6947 | Val Loss: 0.6942
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 65/500 | Train Loss: 0.6939 | Val Loss: 0.6938
#   [Train: 0.50s | Val: 0.20s | Save: 0.01s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 66/500 | Train Loss: 0.6938 | Val Loss: 0.6933
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 67/500 | Train Loss: 0.6934 | Val Loss: 0.6929
#   [Train: 0.56s | Val: 0.20s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 68/500 | Train Loss: 0.6933 | Val Loss: 0.6942
#   [Train: 0.55s | Val: 0.20s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 69/500 | Train Loss: 0.6921 | Val Loss: 0.6928
#   [Train: 0.49s | Val: 0.20s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 70/500 | Train Loss: 0.6922 | Val Loss: 0.6934
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 71/500 | Train Loss: 0.6927 | Val Loss: 0.6914
#   [Train: 0.54s | Val: 0.20s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 72/500 | Train Loss: 0.6910 | Val Loss: 0.6919
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 73/500 | Train Loss: 0.6908 | Val Loss: 0.6929
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 74/500 | Train Loss: 0.6918 | Val Loss: 0.6910
#   [Train: 0.47s | Val: 0.20s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 75/500 | Train Loss: 0.6919 | Val Loss: 0.6926
#   [Train: 0.43s | Val: 0.20s | Save: 0.00s | Total: 0.63s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 76/500 | Train Loss: 0.6913 | Val Loss: 0.6918
#   [Train: 0.50s | Val: 0.23s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 77/500 | Train Loss: 0.6906 | Val Loss: 0.6921
#   [Train: 0.46s | Val: 0.24s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 78/500 | Train Loss: 0.6894 | Val Loss: 0.6905
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 79/500 | Train Loss: 0.6894 | Val Loss: 0.6908
#   [Train: 0.55s | Val: 0.21s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 80/500 | Train Loss: 0.6889 | Val Loss: 0.6907
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 81/500 | Train Loss: 0.6891 | Val Loss: 0.6900
#   [Train: 0.57s | Val: 0.24s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 82/500 | Train Loss: 0.6890 | Val Loss: 0.6911
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 83/500 | Train Loss: 0.6893 | Val Loss: 0.6895
#   [Train: 0.52s | Val: 0.24s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 84/500 | Train Loss: 0.6886 | Val Loss: 0.6909
#   [Train: 0.56s | Val: 0.21s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 85/500 | Train Loss: 0.6881 | Val Loss: 0.6898
#   [Train: 0.45s | Val: 0.22s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 86/500 | Train Loss: 0.6877 | Val Loss: 0.6909
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 87/500 | Train Loss: 0.6889 | Val Loss: 0.6902
#   [Train: 0.54s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 88/500 | Train Loss: 0.6879 | Val Loss: 0.6902
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 89/500 | Train Loss: 0.6881 | Val Loss: 0.6897
#   [Train: 0.53s | Val: 0.20s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 90/500 | Train Loss: 0.6877 | Val Loss: 0.6917
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 91/500 | Train Loss: 0.6873 | Val Loss: 0.6897
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 92/500 | Train Loss: 0.6869 | Val Loss: 0.6893
#   [Train: 0.56s | Val: 0.21s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 93/500 | Train Loss: 0.6888 | Val Loss: 0.6908
#   [Train: 0.51s | Val: 0.20s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 94/500 | Train Loss: 0.6883 | Val Loss: 0.6914
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 95/500 | Train Loss: 0.6870 | Val Loss: 0.6893
#   [Train: 0.59s | Val: 0.22s | Save: 0.01s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 96/500 | Train Loss: 0.6874 | Val Loss: 0.6907
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 97/500 | Train Loss: 0.6856 | Val Loss: 0.6897
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 98/500 | Train Loss: 0.6865 | Val Loss: 0.6895
#   [Train: 0.54s | Val: 0.20s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 99/500 | Train Loss: 0.6862 | Val Loss: 0.6890
#   [Train: 0.55s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 100/500 | Train Loss: 0.6859 | Val Loss: 0.6887
#   [Train: 0.49s | Val: 0.22s | Save: 0.01s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 101/500 | Train Loss: 0.6866 | Val Loss: 0.6891
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 102/500 | Train Loss: 0.6864 | Val Loss: 0.6892
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 103/500 | Train Loss: 0.6854 | Val Loss: 0.6893
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 104/500 | Train Loss: 0.6853 | Val Loss: 0.6901
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 105/500 | Train Loss: 0.6882 | Val Loss: 0.6909
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 106/500 | Train Loss: 0.6870 | Val Loss: 0.6891
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 107/500 | Train Loss: 0.6857 | Val Loss: 0.6895
#   [Train: 0.52s | Val: 0.25s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 108/500 | Train Loss: 0.6869 | Val Loss: 0.6903
#   [Train: 0.48s | Val: 0.22s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 109/500 | Train Loss: 0.6861 | Val Loss: 0.6885
#   [Train: 0.50s | Val: 0.22s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 110/500 | Train Loss: 0.6855 | Val Loss: 0.6888
#   [Train: 0.43s | Val: 0.20s | Save: 0.01s | Total: 0.64s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 111/500 | Train Loss: 0.6856 | Val Loss: 0.6894
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 112/500 | Train Loss: 0.6852 | Val Loss: 0.6885
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 113/500 | Train Loss: 0.6855 | Val Loss: 0.6884
#   [Train: 0.51s | Val: 0.24s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 114/500 | Train Loss: 0.6850 | Val Loss: 0.6888
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 115/500 | Train Loss: 0.6855 | Val Loss: 0.6888
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 116/500 | Train Loss: 0.6849 | Val Loss: 0.6887
#   [Train: 0.54s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 117/500 | Train Loss: 0.6848 | Val Loss: 0.6897
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 118/500 | Train Loss: 0.6860 | Val Loss: 0.6896
#   [Train: 0.57s | Val: 0.23s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 119/500 | Train Loss: 0.6850 | Val Loss: 0.6884
#   [Train: 0.46s | Val: 0.21s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 120/500 | Train Loss: 0.6849 | Val Loss: 0.6891
#   [Train: 0.57s | Val: 0.26s | Save: 0.00s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 121/500 | Train Loss: 0.6854 | Val Loss: 0.6882
#   [Train: 0.54s | Val: 0.26s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 122/500 | Train Loss: 0.6864 | Val Loss: 0.6889
#   [Train: 0.55s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 123/500 | Train Loss: 0.6850 | Val Loss: 0.6879
#   [Train: 0.53s | Val: 0.26s | Save: 0.01s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 124/500 | Train Loss: 0.6848 | Val Loss: 0.6891
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 125/500 | Train Loss: 0.6850 | Val Loss: 0.6887
#   [Train: 0.50s | Val: 0.23s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 126/500 | Train Loss: 0.6844 | Val Loss: 0.6882
#   [Train: 0.47s | Val: 0.22s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 127/500 | Train Loss: 0.6840 | Val Loss: 0.6886
#   [Train: 0.58s | Val: 0.20s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 128/500 | Train Loss: 0.6850 | Val Loss: 0.6886
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 129/500 | Train Loss: 0.6855 | Val Loss: 0.6891
#   [Train: 0.58s | Val: 0.23s | Save: 0.00s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 130/500 | Train Loss: 0.6843 | Val Loss: 0.6878
#   [Train: 0.50s | Val: 0.24s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 131/500 | Train Loss: 0.6847 | Val Loss: 0.6903
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 132/500 | Train Loss: 0.6847 | Val Loss: 0.6912
#   [Train: 0.56s | Val: 0.23s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 133/500 | Train Loss: 0.6853 | Val Loss: 0.6880
#   [Train: 0.57s | Val: 0.25s | Save: 0.00s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 134/500 | Train Loss: 0.6855 | Val Loss: 0.6886
#   [Train: 0.53s | Val: 0.25s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 135/500 | Train Loss: 0.6846 | Val Loss: 0.6888
#   [Train: 0.58s | Val: 0.21s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 136/500 | Train Loss: 0.6845 | Val Loss: 0.6886
#   [Train: 0.55s | Val: 0.23s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 137/500 | Train Loss: 0.6846 | Val Loss: 0.6893
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 138/500 | Train Loss: 0.6859 | Val Loss: 0.6888
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 139/500 | Train Loss: 0.6860 | Val Loss: 0.6880
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 140/500 | Train Loss: 0.6846 | Val Loss: 0.6892
#   [Train: 0.51s | Val: 0.24s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 141/500 | Train Loss: 0.6856 | Val Loss: 0.6880
#   [Train: 0.48s | Val: 0.25s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 142/500 | Train Loss: 0.6847 | Val Loss: 0.6891
#   [Train: 0.56s | Val: 0.23s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 143/500 | Train Loss: 0.6847 | Val Loss: 0.6893
#   [Train: 0.57s | Val: 0.22s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 144/500 | Train Loss: 0.6844 | Val Loss: 0.6883
#   [Train: 0.56s | Val: 0.23s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 145/500 | Train Loss: 0.6841 | Val Loss: 0.6886
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 146/500 | Train Loss: 0.6844 | Val Loss: 0.6890
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 147/500 | Train Loss: 0.6851 | Val Loss: 0.6889
#   [Train: 0.57s | Val: 0.27s | Save: 0.00s | Total: 0.85s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 148/500 | Train Loss: 0.6858 | Val Loss: 0.6919
#   [Train: 0.49s | Val: 0.23s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 149/500 | Train Loss: 0.6862 | Val Loss: 0.6889
#   [Train: 0.55s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 150/500 | Train Loss: 0.6837 | Val Loss: 0.6884
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 151/500 | Train Loss: 0.6838 | Val Loss: 0.6893
#   [Train: 0.58s | Val: 0.25s | Save: 0.00s | Total: 0.84s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 152/500 | Train Loss: 0.6843 | Val Loss: 0.6909
#   [Train: 0.58s | Val: 0.22s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 153/500 | Train Loss: 0.6859 | Val Loss: 0.6894
#   [Train: 0.59s | Val: 0.23s | Save: 0.01s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 154/500 | Train Loss: 0.6845 | Val Loss: 0.6880
#   [Train: 0.58s | Val: 0.20s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 155/500 | Train Loss: 0.6848 | Val Loss: 0.6886
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 156/500 | Train Loss: 0.6843 | Val Loss: 0.6894
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 157/500 | Train Loss: 0.6848 | Val Loss: 0.6883
#   [Train: 0.45s | Val: 0.23s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 158/500 | Train Loss: 0.6839 | Val Loss: 0.6906
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 159/500 | Train Loss: 0.6854 | Val Loss: 0.6879
#   [Train: 0.59s | Val: 0.22s | Save: 0.00s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 160/500 | Train Loss: 0.6850 | Val Loss: 0.6888
#   [Train: 0.58s | Val: 0.24s | Save: 0.00s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 161/500 | Train Loss: 0.6847 | Val Loss: 0.6883
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 162/500 | Train Loss: 0.6835 | Val Loss: 0.6899
#   [Train: 0.58s | Val: 0.24s | Save: 0.00s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 163/500 | Train Loss: 0.6842 | Val Loss: 0.6885
#   [Train: 0.60s | Val: 0.23s | Save: 0.00s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 164/500 | Train Loss: 0.6842 | Val Loss: 0.6892
#   [Train: 0.55s | Val: 0.25s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 165/500 | Train Loss: 0.6839 | Val Loss: 0.6887
#   [Train: 0.55s | Val: 0.21s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 166/500 | Train Loss: 0.6839 | Val Loss: 0.6907
#   [Train: 0.50s | Val: 0.19s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 167/500 | Train Loss: 0.6848 | Val Loss: 0.6893
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 168/500 | Train Loss: 0.6851 | Val Loss: 0.6886
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 169/500 | Train Loss: 0.6842 | Val Loss: 0.6888
#   [Train: 0.49s | Val: 0.20s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 170/500 | Train Loss: 0.6838 | Val Loss: 0.6896
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 171/500 | Train Loss: 0.6852 | Val Loss: 0.6906
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 172/500 | Train Loss: 0.6862 | Val Loss: 0.6904
#   [Train: 0.49s | Val: 0.21s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 173/500 | Train Loss: 0.6839 | Val Loss: 0.6894
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 174/500 | Train Loss: 0.6845 | Val Loss: 0.6883
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 175/500 | Train Loss: 0.6843 | Val Loss: 0.6880
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 176/500 | Train Loss: 0.6844 | Val Loss: 0.6890
#   [Train: 0.48s | Val: 0.22s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 177/500 | Train Loss: 0.6840 | Val Loss: 0.6925
#   [Train: 0.52s | Val: 0.19s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 178/500 | Train Loss: 0.6872 | Val Loss: 0.6927
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 179/500 | Train Loss: 0.6845 | Val Loss: 0.6883
#   [Train: 0.52s | Val: 0.20s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 180/500 | Train Loss: 0.6847 | Val Loss: 0.6892
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 181/500 | Train Loss: 0.6845 | Val Loss: 0.6896
#   [Train: 0.50s | Val: 0.25s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 182/500 | Train Loss: 0.6843 | Val Loss: 0.6892
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 183/500 | Train Loss: 0.6841 | Val Loss: 0.6886
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 184/500 | Train Loss: 0.6850 | Val Loss: 0.6885
#   [Train: 0.56s | Val: 0.21s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 185/500 | Train Loss: 0.6847 | Val Loss: 0.6883
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 186/500 | Train Loss: 0.6840 | Val Loss: 0.6888
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 187/500 | Train Loss: 0.6845 | Val Loss: 0.6886
#   [Train: 0.60s | Val: 0.20s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 188/500 | Train Loss: 0.6846 | Val Loss: 0.6888
#   [Train: 0.49s | Val: 0.23s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 189/500 | Train Loss: 0.6842 | Val Loss: 0.6885
#   [Train: 0.48s | Val: 0.24s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 190/500 | Train Loss: 0.6847 | Val Loss: 0.6884
#   [Train: 0.57s | Val: 0.23s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 191/500 | Train Loss: 0.6846 | Val Loss: 0.6889
#   [Train: 0.50s | Val: 0.24s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 192/500 | Train Loss: 0.6839 | Val Loss: 0.6893
#   [Train: 0.54s | Val: 0.25s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 193/500 | Train Loss: 0.6844 | Val Loss: 0.6884
#   [Train: 0.60s | Val: 0.23s | Save: 0.00s | Total: 0.84s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 194/500 | Train Loss: 0.6840 | Val Loss: 0.6885
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 195/500 | Train Loss: 0.6839 | Val Loss: 0.6888
#   [Train: 0.53s | Val: 0.24s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 196/500 | Train Loss: 0.6847 | Val Loss: 0.6912
#   [Train: 0.59s | Val: 0.21s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 197/500 | Train Loss: 0.6846 | Val Loss: 0.6894
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 198/500 | Train Loss: 0.6841 | Val Loss: 0.6894
#   [Train: 0.55s | Val: 0.21s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 199/500 | Train Loss: 0.6844 | Val Loss: 0.6888
#   [Train: 0.60s | Val: 0.22s | Save: 0.00s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 200/500 | Train Loss: 0.6859 | Val Loss: 0.6899
#   [Train: 0.56s | Val: 0.26s | Save: 0.00s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 201/500 | Train Loss: 0.6849 | Val Loss: 0.6890
#   [Train: 0.54s | Val: 0.19s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 202/500 | Train Loss: 0.6842 | Val Loss: 0.6886
#   [Train: 0.51s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 203/500 | Train Loss: 0.6852 | Val Loss: 0.6901
#   [Train: 0.51s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 204/500 | Train Loss: 0.6856 | Val Loss: 0.6899
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 205/500 | Train Loss: 0.6846 | Val Loss: 0.6946
#   [Train: 0.47s | Val: 0.19s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 206/500 | Train Loss: 0.6871 | Val Loss: 0.6912
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 207/500 | Train Loss: 0.6854 | Val Loss: 0.6895
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 208/500 | Train Loss: 0.6838 | Val Loss: 0.6885
#   [Train: 0.49s | Val: 0.19s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 209/500 | Train Loss: 0.6846 | Val Loss: 0.6887
#   [Train: 0.48s | Val: 0.26s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 210/500 | Train Loss: 0.6839 | Val Loss: 0.6889
#   [Train: 0.47s | Val: 0.19s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 211/500 | Train Loss: 0.6846 | Val Loss: 0.6886
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 212/500 | Train Loss: 0.6837 | Val Loss: 0.6885
#   [Train: 0.44s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 213/500 | Train Loss: 0.6843 | Val Loss: 0.6887
#   [Train: 0.49s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 214/500 | Train Loss: 0.6838 | Val Loss: 0.6888
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 215/500 | Train Loss: 0.6841 | Val Loss: 0.6898
#   [Train: 0.50s | Val: 0.25s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 216/500 | Train Loss: 0.6851 | Val Loss: 0.6917
#   [Train: 0.50s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 217/500 | Train Loss: 0.6859 | Val Loss: 0.6892
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 218/500 | Train Loss: 0.6834 | Val Loss: 0.6884
#   [Train: 0.46s | Val: 0.23s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 219/500 | Train Loss: 0.6844 | Val Loss: 0.6886
#   [Train: 0.55s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 220/500 | Train Loss: 0.6848 | Val Loss: 0.6893
#   [Train: 0.47s | Val: 0.19s | Save: 0.00s | Total: 0.66s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 221/500 | Train Loss: 0.6834 | Val Loss: 0.6893
#   [Train: 0.52s | Val: 0.21s | Save: 0.01s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 222/500 | Train Loss: 0.6837 | Val Loss: 0.6888
#   [Train: 0.55s | Val: 0.21s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 223/500 | Train Loss: 0.6844 | Val Loss: 0.6911
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 224/500 | Train Loss: 0.6854 | Val Loss: 0.6893
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 225/500 | Train Loss: 0.6843 | Val Loss: 0.6893
#   [Train: 0.54s | Val: 0.21s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 226/500 | Train Loss: 0.6840 | Val Loss: 0.6882
#   [Train: 0.42s | Val: 0.19s | Save: 0.01s | Total: 0.63s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 227/500 | Train Loss: 0.6844 | Val Loss: 0.6886
#   [Train: 0.55s | Val: 0.24s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 228/500 | Train Loss: 0.6849 | Val Loss: 0.6897
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 229/500 | Train Loss: 0.6857 | Val Loss: 0.6879
#   [Train: 0.51s | Val: 0.24s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 230/500 | Train Loss: 0.6858 | Val Loss: 0.6896
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 231/500 | Train Loss: 0.6856 | Val Loss: 0.6881
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 232/500 | Train Loss: 0.6846 | Val Loss: 0.6891
#   [Train: 0.49s | Val: 0.22s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 233/500 | Train Loss: 0.6835 | Val Loss: 0.6891
#   [Train: 0.54s | Val: 0.23s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 234/500 | Train Loss: 0.6848 | Val Loss: 0.6895
#   [Train: 0.61s | Val: 0.24s | Save: 0.00s | Total: 0.86s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 235/500 | Train Loss: 0.6845 | Val Loss: 0.6882
#   [Train: 0.54s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 236/500 | Train Loss: 0.6839 | Val Loss: 0.6885
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 237/500 | Train Loss: 0.6839 | Val Loss: 0.6891
#   [Train: 0.53s | Val: 0.24s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 238/500 | Train Loss: 0.6855 | Val Loss: 0.6883
#   [Train: 0.57s | Val: 0.27s | Save: 0.00s | Total: 0.84s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 239/500 | Train Loss: 0.6848 | Val Loss: 0.6884
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 240/500 | Train Loss: 0.6846 | Val Loss: 0.6884
#   [Train: 0.55s | Val: 0.21s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 241/500 | Train Loss: 0.6843 | Val Loss: 0.6881
#   [Train: 0.50s | Val: 0.24s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 242/500 | Train Loss: 0.6840 | Val Loss: 0.6883
#   [Train: 0.54s | Val: 0.23s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 243/500 | Train Loss: 0.6847 | Val Loss: 0.6890
#   [Train: 0.60s | Val: 0.20s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 244/500 | Train Loss: 0.6843 | Val Loss: 0.6888
#   [Train: 0.52s | Val: 0.24s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 245/500 | Train Loss: 0.6841 | Val Loss: 0.6886
#   [Train: 0.53s | Val: 0.23s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 246/500 | Train Loss: 0.6842 | Val Loss: 0.6896
#   [Train: 0.56s | Val: 0.20s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 247/500 | Train Loss: 0.6844 | Val Loss: 0.6884
#   [Train: 0.47s | Val: 0.23s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 248/500 | Train Loss: 0.6839 | Val Loss: 0.6904
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 249/500 | Train Loss: 0.6842 | Val Loss: 0.6890
#   [Train: 0.52s | Val: 0.23s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 250/500 | Train Loss: 0.6839 | Val Loss: 0.6884
#   [Train: 0.45s | Val: 0.20s | Save: 0.00s | Total: 0.65s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 251/500 | Train Loss: 0.6841 | Val Loss: 0.6884
#   [Train: 0.51s | Val: 0.25s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 252/500 | Train Loss: 0.6845 | Val Loss: 0.6897
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 253/500 | Train Loss: 0.6851 | Val Loss: 0.6894
#   [Train: 0.54s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 254/500 | Train Loss: 0.6850 | Val Loss: 0.6894
#   [Train: 0.50s | Val: 0.25s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 255/500 | Train Loss: 0.6854 | Val Loss: 0.6886
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 256/500 | Train Loss: 0.6841 | Val Loss: 0.6891
#   [Train: 0.53s | Val: 0.24s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 257/500 | Train Loss: 0.6849 | Val Loss: 0.6890
#   [Train: 0.52s | Val: 0.21s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 258/500 | Train Loss: 0.6840 | Val Loss: 0.6886
#   [Train: 0.46s | Val: 0.23s | Save: 0.01s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 259/500 | Train Loss: 0.6837 | Val Loss: 0.6897
#   [Train: 0.53s | Val: 0.25s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 260/500 | Train Loss: 0.6843 | Val Loss: 0.6888
#   [Train: 0.56s | Val: 0.24s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 261/500 | Train Loss: 0.6839 | Val Loss: 0.6889
#   [Train: 0.49s | Val: 0.23s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 262/500 | Train Loss: 0.6850 | Val Loss: 0.6892
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 263/500 | Train Loss: 0.6856 | Val Loss: 0.6903
#   [Train: 0.53s | Val: 0.23s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 264/500 | Train Loss: 0.6837 | Val Loss: 0.6886
#   [Train: 0.51s | Val: 0.23s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 265/500 | Train Loss: 0.6845 | Val Loss: 0.6887
#   [Train: 0.54s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 266/500 | Train Loss: 0.6835 | Val Loss: 0.6884
#   [Train: 0.47s | Val: 0.24s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 267/500 | Train Loss: 0.6842 | Val Loss: 0.6904
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 268/500 | Train Loss: 0.6846 | Val Loss: 0.6906
#   [Train: 0.43s | Val: 0.23s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 269/500 | Train Loss: 0.6850 | Val Loss: 0.6903
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.66s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 270/500 | Train Loss: 0.6844 | Val Loss: 0.6891
#   [Train: 0.54s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 271/500 | Train Loss: 0.6838 | Val Loss: 0.6888
#   [Train: 0.51s | Val: 0.23s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 272/500 | Train Loss: 0.6838 | Val Loss: 0.6885
#   [Train: 0.53s | Val: 0.20s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 273/500 | Train Loss: 0.6840 | Val Loss: 0.6889
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# ...
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 402/500 | Train Loss: 0.6843 | Val Loss: 0.6890
#   [Train: 0.53s | Val: 0.20s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 403/500 | Train Loss: 0.6842 | Val Loss: 0.6887
#   [Train: 0.46s | Val: 0.20s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 404/500 | Train Loss: 0.6844 | Val Loss: 0.6890
#   [Train: 0.54s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 405/500 | Train Loss: 0.6842 | Val Loss: 0.6891
#   [Train: 0.53s | Val: 0.25s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 406/500 | Train Loss: 0.6843 | Val Loss: 0.6884
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 407/500 | Train Loss: 0.6845 | Val Loss: 0.6899
#   [Train: 0.45s | Val: 0.19s | Save: 0.00s | Total: 0.65s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 408/500 | Train Loss: 0.6856 | Val Loss: 0.6885
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 409/500 | Train Loss: 0.6852 | Val Loss: 0.6880
#   [Train: 0.54s | Val: 0.21s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 410/500 | Train Loss: 0.6840 | Val Loss: 0.6893
#   [Train: 0.54s | Val: 0.19s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 411/500 | Train Loss: 0.6847 | Val Loss: 0.6888
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 412/500 | Train Loss: 0.6848 | Val Loss: 0.6884
#   [Train: 0.47s | Val: 0.21s | Save: 0.01s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 413/500 | Train Loss: 0.6850 | Val Loss: 0.6883
#   [Train: 0.55s | Val: 0.20s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 414/500 | Train Loss: 0.6850 | Val Loss: 0.6887
#   [Train: 0.56s | Val: 0.23s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 415/500 | Train Loss: 0.6838 | Val Loss: 0.6904
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 416/500 | Train Loss: 0.6847 | Val Loss: 0.6892
#   [Train: 0.54s | Val: 0.23s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 417/500 | Train Loss: 0.6848 | Val Loss: 0.6890
#   [Train: 0.49s | Val: 0.21s | Save: 0.01s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 418/500 | Train Loss: 0.6851 | Val Loss: 0.6888
#   [Train: 0.46s | Val: 0.19s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 419/500 | Train Loss: 0.6847 | Val Loss: 0.6897
#   [Train: 0.54s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 420/500 | Train Loss: 0.6848 | Val Loss: 0.6882
#   [Train: 0.45s | Val: 0.21s | Save: 0.00s | Total: 0.67s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 421/500 | Train Loss: 0.6839 | Val Loss: 0.6886
#   [Train: 0.44s | Val: 0.23s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 422/500 | Train Loss: 0.6836 | Val Loss: 0.6885
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 423/500 | Train Loss: 0.6840 | Val Loss: 0.6885
#   [Train: 0.51s | Val: 0.20s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 424/500 | Train Loss: 0.6845 | Val Loss: 0.6888
#   [Train: 0.50s | Val: 0.22s | Save: 0.01s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 425/500 | Train Loss: 0.6840 | Val Loss: 0.6900
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 426/500 | Train Loss: 0.6845 | Val Loss: 0.6888
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 427/500 | Train Loss: 0.6838 | Val Loss: 0.6896
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 428/500 | Train Loss: 0.6852 | Val Loss: 0.6889
#   [Train: 0.53s | Val: 0.23s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 429/500 | Train Loss: 0.6848 | Val Loss: 0.6885
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 430/500 | Train Loss: 0.6852 | Val Loss: 0.6885
#   [Train: 0.51s | Val: 0.23s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 431/500 | Train Loss: 0.6840 | Val Loss: 0.6891
#   [Train: 0.50s | Val: 0.21s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 432/500 | Train Loss: 0.6841 | Val Loss: 0.6884
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 433/500 | Train Loss: 0.6843 | Val Loss: 0.6882
#   [Train: 0.49s | Val: 0.19s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 434/500 | Train Loss: 0.6838 | Val Loss: 0.6889
#   [Train: 0.52s | Val: 0.20s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 435/500 | Train Loss: 0.6838 | Val Loss: 0.6888
#   [Train: 0.47s | Val: 0.19s | Save: 0.01s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 436/500 | Train Loss: 0.6843 | Val Loss: 0.6889
#   [Train: 0.54s | Val: 0.23s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 437/500 | Train Loss: 0.6872 | Val Loss: 0.6883
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 438/500 | Train Loss: 0.6854 | Val Loss: 0.6913
#   [Train: 0.46s | Val: 0.22s | Save: 0.00s | Total: 0.68s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 439/500 | Train Loss: 0.6853 | Val Loss: 0.6923
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 440/500 | Train Loss: 0.6846 | Val Loss: 0.6894
#   [Train: 0.55s | Val: 0.22s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 441/500 | Train Loss: 0.6842 | Val Loss: 0.6894
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 442/500 | Train Loss: 0.6848 | Val Loss: 0.6886
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 443/500 | Train Loss: 0.6851 | Val Loss: 0.6891
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 444/500 | Train Loss: 0.6845 | Val Loss: 0.6892
#   [Train: 0.50s | Val: 0.23s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 445/500 | Train Loss: 0.6844 | Val Loss: 0.6902
#   [Train: 0.47s | Val: 0.22s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 446/500 | Train Loss: 0.6846 | Val Loss: 0.6883
#   [Train: 0.50s | Val: 0.23s | Save: 0.01s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 447/500 | Train Loss: 0.6841 | Val Loss: 0.6882
#   [Train: 0.55s | Val: 0.21s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 448/500 | Train Loss: 0.6841 | Val Loss: 0.6898
#   [Train: 0.49s | Val: 0.23s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 449/500 | Train Loss: 0.6847 | Val Loss: 0.6888
#   [Train: 0.48s | Val: 0.20s | Save: 0.00s | Total: 0.69s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 450/500 | Train Loss: 0.6841 | Val Loss: 0.6892
#   [Train: 0.49s | Val: 0.25s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 451/500 | Train Loss: 0.6835 | Val Loss: 0.6895
#   [Train: 0.52s | Val: 0.21s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 452/500 | Train Loss: 0.6852 | Val Loss: 0.6885
#   [Train: 0.51s | Val: 0.19s | Save: 0.00s | Total: 0.70s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 453/500 | Train Loss: 0.6847 | Val Loss: 0.6896
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 454/500 | Train Loss: 0.6846 | Val Loss: 0.6887
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 455/500 | Train Loss: 0.6839 | Val Loss: 0.6882
#   [Train: 0.55s | Val: 0.26s | Save: 0.00s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 456/500 | Train Loss: 0.6839 | Val Loss: 0.6895
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 457/500 | Train Loss: 0.6835 | Val Loss: 0.6886
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 458/500 | Train Loss: 0.6849 | Val Loss: 0.6900
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 459/500 | Train Loss: 0.6848 | Val Loss: 0.6894
#   [Train: 0.51s | Val: 0.24s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 460/500 | Train Loss: 0.6851 | Val Loss: 0.6877
#   [Train: 0.55s | Val: 0.21s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 461/500 | Train Loss: 0.6848 | Val Loss: 0.6895
#   [Train: 0.55s | Val: 0.25s | Save: 0.01s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 462/500 | Train Loss: 0.6845 | Val Loss: 0.6897
#   [Train: 0.55s | Val: 0.24s | Save: 0.01s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 463/500 | Train Loss: 0.6840 | Val Loss: 0.6888
#   [Train: 0.56s | Val: 0.27s | Save: 0.00s | Total: 0.84s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 464/500 | Train Loss: 0.6837 | Val Loss: 0.6886
#   [Train: 0.55s | Val: 0.23s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 465/500 | Train Loss: 0.6838 | Val Loss: 0.6889
#   [Train: 0.52s | Val: 0.24s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 466/500 | Train Loss: 0.6852 | Val Loss: 0.6887
#   [Train: 0.52s | Val: 0.27s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 467/500 | Train Loss: 0.6850 | Val Loss: 0.6884
#   [Train: 0.52s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 468/500 | Train Loss: 0.6850 | Val Loss: 0.6918
#   [Train: 0.53s | Val: 0.22s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 469/500 | Train Loss: 0.6859 | Val Loss: 0.6924
#   [Train: 0.52s | Val: 0.23s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 470/500 | Train Loss: 0.6853 | Val Loss: 0.6896
#   [Train: 0.51s | Val: 0.22s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 471/500 | Train Loss: 0.6835 | Val Loss: 0.6879
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 472/500 | Train Loss: 0.6843 | Val Loss: 0.6916
#   [Train: 0.55s | Val: 0.23s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 473/500 | Train Loss: 0.6845 | Val Loss: 0.6889
#   [Train: 0.51s | Val: 0.24s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 474/500 | Train Loss: 0.6839 | Val Loss: 0.6894
#   [Train: 0.47s | Val: 0.23s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 475/500 | Train Loss: 0.6856 | Val Loss: 0.6899
#   [Train: 0.48s | Val: 0.22s | Save: 0.00s | Total: 0.71s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 476/500 | Train Loss: 0.6849 | Val Loss: 0.6892
#   [Train: 0.53s | Val: 0.23s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 477/500 | Train Loss: 0.6842 | Val Loss: 0.6884
#   [Train: 0.54s | Val: 0.21s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 478/500 | Train Loss: 0.6845 | Val Loss: 0.6885
#   [Train: 0.55s | Val: 0.20s | Save: 0.00s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 479/500 | Train Loss: 0.6839 | Val Loss: 0.6891
#   [Train: 0.50s | Val: 0.22s | Save: 0.00s | Total: 0.73s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 480/500 | Train Loss: 0.6843 | Val Loss: 0.6880
#   [Train: 0.49s | Val: 0.24s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 481/500 | Train Loss: 0.6841 | Val Loss: 0.6909
#   [Train: 0.50s | Val: 0.23s | Save: 0.01s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 482/500 | Train Loss: 0.6855 | Val Loss: 0.6883
#   [Train: 0.57s | Val: 0.24s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 483/500 | Train Loss: 0.6840 | Val Loss: 0.6887
#   [Train: 0.55s | Val: 0.26s | Save: 0.01s | Total: 0.83s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 484/500 | Train Loss: 0.6844 | Val Loss: 0.6888
#   [Train: 0.55s | Val: 0.22s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 485/500 | Train Loss: 0.6839 | Val Loss: 0.6886
#   [Train: 0.55s | Val: 0.26s | Save: 0.01s | Total: 0.82s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 486/500 | Train Loss: 0.6856 | Val Loss: 0.6906
#   [Train: 0.54s | Val: 0.24s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 487/500 | Train Loss: 0.6857 | Val Loss: 0.6898
#   [Train: 0.51s | Val: 0.25s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 488/500 | Train Loss: 0.6847 | Val Loss: 0.6881
#   [Train: 0.52s | Val: 0.24s | Save: 0.00s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 489/500 | Train Loss: 0.6833 | Val Loss: 0.6883
#   [Train: 0.53s | Val: 0.21s | Save: 0.00s | Total: 0.75s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 490/500 | Train Loss: 0.6841 | Val Loss: 0.6883
#   [Train: 0.56s | Val: 0.23s | Save: 0.00s | Total: 0.81s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 491/500 | Train Loss: 0.6841 | Val Loss: 0.6899
#   [Train: 0.54s | Val: 0.23s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 492/500 | Train Loss: 0.6855 | Val Loss: 0.6897
#   [Train: 0.51s | Val: 0.20s | Save: 0.00s | Total: 0.72s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 493/500 | Train Loss: 0.6840 | Val Loss: 0.6881
#   [Train: 0.53s | Val: 0.24s | Save: 0.01s | Total: 0.78s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 494/500 | Train Loss: 0.6842 | Val Loss: 0.6893
#   [Train: 0.56s | Val: 0.22s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 495/500 | Train Loss: 0.6841 | Val Loss: 0.6910
#   [Train: 0.54s | Val: 0.24s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 496/500 | Train Loss: 0.6836 | Val Loss: 0.6890
#   [Train: 0.57s | Val: 0.23s | Save: 0.00s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 497/500 | Train Loss: 0.6837 | Val Loss: 0.6885
#   [Train: 0.52s | Val: 0.23s | Save: 0.01s | Total: 0.77s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 498/500 | Train Loss: 0.6837 | Val Loss: 0.6883
#   [Train: 0.50s | Val: 0.23s | Save: 0.00s | Total: 0.74s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 499/500 | Train Loss: 0.6844 | Val Loss: 0.6888
#   [Train: 0.56s | Val: 0.23s | Save: 0.01s | Total: 0.80s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 500/500 | Train Loss: 0.6857 | Val Loss: 0.6896
#   [Train: 0.55s | Val: 0.21s | Save: 0.00s | Total: 0.78s]

# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs

# %%
show_training_history(conf_dict,EXPERIMENT_DIR)

# %% [markdown]
# ## 6.2 inspect transformation function for source nodes h()

# %%
show_hdag_for_source_nodes(conf_dict,EXPERIMENT_DIR,device=device,xmin_plot=-2,xmax_plot=2) # TODO for other nodes funciton
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# h() for  x1:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# h() for  x2:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# h() for  x3:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x4 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(conf_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# Train loader (x1): 100%|██████████| 2/2 [00:00<00:00,  3.14it/s]
# Val loader (x1): 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# Train loader (x2): 100%|██████████| 2/2 [00:00<00:00,  5.83it/s]
# Val loader (x2): 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--
# Train loader (x3): 100%|██████████| 2/2 [00:00<00:00,  6.08it/s]
# Val loader (x3): 100%|██████████| 1/1 [00:00<00:00,  3.90it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x4 ------------*-----------------*-------------------*--
# Train loader (x4): 100%|██████████| 2/2 [00:00<00:00,  4.35it/s]
# Val loader (x4): 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]

# %% [markdown]
# ### Coefficient estimates

# %%
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # enable 3D plotting

# --- Your existing setup ---
verbose    = False
batch_size = 4112
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# this x is only for overlaying your target curve in 2D plots
x1d = torch.linspace(-1, 1, steps=1000).unsqueeze(1).to(device)  # (1000, 1)
def f(x):
    return 0.75 * np.arctan(5 * (x + 0.12))

for node in conf_dict:
    print(f"\n---- check CS of {node} ----")
    if conf_dict[node]['node_type'] == 'source':
        print("Node type: source — skipping.")
        continue

    # load your model
    NODE_DIR   = os.path.join(EXPERIMENT_DIR, node)
    model_path = os.path.join(NODE_DIR, "best_model.pt")
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose).to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()


    for i, module in enumerate(tram_model.nn_shift):
        name = module.__class__.__name__
        print(f"\nModule {i}: {name}")
        print(module)

        if name == 'LinearShift':
            print("  LinearShift weights:")
            print(module.fc.weight.data)
            continue

        # read wanted input dims
        in_feats = module.fc1.in_features
        print(f"  expects input shape = (batch_size, {in_feats})")

        # 2-input case → 3D surface plot
        if in_feats == 2:
            N = 100
            a = torch.linspace(0, 2, steps=N, device=device)
            b = torch.linspace(0, 2, steps=N, device=device)
            A, B = torch.meshgrid(a, b, indexing='ij')       # both (N, N)
            grid = torch.stack([A, B], dim=-1).view(-1, 2)   # (N*N, 2)

            with torch.no_grad():
                Y = module(grid).view(N, N).cpu().numpy()    # back to (N, N)

            A_np = A.cpu().numpy()
            B_np = B.cpu().numpy()

            fig = plt.figure()
            ax  = fig.add_subplot(111, projection='3d')
            ax.plot_surface(A_np, B_np, Y, cmap='viridis', edgecolor='none')
            ax.set_xlabel('input 1')
            ax.set_ylabel('input 2')
            ax.set_zlabel(f'{name}(x₁, x₂)')
            ax.set_title(f"{node} | Module {i}: {name} (3D surface)")
            plt.show()

        # 1-input case → 2D scatter
        else:
            N = 1000
            lin = torch.linspace(-1, 1, steps=N, device=device)
            dummy = lin.unsqueeze(1).repeat(1, in_feats)      # (N, in_feats)

            with torch.no_grad():
                y = module(dummy).squeeze().cpu().numpy()

            plt.figure()
            plt.scatter(dummy[:, 0].cpu().numpy(), y, s=5, label=f"{name} output")
            # overlay target
            plt.scatter(x1d.cpu().numpy(), -f(x1d.cpu().numpy()), c="red", s=5, label="target")
            plt.xlabel("input value")
            plt.ylabel("output value")
            plt.title(f"{node} | Module {i}: {name} (2D)")
            plt.legend()
            plt.show()
# Out:
# ---- check CS of x1 ----
# Node type: source — skipping.
#
# ---- check CS of x2 ----
# Node type: source — skipping.
#
# ---- check CS of x3 ----
# Node type: source — skipping.
#
# ---- check CS of x4 ----
#
# Module 0: ComplexShiftDefaultTabular
# ComplexShiftDefaultTabular(
#   (fc1): Linear(in_features=2, out_features=64, bias=True)
#   (relu1): ReLU()
#   (dropout1): Dropout(p=0.3, inplace=False)
#   (fc2): Linear(in_features=64, out_features=128, bias=True)
#   (relu2): ReLU()
#   (dropout2): Dropout(p=0.3, inplace=False)
#   (fc3): Linear(in_features=128, out_features=64, bias=True)
#   (relu3): ReLU()
#   (dropout3): Dropout(p=0.3, inplace=False)
#   (fc4): Linear(in_features=64, out_features=1, bias=False)
# )
#   expects input shape = (batch_size, 2)
# Module 1: LinearShift
# LinearShift(
#   (fc): Linear(in_features=1, out_features=1, bias=False)
# )
#   LinearShift weights:
# tensor([[0.0310]], device='cuda:0')

# %% [markdown]
# # 7. Sample from Graph

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            n= 10_000,
                            batch_size = 1,
                            delete_all_previously_sampled=True,
                            verbose=True)
# Out:
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/interactions_small/x1/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/interactions_small/x2/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/interactions_small/x3/sampling
# Directory does not exist: /home/bule/TramDag/dev_experiment_logs/interactions_small/x4/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/interactions_small/x1/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# h() for samples in  x1: 100%|██████████| 10000/10000 [00:02<00:00, 4855.64it/s]
# source node, Defaults to SI and 1 as inputs
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:31<00:00, 321.02it/s]
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/interactions_small/x2/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# h() for samples in  x2: 100%|██████████| 10000/10000 [00:01<00:00, 5610.11it/s]
# source node, Defaults to SI and 1 as inputs
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:31<00:00, 319.70it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/interactions_small/x3/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# h() for samples in  x3: 100%|██████████| 10000/10000 [00:01<00:00, 5918.07it/s]
# source node, Defaults to SI and 1 as inputs
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:30<00:00, 323.45it/s]
# /home/bule/TramDag/utils/sampling_tram_data.py:47: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# ----*----------*-------------*--------Sample Node: x4 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/interactions_small/x4/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=2, out_features=64, bias=True)
#       (relu1): ReLU()
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (fc2): Linear(in_features=64, out_features=128, bias=True)
#       (relu2): ReLU()
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (fc3): Linear(in_features=128, out_features=64, bias=True)
#       (relu3): ReLU()
#       (dropout3): Dropout(p=0.3, inplace=False)
#       (fc4): Linear(in_features=64, out_features=1, bias=False)
#     )
#     (1): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x4:   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sample_full_dag_chandru(conf_dict,
#       2                             EXPERIMENT_DIR,
#       3                             device,
#       4                             n= 10_000,
#       5                             batch_size = 1,
#       6                             delete_all_previously_sampled=True,
#       7                             verbose=True)
#
# File ~/TramDag/utils/sampling_tram_data.py:583, in sample_full_dag_chandru(conf_dict, EXPERIMENT_DIR, device, do_interventions, n, batch_size, delete_all_previously_sampled, verbose)
#     581         x = [xi.to(device) for xi in x]
#     582         int_input, shift_list = preprocess_inputs(x,ordered_transformation_terms_in_h.values(), device=device)
# --> 583         model_outputs = tram_model(int_input=int_input, shift_input=shift_list)
#     584         output_list.append(model_outputs)
#     586 if conf_dict[node]['node_type'] == 'source':
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/TramDag/utils/tram_models.py:44, in TramModel.forward(self, int_input, shift_input)
#      42 for i, shift_model in enumerate(self.nn_shift):
#      43     shift_model = shift_model.to(self.device)
# ---> 44     out = shift_model(shift_input[i])
#      45     shift_out.append(out)
#      47 return {'int_out': int_out, 'shift_out': shift_out}
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/TramDag/utils/tram_models.py:166, in ComplexShiftDefaultTabular.forward(self, x)
#     157 def forward(self, x):
#     158     """
#     159     Forward pass through the network.
#     160     Args:
#    (...)
#     164         Tensor: Output tensor of shape (batch_size, 1)
#     165     """
# --> 166     x = self.fc1(x)
#     167     x = self.relu1(x)
#     168     x = self.dropout1(x)
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/tramdag/lib/python3.9/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (2x1 and 2x64)

# %% [markdown]
# ## 7.3 Inspect Sampling

# %%
show_samples_vs_true(test_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')

# %% [markdown]
# ## 7.4 Intervention

# %%
def f(x):
    return -0.3*x  

intervention_df=dgp(10_000, doX=[-1.0, None, None], seed=-1)
sns.pairplot(intervention_df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            do_interventions={'x1':-1.0},
                            n= 10_000,
                            batch_size = 32,
                            delete_all_previously_sampled=True,
                            verbose=True)

# %%
show_samples_vs_true(intervention_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')
