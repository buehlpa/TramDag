# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from scipy.stats import logistic
from scipy.special import logit

import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
from torch.cuda.amp import autocast, GradScaler

if torch.cuda.is_available():
    device = torch.device('cuda')
    print("Train with GPU support.")
else:
    device = torch.device('cpu')
    print("No GPU found, train with CPU support.")

import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt


# own utils
from utils.graph import *
from utils.tram_models import *
from utils.tram_model_helpers import *
from utils.tram_data import *
from utils.continous import *
from utils.sampling_tram_data import *
# Out:
# Train with GPU support.

# %% [markdown]
# # 1. Experiments and Paths

# %%
experiment_name = "do_interventions"   ## <--- set experiment name
seed=42
np.random.seed(seed)

DATA_PATH = "/home/bule/TramDag/data"
LOG_DIR="/home/bule/TramDag/dev_experiment_logs"
EXPERIMENT_DIR = os.path.join(LOG_DIR, experiment_name)
os.makedirs(EXPERIMENT_DIR,exist_ok=True)

# %% [markdown]
# # 2.  Data
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
# - provide data in the form of a pandas dataframe, if there are iamges add the paths to each image to the df
#
# ![image.png](attachment:image.png)

# %% [markdown]
# they made 3 experiments:
# 1. Linear-shift DGP and linear-shift model
# 2. Complex-shift DGP and complex-shift model
# 3. Linear-shift DGP and complex-shift model

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Linear-shift DGP and linear-shift model 
def f(x):
    return -0.3*x  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    
    # h(x1)= SI 
    
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])



    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        z2 = logit(u2)
        x2 = (z2 - 2 * x1) / 5#5#   0.42  in the trainagle strucutred cont last line is 5 for SI
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 -f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          - f(X2)        | replace h(x2|x1) with z
    # z3          = 0.63*x3 + beta3 * x1          - f(X2)        | reformulate to x2
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z3+0.2 * x1   +f(X2))/0.63                   | 

    
    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        z3 = logit(u3)
        x3 = (z3 + 0.2 * x1 + f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])
        
    #df = pd.DataFrame({'x1': x1, 'x2': x2})#, 'x3': x3})
    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df

n_obs=1_000

df = dgp(n_obs=n_obs, seed=42)

EXP_DATA_PATH=os.path.join(EXPERIMENT_DIR, f"{experiment_name}.csv")


if not os.path.exists(EXP_DATA_PATH):
    df = dgp(n_obs=n_obs)

    print(df.head())
    df.to_csv(EXP_DATA_PATH, index=False)

else:
    df = pd.read_csv(EXP_DATA_PATH)
    print(f"Loaded data from {EXP_DATA_PATH}")


sns.pairplot(df)
plt.suptitle("", y=1.02)
plt.tight_layout()
plt.show()
# Out:
# Setting Seed: 42
# Loaded data from /home/bule/TramDag/dev_experiment_logs/do_interventions/do_interventions.csv

# %% [markdown]
# ## 2.1 train test split

# %%
# 1. Split the data
train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)

# 2. Compute quantiles from training data
quantiles = train_df.quantile([0.05, 0.95])
min_vals = quantiles.loc[0.05]
max_vals = quantiles.loc[0.95]

# 3. Normalize all sets using training quantiles
def normalize_with_quantiles(df, min_vals, max_vals):
    return (df - min_vals) / (max_vals - min_vals)

# train_df = normalize_with_quantiles(train_df, min_vals, max_vals)
# val_df = normalize_with_quantiles(val_df, min_vals, max_vals)
# test_df = normalize_with_quantiles(test_df, min_vals, max_vals)

print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Train size: 800, Validation size: 100, Test size: 100

# %% [markdown]
# # 3. Define graph Structure
#
# - define graph and which shift and intercept terms to use

# %%
# describe if data is continous or  ordinal  ['cont', 'ord','other']
# note that other data than tabular can only be used as source 

# TODO support for interactions in CI model eg CI_1

# Example 1 dgp tramdag paper  3x3: 
data_type={'x1':'cont','x2':'cont','x3':'cont'}  # continous , images , ordinal
# data_type={'x1':'cont','x2':'cont'}  # continous , images , ordinal

adj_matrix = np.array([
    [ "0", "ls", "cs"],  # A -> B (cs), A -> C (ls)
    [ "0", "0", "ls"],  # B -> D (ls)
    [ "0", "0", "0"],  # C -> D (cs)
], object)

# adj_matrix = np.array([
#     [ "0", "ls"],  # A -> B (cs), A -> C (ls)
#     [ "0", "0" ]  # B -> D (ls)  # C -> D (cs)
# ], object)


# its also possible to have ci11 and ci12 etc to inlcude multiple varibales for a network for the intercept. aswell as for cs name it with ci11 ci12

plot_seed=5
plot_dag(adj_matrix,data_type, seed=plot_seed)

# %% [markdown]
# # 4. Configuration for the Models
#
# - all SI and LS model are generated outmatically since these are shallow NN's
# - CI and CS have to be defined by the User and can be Passed for each model, -> generate default networks which are generated automaitcally

# %%
# check if there are Ci or Compelx shifts in the models. If yes define the modelnames
nn_names_matrix= create_nn_model_names(adj_matrix,data_type)
plot_nn_names_matrix(nn_names_matrix,data_type)
# Out:
# *************
#  Model has Complex intercepts and Coomplex shifts , please add your Model to the modelzoo
# ************

# %%
#TODO : OPTION write config to a argparser to  and args object to pass datatypes

conf_dict=get_configuration_dict(adj_matrix,nn_names_matrix, data_type)
# write min max to conf dict
for i,node in enumerate(data_type.keys()):
    conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
    conf_dict[node]['max']=max_vals[i].tolist()
    

# write to file
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"{experiment_name}_conf.json")
with open(CONF_DICT_PATH, 'w') as f:
    json.dump(conf_dict, f, indent=4)
    
print(f"Configuration saved to {CONF_DICT_PATH}")

conf_dict
# Out:
# Configuration saved to /home/bule/TramDag/dev_experiment_logs/do_interventions/do_interventions_conf.json
# /tmp/ipykernel_2300916/1695834966.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['min']=min_vals[i].tolist()   # <---- TODO add quanitle marker
# /tmp/ipykernel_2300916/1695834966.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   conf_dict[node]['max']=max_vals[i].tolist()
# {'x1': {'Modelnr': 0,
#   'data_type': 'cont',
#   'node_type': 'source',
#   'parents': [],
#   'parents_datatype': {},
#   'transformation_terms_in_h()': {},
#   'transformation_term_nn_models_in_h()': {},
#   'min': 0.11328144104347268,
#   'max': 0.7896745501534419},
#  'x2': {'Modelnr': 1,
#   'data_type': 'cont',
#   'node_type': 'internal',
#   'parents': ['x1'],
#   'parents_datatype': {'x1': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'LinearShift'},
#   'min': -0.8359509892028653,
#   'max': 0.39512270390329024},
#  'x3': {'Modelnr': 2,
#   'data_type': 'cont',
#   'node_type': 'sink',
#   'parents': ['x1', 'x2'],
#   'parents_datatype': {'x1': 'cont', 'x2': 'cont'},
#   'transformation_terms_in_h()': {'x1': 'cs', 'x2': 'ls'},
#   'transformation_term_nn_models_in_h()': {'x1': 'ComplexShiftDefaultTabular',
#    'x2': 'LinearShift'},
#   'min': -4.576359793833365,
#   'max': 4.628108395764199}}

# %%
DEV_TRAINING=True
train_list=['x1','x2','x3']#['x2']#'x1','x2']#,'x3']#['x1']#['x1','x2','x3']#,#,['x1','x2','x3'] # <-  set the nodes which have to be trained , useful if further training is required else lsit all vars

batch_size = 512#4112
epochs = 100 # <- if you want a higher numbe rof epochs, set the number higher and it loads the old model and starts from there
learning_rate=0.1
use_scheduler =  False

# %%
# For each NODE 
for node in conf_dict:
    
    print(f'\n----*----------*-------------*--------------- Node: {node} ------------*-----------------*-------------------*--')
    
    ########################## 0. Skip nodes ###############################
    if node not in train_list:# Skip if node is not in train_list
        print(f"Skipping node {node} as it's not in the training list.")
        continue
    if (conf_dict[node]['node_type'] == 'source') and (conf_dict[node]['node_type'] == 'other'):# Skip unsupported types
        print(f"Node type : other , is not supported yet")
        continue

    ########################## 1. Setup Paths ###############################
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    os.makedirs(NODE_DIR, exist_ok=True)
    MODEL_PATH, LAST_MODEL_PATH, TRAIN_HIST_PATH, VAL_HIST_PATH = model_train_val_paths(NODE_DIR)

    ########################## 2. Create Model ##############################
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=True).to(device)
    #tram_model =get_fully_specified_tram_model_hardcoded_init_weights_for_si(node, conf_dict, verbose=True).to(device)


    ########################## 3. Create Dataloaders ########################
    train_loader, val_loader = get_dataloader(node, conf_dict, train_df, val_df, batch_size=batch_size, verbose=True)

    ########################## 4. Load Model & History ######################
    if os.path.exists(MODEL_PATH) and os.path.exists(TRAIN_HIST_PATH) and os.path.exists(VAL_HIST_PATH):
        print("Existing model found. Loading weights and history...")
        tram_model.load_state_dict(torch.load(MODEL_PATH))

        with open(TRAIN_HIST_PATH, 'r') as f:
            train_loss_hist = json.load(f)
        with open(VAL_HIST_PATH, 'r') as f:
            val_loss_hist = json.load(f)

        start_epoch = len(train_loss_hist)
        best_val_loss = min(val_loss_hist)
        print(f"Continuing training from epoch {start_epoch}...")
    else:
        print("No existing model found. Starting fresh...")
        train_loss_hist, val_loss_hist = [], []
        start_epoch = 0
        best_val_loss = float('inf')

    # Skip if already trained
    if start_epoch >= epochs:
        print(f"Node {node} already trained for {epochs} epochs. Skipping.")
        continue

    ########################## 5. Optimizer & Scheduler ######################.
    
    ## <---------- TODO use standard SGD and no scheduler
    # optimizer = torch.optim.AdamW(tram_model.parameters(), lr=0.1, eps=1e-8, weight_decay=1e-2)
    # optimizer = torch.optim.AdamW(
    # tram_model.parameters(),
    # lr=1e-3,           # ← two orders of magnitude smaller
    # eps=1e-8,
    # weight_decay=1e-2
    # )   
    optimizer =torch.optim.Adam(tram_model.parameters(), lr=learning_rate)
    
    if use_scheduler:
        scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1)
        #scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer,max_lr=1e-3, total_steps=epochs * len(train_loader),pct_start=0.1, anneal_strategy="cos"       # pick your sweet-spot

    else:
        scheduler = None

    ########################## 6. Min/Max Tensor #############################
    min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
    max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
    min_max = torch.stack([min_vals, max_vals], dim=0)

    ########################## 7. Training Loop ##############################

    if DEV_TRAINING:
        train_val_loop(
            start_epoch,
            epochs,
            tram_model,
            train_loader,
            val_loader,
            train_loss_hist,
            val_loss_hist,
            best_val_loss,
            device,
            optimizer,
            use_scheduler,
            scheduler,
            min_max,
            NODE_DIR,
            save_linear_shifts=True
        )
# Out:
# ----*----------*-------------*--------------- Node: x1 ------------*-----------------*-------------------*--
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# >>>>>>>>>>>>  source node --> x in dataloader contains just 1s
# No existing model found. Starting fresh...
# Saved new best model.
# Epoch 1/100 | Train Loss: 1.3685 | Val Loss: 1.2658
#   [Train: 1.29s | Val: 0.66s | Save: 0.00s | Total: 1.95s]
# Saved new best model.
# Epoch 2/100 | Train Loss: 1.2366 | Val Loss: 1.1408
#   [Train: 0.63s | Val: 0.53s | Save: 0.00s | Total: 1.17s]
# Saved new best model.
# Epoch 3/100 | Train Loss: 1.1162 | Val Loss: 1.0251
#   [Train: 0.60s | Val: 0.37s | Save: 0.01s | Total: 0.98s]
# Saved new best model.
# Epoch 4/100 | Train Loss: 1.0018 | Val Loss: 0.9191
#   [Train: 0.46s | Val: 0.45s | Save: 0.01s | Total: 0.92s]
# Saved new best model.
# Epoch 5/100 | Train Loss: 0.8976 | Val Loss: 0.8229
#   [Train: 0.81s | Val: 0.31s | Save: 0.01s | Total: 1.13s]
# Saved new best model.
# Epoch 6/100 | Train Loss: 0.8045 | Val Loss: 0.7365
#   [Train: 0.57s | Val: 0.42s | Save: 0.00s | Total: 0.99s]
# Saved new best model.
# Epoch 7/100 | Train Loss: 0.7218 | Val Loss: 0.6595
#   [Train: 0.67s | Val: 0.33s | Save: 0.00s | Total: 1.01s]
# Saved new best model.
# Epoch 8/100 | Train Loss: 0.6460 | Val Loss: 0.5912
#   [Train: 0.42s | Val: 0.59s | Save: 0.00s | Total: 1.02s]
# Saved new best model.
# Epoch 9/100 | Train Loss: 0.5819 | Val Loss: 0.5304
#   [Train: 0.56s | Val: 0.35s | Save: 0.01s | Total: 0.92s]
# Saved new best model.
# Epoch 10/100 | Train Loss: 0.5232 | Val Loss: 0.4765
#   [Train: 0.61s | Val: 0.45s | Save: 0.01s | Total: 1.06s]
# Saved new best model.
# Epoch 11/100 | Train Loss: 0.4678 | Val Loss: 0.4282
#   [Train: 0.51s | Val: 0.62s | Save: 0.00s | Total: 1.13s]
# Saved new best model.
# Epoch 12/100 | Train Loss: 0.4247 | Val Loss: 0.3849
#   [Train: 0.51s | Val: 0.39s | Save: 0.00s | Total: 0.91s]
# Saved new best model.
# Epoch 13/100 | Train Loss: 0.3784 | Val Loss: 0.3459
#   [Train: 0.63s | Val: 0.40s | Save: 0.00s | Total: 1.04s]
# Saved new best model.
# Epoch 14/100 | Train Loss: 0.3433 | Val Loss: 0.3103
#   [Train: 0.54s | Val: 0.64s | Save: 0.01s | Total: 1.19s]
# Saved new best model.
# Epoch 15/100 | Train Loss: 0.3104 | Val Loss: 0.2778
#   [Train: 0.44s | Val: 0.36s | Save: 0.00s | Total: 0.80s]
# Saved new best model.
# Epoch 16/100 | Train Loss: 0.2750 | Val Loss: 0.2480
#   [Train: 0.56s | Val: 0.42s | Save: 0.00s | Total: 0.99s]
# Saved new best model.
# Epoch 17/100 | Train Loss: 0.2529 | Val Loss: 0.2205
#   [Train: 0.67s | Val: 0.58s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 18/100 | Train Loss: 0.2218 | Val Loss: 0.1951
#   [Train: 0.53s | Val: 0.40s | Save: 0.00s | Total: 0.93s]
# Saved new best model.
# Epoch 19/100 | Train Loss: 0.1947 | Val Loss: 0.1714
#   [Train: 0.55s | Val: 0.33s | Save: 0.00s | Total: 0.89s]
# Saved new best model.
# Epoch 20/100 | Train Loss: 0.1685 | Val Loss: 0.1495
#   [Train: 0.46s | Val: 0.55s | Save: 0.01s | Total: 1.01s]
# Saved new best model.
# Epoch 21/100 | Train Loss: 0.1523 | Val Loss: 0.1291
#   [Train: 0.47s | Val: 0.32s | Save: 0.00s | Total: 0.80s]
# Saved new best model.
# Epoch 22/100 | Train Loss: 0.1330 | Val Loss: 0.1101
#   [Train: 0.53s | Val: 0.38s | Save: 0.00s | Total: 0.92s]
# Saved new best model.
# Epoch 23/100 | Train Loss: 0.1124 | Val Loss: 0.0923
#   [Train: 0.50s | Val: 0.60s | Save: 0.01s | Total: 1.10s]
# Saved new best model.
# Epoch 24/100 | Train Loss: 0.0940 | Val Loss: 0.0757
#   [Train: 0.77s | Val: 0.47s | Save: 0.00s | Total: 1.24s]
# Saved new best model.
# Epoch 25/100 | Train Loss: 0.0757 | Val Loss: 0.0603
#   [Train: 0.79s | Val: 0.42s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 26/100 | Train Loss: 0.0635 | Val Loss: 0.0458
#   [Train: 0.56s | Val: 0.43s | Save: 0.01s | Total: 1.00s]
# Saved new best model.
# Epoch 27/100 | Train Loss: 0.0470 | Val Loss: 0.0322
#   [Train: 0.83s | Val: 0.67s | Save: 0.01s | Total: 1.50s]
# Saved new best model.
# Epoch 28/100 | Train Loss: 0.0358 | Val Loss: 0.0194
#   [Train: 0.60s | Val: 0.38s | Save: 0.01s | Total: 0.98s]
# Saved new best model.
# Epoch 29/100 | Train Loss: 0.0246 | Val Loss: 0.0073
#   [Train: 0.42s | Val: 0.30s | Save: 0.00s | Total: 0.73s]
# Saved new best model.
# Epoch 30/100 | Train Loss: 0.0134 | Val Loss: -0.0041
#   [Train: 0.58s | Val: 0.44s | Save: 0.00s | Total: 1.03s]
# Saved new best model.
# Epoch 31/100 | Train Loss: -0.0039 | Val Loss: -0.0150
#   [Train: 0.69s | Val: 0.62s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 32/100 | Train Loss: -0.0113 | Val Loss: -0.0253
#   [Train: 0.46s | Val: 0.46s | Save: 0.01s | Total: 0.93s]
# Saved new best model.
# Epoch 33/100 | Train Loss: -0.0230 | Val Loss: -0.0352
#   [Train: 0.80s | Val: 0.40s | Save: 0.01s | Total: 1.21s]
# Saved new best model.
# Epoch 34/100 | Train Loss: -0.0265 | Val Loss: -0.0446
#   [Train: 0.48s | Val: 0.46s | Save: 0.01s | Total: 0.95s]
# Saved new best model.
# Epoch 35/100 | Train Loss: -0.0404 | Val Loss: -0.0536
#   [Train: 0.54s | Val: 0.51s | Save: 0.00s | Total: 1.06s]
# Saved new best model.
# Epoch 36/100 | Train Loss: -0.0456 | Val Loss: -0.0623
#   [Train: 0.80s | Val: 0.41s | Save: 0.01s | Total: 1.22s]
# Saved new best model.
# Epoch 37/100 | Train Loss: -0.0576 | Val Loss: -0.0706
#   [Train: 0.80s | Val: 0.63s | Save: 0.00s | Total: 1.43s]
# Saved new best model.
# Epoch 38/100 | Train Loss: -0.0710 | Val Loss: -0.0787
#   [Train: 0.65s | Val: 0.43s | Save: 0.00s | Total: 1.09s]
# Saved new best model.
# Epoch 39/100 | Train Loss: -0.0728 | Val Loss: -0.0865
#   [Train: 0.91s | Val: 0.52s | Save: 0.01s | Total: 1.44s]
# Saved new best model.
# Epoch 40/100 | Train Loss: -0.0841 | Val Loss: -0.0940
#   [Train: 0.81s | Val: 0.45s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 41/100 | Train Loss: -0.0929 | Val Loss: -0.1013
#   [Train: 0.51s | Val: 0.59s | Save: 0.01s | Total: 1.10s]
# Saved new best model.
# Epoch 42/100 | Train Loss: -0.0972 | Val Loss: -0.1084
#   [Train: 0.71s | Val: 0.47s | Save: 0.01s | Total: 1.19s]
# Saved new best model.
# Epoch 43/100 | Train Loss: -0.1030 | Val Loss: -0.1153
#   [Train: 0.50s | Val: 0.55s | Save: 0.00s | Total: 1.05s]
# Saved new best model.
# Epoch 44/100 | Train Loss: -0.1102 | Val Loss: -0.1220
#   [Train: 0.69s | Val: 0.68s | Save: 0.01s | Total: 1.39s]
# Saved new best model.
# Epoch 45/100 | Train Loss: -0.1196 | Val Loss: -0.1285
#   [Train: 0.53s | Val: 0.44s | Save: 0.01s | Total: 0.98s]
# Saved new best model.
# Epoch 46/100 | Train Loss: -0.1245 | Val Loss: -0.1349
#   [Train: 0.61s | Val: 0.40s | Save: 0.01s | Total: 1.02s]
# Saved new best model.
# Epoch 47/100 | Train Loss: -0.1361 | Val Loss: -0.1411
#   [Train: 0.67s | Val: 0.55s | Save: 0.00s | Total: 1.22s]
# Saved new best model.
# Epoch 48/100 | Train Loss: -0.1398 | Val Loss: -0.1471
#   [Train: 0.85s | Val: 0.54s | Save: 0.00s | Total: 1.39s]
# Saved new best model.
# Epoch 49/100 | Train Loss: -0.1473 | Val Loss: -0.1531
#   [Train: 0.73s | Val: 0.63s | Save: 0.00s | Total: 1.36s]
# Saved new best model.
# Epoch 50/100 | Train Loss: -0.1500 | Val Loss: -0.1588
#   [Train: 0.82s | Val: 0.47s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 51/100 | Train Loss: -0.1619 | Val Loss: -0.1645
#   [Train: 0.78s | Val: 0.70s | Save: 0.00s | Total: 1.49s]
# Saved new best model.
# Epoch 52/100 | Train Loss: -0.1612 | Val Loss: -0.1700
#   [Train: 0.74s | Val: 0.48s | Save: 0.00s | Total: 1.22s]
# Saved new best model.
# Epoch 53/100 | Train Loss: -0.1685 | Val Loss: -0.1754
#   [Train: 0.65s | Val: 0.54s | Save: 0.00s | Total: 1.20s]
# Saved new best model.
# Epoch 54/100 | Train Loss: -0.1796 | Val Loss: -0.1807
#   [Train: 0.63s | Val: 0.56s | Save: 0.01s | Total: 1.20s]
# Saved new best model.
# Epoch 55/100 | Train Loss: -0.1804 | Val Loss: -0.1859
#   [Train: 0.72s | Val: 0.62s | Save: 0.00s | Total: 1.35s]
# Saved new best model.
# Epoch 56/100 | Train Loss: -0.1838 | Val Loss: -0.1909
#   [Train: 0.67s | Val: 0.70s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 57/100 | Train Loss: -0.1923 | Val Loss: -0.1959
#   [Train: 0.64s | Val: 0.47s | Save: 0.00s | Total: 1.12s]
# Saved new best model.
# Epoch 58/100 | Train Loss: -0.1978 | Val Loss: -0.2008
#   [Train: 0.57s | Val: 0.33s | Save: 0.00s | Total: 0.90s]
# Saved new best model.
# Epoch 59/100 | Train Loss: -0.1997 | Val Loss: -0.2056
#   [Train: 0.73s | Val: 0.64s | Save: 0.00s | Total: 1.38s]
# Saved new best model.
# Epoch 60/100 | Train Loss: -0.2047 | Val Loss: -0.2103
#   [Train: 0.59s | Val: 0.54s | Save: 0.01s | Total: 1.14s]
# Saved new best model.
# Epoch 61/100 | Train Loss: -0.2045 | Val Loss: -0.2149
#   [Train: 0.49s | Val: 0.68s | Save: 0.01s | Total: 1.17s]
# Saved new best model.
# Epoch 62/100 | Train Loss: -0.2190 | Val Loss: -0.2194
#   [Train: 0.74s | Val: 0.48s | Save: 0.01s | Total: 1.23s]
# Saved new best model.
# Epoch 63/100 | Train Loss: -0.2195 | Val Loss: -0.2238
#   [Train: 0.76s | Val: 0.42s | Save: 0.00s | Total: 1.18s]
# Saved new best model.
# Epoch 64/100 | Train Loss: -0.2224 | Val Loss: -0.2282
#   [Train: 0.51s | Val: 0.44s | Save: 0.00s | Total: 0.95s]
# Saved new best model.
# Epoch 65/100 | Train Loss: -0.2215 | Val Loss: -0.2325
#   [Train: 0.79s | Val: 0.56s | Save: 0.00s | Total: 1.35s]
# Saved new best model.
# Epoch 66/100 | Train Loss: -0.2362 | Val Loss: -0.2367
#   [Train: 0.74s | Val: 0.60s | Save: 0.00s | Total: 1.34s]
# Saved new best model.
# Epoch 67/100 | Train Loss: -0.2311 | Val Loss: -0.2408
#   [Train: 0.52s | Val: 0.37s | Save: 0.00s | Total: 0.89s]
# Saved new best model.
# Epoch 68/100 | Train Loss: -0.2402 | Val Loss: -0.2448
#   [Train: 0.75s | Val: 0.49s | Save: 0.01s | Total: 1.25s]
# Saved new best model.
# Epoch 69/100 | Train Loss: -0.2415 | Val Loss: -0.2488
#   [Train: 1.03s | Val: 0.61s | Save: 0.01s | Total: 1.64s]
# Saved new best model.
# Epoch 70/100 | Train Loss: -0.2466 | Val Loss: -0.2527
#   [Train: 0.61s | Val: 0.71s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 71/100 | Train Loss: -0.2516 | Val Loss: -0.2565
#   [Train: 0.71s | Val: 0.60s | Save: 0.01s | Total: 1.31s]
# Saved new best model.
# Epoch 72/100 | Train Loss: -0.2534 | Val Loss: -0.2603
#   [Train: 0.88s | Val: 0.31s | Save: 0.00s | Total: 1.19s]
# Saved new best model.
# Epoch 73/100 | Train Loss: -0.2644 | Val Loss: -0.2640
#   [Train: 0.47s | Val: 0.71s | Save: 0.01s | Total: 1.19s]
# Saved new best model.
# Epoch 74/100 | Train Loss: -0.2608 | Val Loss: -0.2676
#   [Train: 0.48s | Val: 0.40s | Save: 0.00s | Total: 0.88s]
# Saved new best model.
# Epoch 75/100 | Train Loss: -0.2708 | Val Loss: -0.2712
#   [Train: 0.88s | Val: 0.46s | Save: 0.00s | Total: 1.34s]
# Saved new best model.
# Epoch 76/100 | Train Loss: -0.2712 | Val Loss: -0.2747
#   [Train: 0.71s | Val: 0.39s | Save: 0.00s | Total: 1.09s]
# Saved new best model.
# Epoch 77/100 | Train Loss: -0.2731 | Val Loss: -0.2781
#   [Train: 0.51s | Val: 0.47s | Save: 0.00s | Total: 0.99s]
# Saved new best model.
# Epoch 78/100 | Train Loss: -0.2768 | Val Loss: -0.2815
#   [Train: 0.86s | Val: 0.46s | Save: 0.01s | Total: 1.33s]
# Saved new best model.
# Epoch 79/100 | Train Loss: -0.2770 | Val Loss: -0.2848
#   [Train: 0.55s | Val: 0.39s | Save: 0.00s | Total: 0.95s]
# Saved new best model.
# Epoch 80/100 | Train Loss: -0.2861 | Val Loss: -0.2881
#   [Train: 0.52s | Val: 0.51s | Save: 0.00s | Total: 1.03s]
# Saved new best model.
# Epoch 81/100 | Train Loss: -0.2908 | Val Loss: -0.2913
#   [Train: 0.84s | Val: 0.35s | Save: 0.00s | Total: 1.20s]
# Saved new best model.
# Epoch 82/100 | Train Loss: -0.2908 | Val Loss: -0.2945
#   [Train: 0.77s | Val: 0.59s | Save: 0.01s | Total: 1.37s]
# Saved new best model.
# Epoch 83/100 | Train Loss: -0.2989 | Val Loss: -0.2976
#   [Train: 0.64s | Val: 0.56s | Save: 0.01s | Total: 1.20s]
# Saved new best model.
# Epoch 84/100 | Train Loss: -0.3021 | Val Loss: -0.3007
#   [Train: 0.84s | Val: 0.39s | Save: 0.00s | Total: 1.23s]
# Saved new best model.
# Epoch 85/100 | Train Loss: -0.3009 | Val Loss: -0.3037
#   [Train: 0.60s | Val: 0.60s | Save: 0.01s | Total: 1.21s]
# Saved new best model.
# Epoch 86/100 | Train Loss: -0.3026 | Val Loss: -0.3067
#   [Train: 0.71s | Val: 0.40s | Save: 0.01s | Total: 1.11s]
# Saved new best model.
# Epoch 87/100 | Train Loss: -0.3077 | Val Loss: -0.3096
#   [Train: 0.54s | Val: 0.42s | Save: 0.01s | Total: 0.97s]
# Saved new best model.
# Epoch 88/100 | Train Loss: -0.3161 | Val Loss: -0.3124
#   [Train: 0.38s | Val: 0.31s | Save: 0.00s | Total: 0.69s]
# Saved new best model.
# Epoch 89/100 | Train Loss: -0.3095 | Val Loss: -0.3153
#   [Train: 0.49s | Val: 0.42s | Save: 0.01s | Total: 0.92s]
# Saved new best model.
# Epoch 90/100 | Train Loss: -0.3105 | Val Loss: -0.3181
#   [Train: 0.51s | Val: 0.41s | Save: 0.00s | Total: 0.92s]
# Saved new best model.
# Epoch 91/100 | Train Loss: -0.3196 | Val Loss: -0.3208
#   [Train: 0.93s | Val: 0.61s | Save: 0.00s | Total: 1.55s]
# Saved new best model.
# Epoch 92/100 | Train Loss: -0.3156 | Val Loss: -0.3235
#   [Train: 0.48s | Val: 0.41s | Save: 0.00s | Total: 0.90s]
# Saved new best model.
# Epoch 93/100 | Train Loss: -0.3236 | Val Loss: -0.3262
#   [Train: 0.51s | Val: 0.38s | Save: 0.01s | Total: 0.90s]
# Saved new best model.
# Epoch 94/100 | Train Loss: -0.3252 | Val Loss: -0.3288
#   [Train: 0.44s | Val: 0.47s | Save: 0.00s | Total: 0.91s]
# Saved new best model.
# Epoch 95/100 | Train Loss: -0.3301 | Val Loss: -0.3314
#   [Train: 0.40s | Val: 0.44s | Save: 0.00s | Total: 0.85s]
# Saved new best model.
# Epoch 96/100 | Train Loss: -0.3329 | Val Loss: -0.3339
#   [Train: 0.52s | Val: 0.42s | Save: 0.01s | Total: 0.95s]
# Saved new best model.
# Epoch 97/100 | Train Loss: -0.3361 | Val Loss: -0.3364
#   [Train: 0.69s | Val: 0.58s | Save: 0.01s | Total: 1.28s]
# Saved new best model.
# Epoch 98/100 | Train Loss: -0.3290 | Val Loss: -0.3389
#   [Train: 0.63s | Val: 0.49s | Save: 0.00s | Total: 1.12s]
# Saved new best model.
# Epoch 99/100 | Train Loss: -0.3388 | Val Loss: -0.3413
#   [Train: 0.66s | Val: 0.47s | Save: 0.01s | Total: 1.14s]
# Saved new best model.
# Epoch 100/100 | Train Loss: -0.3337 | Val Loss: -0.3437
#   [Train: 0.56s | Val: 0.47s | Save: 0.01s | Total: 1.05s]
#
# ----*----------*-------------*--------------- Node: x2 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# No existing model found. Starting fresh...
# Saved new best model.
# Epoch 1/100 | Train Loss: 1.9143 | Val Loss: 1.8077
#   [Train: 0.52s | Val: 0.44s | Save: 0.00s | Total: 0.96s]
# Saved new best model.
# Epoch 2/100 | Train Loss: 1.7862 | Val Loss: 1.6839
#   [Train: 0.78s | Val: 0.38s | Save: 0.00s | Total: 1.16s]
# Saved new best model.
# Epoch 3/100 | Train Loss: 1.6642 | Val Loss: 1.5681
#   [Train: 0.61s | Val: 0.49s | Save: 0.00s | Total: 1.10s]
# Saved new best model.
# Epoch 4/100 | Train Loss: 1.5486 | Val Loss: 1.4610
#   [Train: 0.68s | Val: 0.47s | Save: 0.01s | Total: 1.16s]
# Saved new best model.
# Epoch 5/100 | Train Loss: 1.4416 | Val Loss: 1.3629
#   [Train: 0.57s | Val: 0.49s | Save: 0.00s | Total: 1.06s]
# Saved new best model.
# Epoch 6/100 | Train Loss: 1.3445 | Val Loss: 1.2731
#   [Train: 0.49s | Val: 0.53s | Save: 0.01s | Total: 1.02s]
# Saved new best model.
# Epoch 7/100 | Train Loss: 1.2555 | Val Loss: 1.1915
#   [Train: 0.75s | Val: 0.50s | Save: 0.00s | Total: 1.26s]
# Saved new best model.
# Epoch 8/100 | Train Loss: 1.1792 | Val Loss: 1.1181
#   [Train: 1.08s | Val: 0.63s | Save: 0.01s | Total: 1.72s]
# Saved new best model.
# Epoch 9/100 | Train Loss: 1.1059 | Val Loss: 1.0526
#   [Train: 0.55s | Val: 0.73s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 10/100 | Train Loss: 1.0380 | Val Loss: 0.9946
#   [Train: 0.77s | Val: 0.42s | Save: 0.01s | Total: 1.20s]
# Saved new best model.
# Epoch 11/100 | Train Loss: 0.9835 | Val Loss: 0.9435
#   [Train: 0.60s | Val: 0.95s | Save: 0.00s | Total: 1.56s]
# Saved new best model.
# Epoch 12/100 | Train Loss: 0.9287 | Val Loss: 0.8987
#   [Train: 0.58s | Val: 0.50s | Save: 0.00s | Total: 1.09s]
# Saved new best model.
# Epoch 13/100 | Train Loss: 0.8875 | Val Loss: 0.8592
#   [Train: 0.65s | Val: 0.38s | Save: 0.00s | Total: 1.04s]
# Saved new best model.
# Epoch 14/100 | Train Loss: 0.8513 | Val Loss: 0.8247
#   [Train: 0.63s | Val: 0.40s | Save: 0.01s | Total: 1.04s]
# Saved new best model.
# Epoch 15/100 | Train Loss: 0.8178 | Val Loss: 0.7946
#   [Train: 0.52s | Val: 0.33s | Save: 0.00s | Total: 0.85s]
# Saved new best model.
# Epoch 16/100 | Train Loss: 0.7896 | Val Loss: 0.7684
#   [Train: 0.48s | Val: 0.57s | Save: 0.00s | Total: 1.06s]
# Saved new best model.
# Epoch 17/100 | Train Loss: 0.7603 | Val Loss: 0.7457
#   [Train: 0.51s | Val: 0.40s | Save: 0.00s | Total: 0.91s]
# Saved new best model.
# Epoch 18/100 | Train Loss: 0.7373 | Val Loss: 0.7258
#   [Train: 0.36s | Val: 0.52s | Save: 0.01s | Total: 0.89s]
# Saved new best model.
# Epoch 19/100 | Train Loss: 0.7128 | Val Loss: 0.7082
#   [Train: 0.56s | Val: 0.73s | Save: 0.01s | Total: 1.30s]
# Saved new best model.
# Epoch 20/100 | Train Loss: 0.6945 | Val Loss: 0.6927
#   [Train: 0.98s | Val: 0.71s | Save: 0.00s | Total: 1.70s]
# Saved new best model.
# Epoch 21/100 | Train Loss: 0.6841 | Val Loss: 0.6788
#   [Train: 0.91s | Val: 0.57s | Save: 0.00s | Total: 1.49s]
# Saved new best model.
# Epoch 22/100 | Train Loss: 0.6679 | Val Loss: 0.6665
#   [Train: 0.73s | Val: 0.49s | Save: 0.00s | Total: 1.22s]
# Saved new best model.
# Epoch 23/100 | Train Loss: 0.6529 | Val Loss: 0.6557
#   [Train: 0.92s | Val: 0.49s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 24/100 | Train Loss: 0.6445 | Val Loss: 0.6459
#   [Train: 0.72s | Val: 0.54s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 25/100 | Train Loss: 0.6333 | Val Loss: 0.6369
#   [Train: 0.67s | Val: 0.62s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 26/100 | Train Loss: 0.6194 | Val Loss: 0.6287
#   [Train: 0.45s | Val: 0.38s | Save: 0.01s | Total: 0.84s]
# Saved new best model.
# Epoch 27/100 | Train Loss: 0.6103 | Val Loss: 0.6214
#   [Train: 0.59s | Val: 0.46s | Save: 0.00s | Total: 1.05s]
# Saved new best model.
# Epoch 28/100 | Train Loss: 0.6002 | Val Loss: 0.6148
#   [Train: 0.53s | Val: 0.45s | Save: 0.00s | Total: 0.99s]
# Saved new best model.
# Epoch 29/100 | Train Loss: 0.5966 | Val Loss: 0.6087
#   [Train: 0.48s | Val: 0.55s | Save: 0.00s | Total: 1.04s]
# Saved new best model.
# Epoch 30/100 | Train Loss: 0.5939 | Val Loss: 0.6028
#   [Train: 0.72s | Val: 0.54s | Save: 0.02s | Total: 1.28s]
# Saved new best model.
# Epoch 31/100 | Train Loss: 0.5856 | Val Loss: 0.5973
#   [Train: 0.73s | Val: 0.44s | Save: 0.01s | Total: 1.18s]
# Saved new best model.
# Epoch 32/100 | Train Loss: 0.5724 | Val Loss: 0.5922
#   [Train: 0.66s | Val: 0.51s | Save: 0.00s | Total: 1.17s]
# Saved new best model.
# Epoch 33/100 | Train Loss: 0.5703 | Val Loss: 0.5873
#   [Train: 0.70s | Val: 0.40s | Save: 0.01s | Total: 1.11s]
# Saved new best model.
# Epoch 34/100 | Train Loss: 0.5673 | Val Loss: 0.5828
#   [Train: 0.89s | Val: 0.51s | Save: 0.01s | Total: 1.42s]
# Saved new best model.
# Epoch 35/100 | Train Loss: 0.5654 | Val Loss: 0.5785
#   [Train: 0.52s | Val: 0.43s | Save: 0.01s | Total: 0.96s]
# Saved new best model.
# Epoch 36/100 | Train Loss: 0.5611 | Val Loss: 0.5743
#   [Train: 0.68s | Val: 0.48s | Save: 0.00s | Total: 1.16s]
# Saved new best model.
# Epoch 37/100 | Train Loss: 0.5616 | Val Loss: 0.5703
#   [Train: 0.71s | Val: 0.54s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 38/100 | Train Loss: 0.5454 | Val Loss: 0.5669
#   [Train: 0.84s | Val: 0.43s | Save: 0.00s | Total: 1.28s]
# Saved new best model.
# Epoch 39/100 | Train Loss: 0.5490 | Val Loss: 0.5640
#   [Train: 0.79s | Val: 0.47s | Save: 0.00s | Total: 1.27s]
# Saved new best model.
# Epoch 40/100 | Train Loss: 0.5483 | Val Loss: 0.5610
#   [Train: 0.57s | Val: 0.47s | Save: 0.01s | Total: 1.05s]
# Saved new best model.
# Epoch 41/100 | Train Loss: 0.5432 | Val Loss: 0.5576
#   [Train: 0.57s | Val: 0.53s | Save: 0.01s | Total: 1.11s]
# Saved new best model.
# Epoch 42/100 | Train Loss: 0.5407 | Val Loss: 0.5545
#   [Train: 0.63s | Val: 0.50s | Save: 0.00s | Total: 1.14s]
# Saved new best model.
# Epoch 43/100 | Train Loss: 0.5306 | Val Loss: 0.5516
#   [Train: 0.69s | Val: 0.36s | Save: 0.01s | Total: 1.05s]
# Saved new best model.
# Epoch 44/100 | Train Loss: 0.5309 | Val Loss: 0.5490
#   [Train: 0.57s | Val: 0.42s | Save: 0.01s | Total: 1.00s]
# Saved new best model.
# Epoch 45/100 | Train Loss: 0.5220 | Val Loss: 0.5463
#   [Train: 0.61s | Val: 0.39s | Save: 0.01s | Total: 1.01s]
# Saved new best model.
# Epoch 46/100 | Train Loss: 0.5311 | Val Loss: 0.5439
#   [Train: 0.59s | Val: 0.69s | Save: 0.00s | Total: 1.29s]
# Saved new best model.
# Epoch 47/100 | Train Loss: 0.5218 | Val Loss: 0.5417
#   [Train: 0.75s | Val: 0.50s | Save: 0.02s | Total: 1.28s]
# Saved new best model.
# Epoch 48/100 | Train Loss: 0.5109 | Val Loss: 0.5397
#   [Train: 0.63s | Val: 0.62s | Save: 0.01s | Total: 1.26s]
# Saved new best model.
# Epoch 49/100 | Train Loss: 0.5270 | Val Loss: 0.5376
#   [Train: 0.77s | Val: 0.36s | Save: 0.00s | Total: 1.14s]
# Saved new best model.
# Epoch 50/100 | Train Loss: 0.5100 | Val Loss: 0.5357
#   [Train: 0.65s | Val: 0.56s | Save: 0.00s | Total: 1.22s]
# Saved new best model.
# Epoch 51/100 | Train Loss: 0.5199 | Val Loss: 0.5339
#   [Train: 0.64s | Val: 0.60s | Save: 0.00s | Total: 1.25s]
# Saved new best model.
# Epoch 52/100 | Train Loss: 0.5051 | Val Loss: 0.5320
#   [Train: 0.69s | Val: 0.49s | Save: 0.00s | Total: 1.19s]
# Saved new best model.
# Epoch 53/100 | Train Loss: 0.5127 | Val Loss: 0.5297
#   [Train: 0.66s | Val: 0.37s | Save: 0.00s | Total: 1.03s]
# Saved new best model.
# Epoch 54/100 | Train Loss: 0.5027 | Val Loss: 0.5274
#   [Train: 0.56s | Val: 0.66s | Save: 0.01s | Total: 1.23s]
# Saved new best model.
# Epoch 55/100 | Train Loss: 0.5018 | Val Loss: 0.5253
#   [Train: 0.63s | Val: 0.53s | Save: 0.01s | Total: 1.17s]
# Saved new best model.
# Epoch 56/100 | Train Loss: 0.5008 | Val Loss: 0.5234
#   [Train: 0.81s | Val: 0.34s | Save: 0.00s | Total: 1.16s]
# Saved new best model.
# Epoch 57/100 | Train Loss: 0.4919 | Val Loss: 0.5218
#   [Train: 0.60s | Val: 0.39s | Save: 0.01s | Total: 1.00s]
# Saved new best model.
# Epoch 58/100 | Train Loss: 0.4855 | Val Loss: 0.5204
#   [Train: 0.52s | Val: 0.61s | Save: 0.01s | Total: 1.14s]
# Saved new best model.
# Epoch 59/100 | Train Loss: 0.4877 | Val Loss: 0.5193
#   [Train: 0.58s | Val: 0.58s | Save: 0.00s | Total: 1.17s]
# Saved new best model.
# Epoch 60/100 | Train Loss: 0.4877 | Val Loss: 0.5181
#   [Train: 0.57s | Val: 0.63s | Save: 0.00s | Total: 1.21s]
# Saved new best model.
# Epoch 61/100 | Train Loss: 0.4931 | Val Loss: 0.5170
#   [Train: 0.95s | Val: 0.52s | Save: 0.01s | Total: 1.48s]
# Saved new best model.
# Epoch 62/100 | Train Loss: 0.4939 | Val Loss: 0.5153
#   [Train: 0.81s | Val: 0.42s | Save: 0.01s | Total: 1.24s]
# Saved new best model.
# Epoch 63/100 | Train Loss: 0.4825 | Val Loss: 0.5133
#   [Train: 0.49s | Val: 0.39s | Save: 0.01s | Total: 0.89s]
# Saved new best model.
# Epoch 64/100 | Train Loss: 0.4782 | Val Loss: 0.5112
#   [Train: 0.55s | Val: 0.33s | Save: 0.00s | Total: 0.89s]
# Saved new best model.
# Epoch 65/100 | Train Loss: 0.4851 | Val Loss: 0.5095
#   [Train: 0.49s | Val: 0.43s | Save: 0.01s | Total: 0.93s]
# Saved new best model.
# Epoch 66/100 | Train Loss: 0.4810 | Val Loss: 0.5080
#   [Train: 0.55s | Val: 0.45s | Save: 0.01s | Total: 1.01s]
# Saved new best model.
# Epoch 67/100 | Train Loss: 0.4812 | Val Loss: 0.5068
#   [Train: 0.58s | Val: 0.36s | Save: 0.01s | Total: 0.95s]
# Saved new best model.
# Epoch 68/100 | Train Loss: 0.4694 | Val Loss: 0.5057
#   [Train: 0.48s | Val: 0.45s | Save: 0.00s | Total: 0.94s]
# Saved new best model.
# Epoch 69/100 | Train Loss: 0.4945 | Val Loss: 0.5044
#   [Train: 0.67s | Val: 0.39s | Save: 0.01s | Total: 1.07s]
# Saved new best model.
# Epoch 70/100 | Train Loss: 0.4825 | Val Loss: 0.5031
#   [Train: 0.67s | Val: 0.65s | Save: 0.01s | Total: 1.34s]
# Saved new best model.
# Epoch 71/100 | Train Loss: 0.4684 | Val Loss: 0.5016
#   [Train: 0.45s | Val: 0.43s | Save: 0.00s | Total: 0.90s]
# Saved new best model.
# Epoch 72/100 | Train Loss: 0.4816 | Val Loss: 0.5004
#   [Train: 0.63s | Val: 0.36s | Save: 0.01s | Total: 0.99s]
# Saved new best model.
# Epoch 73/100 | Train Loss: 0.4751 | Val Loss: 0.4991
#   [Train: 0.37s | Val: 0.43s | Save: 0.01s | Total: 0.81s]
# Saved new best model.
# Epoch 74/100 | Train Loss: 0.4654 | Val Loss: 0.4980
#   [Train: 0.59s | Val: 0.50s | Save: 0.01s | Total: 1.10s]
# Saved new best model.
# Epoch 75/100 | Train Loss: 0.4656 | Val Loss: 0.4967
#   [Train: 0.73s | Val: 0.49s | Save: 0.01s | Total: 1.23s]
# Saved new best model.
# Epoch 76/100 | Train Loss: 0.4667 | Val Loss: 0.4952
#   [Train: 0.56s | Val: 0.44s | Save: 0.01s | Total: 1.00s]
# Saved new best model.
# Epoch 77/100 | Train Loss: 0.4781 | Val Loss: 0.4940
#   [Train: 0.59s | Val: 0.53s | Save: 0.00s | Total: 1.13s]
# Saved new best model.
# Epoch 78/100 | Train Loss: 0.4684 | Val Loss: 0.4928
#   [Train: 0.50s | Val: 0.53s | Save: 0.01s | Total: 1.04s]
# Saved new best model.
# Epoch 79/100 | Train Loss: 0.4631 | Val Loss: 0.4913
#   [Train: 0.55s | Val: 0.41s | Save: 0.01s | Total: 0.98s]
# Saved new best model.
# Epoch 80/100 | Train Loss: 0.4706 | Val Loss: 0.4899
#   [Train: 0.75s | Val: 0.53s | Save: 0.01s | Total: 1.29s]
# Saved new best model.
# Epoch 81/100 | Train Loss: 0.4682 | Val Loss: 0.4885
#   [Train: 0.69s | Val: 0.35s | Save: 0.00s | Total: 1.04s]
# Saved new best model.
# Epoch 82/100 | Train Loss: 0.4577 | Val Loss: 0.4873
#   [Train: 0.60s | Val: 0.39s | Save: 0.00s | Total: 0.99s]
# Saved new best model.
# Epoch 83/100 | Train Loss: 0.4747 | Val Loss: 0.4862
#   [Train: 0.69s | Val: 0.43s | Save: 0.00s | Total: 1.13s]
# Saved new best model.
# Epoch 84/100 | Train Loss: 0.4497 | Val Loss: 0.4852
#   [Train: 0.67s | Val: 0.63s | Save: 0.00s | Total: 1.31s]
# Saved new best model.
# Epoch 85/100 | Train Loss: 0.4376 | Val Loss: 0.4843
#   [Train: 0.56s | Val: 0.51s | Save: 0.00s | Total: 1.08s]
# Saved new best model.
# Epoch 86/100 | Train Loss: 0.4525 | Val Loss: 0.4836
#   [Train: 0.66s | Val: 0.51s | Save: 0.01s | Total: 1.18s]
# Saved new best model.
# Epoch 87/100 | Train Loss: 0.4592 | Val Loss: 0.4826
#   [Train: 0.67s | Val: 0.62s | Save: 0.00s | Total: 1.30s]
# Saved new best model.
# Epoch 88/100 | Train Loss: 0.4544 | Val Loss: 0.4813
#   [Train: 1.04s | Val: 0.49s | Save: 0.00s | Total: 1.53s]
# Saved new best model.
# Epoch 89/100 | Train Loss: 0.4514 | Val Loss: 0.4796
#   [Train: 0.66s | Val: 0.40s | Save: 0.00s | Total: 1.07s]
# Saved new best model.
# Epoch 90/100 | Train Loss: 0.4420 | Val Loss: 0.4782
#   [Train: 0.56s | Val: 0.47s | Save: 0.01s | Total: 1.04s]
# Saved new best model.
# Epoch 91/100 | Train Loss: 0.4520 | Val Loss: 0.4770
#   [Train: 0.61s | Val: 0.38s | Save: 0.00s | Total: 1.00s]
# Saved new best model.
# Epoch 92/100 | Train Loss: 0.4467 | Val Loss: 0.4762
#   [Train: 0.56s | Val: 0.34s | Save: 0.01s | Total: 0.92s]
# Saved new best model.
# Epoch 93/100 | Train Loss: 0.4529 | Val Loss: 0.4755
#   [Train: 0.60s | Val: 0.38s | Save: 0.01s | Total: 0.99s]
# Saved new best model.
# Epoch 94/100 | Train Loss: 0.4566 | Val Loss: 0.4751
#   [Train: 0.51s | Val: 0.46s | Save: 0.01s | Total: 0.98s]
# Saved new best model.
# Epoch 95/100 | Train Loss: 0.4513 | Val Loss: 0.4744
#   [Train: 0.70s | Val: 0.34s | Save: 0.00s | Total: 1.04s]
# Saved new best model.
# Epoch 96/100 | Train Loss: 0.4504 | Val Loss: 0.4730
#   [Train: 0.57s | Val: 0.53s | Save: 0.00s | Total: 1.11s]
# Saved new best model.
# Epoch 97/100 | Train Loss: 0.4469 | Val Loss: 0.4715
#   [Train: 0.44s | Val: 0.37s | Save: 0.00s | Total: 0.82s]
# Saved new best model.
# Epoch 98/100 | Train Loss: 0.4442 | Val Loss: 0.4701
#   [Train: 0.46s | Val: 0.50s | Save: 0.00s | Total: 0.96s]
# Saved new best model.
# Epoch 99/100 | Train Loss: 0.4472 | Val Loss: 0.4691
#   [Train: 0.45s | Val: 0.30s | Save: 0.01s | Total: 0.76s]
# Saved new best model.
# Epoch 100/100 | Train Loss: 0.4369 | Val Loss: 0.4681
#   [Train: 0.59s | Val: 0.46s | Save: 0.01s | Total: 1.07s]
#
# ----*----------*-------------*--------------- Node: x3 ------------*-----------------*-------------------*--
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): ComplexShiftDefaultTabular(
#       (fc1): Linear(in_features=1, out_features=8, bias=True)
#       (relu1): ReLU()
#       (fc2): Linear(in_features=8, out_features=8, bias=True)
#       (relu2): ReLU()
#       (fc3): Linear(in_features=8, out_features=1, bias=False)
#     )
#     (1): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# No existing model found. Starting fresh...
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 1/100 | Train Loss: 3.9290 | Val Loss: 3.8342
#   [Train: 0.58s | Val: 0.41s | Save: 0.00s | Total: 1.00s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 2/100 | Train Loss: 3.7874 | Val Loss: 3.7049
#   [Train: 0.57s | Val: 0.33s | Save: 0.00s | Total: 0.91s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 3/100 | Train Loss: 3.6616 | Val Loss: 3.5875
#   [Train: 0.59s | Val: 0.33s | Save: 0.00s | Total: 0.92s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 4/100 | Train Loss: 3.5465 | Val Loss: 3.4746
#   [Train: 0.45s | Val: 0.52s | Save: 0.01s | Total: 0.98s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 5/100 | Train Loss: 3.4391 | Val Loss: 3.3726
#   [Train: 0.56s | Val: 0.45s | Save: 0.01s | Total: 1.02s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 6/100 | Train Loss: 3.3424 | Val Loss: 3.2803
#   [Train: 0.48s | Val: 0.38s | Save: 0.01s | Total: 0.88s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 7/100 | Train Loss: 3.2534 | Val Loss: 3.1948
#   [Train: 0.41s | Val: 0.38s | Save: 0.00s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 8/100 | Train Loss: 3.1698 | Val Loss: 3.1110
#   [Train: 0.70s | Val: 0.31s | Save: 0.01s | Total: 1.03s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 9/100 | Train Loss: 3.0949 | Val Loss: 3.0379
#   [Train: 0.49s | Val: 0.56s | Save: 0.00s | Total: 1.05s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 10/100 | Train Loss: 3.0229 | Val Loss: 2.9755
#   [Train: 0.54s | Val: 0.44s | Save: 0.01s | Total: 0.99s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 11/100 | Train Loss: 2.9650 | Val Loss: 2.9076
#   [Train: 0.68s | Val: 0.52s | Save: 0.00s | Total: 1.21s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 12/100 | Train Loss: 2.9092 | Val Loss: 2.8526
#   [Train: 0.83s | Val: 0.53s | Save: 0.01s | Total: 1.37s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 13/100 | Train Loss: 2.8528 | Val Loss: 2.8088
#   [Train: 0.75s | Val: 0.45s | Save: 0.01s | Total: 1.21s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 14/100 | Train Loss: 2.8136 | Val Loss: 2.7567
#   [Train: 0.69s | Val: 0.47s | Save: 0.00s | Total: 1.16s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 15/100 | Train Loss: 2.7733 | Val Loss: 2.7211
#   [Train: 0.87s | Val: 0.54s | Save: 0.00s | Total: 1.42s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 16/100 | Train Loss: 2.7312 | Val Loss: 2.6897
#   [Train: 0.66s | Val: 0.47s | Save: 0.01s | Total: 1.14s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 17/100 | Train Loss: 2.7021 | Val Loss: 2.6480
#   [Train: 0.63s | Val: 0.43s | Save: 0.00s | Total: 1.06s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 18/100 | Train Loss: 2.6752 | Val Loss: 2.6236
#   [Train: 0.78s | Val: 0.46s | Save: 0.01s | Total: 1.26s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 19/100 | Train Loss: 2.6404 | Val Loss: 2.6070
#   [Train: 0.75s | Val: 0.35s | Save: 0.01s | Total: 1.11s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 20/100 | Train Loss: 2.6294 | Val Loss: 2.5679
#   [Train: 0.58s | Val: 0.42s | Save: 0.00s | Total: 1.01s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 21/100 | Train Loss: 2.5953 | Val Loss: 2.5495
#   [Train: 0.42s | Val: 0.35s | Save: 0.01s | Total: 0.79s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 22/100 | Train Loss: 2.5784 | Val Loss: 2.5449
#   [Train: 0.86s | Val: 0.46s | Save: 0.01s | Total: 1.34s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 23/100 | Train Loss: 2.5601 | Val Loss: 2.5138
#   [Train: 0.67s | Val: 0.45s | Save: 0.01s | Total: 1.13s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 24/100 | Train Loss: 2.5549 | Val Loss: 2.4950
#   [Train: 0.47s | Val: 0.42s | Save: 0.01s | Total: 0.90s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 25/100 | Train Loss: 2.5321 | Val Loss: 2.4916
#   [Train: 0.60s | Val: 0.49s | Save: 0.01s | Total: 1.11s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 26/100 | Train Loss: 2.5279 | Val Loss: 2.4734
#   [Train: 0.57s | Val: 0.50s | Save: 0.01s | Total: 1.08s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 27/100 | Train Loss: 2.5075 | Val Loss: 2.4554
#   [Train: 0.51s | Val: 0.45s | Save: 0.01s | Total: 0.97s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 28/100 | Train Loss: 2.5117 | Val Loss: 2.4535
#   [Train: 0.61s | Val: 0.56s | Save: 0.01s | Total: 1.19s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 29/100 | Train Loss: 2.4960 | Val Loss: 2.4412
#   [Train: 0.63s | Val: 0.41s | Save: 0.01s | Total: 1.04s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 30/100 | Train Loss: 2.4928 | Val Loss: 2.4277
#   [Train: 0.49s | Val: 0.46s | Save: 0.01s | Total: 0.96s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 31/100 | Train Loss: 2.4897 | Val Loss: 2.4274
#   [Train: 0.61s | Val: 0.51s | Save: 0.00s | Total: 1.14s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 32/100 | Train Loss: 2.4705 | Val Loss: 2.4128
#   [Train: 0.75s | Val: 0.49s | Save: 0.01s | Total: 1.25s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 33/100 | Train Loss: 2.4519 | Val Loss: 2.4059
#   [Train: 0.77s | Val: 0.49s | Save: 0.01s | Total: 1.27s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 34/100 | Train Loss: 2.4640 | Val Loss: 2.4061
#   [Train: 0.75s | Val: 0.39s | Save: 0.00s | Total: 1.14s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 35/100 | Train Loss: 2.4668 | Val Loss: 2.4009
#   [Train: 0.61s | Val: 0.69s | Save: 0.01s | Total: 1.31s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 36/100 | Train Loss: 2.4386 | Val Loss: 2.3967
#   [Train: 0.68s | Val: 0.64s | Save: 0.01s | Total: 1.33s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 37/100 | Train Loss: 2.4507 | Val Loss: 2.3863
#   [Train: 0.68s | Val: 0.44s | Save: 0.01s | Total: 1.14s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 38/100 | Train Loss: 2.4446 | Val Loss: 2.3814
#   [Train: 0.83s | Val: 0.58s | Save: 0.01s | Total: 1.43s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 39/100 | Train Loss: 2.4456 | Val Loss: 2.3838
#   [Train: 0.58s | Val: 0.43s | Save: 0.00s | Total: 1.02s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 40/100 | Train Loss: 2.4251 | Val Loss: 2.3728
#   [Train: 0.52s | Val: 0.33s | Save: 0.01s | Total: 0.86s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 41/100 | Train Loss: 2.4349 | Val Loss: 2.3718
#   [Train: 0.48s | Val: 0.39s | Save: 0.00s | Total: 0.88s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 42/100 | Train Loss: 2.4335 | Val Loss: 2.3693
#   [Train: 0.41s | Val: 0.34s | Save: 0.01s | Total: 0.76s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 43/100 | Train Loss: 2.4321 | Val Loss: 2.3669
#   [Train: 0.73s | Val: 0.49s | Save: 0.01s | Total: 1.24s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 44/100 | Train Loss: 2.4279 | Val Loss: 2.3703
#   [Train: 0.50s | Val: 0.56s | Save: 0.01s | Total: 1.07s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 45/100 | Train Loss: 2.4380 | Val Loss: 2.3590
#   [Train: 0.57s | Val: 0.53s | Save: 0.01s | Total: 1.12s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 46/100 | Train Loss: 2.4204 | Val Loss: 2.3743
#   [Train: 0.87s | Val: 0.45s | Save: 0.01s | Total: 1.33s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 47/100 | Train Loss: 2.4146 | Val Loss: 2.3579
#   [Train: 0.79s | Val: 0.37s | Save: 0.00s | Total: 1.17s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 48/100 | Train Loss: 2.4239 | Val Loss: 2.3536
#   [Train: 0.59s | Val: 0.43s | Save: 0.01s | Total: 1.04s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 49/100 | Train Loss: 2.4095 | Val Loss: 2.3657
#   [Train: 0.56s | Val: 0.55s | Save: 0.01s | Total: 1.12s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 50/100 | Train Loss: 2.4213 | Val Loss: 2.3546
#   [Train: 0.69s | Val: 0.35s | Save: 0.01s | Total: 1.05s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 51/100 | Train Loss: 2.4235 | Val Loss: 2.3458
#   [Train: 0.66s | Val: 0.73s | Save: 0.01s | Total: 1.40s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 52/100 | Train Loss: 2.4135 | Val Loss: 2.3543
#   [Train: 0.74s | Val: 0.65s | Save: 0.01s | Total: 1.40s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 53/100 | Train Loss: 2.4163 | Val Loss: 2.3469
#   [Train: 0.74s | Val: 0.37s | Save: 0.00s | Total: 1.12s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 54/100 | Train Loss: 2.4023 | Val Loss: 2.3450
#   [Train: 0.62s | Val: 0.73s | Save: 0.01s | Total: 1.36s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 55/100 | Train Loss: 2.4172 | Val Loss: 2.3422
#   [Train: 0.62s | Val: 0.46s | Save: 0.01s | Total: 1.09s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 56/100 | Train Loss: 2.4202 | Val Loss: 2.3434
#   [Train: 0.73s | Val: 0.57s | Save: 0.01s | Total: 1.32s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 57/100 | Train Loss: 2.4061 | Val Loss: 2.3421
#   [Train: 0.81s | Val: 0.35s | Save: 0.00s | Total: 1.18s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 58/100 | Train Loss: 2.4038 | Val Loss: 2.3364
#   [Train: 0.47s | Val: 0.52s | Save: 0.01s | Total: 0.99s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 59/100 | Train Loss: 2.4209 | Val Loss: 2.3492
#   [Train: 0.71s | Val: 0.56s | Save: 0.01s | Total: 1.29s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 60/100 | Train Loss: 2.4201 | Val Loss: 2.3621
#   [Train: 0.86s | Val: 0.65s | Save: 0.01s | Total: 1.53s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 61/100 | Train Loss: 2.4040 | Val Loss: 2.3338
#   [Train: 0.63s | Val: 0.42s | Save: 0.01s | Total: 1.06s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 62/100 | Train Loss: 2.4196 | Val Loss: 2.3429
#   [Train: 0.79s | Val: 0.59s | Save: 0.00s | Total: 1.39s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 63/100 | Train Loss: 2.4286 | Val Loss: 2.3701
#   [Train: 0.73s | Val: 0.60s | Save: 0.01s | Total: 1.34s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 64/100 | Train Loss: 2.3983 | Val Loss: 2.3316
#   [Train: 0.63s | Val: 0.52s | Save: 0.01s | Total: 1.17s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 65/100 | Train Loss: 2.4400 | Val Loss: 2.3318
#   [Train: 0.89s | Val: 0.44s | Save: 0.01s | Total: 1.33s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 66/100 | Train Loss: 2.4102 | Val Loss: 2.3604
#   [Train: 0.67s | Val: 0.33s | Save: 0.01s | Total: 1.01s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 67/100 | Train Loss: 2.4155 | Val Loss: 2.3339
#   [Train: 0.55s | Val: 0.57s | Save: 0.00s | Total: 1.13s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 68/100 | Train Loss: 2.4150 | Val Loss: 2.3286
#   [Train: 0.66s | Val: 0.43s | Save: 0.01s | Total: 1.10s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 69/100 | Train Loss: 2.3996 | Val Loss: 2.3535
#   [Train: 0.81s | Val: 0.41s | Save: 0.01s | Total: 1.23s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 70/100 | Train Loss: 2.4051 | Val Loss: 2.3390
#   [Train: 0.65s | Val: 0.51s | Save: 0.01s | Total: 1.17s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 71/100 | Train Loss: 2.4085 | Val Loss: 2.3276
#   [Train: 0.51s | Val: 0.46s | Save: 0.01s | Total: 0.98s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 72/100 | Train Loss: 2.3982 | Val Loss: 2.3373
#   [Train: 0.58s | Val: 0.33s | Save: 0.01s | Total: 0.92s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 73/100 | Train Loss: 2.3898 | Val Loss: 2.3472
#   [Train: 0.65s | Val: 0.42s | Save: 0.00s | Total: 1.08s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 74/100 | Train Loss: 2.4021 | Val Loss: 2.3326
#   [Train: 0.74s | Val: 0.57s | Save: 0.01s | Total: 1.32s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 75/100 | Train Loss: 2.4049 | Val Loss: 2.3277
#   [Train: 0.74s | Val: 0.44s | Save: 0.01s | Total: 1.19s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 76/100 | Train Loss: 2.4051 | Val Loss: 2.3302
#   [Train: 0.66s | Val: 0.77s | Save: 0.01s | Total: 1.44s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 77/100 | Train Loss: 2.3887 | Val Loss: 2.3331
#   [Train: 0.73s | Val: 0.58s | Save: 0.00s | Total: 1.31s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 78/100 | Train Loss: 2.4020 | Val Loss: 2.3282
#   [Train: 0.62s | Val: 0.43s | Save: 0.01s | Total: 1.06s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 79/100 | Train Loss: 2.3993 | Val Loss: 2.3335
#   [Train: 0.64s | Val: 0.48s | Save: 0.00s | Total: 1.13s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 80/100 | Train Loss: 2.4030 | Val Loss: 2.3328
#   [Train: 0.66s | Val: 0.52s | Save: 0.00s | Total: 1.18s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 81/100 | Train Loss: 2.4014 | Val Loss: 2.3268
#   [Train: 0.75s | Val: 0.48s | Save: 0.01s | Total: 1.25s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 82/100 | Train Loss: 2.4131 | Val Loss: 2.3363
#   [Train: 0.72s | Val: 0.61s | Save: 0.00s | Total: 1.34s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 83/100 | Train Loss: 2.4181 | Val Loss: 2.3281
#   [Train: 0.71s | Val: 0.37s | Save: 0.00s | Total: 1.08s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 84/100 | Train Loss: 2.4032 | Val Loss: 2.3301
#   [Train: 0.63s | Val: 0.47s | Save: 0.00s | Total: 1.11s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 85/100 | Train Loss: 2.4180 | Val Loss: 2.3278
#   [Train: 0.58s | Val: 0.38s | Save: 0.00s | Total: 0.97s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 86/100 | Train Loss: 2.4024 | Val Loss: 2.3249
#   [Train: 0.54s | Val: 0.30s | Save: 0.00s | Total: 0.86s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 87/100 | Train Loss: 2.4014 | Val Loss: 2.3302
#   [Train: 0.63s | Val: 0.56s | Save: 0.00s | Total: 1.20s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 88/100 | Train Loss: 2.3846 | Val Loss: 2.3374
#   [Train: 0.70s | Val: 0.56s | Save: 0.01s | Total: 1.27s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 89/100 | Train Loss: 2.4072 | Val Loss: 2.3253
#   [Train: 0.54s | Val: 0.48s | Save: 0.00s | Total: 1.03s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 90/100 | Train Loss: 2.4063 | Val Loss: 2.3308
#   [Train: 0.65s | Val: 0.58s | Save: 0.00s | Total: 1.24s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 91/100 | Train Loss: 2.4132 | Val Loss: 2.3411
#   [Train: 0.50s | Val: 0.45s | Save: 0.00s | Total: 0.96s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 92/100 | Train Loss: 2.4101 | Val Loss: 2.3220
#   [Train: 0.57s | Val: 0.43s | Save: 0.01s | Total: 1.00s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 93/100 | Train Loss: 2.4084 | Val Loss: 2.3264
#   [Train: 0.64s | Val: 0.53s | Save: 0.01s | Total: 1.18s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 94/100 | Train Loss: 2.3950 | Val Loss: 2.3381
#   [Train: 0.71s | Val: 0.55s | Save: 0.00s | Total: 1.27s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 95/100 | Train Loss: 2.3963 | Val Loss: 2.3258
#   [Train: 0.78s | Val: 0.38s | Save: 0.00s | Total: 1.17s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Saved new best model.
# Epoch 96/100 | Train Loss: 2.4330 | Val Loss: 2.3210
#   [Train: 0.76s | Val: 0.45s | Save: 0.00s | Total: 1.21s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 97/100 | Train Loss: 2.3997 | Val Loss: 2.3298
#   [Train: 0.50s | Val: 0.55s | Save: 0.00s | Total: 1.06s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 98/100 | Train Loss: 2.4215 | Val Loss: 2.3413
#   [Train: 0.56s | Val: 0.40s | Save: 0.00s | Total: 0.97s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 99/100 | Train Loss: 2.4098 | Val Loss: 2.3246
#   [Train: 0.82s | Val: 0.43s | Save: 0.01s | Total: 1.26s]
# shift_0: 'fc' or 'weight' layer does not exist.
# Epoch 100/100 | Train Loss: 2.4175 | Val Loss: 2.3241
#   [Train: 0.77s | Val: 0.51s | Save: 0.01s | Total: 1.29s]

# %% [markdown]
# # 6 Inspect Training

# %% [markdown]
# ## 6.1 Loss vs epochs

# %%
show_training_history(conf_dict,EXPERIMENT_DIR)

# %% [markdown]
# ## 6.2 inspect transformation function for source nodes h()

# %%
show_hdag_for_source_nodes(conf_dict,EXPERIMENT_DIR,device=device,xmin_plot=0,xmax_plot=1) # TODO for other nodes funciton
# Out:
# ----*----------*-------------*--------Inspect TRAFO Node: x1 ------------*-----------------*-------------------*--
# h() for  x1:   0%|          | 0/1000 [00:00<?, ?it/s]
# ----*----------*-------------*--------Inspect TRAFO Node: x2 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance
#
# ----*----------*-------------*--------Inspect TRAFO Node: x3 ------------*-----------------*-------------------*--
# skipped.. since h does depend on parents and is different for every instance

# %%
inspect_trafo_standart_logistic(conf_dict,EXPERIMENT_DIR,train_df,val_df,device,verbose=False)
# Out:
# ----*----------*-------------*--------h(data) should be standard logistic: x1 ------------*-----------------*-------------------*--
# Train loader (x1): 100%|██████████| 1/1 [00:00<00:00,  1.57it/s]
# Val loader (x1): 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x2 ------------*-----------------*-------------------*--
# Train loader (x2): 100%|██████████| 1/1 [00:00<00:00,  1.92it/s]
# Val loader (x2): 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# ----*----------*-------------*--------h(data) should be standard logistic: x3 ------------*-----------------*-------------------*--
# Train loader (x3): 100%|██████████| 1/1 [00:00<00:00,  2.31it/s]
# Val loader (x3): 100%|██████████| 1/1 [00:00<00:00,  1.85it/s]

# %% [markdown]
# ### Coefficient estimates

# %%
# x1-> x2, x1-> x3, x2-> x3
true_coeffs = {'x2': [2],'x3': [-0.2, 0.3]}

for node in conf_dict:
    print(f'\n----*----------*-------------*--------check LS of {node} ------------*-----------------*-------------------*--')
    
    if conf_dict[node]['node_type'] == 'source':
        print(f"Node type :source")
        continue
    
    # Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    # Load saved shifts
    shift_path = os.path.join(NODE_DIR, "linear_shifts_all_epochs.json")
    with open(shift_path, 'r') as f:
        all_shift_weights = json.load(f)

    # Sort epochs numerically
    epochs = sorted(all_shift_weights.keys(), key=lambda x: int(x.split('_')[1]))

    # Number of shifts (incoming edges) for this node
    example_epoch = all_shift_weights[epochs[0]]
    num_shifts = len(example_epoch)

    # Plot per shift (incoming edge)
    for shifts_idx in range(num_shifts):
        

        shift_name = f"shift_{shifts_idx}"
        weights_over_time = []

        for epoch in epochs:
            weight_matrix = np.array(all_shift_weights[epoch][shift_name])  # shape: [out_features, in_features]
            avg_weight = weight_matrix.mean()
            weights_over_time.append(avg_weight)

        plt.figure()
        plt.plot(range(1, len(epochs) + 1), weights_over_time)

        # If this node has a true coefficient for this shift, draw a horizontal red line
        if node in true_coeffs:
            true_val = true_coeffs[node][shifts_idx]
            plt.axhline(y=true_val, color='r', linestyle='--', label=f"True coeff = {true_val}")
            plt.legend()

        plt.title(f"Linear Shift Weights in h({node}), ")
        plt.xlabel("Epoch")
        plt.ylabel(fr'$\hat{{\beta}}_{{{conf_dict[node]["parents"][shifts_idx]}}}$')
        plt.grid(True)
        plt.tight_layout()
        plt.show()
# Out:
# ----*----------*-------------*--------check LS of x1 ------------*-----------------*-------------------*--
# Node type :source
#
# ----*----------*-------------*--------check LS of x2 ------------*-----------------*-------------------*--
# ----*----------*-------------*--------check LS of x3 ------------*-----------------*-------------------*--
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 33
#      30 weights_over_time = []
#      32 for epoch in epochs:
# ---> 33     weight_matrix = np.array(all_shift_weights[epoch][shift_name])  # shape: [out_features, in_features]
#      34     avg_weight = weight_matrix.mean()
#      35     weights_over_time.append(avg_weight)
#
# KeyError: 'shift_0'

# %%
verbose=False


batch_size = 4112
for node in conf_dict:
    print(f'\n----*----------*-------------*--------check CS of {node} ------------*-----------------*-------------------*--')
    
    if (conf_dict[node]['node_type'] == 'source'):
        print(f"Node type : other , is not supported yet")
        continue
    
    
    #### 0. Paths
    NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
    
    ##### 1. Load model 
    model_path = os.path.join(NODE_DIR, "best_model.pt")
    tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose)
    tram_model = tram_model.to(device)
    tram_model.load_state_dict(torch.load(model_path))
    tram_model.eval()
    
    # for name, param in tram_model.state_dict().items():
    #     print(f"{name}: {param.data}")
        
    for i in range(len(tram_model.nn_shift)):
        print(tram_model.nn_shift[i].fc.weight.data)
# Out:
# ----*----------*-------------*--------check CS of x1 ------------*-----------------*-------------------*--
# Node type : other , is not supported yet
#
# ----*----------*-------------*--------check CS of x2 ------------*-----------------*-------------------*--
# tensor([[0.5895]], device='cuda:0')
#
# ----*----------*-------------*--------check CS of x3 ------------*-----------------*-------------------*--
# tensor([[-0.6292]], device='cuda:0')
# tensor([[0.2878]], device='cuda:0')

# %%
def sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            do_interventions,
                            n= 10_000,
                            batch_size = 32,
                            delete_all_previously_sampled=True,
                            verbose=True):

    if delete_all_previously_sampled:
        delete_all_samplings(conf_dict, EXPERIMENT_DIR)
        
    # repeat process until all nodes are sampled
    processed_nodes=[]
    while set(processed_nodes) != set([conf_dict.keys()]): 
        for node in conf_dict:
            if node in processed_nodes:
                if verbose :
                    print('node is already  in sampled list')
                continue
            
            print(f'\n----*----------*-------------*--------Sample Node: {node} ------------*-----------------*-------------------*--')
            
            
            
            ## TODO For DO interventions i just save the DO values for all datapoints as roots
            ## TODO change the names of roots to sampled
            
            
            ## 1. Paths 
            NODE_DIR = os.path.join(EXPERIMENT_DIR, f'{node}')
            SAMPLING_DIR = os.path.join(NODE_DIR, 'sampling')
            os.makedirs(SAMPLING_DIR, exist_ok=True)
            
            
            ## 2. Check if roots and latents already exist 
            if check_roots_and_latents(NODE_DIR, rootfinder='chandrupatla', verbose=verbose):
                processed_nodes.append(node)
                continue
            
            ## 3. logic to make sure parents are always sampled first
            skipping_node = False
            if conf_dict[node]['node_type'] != 'source':
                for parent in conf_dict[node]['parents']:
                    if not check_roots_and_latents(os.path.join(EXPERIMENT_DIR, parent), rootfinder='chandrupatla', verbose=verbose):
                        skipping_node = True
                        break
                    
            if skipping_node:
                print(f"Skipping {node} as parent {parent} is not sampled yet.")
                continue
            
            
            
            
            ### sampling latents
            latent_sample = torch.tensor(logistic.rvs(size=n), dtype=torch.float32).to(device)
            #latent_sample = truncated_logistic_sample(n=n, low=0, high=1, device=device)
            
            if verbose:
                print("-- sampled latents")
            
            
            ### load modelweights
            model_path = os.path.join(NODE_DIR, "best_model.pt")
            tram_model = get_fully_specified_tram_model(node, conf_dict, verbose=verbose).to(device)
            tram_model.load_state_dict(torch.load(model_path))
            
            if verbose:
                print("-- loaded modelweights")
                
            dataset = SamplingDataset(node=node, EXPERIMENT_DIR=EXPERIMENT_DIR, rootfinder='chandrupatla', number_of_samples=n, conf_dict=conf_dict, transform=None)
            sample_loader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=0)
            
            output_list = []
            with torch.no_grad():
                for x in tqdm(sample_loader, desc=f"h() for samples in  {node}"):
                    x = [xi.to(device) for xi in x]
                    int_input, shift_list = preprocess_inputs(x, device=device)
                    model_outputs = tram_model(int_input=int_input, shift_input=shift_list)
                    output_list.append(model_outputs)
                    
            if conf_dict[node]['node_type'] == 'source':
                if verbose:
                    print("source node, Defaults to SI and 1 as inputs")
                theta_single = output_list[0]['int_out'][0]
                theta_single = transform_intercepts_continous(theta_single)
                thetas_expanded = theta_single.repeat(n, 1)
                shifts = torch.zeros(n, device=device)
            else:
                if verbose:
                    print("node has parents, previously sampled data is loaded for each pa(node)")
                y_pred = merge_outputs(output_list, skip_nan=True)
                shifts = y_pred['shift_out']
                if shifts is None:
                    print("shift_out was None; defaulting to zeros.")
                    shifts = torch.zeros(n, device=device)
                thetas = y_pred['int_out']
                thetas_expanded = transform_intercepts_continous(thetas).squeeze()
                shifts = shifts.squeeze()
            
            
            
            low = torch.full((n,), -1e5, device=device)
            high = torch.full((n,), 1e5, device=device)
            
            min_vals = torch.tensor(conf_dict[node]['min'], dtype=torch.float32).to(device)
            max_vals = torch.tensor(conf_dict[node]['max'], dtype=torch.float32).to(device)
            min_max = torch.stack([min_vals, max_vals], dim=0)
            
            
            ## Root finder using Chandrupatla's method
            def f_vectorized(targets):
                return vectorized_object_function(
                    thetas_expanded,
                    targets,
                    shifts,
                    latent_sample,
                    k_min=min_max[0],
                    k_max=min_max[1]
                )
                
            root = chandrupatla_root_finder(
                f_vectorized,
                low,
                high,
                max_iter=10_000,
                tol=1e-9
            )
            
            ## Saving
            root_path = os.path.join(SAMPLING_DIR, "roots_chandrupatla.pt")
            latents_path = os.path.join(SAMPLING_DIR, "latents.pt")
            
            if torch.isnan(root).any():
                print(f'Caution! Sampling for {node} consists of NaNs')
                
            torch.save(root, root_path)
            torch.save(latent_sample, latents_path)
            
            processed_nodes.append(node)

# %% [markdown]
# # 7. Sample from Graph

# %%
sample_full_dag_chandru(conf_dict,
                            EXPERIMENT_DIR,
                            device,
                            n= 10_000,
                            batch_size = 1,
                            delete_all_previously_sampled=True,
                            verbose=True)
# Out:
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x1/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/sampling
# Deleted directory: /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x1/sampling
# -- sampled latents
# >>>>>>>>>>>>  source node --> only  modelled only  by si
# TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
# )
# -- loaded modelweights
# h() for samples in  x1: 100%|██████████| 10000/10000 [00:03<00:00, 3096.79it/s]
# source node, Defaults to SI and 1 as inputs
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:57<00:00, 172.72it/s]
# /home/bule/TramDag/utils/sampling_tram_data.py:45: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   tensor_list.append(torch.tensor(tensor))  # ensure tensor type
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x2/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0): LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x2: 100%|██████████| 10000/10000 [00:05<00:00, 1851.93it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:58<00:00, 172.38it/s]
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# Root or latent files not found in /home/bule/TramDag/dev_experiment_logs/tramdagpaper_exp6_1_linearDGP_ls_25/x3/sampling
# -- sampled latents
# >>>>>>>>>>>> No ci detected --> intercept defaults to si
# >>> TRAM MODEL:
#  TramModel(
#   (nn_int): SimpleIntercept(
#     (fc): Linear(in_features=1, out_features=20, bias=False)
#   )
#   (nn_shift): ModuleList(
#     (0-1): 2 x LinearShift(
#       (fc): Linear(in_features=1, out_features=1, bias=False)
#     )
#   )
# )
# -- loaded modelweights
# h() for samples in  x3: 100%|██████████| 10000/10000 [00:07<00:00, 1310.07it/s]
# node has parents, previously sampled data is loaded for each pa(node)
# Chandrupatla root finding: 100%|██████████| 10000/10000 [00:57<00:00, 172.61it/s]

# %% [markdown]
# ## 7.3 Inspect Sampling

# %%
show_samples_vs_true(test_df,conf_dict,EXPERIMENT_DIR,rootfinder='chandrupatla')
