# %% [markdown]
# # Experiment
#
# - same experiment as in https://arxiv.org/pdf/2503.16206 6.1 Conitnous Case
#
# 1. Linear-shift DGP and linear-shift model
# 2. **Complex-shift DGP and complex-shift model**  <------------------
# 3. Linear-shift DGP and complex-shift model
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## DATA

# %%
from scipy.special import logit
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import seaborn as sns


# 1. complex-shift DGP and linear-shift model 
def f(x):
    return 0.75*np.arctan(5*(x+0.12))  

def dgp(n_obs, doX=[None, None, None], seed=-1):
    if seed > 0:
        np.random.seed(seed)
        print(f"Setting Seed: {seed}")
    
    # Generate x1 from a 2-component GMM
    # h(x1)= SI 
    
    if doX[0] is None:
        x1_A = np.random.normal(0.25, 0.1, n_obs)
        x1_B = np.random.normal(0.73, 0.05, n_obs)
        mix = np.random.choice([0, 1], size=n_obs)
        x1 = np.where(mix == 0, x1_A, x1_B)
    else:
        x1 = np.full(n_obs, doX[0])

    # Fz(z)=Fy(y)
    # Fz(h(y|x))=Fy(y)    | z= h(y|x)

    # Generate x2
    
    # h(x2|x1)= Bernsteinpol(x2) + beta2 * x1        | bernsteinpol is just linearized assumed with a constant factor say 0.42
    # h(x2|x1)= 0.42*x2 + beta2 * x1                 | replace h(x2|x1) with z
    # z       = 0.42*x2 + beta2 * x1                 | reformulate to x2
    # x2      = (z-beta2 * x1 )/0.42                 | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x2      = (z-beta2 * x1 )/0.42                 | set beta = 2 (on the edge of the graph)
    # x2      = (z-2 * x1 )/0.42                     |
    
    if doX[1] is None:
        u2 = np.random.uniform(size=n_obs)
        z2 = logit(u2)
        x2 = (z2 - 2 * x1) / 5#5#   0.42  in the trainagle strucutred cont last line is 5 for SI
    else:
        x2 = np.full(n_obs, doX[1])

    # Generate x3
    
    # h(x3|x2,x1)= Bernsteinpol(x3) + beta3 * x1 -f(X2)        | bernsteinpol is just linearized assumed with a constant factor say 0.63
    # h(x3|x2,x1)= 0.63*x3 + beta3 * x1          - f(X2)        | replace h(x2|x1) with z
    # z3          = 0.63*x3 + beta3 * x1          - f(X2)        | reformulate to x2
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | sample z from standart logistic via uniform and logit(np.random.uniform(size=n_obs))
    # x3         = (z3-beta3 * x1 +f(X2))/0.63                   | set beta = -0.2 (on the edge of the graph)
    # x3         = (z3+0.2 * x1   +f(X2))/0.63                   | 

    if doX[2] is None:
        u3 = np.random.uniform(size=n_obs)
        z3 = logit(u3)
        x3 = (z3 + 0.2 * x1 + f(x2)) / 0.63
    else:
        x3 = np.full(n_obs, doX[2])
        
    #df = pd.DataFrame({'x1': x1, 'x2': x2})#, 'x3': x3})
    df = pd.DataFrame({'x1': x1, 'x2': x2, 'x3': x3})
    return df

df = dgp(n_obs=100_000, seed=42)
df.info()
sns.pairplot(df)

train_df, temp_df = train_test_split(df, test_size=0.2, random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42)
print(f"Train size: {len(train_df)}, Validation size: {len(val_df)}, Test size: {len(test_df)}")
# Out:
# Setting Seed: 42
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   x1      100000 non-null  float64
#  1   x2      100000 non-null  float64
#  2   x3      100000 non-null  float64
# dtypes: float64(3)
# memory usage: 2.3 MB
# Train size: 80000, Validation size: 10000, Test size: 10000

# %% [markdown]
# # Model Configuration and Setup

# %%
from tramdag import TramDagConfig
import os

# %%
experiment_name = "Continous_3_vars_complex_DGP_LS"      ## <--- set experiment name
EXPERIMENT_DIR = os.path.join(os.getcwd(), experiment_name)
CONF_DICT_PATH = os.path.join(EXPERIMENT_DIR, f"configuration.json")
cfg=TramDagConfig()
cfg.setup_configuration(experiment_name,EXPERIMENT_DIR)
# Out:
# Created new configuration file at /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/configuration.json

# %%
data_type= {'x1':'continous','x2':'continous','x3':'continous'} 
cfg.set_data_type(data_type)
# Out:
# ---------------------------------------------------------------------------------------------------------
#                                        |                       MODEL SETTINGS
# Variable             | dtype           | As Predictor                   | As Target
# ---------------------------------------------------------------------------------------------------------
# x1                   | continous       | continuous [c]                 | continuous [c]
# x2                   | continous       | continuous [c]                 | continuous [c]
# x3                   | continous       | continuous [c]                 | continuous [c]
# ---------------------------------------------------------------------------------------------------------
# Configuration updated successfully at /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/configuration.json.

# %%
cfg.set_meta_adj_matrix()
# Out:
# No matrix found. Please fill out the DAG and click 'Generate'.
# --------------HINT:-------------
#
# Enter 0 if no arrow exists.
#
# ls = Linear shift
# cs = Complex shift
#
# ci = Complex intercept
# Simple intercepts must NOT be specified — they are automatically provided unless a complex intercept is defined.
#
# If variables interact, specify interaction terms as follows:
#   Example: cs(x1,x2)
#     → at x1: cs11
#     → at x2: cs12
# If another interacting group exists (e.g. x3, x4) on the same node:
#     → at x3: cs21
#     → at x4: cs22
#
# the sam e works for complex intercept but only one group is allowd:
# Note: The first number denotes the interaction group, and the second the participant. This numbering scheme is used internally to maintain consistent input ordering.
# VBox(children=(Label(value="Fill in the adjacency matrix (upper triangle only).: Use 'ls', 'cs', etc. to defin…

# %%
cfg.set_tramdag_nn_models()
# Out:
# *************
# Model has Complex intercepts and/or Complex shifts.
#
# For standard networks, hit the 'Generate' button.
#
# If you want to add your own models for complex shifts and/or complex intercepts,
# add them to models.py, reload, then enter the model name in the corresponding field
# in this tool and hit 'Generate'.
# *************
# VBox(children=(Label(value='Edit only the existing model names (non-zero entries).'), GridBox(children=(Label(…

# %% [markdown]
# # Model Fit

# %%
from tramdag import TramDagModel
device='cpu'

# %%
td_model = TramDagModel.from_config(cfg, set_initial_weights=True,verbose=True,debug=False,device=device,initial_data = train_df)
# Out:
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )
# [INFO] Initialized intercept model with preinitialized weights: SimpleIntercept(
#   (fc): Linear(in_features=1, out_features=20, bias=False)
# )

# %%
EPOCHS=300 
BATCH_SIZE=1000


td_model.fit(train_df, val_df,
             learning_rate=1e-2,
             epochs=EPOCHS,
             batch_size=BATCH_SIZE,
             device=device,
             num_workers=8,
             prefetch_factor=8,
             persistent_workers =True)
# Out:
# [INFO] Computing new minmax dict from training data...
# [INFO] Saved new minmax dict to /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/min_max_scaling.json
# [INFO] Training 3 nodes (sequential) on cpu
#
# [INFO] Training node 'x1' for 300 epochs on cpu (pid=3042540)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# ===== Epoch 151/300 =====
# [INFO] Saved simple intercept weights for epoch 151 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 151: Train NLL=-0.5740 | Val NLL=-0.5783 | Time=1.20s
#
# ===== Epoch 152/300 =====
# [INFO] Saved simple intercept weights for epoch 152 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 152: Train NLL=-0.5740 | Val NLL=-0.5783 | Time=0.87s
#
# ===== Epoch 153/300 =====
# [INFO] Saved simple intercept weights for epoch 153 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 153: Train NLL=-0.5740 | Val NLL=-0.5784 | Time=0.76s
#
# ===== Epoch 154/300 =====
# [INFO] Saved simple intercept weights for epoch 154 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 154: Train NLL=-0.5740 | Val NLL=-0.5784 | Time=0.74s
#
# ===== Epoch 155/300 =====
# [INFO] Saved simple intercept weights for epoch 155 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 155: Train NLL=-0.5740 | Val NLL=-0.5784 | Time=0.76s
#
# ===== Epoch 156/300 =====
# [INFO] Saved simple intercept weights for epoch 156 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 156: Train NLL=-0.5740 | Val NLL=-0.5784 | Time=0.75s
#
# ===== Epoch 157/300 =====
# [INFO] Saved simple intercept weights for epoch 157 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 157: Train NLL=-0.5741 | Val NLL=-0.5784 | Time=0.77s
#
# ===== Epoch 158/300 =====
# [INFO] Saved simple intercept weights for epoch 158 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 158: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.72s
#
# ===== Epoch 159/300 =====
# [INFO] Saved simple intercept weights for epoch 159 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 159: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.77s
#
# ===== Epoch 160/300 =====
# [INFO] Saved simple intercept weights for epoch 160 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 160: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.98s
#
# ===== Epoch 161/300 =====
# [INFO] Saved simple intercept weights for epoch 161 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 161: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.70s
#
# ===== Epoch 162/300 =====
# [INFO] Saved simple intercept weights for epoch 162 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 162: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.79s
#
# ===== Epoch 163/300 =====
# [INFO] Saved simple intercept weights for epoch 163 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 163: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.74s
#
# ===== Epoch 164/300 =====
# [INFO] Saved simple intercept weights for epoch 164 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 164: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.74s
#
# ===== Epoch 165/300 =====
# [INFO] Saved simple intercept weights for epoch 165 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 165: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.77s
#
# ===== Epoch 166/300 =====
# [INFO] Saved simple intercept weights for epoch 166 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 166: Train NLL=-0.5741 | Val NLL=-0.5785 | Time=0.85s
#
# ===== Epoch 167/300 =====
# [INFO] Saved simple intercept weights for epoch 167 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 167: Train NLL=-0.5742 | Val NLL=-0.5785 | Time=0.71s
#
# ===== Epoch 168/300 =====
# [INFO] Saved simple intercept weights for epoch 168 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 168: Train NLL=-0.5742 | Val NLL=-0.5785 | Time=0.75s
#
# ===== Epoch 169/300 =====
# [INFO] Saved simple intercept weights for epoch 169 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 169: Train NLL=-0.5742 | Val NLL=-0.5785 | Time=1.04s
#
# ===== Epoch 170/300 =====
# [INFO] Saved simple intercept weights for epoch 170 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 170: Train NLL=-0.5742 | Val NLL=-0.5785 | Time=0.75s
#
# ===== Epoch 171/300 =====
# [INFO] Saved simple intercept weights for epoch 171 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 171: Train NLL=-0.5742 | Val NLL=-0.5785 | Time=0.71s
#
# ===== Epoch 172/300 =====
# [INFO] Saved simple intercept weights for epoch 172 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 172: Train NLL=-0.5742 | Val NLL=-0.5786 | Time=0.76s
#
# ===== Epoch 173/300 =====
# [INFO] Saved simple intercept weights for epoch 173 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 173: Train NLL=-0.5742 | Val NLL=-0.5786 | Time=0.88s
#
# ===== Epoch 174/300 =====
# [INFO] Saved simple intercept weights for epoch 174 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 174: Train NLL=-0.5742 | Val NLL=-0.5786 | Time=0.72s
#
# ===== Epoch 175/300 =====
# [INFO] Saved simple intercept weights for epoch 175 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 175: Train NLL=-0.5742 | Val NLL=-0.5786 | Time=0.73s
#
# ===== Epoch 176/300 =====
# [INFO] Saved simple intercept weights for epoch 176 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 176: Train NLL=-0.5742 | Val NLL=-0.5786 | Time=0.94s
#
# ===== Epoch 177/300 =====
# [INFO] Saved simple intercept weights for epoch 177 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 177: Train NLL=-0.5742 | Val NLL=-0.5786 | Time=0.92s
#
# ===== Epoch 178/300 =====
# [INFO] Saved simple intercept weights for epoch 178 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 178: Train NLL=-0.5743 | Val NLL=-0.5786 | Time=0.75s
#
# ===== Epoch 179/300 =====
# [INFO] Saved simple intercept weights for epoch 179 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 179: Train NLL=-0.5742 | Val NLL=-0.5786 | Time=0.88s
#
# ===== Epoch 180/300 =====
# [INFO] Saved simple intercept weights for epoch 180 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 180: Train NLL=-0.5743 | Val NLL=-0.5786 | Time=0.79s
#
# ===== Epoch 181/300 =====
# [INFO] Saved simple intercept weights for epoch 181 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 181: Train NLL=-0.5743 | Val NLL=-0.5786 | Time=0.79s
#
# ===== Epoch 182/300 =====
# [INFO] Saved simple intercept weights for epoch 182 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 182: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=1.09s
#
# ===== Epoch 183/300 =====
# [INFO] Saved simple intercept weights for epoch 183 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 183: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.75s
#
# ===== Epoch 184/300 =====
# [INFO] Saved simple intercept weights for epoch 184 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 184: Train NLL=-0.5743 | Val NLL=-0.5786 | Time=0.78s
#
# ===== Epoch 185/300 =====
# [INFO] Saved simple intercept weights for epoch 185 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 185: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.85s
#
# ===== Epoch 186/300 =====
# [INFO] Saved simple intercept weights for epoch 186 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 186: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.88s
#
# ===== Epoch 187/300 =====
# [INFO] Saved simple intercept weights for epoch 187 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 187: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.79s
#
# ===== Epoch 188/300 =====
# [INFO] Saved simple intercept weights for epoch 188 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 188: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.70s
#
# ===== Epoch 189/300 =====
# [INFO] Saved simple intercept weights for epoch 189 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 189: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.84s
#
# ===== Epoch 190/300 =====
# [INFO] Saved simple intercept weights for epoch 190 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 190: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.73s
#
# ===== Epoch 191/300 =====
# [INFO] Saved simple intercept weights for epoch 191 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 191: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.72s
#
# ===== Epoch 192/300 =====
# [INFO] Saved simple intercept weights for epoch 192 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 192: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.92s
#
# ===== Epoch 193/300 =====
# [INFO] Saved simple intercept weights for epoch 193 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 193: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.74s
#
# ===== Epoch 194/300 =====
# [INFO] Saved simple intercept weights for epoch 194 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 194: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.71s
#
# ===== Epoch 195/300 =====
# [INFO] Saved simple intercept weights for epoch 195 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 195: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.78s
#
# ===== Epoch 196/300 =====
# [INFO] Saved simple intercept weights for epoch 196 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 196: Train NLL=-0.5743 | Val NLL=-0.5786 | Time=0.77s
#
# ===== Epoch 197/300 =====
# [INFO] Saved simple intercept weights for epoch 197 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 197: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.83s
#
# ===== Epoch 198/300 =====
# [INFO] Saved simple intercept weights for epoch 198 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 198: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.79s
#
# ===== Epoch 199/300 =====
# [INFO] Saved simple intercept weights for epoch 199 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 199: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.89s
#
# ===== Epoch 200/300 =====
# [INFO] Saved simple intercept weights for epoch 200 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 200: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.76s
#
# ===== Epoch 201/300 =====
# [INFO] Saved simple intercept weights for epoch 201 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 201: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.72s
#
# ===== Epoch 202/300 =====
# [INFO] Saved simple intercept weights for epoch 202 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 202: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=1.03s
#
# ===== Epoch 203/300 =====
# [INFO] Saved simple intercept weights for epoch 203 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 203: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.85s
#
# ===== Epoch 204/300 =====
# [INFO] Saved simple intercept weights for epoch 204 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 204: Train NLL=-0.5743 | Val NLL=-0.5787 | Time=0.81s
#
# ===== Epoch 205/300 =====
# [INFO] Saved simple intercept weights for epoch 205 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 205: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.76s
#
# ===== Epoch 206/300 =====
# [INFO] Saved simple intercept weights for epoch 206 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 206: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.74s
#
# ===== Epoch 207/300 =====
# [INFO] Saved simple intercept weights for epoch 207 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 207: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.83s
#
# ===== Epoch 208/300 =====
# [INFO] Saved simple intercept weights for epoch 208 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 208: Train NLL=-0.5744 | Val NLL=-0.5786 | Time=0.79s
#
# ===== Epoch 209/300 =====
# [INFO] Saved simple intercept weights for epoch 209 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 209: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.81s
#
# ===== Epoch 210/300 =====
# [INFO] Saved simple intercept weights for epoch 210 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 210: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.81s
#
# ===== Epoch 211/300 =====
# [INFO] Saved simple intercept weights for epoch 211 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 211: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.88s
#
# ===== Epoch 212/300 =====
# [INFO] Saved simple intercept weights for epoch 212 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 212: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.87s
#
# ===== Epoch 213/300 =====
# [INFO] Saved simple intercept weights for epoch 213 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 213: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.76s
#
# ===== Epoch 214/300 =====
# [INFO] Saved simple intercept weights for epoch 214 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 214: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.75s
#
# ===== Epoch 215/300 =====
# [INFO] Saved simple intercept weights for epoch 215 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 215: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.83s
#
# ===== Epoch 216/300 =====
# [INFO] Saved simple intercept weights for epoch 216 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 216: Train NLL=-0.5744 | Val NLL=-0.5786 | Time=0.81s
#
# ===== Epoch 217/300 =====
# [INFO] Saved simple intercept weights for epoch 217 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 217: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.74s
#
# ===== Epoch 218/300 =====
# [INFO] Saved simple intercept weights for epoch 218 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 218: Train NLL=-0.5744 | Val NLL=-0.5787 | Time=0.95s
#
# ===== Epoch 219/300 =====
# [INFO] Saved simple intercept weights for epoch 219 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 219: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.90s
#
# ===== Epoch 220/300 =====
# [INFO] Saved simple intercept weights for epoch 220 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 220: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.93s
#
# ===== Epoch 221/300 =====
# [INFO] Saved simple intercept weights for epoch 221 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 221: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.94s
#
# ===== Epoch 222/300 =====
# [INFO] Saved simple intercept weights for epoch 222 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 222: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.74s
#
# ===== Epoch 223/300 =====
# [INFO] Saved simple intercept weights for epoch 223 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 223: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.76s
#
# ===== Epoch 224/300 =====
# [INFO] Saved simple intercept weights for epoch 224 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 224: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.77s
#
# ===== Epoch 225/300 =====
# [INFO] Saved simple intercept weights for epoch 225 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 225: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.73s
#
# ===== Epoch 226/300 =====
# [INFO] Saved simple intercept weights for epoch 226 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 226: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.90s
#
# ===== Epoch 227/300 =====
# [INFO] Saved simple intercept weights for epoch 227 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 227: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.76s
#
# ===== Epoch 228/300 =====
# [INFO] Saved simple intercept weights for epoch 228 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 228: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=1.02s
#
# ===== Epoch 229/300 =====
# [INFO] Saved simple intercept weights for epoch 229 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 229: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.80s
#
# ===== Epoch 230/300 =====
# [INFO] Saved simple intercept weights for epoch 230 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 230: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.81s
#
# ===== Epoch 231/300 =====
# [INFO] Saved simple intercept weights for epoch 231 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 231: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.83s
#
# ===== Epoch 232/300 =====
# [INFO] Saved simple intercept weights for epoch 232 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 232: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.93s
#
# ===== Epoch 233/300 =====
# [INFO] Saved simple intercept weights for epoch 233 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 233: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.93s
#
# ===== Epoch 234/300 =====
# [INFO] Saved simple intercept weights for epoch 234 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 234: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.77s
#
# ===== Epoch 235/300 =====
# [INFO] Saved simple intercept weights for epoch 235 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 235: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.87s
#
# ===== Epoch 236/300 =====
# [INFO] Saved simple intercept weights for epoch 236 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 236: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.77s
#
# ===== Epoch 237/300 =====
# [INFO] Saved simple intercept weights for epoch 237 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 237: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.76s
#
# ===== Epoch 238/300 =====
# [INFO] Saved simple intercept weights for epoch 238 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 238: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.79s
#
# ===== Epoch 239/300 =====
# [INFO] Saved simple intercept weights for epoch 239 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 239: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.84s
#
# ===== Epoch 240/300 =====
# [INFO] Saved simple intercept weights for epoch 240 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 240: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.80s
#
# ===== Epoch 241/300 =====
# [INFO] Saved simple intercept weights for epoch 241 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 241: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.85s
#
# ===== Epoch 242/300 =====
# [INFO] Saved simple intercept weights for epoch 242 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 242: Train NLL=-0.5744 | Val NLL=-0.5789 | Time=0.77s
#
# ===== Epoch 243/300 =====
# [INFO] Saved simple intercept weights for epoch 243 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 243: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.95s
#
# ===== Epoch 244/300 =====
# [INFO] Saved simple intercept weights for epoch 244 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 244: Train NLL=-0.5744 | Val NLL=-0.5789 | Time=0.81s
#
# ===== Epoch 245/300 =====
# [INFO] Saved simple intercept weights for epoch 245 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 245: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.77s
#
# ===== Epoch 246/300 =====
# [INFO] Saved simple intercept weights for epoch 246 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 246: Train NLL=-0.5744 | Val NLL=-0.5789 | Time=0.79s
#
# ===== Epoch 247/300 =====
# [INFO] Saved simple intercept weights for epoch 247 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 247: Train NLL=-0.5744 | Val NLL=-0.5789 | Time=0.89s
#
# ===== Epoch 248/300 =====
# [INFO] Saved simple intercept weights for epoch 248 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 248: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.82s
#
# ===== Epoch 249/300 =====
# [INFO] Saved simple intercept weights for epoch 249 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 249: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.75s
#
# ===== Epoch 250/300 =====
# [INFO] Saved simple intercept weights for epoch 250 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 250: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=1.01s
#
# ===== Epoch 251/300 =====
# [INFO] Saved simple intercept weights for epoch 251 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 251: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.83s
#
# ===== Epoch 252/300 =====
# [INFO] Saved simple intercept weights for epoch 252 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 252: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.86s
#
# ===== Epoch 253/300 =====
# [INFO] Saved simple intercept weights for epoch 253 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 253: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.89s
#
# ===== Epoch 254/300 =====
# [INFO] Saved simple intercept weights for epoch 254 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 254: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.75s
#
# ===== Epoch 255/300 =====
# [INFO] Saved simple intercept weights for epoch 255 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 255: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.88s
#
# ===== Epoch 256/300 =====
# [INFO] Saved simple intercept weights for epoch 256 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 256: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.96s
#
# ===== Epoch 257/300 =====
# [INFO] Saved simple intercept weights for epoch 257 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 257: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.79s
#
# ===== Epoch 258/300 =====
# [INFO] Saved simple intercept weights for epoch 258 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 258: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.76s
#
# ===== Epoch 259/300 =====
# [INFO] Saved simple intercept weights for epoch 259 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 259: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.74s
#
# ===== Epoch 260/300 =====
# [INFO] Saved simple intercept weights for epoch 260 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 260: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.92s
#
# ===== Epoch 261/300 =====
# [INFO] Saved simple intercept weights for epoch 261 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 261: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.76s
#
# ===== Epoch 262/300 =====
# [INFO] Saved simple intercept weights for epoch 262 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 262: Train NLL=-0.5744 | Val NLL=-0.5789 | Time=0.75s
#
# ===== Epoch 263/300 =====
# [INFO] Saved simple intercept weights for epoch 263 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 263: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.91s
#
# ===== Epoch 264/300 =====
# [INFO] Saved simple intercept weights for epoch 264 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 264: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.77s
#
# ===== Epoch 265/300 =====
# [INFO] Saved simple intercept weights for epoch 265 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 265: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.87s
#
# ===== Epoch 266/300 =====
# [INFO] Saved simple intercept weights for epoch 266 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 266: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.77s
#
# ===== Epoch 267/300 =====
# [INFO] Saved simple intercept weights for epoch 267 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 267: Train NLL=-0.5744 | Val NLL=-0.5788 | Time=0.76s
#
# ===== Epoch 268/300 =====
# [INFO] Saved simple intercept weights for epoch 268 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 268: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.91s
#
# ===== Epoch 269/300 =====
# [INFO] Saved simple intercept weights for epoch 269 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 269: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.78s
#
# ===== Epoch 270/300 =====
# [INFO] Saved simple intercept weights for epoch 270 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 270: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.88s
#
# ===== Epoch 271/300 =====
# [INFO] Saved simple intercept weights for epoch 271 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 271: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.76s
#
# ===== Epoch 272/300 =====
# [INFO] Saved simple intercept weights for epoch 272 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 272: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.98s
#
# ===== Epoch 273/300 =====
# [INFO] Saved simple intercept weights for epoch 273 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 273: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.89s
#
# ===== Epoch 274/300 =====
# [INFO] Saved simple intercept weights for epoch 274 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 274: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.95s
#
# ===== Epoch 275/300 =====
# [INFO] Saved simple intercept weights for epoch 275 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 275: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.82s
#
# ===== Epoch 276/300 =====
# [INFO] Saved simple intercept weights for epoch 276 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 276: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.92s
#
# ===== Epoch 277/300 =====
# [INFO] Saved simple intercept weights for epoch 277 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 277: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.88s
#
# ===== Epoch 278/300 =====
# [INFO] Saved simple intercept weights for epoch 278 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 278: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.73s
#
# ===== Epoch 279/300 =====
# [INFO] Saved simple intercept weights for epoch 279 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 279: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.97s
#
# ===== Epoch 280/300 =====
# [INFO] Saved simple intercept weights for epoch 280 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 280: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.85s
#
# ===== Epoch 281/300 =====
# [INFO] Saved simple intercept weights for epoch 281 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 281: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.77s
#
# ===== Epoch 282/300 =====
# [INFO] Saved simple intercept weights for epoch 282 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 282: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.76s
#
# ===== Epoch 283/300 =====
# [INFO] Saved simple intercept weights for epoch 283 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 283: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.77s
#
# ===== Epoch 284/300 =====
# [INFO] Saved simple intercept weights for epoch 284 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 284: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.71s
#
# ===== Epoch 285/300 =====
# [INFO] Saved simple intercept weights for epoch 285 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 285: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.76s
#
# ===== Epoch 286/300 =====
# [INFO] Saved simple intercept weights for epoch 286 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 286: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.80s
#
# ===== Epoch 287/300 =====
# [INFO] Saved simple intercept weights for epoch 287 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 287: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.92s
#
# ===== Epoch 288/300 =====
# [INFO] Saved simple intercept weights for epoch 288 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 288: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.79s
#
# ===== Epoch 289/300 =====
# [INFO] Saved simple intercept weights for epoch 289 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 289: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.81s
#
# ===== Epoch 290/300 =====
# [INFO] Saved simple intercept weights for epoch 290 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 290: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.92s
#
# ===== Epoch 291/300 =====
# [INFO] Saved simple intercept weights for epoch 291 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 291: Train NLL=-0.5744 | Val NLL=-0.5789 | Time=0.77s
#
# ===== Epoch 292/300 =====
# [INFO] Saved simple intercept weights for epoch 292 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 292: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.77s
#
# ===== Epoch 293/300 =====
# [INFO] Saved simple intercept weights for epoch 293 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 293: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.74s
#
# ===== Epoch 294/300 =====
# [INFO] Saved simple intercept weights for epoch 294 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 294: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.87s
#
# ===== Epoch 295/300 =====
# [INFO] Saved simple intercept weights for epoch 295 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 295: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=1.06s
#
# ===== Epoch 296/300 =====
# [INFO] Saved simple intercept weights for epoch 296 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 296: Train NLL=-0.5745 | Val NLL=-0.5788 | Time=0.83s
#
# ===== Epoch 297/300 =====
# [INFO] Saved simple intercept weights for epoch 297 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 297: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.80s
#
# ===== Epoch 298/300 =====
# [INFO] Saved simple intercept weights for epoch 298 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 298: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.74s
#
# ===== Epoch 299/300 =====
# [INFO] Saved simple intercept weights for epoch 299 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 299: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.78s
#
# ===== Epoch 300/300 =====
# [INFO] Saved simple intercept weights for epoch 300 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/simple_intercepts_all_epochs.json
# [INFO] Epoch 300: Train NLL=-0.5745 | Val NLL=-0.5789 | Time=0.84s
#
# [INFO] Training node 'x2' for 300 epochs on cpu (pid=3042540)
# [INFO] Existing model found. Loading weights and history from LAST model...
#
# ===== Epoch 151/300 =====
# [INFO] Saved linear shift weights for epoch 151 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 151 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 151: Train NLL=0.3482 | Val NLL=0.3429 | Time=1.30s
#
# ===== Epoch 152/300 =====
# [INFO] Saved linear shift weights for epoch 152 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 152 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 152: Train NLL=0.3482 | Val NLL=0.3429 | Time=0.88s
#
# ===== Epoch 153/300 =====
# [INFO] Saved linear shift weights for epoch 153 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 153 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 153: Train NLL=0.3482 | Val NLL=0.3428 | Time=0.84s
#
# ===== Epoch 154/300 =====
# [INFO] Saved linear shift weights for epoch 154 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 154 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 154: Train NLL=0.3482 | Val NLL=0.3427 | Time=0.87s
#
# ===== Epoch 155/300 =====
# [INFO] Saved linear shift weights for epoch 155 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 155 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 155: Train NLL=0.3481 | Val NLL=0.3427 | Time=0.98s
#
# ===== Epoch 156/300 =====
# [INFO] Saved linear shift weights for epoch 156 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 156 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 156: Train NLL=0.3481 | Val NLL=0.3427 | Time=0.82s
#
# ===== Epoch 157/300 =====
# [INFO] Saved linear shift weights for epoch 157 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 157 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 157: Train NLL=0.3481 | Val NLL=0.3427 | Time=0.86s
#
# ===== Epoch 158/300 =====
# [INFO] Saved linear shift weights for epoch 158 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 158 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 158: Train NLL=0.3481 | Val NLL=0.3426 | Time=0.81s
#
# ===== Epoch 159/300 =====
# [INFO] Saved linear shift weights for epoch 159 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 159 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 159: Train NLL=0.3481 | Val NLL=0.3427 | Time=0.80s
#
# ===== Epoch 160/300 =====
# [INFO] Saved linear shift weights for epoch 160 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 160 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 160: Train NLL=0.3480 | Val NLL=0.3429 | Time=1.01s
#
# ===== Epoch 161/300 =====
# [INFO] Saved linear shift weights for epoch 161 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 161 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 161: Train NLL=0.3480 | Val NLL=0.3426 | Time=1.07s
#
# ===== Epoch 162/300 =====
# [INFO] Saved linear shift weights for epoch 162 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 162 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 162: Train NLL=0.3480 | Val NLL=0.3430 | Time=0.90s
#
# ===== Epoch 163/300 =====
# [INFO] Saved linear shift weights for epoch 163 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 163 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 163: Train NLL=0.3480 | Val NLL=0.3426 | Time=0.80s
#
# ===== Epoch 164/300 =====
# [INFO] Saved linear shift weights for epoch 164 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 164 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 164: Train NLL=0.3480 | Val NLL=0.3425 | Time=0.94s
#
# ===== Epoch 165/300 =====
# [INFO] Saved linear shift weights for epoch 165 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 165 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 165: Train NLL=0.3480 | Val NLL=0.3426 | Time=0.85s
#
# ===== Epoch 166/300 =====
# [INFO] Saved linear shift weights for epoch 166 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 166 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 166: Train NLL=0.3480 | Val NLL=0.3425 | Time=0.83s
#
# ===== Epoch 167/300 =====
# [INFO] Saved linear shift weights for epoch 167 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 167 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 167: Train NLL=0.3480 | Val NLL=0.3426 | Time=0.94s
#
# ===== Epoch 168/300 =====
# [INFO] Saved linear shift weights for epoch 168 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 168 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Epoch 168: Train NLL=0.3479 | Val NLL=0.3426 | Time=0.82s
#
# ===== Epoch 169/300 =====
# [INFO] Saved linear shift weights for epoch 169 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 169 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 169: Train NLL=0.3479 | Val NLL=0.3425 | Time=0.88s
#
# ===== Epoch 170/300 =====
# ...
# [INFO] Saved simple intercept weights for epoch 262 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 262: Train NLL=2.4169 | Val NLL=2.4151 | Time=1.24s
#
# ===== Epoch 263/300 =====
# [INFO] Saved linear shift weights for epoch 263 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 263 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 263: Train NLL=2.4168 | Val NLL=2.4152 | Time=1.10s
#
# ===== Epoch 264/300 =====
# [INFO] Saved linear shift weights for epoch 264 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 264 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 264: Train NLL=2.4170 | Val NLL=2.4152 | Time=1.25s
#
# ===== Epoch 265/300 =====
# [INFO] Saved linear shift weights for epoch 265 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 265 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 265: Train NLL=2.4169 | Val NLL=2.4151 | Time=1.11s
#
# ===== Epoch 266/300 =====
# [INFO] Saved linear shift weights for epoch 266 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 266 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 266: Train NLL=2.4171 | Val NLL=2.4148 | Time=1.08s
#
# ===== Epoch 267/300 =====
# [INFO] Saved linear shift weights for epoch 267 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 267 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 267: Train NLL=2.4166 | Val NLL=2.4152 | Time=1.27s
#
# ===== Epoch 268/300 =====
# [INFO] Saved linear shift weights for epoch 268 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 268 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 268: Train NLL=2.4170 | Val NLL=2.4150 | Time=1.20s
#
# ===== Epoch 269/300 =====
# [INFO] Saved linear shift weights for epoch 269 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 269 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 269: Train NLL=2.4169 | Val NLL=2.4150 | Time=1.19s
#
# ===== Epoch 270/300 =====
# [INFO] Saved linear shift weights for epoch 270 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 270 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 270: Train NLL=2.4170 | Val NLL=2.4154 | Time=1.11s
#
# ===== Epoch 271/300 =====
# [INFO] Saved linear shift weights for epoch 271 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 271 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 271: Train NLL=2.4175 | Val NLL=2.4151 | Time=1.05s
#
# ===== Epoch 272/300 =====
# [INFO] Saved linear shift weights for epoch 272 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 272 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 272: Train NLL=2.4166 | Val NLL=2.4149 | Time=1.10s
#
# ===== Epoch 273/300 =====
# [INFO] Saved linear shift weights for epoch 273 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 273 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 273: Train NLL=2.4165 | Val NLL=2.4148 | Time=1.10s
#
# ===== Epoch 274/300 =====
# [INFO] Saved linear shift weights for epoch 274 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 274 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 274: Train NLL=2.4171 | Val NLL=2.4147 | Time=1.14s
#
# ===== Epoch 275/300 =====
# [INFO] Saved linear shift weights for epoch 275 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 275 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 275: Train NLL=2.4167 | Val NLL=2.4146 | Time=1.06s
#
# ===== Epoch 276/300 =====
# [INFO] Saved linear shift weights for epoch 276 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 276 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 276: Train NLL=2.4169 | Val NLL=2.4153 | Time=1.32s
#
# ===== Epoch 277/300 =====
# [INFO] Saved linear shift weights for epoch 277 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 277 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 277: Train NLL=2.4168 | Val NLL=2.4147 | Time=1.09s
#
# ===== Epoch 278/300 =====
# [INFO] Saved linear shift weights for epoch 278 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 278 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 278: Train NLL=2.4171 | Val NLL=2.4155 | Time=1.10s
#
# ===== Epoch 279/300 =====
# [INFO] Saved linear shift weights for epoch 279 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 279 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 279: Train NLL=2.4170 | Val NLL=2.4149 | Time=1.16s
#
# ===== Epoch 280/300 =====
# [INFO] Saved linear shift weights for epoch 280 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 280 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 280: Train NLL=2.4166 | Val NLL=2.4149 | Time=1.11s
#
# ===== Epoch 281/300 =====
# [INFO] Saved linear shift weights for epoch 281 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 281 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 281: Train NLL=2.4167 | Val NLL=2.4149 | Time=1.21s
#
# ===== Epoch 282/300 =====
# [INFO] Saved linear shift weights for epoch 282 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 282 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 282: Train NLL=2.4169 | Val NLL=2.4148 | Time=1.10s
#
# ===== Epoch 283/300 =====
# [INFO] Saved linear shift weights for epoch 283 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 283 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 283: Train NLL=2.4168 | Val NLL=2.4150 | Time=1.31s
#
# ===== Epoch 284/300 =====
# [INFO] Saved linear shift weights for epoch 284 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 284 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 284: Train NLL=2.4166 | Val NLL=2.4146 | Time=1.27s
#
# ===== Epoch 285/300 =====
# [INFO] Saved linear shift weights for epoch 285 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 285 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 285: Train NLL=2.4166 | Val NLL=2.4146 | Time=1.48s
#
# ===== Epoch 286/300 =====
# [INFO] Saved linear shift weights for epoch 286 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 286 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 286: Train NLL=2.4166 | Val NLL=2.4152 | Time=1.11s
#
# ===== Epoch 287/300 =====
# [INFO] Saved linear shift weights for epoch 287 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 287 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 287: Train NLL=2.4166 | Val NLL=2.4145 | Time=1.09s
#
# ===== Epoch 288/300 =====
# [INFO] Saved linear shift weights for epoch 288 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 288 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 288: Train NLL=2.4168 | Val NLL=2.4186 | Time=1.11s
#
# ===== Epoch 289/300 =====
# [INFO] Saved linear shift weights for epoch 289 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 289 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 289: Train NLL=2.4165 | Val NLL=2.4152 | Time=1.01s
#
# ===== Epoch 290/300 =====
# [INFO] Saved linear shift weights for epoch 290 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 290 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 290: Train NLL=2.4168 | Val NLL=2.4150 | Time=1.12s
#
# ===== Epoch 291/300 =====
# [INFO] Saved linear shift weights for epoch 291 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 291 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 291: Train NLL=2.4166 | Val NLL=2.4151 | Time=1.11s
#
# ===== Epoch 292/300 =====
# [INFO] Saved linear shift weights for epoch 292 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 292 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 292: Train NLL=2.4165 | Val NLL=2.4146 | Time=1.35s
#
# ===== Epoch 293/300 =====
# [INFO] Saved linear shift weights for epoch 293 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 293 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 293: Train NLL=2.4165 | Val NLL=2.4152 | Time=1.08s
#
# ===== Epoch 294/300 =====
# [INFO] Saved linear shift weights for epoch 294 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 294 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 294: Train NLL=2.4171 | Val NLL=2.4146 | Time=1.19s
#
# ===== Epoch 295/300 =====
# [INFO] Saved linear shift weights for epoch 295 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 295 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 295: Train NLL=2.4168 | Val NLL=2.4146 | Time=1.14s
#
# ===== Epoch 296/300 =====
# [INFO] Saved linear shift weights for epoch 296 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 296 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Saved new best model.
# [INFO] Epoch 296: Train NLL=2.4164 | Val NLL=2.4145 | Time=1.05s
#
# ===== Epoch 297/300 =====
# [INFO] Saved linear shift weights for epoch 297 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 297 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 297: Train NLL=2.4166 | Val NLL=2.4157 | Time=1.16s
#
# ===== Epoch 298/300 =====
# [INFO] Saved linear shift weights for epoch 298 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 298 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 298: Train NLL=2.4166 | Val NLL=2.4149 | Time=1.08s
#
# ===== Epoch 299/300 =====
# [INFO] Saved linear shift weights for epoch 299 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 299 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 299: Train NLL=2.4163 | Val NLL=2.4155 | Time=1.22s
#
# ===== Epoch 300/300 =====
# [INFO] Saved linear shift weights for epoch 300 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/linear_shifts_all_epochs.json
# [INFO] Saved simple intercept weights for epoch 300 -> /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/simple_intercepts_all_epochs.json
# [INFO] Epoch 300: Train NLL=2.4165 | Val NLL=2.4170 | Time=1.28s

# %% [markdown]
# # Fit diagnostics

# %%
td_model.plot_loss_history()
# Out:
# [INFO] Loaded training/validation histories for 3 nodes.

# %%
td_model.plot_linear_shift_history(ref_lines={'x2':[2],'x3':[-0.24]})
# Out:
# [WARNING] No linear shift history found for node 'x1' at /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/linear_shifts_all_epochs.json
# /home/bule/anaconda3/envs/tramdag_test/lib/python3.9/site-packages/tramdag/TramDagModel.py:936: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(flatten)

# %%
td_model.plot_simple_intercepts_history()
# Out:
# /home/bule/anaconda3/envs/tramdag_test/lib/python3.9/site-packages/tramdag/TramDagModel.py:989: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(extract_scalar)

# %%
td_model.plot_hdag(train_df,variables=['x1','x2','x3'],plot_n_rows=1)
# Out:
# [WARNING] len(df)>1, set: plot_n_rows accordingly
# x1: Simple intercept — identical h() for all samples.
# === Sample 1/1 ===
# x1    0.729475
# x2   -0.573516
# x3   -5.786670
# Name: 75220, dtype: float64
# === Sample 1/1 ===
# x1    0.729475
# x2   -0.573516
# x3   -5.786670
# Name: 75220, dtype: float64

# %%
td_model.plot_latents(train_df)
# Out:
# [INFO] Final latent DataFrame shape: (80000, 6)

# %%
td_model.nll(train_df)
# Out:
# {'x1': -0.5735894640286764, 'x2': 0.3474327325820923, 'x3': 2.419990301132202}

# %% [markdown]
# ## Inspecting a complex shift term

# %%
import torch
import matplotlib.pyplot as plt

x = torch.linspace(-1, 1, steps=1000).unsqueeze(1).to(device)  # (100, 1)

with torch.no_grad():
    y=td_model.models['x3'].nn_shift[0](x) # take node x3 nnshift list and the first element which is the complex shift
plt.scatter(x.cpu().numpy(),y.cpu().numpy())
plt.scatter(x.cpu().numpy(),-f(x.cpu().numpy()),cmap="red")
plt.show()
# Out:
# /tmp/ipykernel_3042540/3589819528.py:9: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x.cpu().numpy(),-f(x.cpu().numpy()),cmap="red")

# %% [markdown]
# # SAMPLING

# %% [markdown]
# ## Observational

# %%
samples_observational, latents = td_model.sample()
td_model.plot_samples_vs_true(test_df,samples_observational)
# Out:
# [INFO] Starting full DAG sampling with 10000 samples per node.
# [INFO] Deleting all previously sampled data.
# Directory does not exist: /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/sampling
# Directory does not exist: /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/sampling
# Directory does not exist: /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x1 from standard logistic distribution
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 48.72it/s]
# [INFO] Completed sampling for node 'x1'
#
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x2 from standard logistic distribution
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:01<00:00, 51.13it/s]
# [INFO] Completed sampling for node 'x2'
#
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x3 from standard logistic distribution
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 49.83it/s]
# [INFO] Completed sampling for node 'x3'
# [INFO] DAG sampling completed successfully for all nodes.

# %% [markdown]
# ## Interventional

# %%
intervention_value= 0.0
samples_inter, latents = td_model.sample(do_interventions={'x1':intervention_value})
inter_df=dgp(n_obs=10_000, doX=[intervention_value , None, None])
td_model.plot_samples_vs_true(inter_df,samples_inter)
# Out:
# [INFO] Starting full DAG sampling with 10000 samples per node.
# [INFO] Interventions specified for nodes: ['x1']
# [INFO] Deleting all previously sampled data.
# Deleted directory: /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x1/sampling
# Deleted directory: /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x2/sampling
# Deleted directory: /home/bule/TramDag/example_notebooks/Continous_3_vars_complex_DGP_LS/x3/sampling
#
# ----*----------*-------------*--------Sample Node: x1 ------------*-----------------*-------------------*--
# [INFO] Applying intervention for node 'x1' with value 0.0
# [INFO] Interventional data for node x1 is saved
#
# ----*----------*-------------*--------Sample Node: x2 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x2 from standard logistic distribution
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:02<00:00, 49.03it/s]
# [INFO] Completed sampling for node 'x2'
#
# ----*----------*-------------*--------Sample Node: x3 ------------*-----------------*-------------------*--
# [INFO] Sampling new latents for node x3 from standard logistic distribution
# [INFO] Chandrupatla root finding ->  iterations:: 100%|██████████| 100/100 [00:01<00:00, 50.49it/s]
# [INFO] Completed sampling for node 'x3'
# [INFO] DAG sampling completed successfully for all nodes.
